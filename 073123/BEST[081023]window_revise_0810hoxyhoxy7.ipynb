# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.utils.data as data_util
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import MinMaxScaler
from torchsummary import summary
from sklearn.metrics import r2_score

# %%
CUDA = torch.cuda.is_available()
print(CUDA)

device = torch.device('cuda:0' if CUDA else 'cpu')
# Out:
# True

# %%
elec = pd.read_csv('elec_merge.csv')
nelec = pd.read_csv('n_elec_merge.csv')
dhw = pd.read_csv('dhw_merge.csv')

# %%
elec = elec.drop(['YEAR'], axis=1)
nelec = nelec.drop(['YEAR'], axis=1)
dhw = dhw.drop(['YEAR'], axis=1)

# %%
input_nelec = nelec.iloc[:-1,].reset_index(drop=True)
output_nelec = nelec[['n_elec']].iloc[1:].reset_index(drop=True)
output_nelec.columns = ['nelec']

input_elec = elec.iloc[:-1,].reset_index(drop=True)
output_elec = elec[['ELEC']].iloc[1:].reset_index(drop=True)
output_elec.columns = ['elec']

input_dhw = dhw.iloc[:-1,].reset_index(drop=True)
output_dhw = dhw[['DHW']].iloc[1:].reset_index(drop=True)
output_dhw.columns = ['dhw']

nelec = pd.concat([input_nelec, output_nelec], axis=1)
elec = pd.concat([input_elec, output_elec], axis=1)
dhw = pd.concat([input_dhw, output_dhw], axis=1)

# input_nelec = nelec.iloc[:-1,:-1].reset_index(drop=True)
# output_nelec = nelec[['n_elec']].iloc[:-1].reset_index(drop=True)
# output_nelec2 = nelec['n_elec'][1:].reset_index(drop=True)
# output_nelec['nelec'] = output_nelec2

# input_elec = elec.iloc[:-1,:-1].reset_index(drop=True)
# output_elec = elec[['ELEC']].iloc[:-1].reset_index(drop=True)
# output_elec2= elec['ELEC'][1:].reset_index(drop=True)
# output_elec['elec'] = output_elec2

# input_dhw = dhw.iloc[:-1,:-1].reset_index(drop=True)
# output_dhw = dhw[['DHW']].iloc[:-1].reset_index(drop=True)
# output_dhw2 = dhw['DHW'][1:].reset_index(drop=True)
# output_dhw['dhw'] = output_dhw2

# %%
scaler_nelec = MinMaxScaler()
scaler_elec = MinMaxScaler()
scaler_dhw = MinMaxScaler()

scaler_nelec.fit(nelec)
scaler_elec.fit(elec)
scaler_dhw.fit(dhw)

scaled_nelec = scaler_nelec.transform(nelec)
scaled_elec = scaler_elec.transform(elec)
scaled_dhw = scaler_dhw.transform(dhw)

nelec = pd.DataFrame(scaled_nelec, index=nelec.index, columns=nelec.columns)
elec = pd.DataFrame(scaled_elec, index=elec.index, columns=elec.columns)
dhw = pd.DataFrame(scaled_dhw, index=dhw.index, columns=dhw.columns)

# scaler_nelec = MinMaxScaler()
# scaler_elec = MinMaxScaler()
# scaler_dhw = MinMaxScaler()

# scaler_nelec.fit(input_nelec)
# scaler_elec.fit(input_elec)
# scaler_dhw.fit(input_dhw)

# scaled_nelec = scaler_nelec.transform(input_nelec)
# scaled_elec = scaler_elec.transform(input_elec)
# scaled_dhw = scaler_dhw.transform(input_dhw)

# nelec_x = pd.DataFrame(scaled_nelec, index=input_nelec.index, columns=input_nelec.columns)
# elec_x = pd.DataFrame(scaled_elec, index=input_elec.index, columns=input_elec.columns)
# dhw_x = pd.DataFrame(scaled_dhw, index=input_dhw.index, columns=input_dhw.columns)

# nelec = pd.concat([nelec_x, output_nelec], axis=1)
# elec = pd.concat([elec_x, output_elec], axis=1)
# dhw = pd.concat([dhw_x, output_dhw], axis=1)

# %%
standard_nelec = int(len(nelec) * 0.7)
standard_elec = int(len(elec) * 0.7)
standard_dhw = int(len(dhw) * 0.7)

nelec_train = nelec.iloc[:standard_nelec]
nelec_test = nelec.iloc[standard_nelec:].reset_index(drop=True)

elec_train = elec.iloc[:standard_elec]
elec_test = elec.iloc[standard_elec:].reset_index(drop=True)

dhw_train = dhw.iloc[:standard_dhw]
dhw_test = dhw.iloc[standard_dhw:].reset_index(drop=True)

# %%
nelec_trainx = nelec_train.drop(['nelec'], axis=1)
nelec_trainy = nelec_train[['nelec']]

nelec_testx = nelec_test.drop(['nelec'], axis=1)
nelec_testy = nelec_test[['nelec']]

elec_trainx = elec_train.drop(['elec'], axis=1)
elec_trainy = elec_train[['elec']]

elec_testx = elec_test.drop(['elec'], axis=1)
elec_testy = elec_test[['elec']]

dhw_trainx = dhw_train.drop(['dhw'], axis=1)
dhw_trainy = dhw_train[['dhw']]

dhw_testx = dhw_test.drop(['dhw'], axis=1)
dhw_testy = dhw_test[['dhw']]

# %%
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-1]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

nelec_trainx, nelec_trainy = buildDataSet(nelec_trainx, nelec_trainy, 7)
nelec_testx, nelec_testy = buildDataSet(nelec_testx, nelec_testy, 7)

elec_trainx, elec_trainy = buildDataSet(elec_trainx, elec_trainy, 7)
elec_testx, elec_testy = buildDataSet(elec_testx, elec_testy, 7)

dhw_trainx, dhw_trainy = buildDataSet(dhw_trainx, dhw_trainy, 7)
dhw_testx, dhw_testy = buildDataSet(dhw_testx, dhw_testy, 7)

# %%
print(nelec_trainx.shape)
print(nelec_trainy.shape)
print(nelec_testx.shape)
print(nelec_testy.shape)
print(elec_trainx.shape)
print(elec_trainy.shape)
print(elec_testx.shape)
print(elec_testy.shape)
print(dhw_trainx.shape)
print(dhw_trainy.shape)
print(dhw_testx.shape)
print(dhw_testy.shape)
# Out:
# (20409, 7, 12)
# (20409, 1)
# (8744, 7, 12)
# (8744, 1)
# (2984, 7, 12)
# (2984, 1)
# (1275, 7, 12)
# (1275, 1)
# (20409, 7, 12)
# (20409, 1)
# (8744, 7, 12)
# (8744, 1)

# %%
# 텐서로 변환
nelec_trainx_tensor = torch.FloatTensor(nelec_trainx)
nelec_trainy_tensor = torch.FloatTensor(nelec_trainy)

nelec_testx_tensor = torch.FloatTensor(nelec_testx)
nelec_testy_tensor = torch.FloatTensor(nelec_testy)

elec_trainx_tensor = torch.FloatTensor(elec_trainx)
elec_trainy_tensor = torch.FloatTensor(elec_trainy)

elec_testx_tensor = torch.FloatTensor(elec_testx)
elec_testy_tensor = torch.FloatTensor(elec_testy)

dhw_trainx_tensor = torch.FloatTensor(dhw_trainx)
dhw_trainy_tensor = torch.FloatTensor(dhw_trainy)

dhw_testx_tensor = torch.FloatTensor(dhw_testx)
dhw_testy_tensor = torch.FloatTensor(dhw_testy)

# %%
# 텐서 형태로 데이터 정의
nelec_train = TensorDataset(nelec_trainx_tensor, nelec_trainy_tensor)
nelec_test = TensorDataset(nelec_testx_tensor, nelec_testy_tensor)

elec_train = TensorDataset(elec_trainx_tensor, elec_trainy_tensor)
elec_test = TensorDataset(elec_testx_tensor, elec_testy_tensor)

dhw_train = TensorDataset(dhw_trainx_tensor, dhw_trainy_tensor)
dhw_test = TensorDataset(dhw_testx_tensor, dhw_testy_tensor)

# %%
batch_for_nelec_train = len(nelec_trainx)
batch_for_nelec_test = len(nelec_testx)
batch_for_elec_train = len(elec_trainx)
batch_for_elec_test = len(elec_testx)
batch_for_dhw_train = len(dhw_trainx)
batch_for_dhw_test = len(dhw_testx)

NELEC_train = DataLoader(nelec_train,
                        batch_size=1024,#batch_for_nelec_train,
                        shuffle=False,  
                        drop_last=True)

NELEC_test = DataLoader(nelec_test,
                        batch_size=1024,#batch_for_nelec_test,
                        shuffle=False,  
                        drop_last=True)

ELEC_train = DataLoader(elec_train,
                        batch_size=1024,#batch_for_elec_train,
                        shuffle=False,  
                        drop_last=True)

ELEC_test = DataLoader(elec_test,
                        batch_size=1024,#batch_for_elec_test,
                        shuffle=False,  
                        drop_last=True)

DHW_train = DataLoader(dhw_train,
                        batch_size=1024,#batch_for_dhw_train,
                        shuffle=False,  
                        drop_last=True)

DHW_test = DataLoader(dhw_test,
                        batch_size=1024,#batch_for_dhw_test,
                        shuffle=False,  
                        drop_last=True)

# %%
# # 데이터셋의 개수를 가정하여 변수에 저장
# nelec_train_size = len(nelec_train)
# nelec_test_size = len(nelec_test)
# elec_train_size = len(elec_train)
# elec_test_size = len(elec_test)
# dhw_train_size = len(dhw_train)
# dhw_test_size = len(dhw_test)

# # 각 DataLoader에서 생성되는 배치의 개수 계산
# nelec_train_batches = nelec_train_size // batch_for_nelec_train
# nelec_test_batches = nelec_test_size // batch_for_nelec_test
# elec_train_batches = elec_train_size // batch_for_elec_train
# elec_test_batches = elec_test_size // batch_for_elec_test
# dhw_train_batches = dhw_train_size // batch_for_dhw_train
# dhw_test_batches = dhw_test_size // batch_for_dhw_test

# # 결과 출력
# print("nelec_train batches:", nelec_train_batches)
# print("nelec_test batches:", nelec_test_batches)
# print("elec_train batches:", elec_train_batches)
# print("elec_test batches:", elec_test_batches)
# print("dhw_train batches:", dhw_train_batches)
# print("dhw_test batches:", dhw_test_batches)

# %% [markdown]
# # 모델 구조 선언

# %%
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ### GradientReversalLayer

# %%
class GradientReversalFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, x):
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return (grad_output * -1), None

class GradientReversalLayer(torch.nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x):
        return GradientReversalFunction.apply(x)

# %% [markdown]
# ### LSTM for Feature Extraction

# %%
class Swish(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return x * self.sigmoid(x)

# %%
class lstm(nn.Module):
    def __init__(self):
        super(lstm, self).__init__()
        self.lstm1 = nn.LSTM(12, 64, batch_first=True)
        self.bn1 = nn.BatchNorm1d(7)
        
        self.lstm2 = nn.LSTM(64, 64, batch_first=True)
        self.bn2 = nn.BatchNorm1d(7)
        
        self.lstm3 = nn.LSTM(64,64, batch_first=True)
        
        self.fc = nn.Linear(64, 64, bias=False)
        self.fc2 = nn.Linear(64, 100, bias=False)
        self.bn3 = nn.BatchNorm1d(7)
        
        self.dropout = nn.Dropout(0.5)
        self.swish = Swish()
        self.tanh = nn.Tanh()

        
    def forward(self, x):
        x, (h,c) = self.lstm1(x)
        x = self.bn1(x)
        x = self.tanh(x)

        x, (h, c) = self.lstm2(x, (h, c))
        x = self.bn2(x)
        x = self.tanh(x)
        
        x, _ = self.lstm3(x, (h, c))
        x = self.bn2(x)
        x = self.tanh(x)
        
        x = self.fc(x)
        x = self.bn3(x)
        x = self.fc2(x[:,-1,:])
        x = self.dropout(x)
        x = self.swish(x)
        return x

# %%
# hoxy = lstm()
# inputx = torch.randn(1024,7,12)
# hoxy2 = hoxy(inputx)
# print(hoxy2.shape)

# %%
class domain_regression(nn.Module):
    def __init__(self):
        super(domain_regression, self).__init__()
        self.regression_layer1 = nn.Linear(100, 100)
        self.regression_layer2 = nn.Linear(100, 100)
        self.regression_layer3 = nn.Linear(100, 100)
        self.regression_layer4 = nn.Linear(100, 1)
        self.swish = Swish()
        
    def forward(self, x):
        x = self.swish(self.regression_layer1(x))
        x = self.swish(self.regression_layer2(x))
        x = self.swish(self.regression_layer3(x))
        x = self.swish(self.regression_layer4(x))
        return x

# %% [markdown]
# ### Domain Classification

# %%
class domain_classfication(nn.Module):
    def __init__(self):
        super(domain_classfication, self).__init__()
        self.classification_layer0 = GradientReversalLayer()
        self.classification_layer1 = nn.Linear(100, 100)
        self.classification_layer2 = nn.Linear(100,100)
        self.classification_layer3 = nn.Linear(100,100)
        self.classification_layer4 = nn.Linear(100, 1)
        self.swish = Swish()
        
    def forward(self, x):
        x = self.classification_layer0(x)
        x = self.swish(self.classification_layer1(x))
        x = self.swish(self.classification_layer2(x))
        x = self.swish(self.classification_layer3(x))
        x = torch.sigmoid(self.classification_layer4(x))
        return x

# %% [markdown]
# ### Set the DANN

# %%
class dann(nn.Module):
    def __init__(self, lstm):
        super(dann, self).__init__()
        self.lstm = lstm
        self.regression = domain_regression()
        self.classification = domain_classfication()
        
    def forward(self, x):
        feature = self.lstm(x)
        reg_output = self.regression(feature)
        cla_output = self.classification(feature)
        
        return reg_output, cla_output

# %% [markdown]
# ### Loss 선언

# %%
class dann_loss(nn.Module):
    def __init__(self):
        super(dann_loss, self).__init__()
        self.reg = nn.L1Loss() # 회귀 L1 손실 == MAE
        self.cla = nn.BCEWithLogitsLoss() # 도메인 분류
        
    def forward(self, result, reg_real, domain_num, alpha=1):
        reg_output, cla_output = result
        batch_size = reg_output.shape[0]
        cla_target = torch.FloatTensor([domain_num] * batch_size).unsqueeze(1).to(device)
        
        reg_loss = self.reg(reg_output, reg_real)
        cla_loss = self.cla(cla_output, cla_target)
        cla_loss2 = cla_loss * alpha
        
        loss = reg_loss + cla_loss2
        
        return loss, reg_loss, cla_loss2

# %%
my_lstm = lstm().to(device)
model = dann(my_lstm).to(device)
loss_fn = dann_loss().to(device)

# %% [markdown]
# # 훈련

# %%
# from torch.optim.lr_scheduler import LinearLR

# alpha = 1.0
# epochs = 200

# model.train() # 훈련 모드 설정

# optimizer= torch.optim.Adamax(model.parameters(), lr=0.01)#, weight_decay=0.01)
# scheduler = LinearLR(optimizer, start_factor=1.0, end_factor=0.0, total_iters = epochs * len(NELEC_train))

# patience = 100  # Early stopping을 위한 기다리는 최대 epoch 수
# best_loss = float('inf')
# best_source_loss = float('inf')
# best_model_state_dict = None
# counter = 10  # Early stopping 카운터

# for i in range(1, epochs + 1):
#     total_loss = 0
#     source_total_loss = 0
#     target_total_loss = 0
#     src_reg_total = 0
#     src_cla_total = 0
#     tar_reg_total = 0
#     tar_cal_total = 0
#     reg_loss_total = 0
#     cla_loss_total = 0
#     for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
#         source_x = source_data[0].to(device)
#         source_y = source_data[1].to(device)
#         target_x = target_data[0].to(device)
#         target_y = target_data[1].to(device)
#         #print(source_x.shape)
#         #print(source_y.shape)
#         #print(target_x.shape)
#         #print(target_y.shape)
#         # 순전파
#         source_result = model(source_x)
#         target_result = model(target_x)
#         #print(source_result[0].shape)
#         #print(target_result[0].shape)
#         #print(source_result[1].shape)
#         #print(target_result[1].shape)
#         # 순전파 loss
#         source_loss, source_reg_loss, source_cla_loss = loss_fn(source_result, source_y, 1, alpha=alpha) # 소스 도메인 레이블 1
#         target_loss, target_reg_loss, target_cla_loss = loss_fn(target_result, target_y, 0, alpha=alpha) # 타겟 도메인 레이블 0
        
#         loss = source_loss + target_loss
#         reg_loss = source_reg_loss + target_reg_loss
#         cla_loss = source_cla_loss + target_cla_loss
        
#         #src_reg_total += source_reg_loss.item()
#         #src_cla_total += source_cla_loss.item()
#         #tar_reg_total += target_reg_loss.item()
#         #tar_cal_total += target_cla_loss.item()
        
#         #source_total_loss += source_loss.item()
#         #target_total_loss += target_loss.item()
        
#         reg_loss_total += reg_loss.item()
#         cla_loss_total += cla_loss.item()
        
#         total_loss += loss.item()
        
#         # 그래디언트 계산 및 업데이트
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()
#         scheduler.step()
        
#         # Early stopping 확인
#     if reg_loss_total / len(NELEC_train) < best_loss:
#         best_loss = reg_loss_total / len(NELEC_train)
#         best_model_state_dict = model.state_dict()
#         counter = 0  # Counter 초기화
#     else:
#         counter += 1
#         if counter >= patience:
#             print(f'Early stopping at epoch {i}')
#             break

#     print('Epoch : %d, Total Avg Loss : %.4f' % (i, total_loss / len(NELEC_train)))     
#     #print('Source Avg Loss : %.4f' % (source_total_loss / len(NELEC_train)))
#     #print('Target Avg Loss : %.4f' % (target_total_loss / len(NELEC_train)))
#     #print('Source Avg reg Loss : %.4f' % (src_reg_total / len(NELEC_train)))
#     #print('Target Avg reg Loss : %.4f' % (tar_reg_total / len(NELEC_train)))
#     #print('Source Avg cla Loss : %.4f' % (src_cla_total / len(NELEC_train)))
#     #print('Target Avg cla Loss : %.4f' % (tar_cal_total / len(NELEC_train)))
#     print('Avg Regression Loss : %.4f' % (reg_loss_total / len(NELEC_train)))
#     print('Avg Classification Loss : %.4f' % (cla_loss_total / len(NELEC_train)))
#     print('')
    
#     # source_loss가 가장 낮은 경우 모델 가중치 저장
#     if reg_loss_total / len(NELEC_train) < best_source_loss:
#         best_source_loss = reg_loss_total / len(NELEC_train)
#         best_model_state_dict = model.state_dict()

# # 최상의 모델을 파일로 저장
# if best_model_state_dict is not None:
#     torch.save(best_model_state_dict, '0810hoxyhoxy7.pth')
#     #torch.save(model, "model.pth")
# Out:
# Epoch : 1, Total Avg Loss : 2.1093
# Avg Regression Loss : 0.6382
# Avg Classification Loss : 1.4711
#
# Epoch : 2, Total Avg Loss : 1.7899
# Avg Regression Loss : 0.4035
# Avg Classification Loss : 1.3864
#
# Epoch : 3, Total Avg Loss : 1.8073
# Avg Regression Loss : 0.4210
# Avg Classification Loss : 1.3863
#
# Epoch : 4, Total Avg Loss : 1.8036
# Avg Regression Loss : 0.4173
# Avg Classification Loss : 1.3863
#
# Epoch : 5, Total Avg Loss : 1.7924
# Avg Regression Loss : 0.4061
# Avg Classification Loss : 1.3863
#
# Epoch : 6, Total Avg Loss : 1.7910
# Avg Regression Loss : 0.4047
# Avg Classification Loss : 1.3863
#
# Epoch : 7, Total Avg Loss : 1.7906
# Avg Regression Loss : 0.4043
# Avg Classification Loss : 1.3863
#
# Epoch : 8, Total Avg Loss : 1.7898
# Avg Regression Loss : 0.4035
# Avg Classification Loss : 1.3863
#
# Epoch : 9, Total Avg Loss : 1.7894
# Avg Regression Loss : 0.4031
# Avg Classification Loss : 1.3863
#
# Epoch : 10, Total Avg Loss : 1.7890
# Avg Regression Loss : 0.4027
# Avg Classification Loss : 1.3863
#
# Epoch : 11, Total Avg Loss : 1.7886
# Avg Regression Loss : 0.4023
# Avg Classification Loss : 1.3863
#
# Epoch : 12, Total Avg Loss : 1.7884
# Avg Regression Loss : 0.4021
# Avg Classification Loss : 1.3863
#
# Epoch : 13, Total Avg Loss : 1.7880
# Avg Regression Loss : 0.4017
# Avg Classification Loss : 1.3863
#
# Epoch : 14, Total Avg Loss : 1.7876
# Avg Regression Loss : 0.4013
# Avg Classification Loss : 1.3863
#
# Epoch : 15, Total Avg Loss : 1.7873
# Avg Regression Loss : 0.4010
# Avg Classification Loss : 1.3863
#
# Epoch : 16, Total Avg Loss : 1.7870
# Avg Regression Loss : 0.4007
# Avg Classification Loss : 1.3863
#
# Epoch : 17, Total Avg Loss : 1.7866
# Avg Regression Loss : 0.4003
# Avg Classification Loss : 1.3863
#
# Epoch : 18, Total Avg Loss : 1.7865
# Avg Regression Loss : 0.4003
# Avg Classification Loss : 1.3863
#
# Epoch : 19, Total Avg Loss : 1.7861
# Avg Regression Loss : 0.3998
# Avg Classification Loss : 1.3863
#
# Epoch : 20, Total Avg Loss : 1.7860
# Avg Regression Loss : 0.3997
# Avg Classification Loss : 1.3863
#
# Epoch : 21, Total Avg Loss : 1.7857
# Avg Regression Loss : 0.3994
# Avg Classification Loss : 1.3863
#
# Epoch : 22, Total Avg Loss : 1.7855
# Avg Regression Loss : 0.3992
# Avg Classification Loss : 1.3863
#
# Epoch : 23, Total Avg Loss : 1.7852
# Avg Regression Loss : 0.3989
# Avg Classification Loss : 1.3863
#
# Epoch : 24, Total Avg Loss : 1.7850
# Avg Regression Loss : 0.3987
# Avg Classification Loss : 1.3863
#
# Epoch : 25, Total Avg Loss : 1.7847
# Avg Regression Loss : 0.3985
# Avg Classification Loss : 1.3863
#
# Epoch : 26, Total Avg Loss : 1.7845
# Avg Regression Loss : 0.3982
# Avg Classification Loss : 1.3863
#
# Epoch : 27, Total Avg Loss : 1.7844
# Avg Regression Loss : 0.3981
# Avg Classification Loss : 1.3863
#
# Epoch : 28, Total Avg Loss : 1.7842
# Avg Regression Loss : 0.3979
# Avg Classification Loss : 1.3863
#
# Epoch : 29, Total Avg Loss : 1.7839
# Avg Regression Loss : 0.3977
# Avg Classification Loss : 1.3863
#
# Epoch : 30, Total Avg Loss : 1.7838
# Avg Regression Loss : 0.3975
# Avg Classification Loss : 1.3863
#
# Epoch : 31, Total Avg Loss : 1.7836
# Avg Regression Loss : 0.3973
# Avg Classification Loss : 1.3863
#
# Epoch : 32, Total Avg Loss : 1.7834
# Avg Regression Loss : 0.3971
# Avg Classification Loss : 1.3863
#
# Epoch : 33, Total Avg Loss : 1.7832
# Avg Regression Loss : 0.3969
# Avg Classification Loss : 1.3863
#
# Epoch : 34, Total Avg Loss : 1.7831
# Avg Regression Loss : 0.3968
# Avg Classification Loss : 1.3863
#
# Epoch : 35, Total Avg Loss : 1.7828
# Avg Regression Loss : 0.3965
# Avg Classification Loss : 1.3863
#
# Epoch : 36, Total Avg Loss : 1.7828
# Avg Regression Loss : 0.3965
# Avg Classification Loss : 1.3863
#
# Epoch : 37, Total Avg Loss : 1.7826
# Avg Regression Loss : 0.3963
# Avg Classification Loss : 1.3863
#
# Epoch : 38, Total Avg Loss : 1.7824
# Avg Regression Loss : 0.3961
# Avg Classification Loss : 1.3863
#
# Epoch : 39, Total Avg Loss : 1.7823
# Avg Regression Loss : 0.3960
# Avg Classification Loss : 1.3863
#
# Epoch : 40, Total Avg Loss : 1.7822
# Avg Regression Loss : 0.3959
# Avg Classification Loss : 1.3863
#
# Epoch : 41, Total Avg Loss : 1.7820
# Avg Regression Loss : 0.3957
# Avg Classification Loss : 1.3863
#
# Epoch : 42, Total Avg Loss : 1.7819
# Avg Regression Loss : 0.3956
# Avg Classification Loss : 1.3863
#
# Epoch : 43, Total Avg Loss : 1.7817
# Avg Regression Loss : 0.3954
# Avg Classification Loss : 1.3863
#
# Epoch : 44, Total Avg Loss : 1.7815
# Avg Regression Loss : 0.3952
# Avg Classification Loss : 1.3863
#
# Epoch : 45, Total Avg Loss : 1.7814
# Avg Regression Loss : 0.3951
# Avg Classification Loss : 1.3863
#
# Epoch : 46, Total Avg Loss : 1.7813
# Avg Regression Loss : 0.3950
# Avg Classification Loss : 1.3863
#
# Epoch : 47, Total Avg Loss : 1.7811
# Avg Regression Loss : 0.3948
# Avg Classification Loss : 1.3863
#
# Epoch : 48, Total Avg Loss : 1.7807
# Avg Regression Loss : 0.3944
# Avg Classification Loss : 1.3863
#
# Epoch : 49, Total Avg Loss : 1.7802
# Avg Regression Loss : 0.3939
# Avg Classification Loss : 1.3863
#
# Epoch : 50, Total Avg Loss : 1.7736
# Avg Regression Loss : 0.3869
# Avg Classification Loss : 1.3867
#
# Epoch : 51, Total Avg Loss : 1.7869
# Avg Regression Loss : 0.4006
# Avg Classification Loss : 1.3863
#
# Epoch : 52, Total Avg Loss : 1.7547
# Avg Regression Loss : 0.3541
# Avg Classification Loss : 1.4006
#
# Epoch : 53, Total Avg Loss : 1.6766
# Avg Regression Loss : 0.2902
# Avg Classification Loss : 1.3864
#
# Epoch : 54, Total Avg Loss : 1.6287
# Avg Regression Loss : 0.2425
# Avg Classification Loss : 1.3862
#
# Epoch : 55, Total Avg Loss : 1.6598
# Avg Regression Loss : 0.2734
# Avg Classification Loss : 1.3863
#
# Epoch : 56, Total Avg Loss : 1.6291
# Avg Regression Loss : 0.2429
# Avg Classification Loss : 1.3862
#
# Epoch : 57, Total Avg Loss : 1.5316
# Avg Regression Loss : 0.1463
# Avg Classification Loss : 1.3854
#
# Epoch : 58, Total Avg Loss : 1.7088
# Avg Regression Loss : 0.2975
# Avg Classification Loss : 1.4112
#
# Epoch : 59, Total Avg Loss : 1.7613
# Avg Regression Loss : 0.3749
# Avg Classification Loss : 1.3863
#
# Epoch : 60, Total Avg Loss : 1.6488
# Avg Regression Loss : 0.2625
# Avg Classification Loss : 1.3863
#
# Epoch : 61, Total Avg Loss : 1.5997
# Avg Regression Loss : 0.2132
# Avg Classification Loss : 1.3865
#
# Epoch : 62, Total Avg Loss : 1.6174
# Avg Regression Loss : 0.2308
# Avg Classification Loss : 1.3866
#
# Epoch : 63, Total Avg Loss : 1.5944
# Avg Regression Loss : 0.2076
# Avg Classification Loss : 1.3869
#
# Epoch : 64, Total Avg Loss : 1.5410
# Avg Regression Loss : 0.1537
# Avg Classification Loss : 1.3872
#
# Epoch : 65, Total Avg Loss : 1.5110
# Avg Regression Loss : 0.1247
# Avg Classification Loss : 1.3863
#
# Epoch : 66, Total Avg Loss : 1.5085
# Avg Regression Loss : 0.1222
# Avg Classification Loss : 1.3863
#
# Epoch : 67, Total Avg Loss : 1.5413
# Avg Regression Loss : 0.1550
# Avg Classification Loss : 1.3863
#
# Epoch : 68, Total Avg Loss : 1.5980
# Avg Regression Loss : 0.2117
# Avg Classification Loss : 1.3863
#
# Epoch : 69, Total Avg Loss : 1.5472
# Avg Regression Loss : 0.1609
# Avg Classification Loss : 1.3863
#
# Epoch : 70, Total Avg Loss : 1.4956
# Avg Regression Loss : 0.1093
# Avg Classification Loss : 1.3863
#
# Epoch : 71, Total Avg Loss : 1.4933
# Avg Regression Loss : 0.1070
# Avg Classification Loss : 1.3863
#
# Epoch : 72, Total Avg Loss : 1.5124
# Avg Regression Loss : 0.1261
# Avg Classification Loss : 1.3863
#
# Epoch : 73, Total Avg Loss : 1.5155
# Avg Regression Loss : 0.1293
# Avg Classification Loss : 1.3863
#
# Epoch : 74, Total Avg Loss : 1.5541
# Avg Regression Loss : 0.1677
# Avg Classification Loss : 1.3863
#
# Epoch : 75, Total Avg Loss : 1.5245
# Avg Regression Loss : 0.1383
# Avg Classification Loss : 1.3863
#
# Epoch : 76, Total Avg Loss : 1.4847
# Avg Regression Loss : 0.0984
# Avg Classification Loss : 1.3863
#
# Epoch : 77, Total Avg Loss : 1.4693
# Avg Regression Loss : 0.0830
# Avg Classification Loss : 1.3863
#
# Epoch : 78, Total Avg Loss : 1.4799
# Avg Regression Loss : 0.0936
# Avg Classification Loss : 1.3863
#
# Epoch : 79, Total Avg Loss : 1.4780
# Avg Regression Loss : 0.0918
# Avg Classification Loss : 1.3863
#
# Epoch : 80, Total Avg Loss : 1.4584
# Avg Regression Loss : 0.0721
# Avg Classification Loss : 1.3863
#
# Epoch : 81, Total Avg Loss : 1.4841
# Avg Regression Loss : 0.0979
# Avg Classification Loss : 1.3863
#
# Epoch : 82, Total Avg Loss : 1.4803
# Avg Regression Loss : 0.0940
# Avg Classification Loss : 1.3863
#
# Epoch : 83, Total Avg Loss : 1.5108
# Avg Regression Loss : 0.1245
# Avg Classification Loss : 1.3863
#
# Epoch : 84, Total Avg Loss : 1.4788
# Avg Regression Loss : 0.0925
# Avg Classification Loss : 1.3863
#
# Epoch : 85, Total Avg Loss : 1.5265
# Avg Regression Loss : 0.1403
# Avg Classification Loss : 1.3863
#
# Epoch : 86, Total Avg Loss : 1.4817
# Avg Regression Loss : 0.0954
# Avg Classification Loss : 1.3863
#
# Epoch : 87, Total Avg Loss : 1.4644
# Avg Regression Loss : 0.0781
# Avg Classification Loss : 1.3863
#
# Epoch : 88, Total Avg Loss : 1.4610
# Avg Regression Loss : 0.0747
# Avg Classification Loss : 1.3863
#
# Epoch : 89, Total Avg Loss : 1.4581
# Avg Regression Loss : 0.0719
# Avg Classification Loss : 1.3863
#
# Epoch : 90, Total Avg Loss : 1.4528
# Avg Regression Loss : 0.0665
# Avg Classification Loss : 1.3863
#
# Epoch : 91, Total Avg Loss : 1.4580
# Avg Regression Loss : 0.0718
# Avg Classification Loss : 1.3863
#
# Epoch : 92, Total Avg Loss : 1.4713
# Avg Regression Loss : 0.0851
# Avg Classification Loss : 1.3863
#
# Epoch : 93, Total Avg Loss : 1.4563
# Avg Regression Loss : 0.0700
# Avg Classification Loss : 1.3863
#
# Epoch : 94, Total Avg Loss : 1.4505
# Avg Regression Loss : 0.0643
# Avg Classification Loss : 1.3862
#
# Epoch : 95, Total Avg Loss : 1.4491
# Avg Regression Loss : 0.0628
# Avg Classification Loss : 1.3862
#
# Epoch : 96, Total Avg Loss : 1.4473
# Avg Regression Loss : 0.0610
# Avg Classification Loss : 1.3862
#
# Epoch : 97, Total Avg Loss : 1.4554
# Avg Regression Loss : 0.0692
# Avg Classification Loss : 1.3862
#
# Epoch : 98, Total Avg Loss : 1.4497
# Avg Regression Loss : 0.0636
# Avg Classification Loss : 1.3861
#
# Epoch : 99, Total Avg Loss : 1.4660
# Avg Regression Loss : 0.0800
# Avg Classification Loss : 1.3860
#
# Epoch : 100, Total Avg Loss : 1.4585
# Avg Regression Loss : 0.0730
# Avg Classification Loss : 1.3855
#
# Epoch : 101, Total Avg Loss : 1.4386
# Avg Regression Loss : 0.0651
# Avg Classification Loss : 1.3735
#
# Epoch : 102, Total Avg Loss : 1.3892
# Avg Regression Loss : 0.0723
# Avg Classification Loss : 1.3169
#
# Epoch : 103, Total Avg Loss : 1.4302
# Avg Regression Loss : 0.1168
# Avg Classification Loss : 1.3134
#
# Epoch : 104, Total Avg Loss : 1.4303
# Avg Regression Loss : 0.1035
# Avg Classification Loss : 1.3269
#
# Epoch : 105, Total Avg Loss : 1.4274
# Avg Regression Loss : 0.0969
# Avg Classification Loss : 1.3305
#
# Epoch : 106, Total Avg Loss : 1.4175
# Avg Regression Loss : 0.0840
# Avg Classification Loss : 1.3335
#
# Epoch : 107, Total Avg Loss : 1.4362
# Avg Regression Loss : 0.0963
# Avg Classification Loss : 1.3399
#
# Epoch : 108, Total Avg Loss : 1.4321
# Avg Regression Loss : 0.0900
# Avg Classification Loss : 1.3421
#
# Epoch : 109, Total Avg Loss : 1.4619
# Avg Regression Loss : 0.1004
# Avg Classification Loss : 1.3615
#
# Epoch : 110, Total Avg Loss : 1.4239
# Avg Regression Loss : 0.0902
# Avg Classification Loss : 1.3338
#
# Epoch : 111, Total Avg Loss : 1.4148
# Avg Regression Loss : 0.0874
# Avg Classification Loss : 1.3274
#
# Epoch : 112, Total Avg Loss : 1.4477
# Avg Regression Loss : 0.1107
# Avg Classification Loss : 1.3370
#
# Epoch : 113, Total Avg Loss : 1.4307
# Avg Regression Loss : 0.0957
# Avg Classification Loss : 1.3350
#
# Epoch : 114, Total Avg Loss : 1.4387
# Avg Regression Loss : 0.1009
# Avg Classification Loss : 1.3377
#
# Epoch : 115, Total Avg Loss : 1.4261
# Avg Regression Loss : 0.0871
# Avg Classification Loss : 1.3390
#
# Epoch : 116, Total Avg Loss : 1.4269
# Avg Regression Loss : 0.0906
# Avg Classification Loss : 1.3363
#
# Epoch : 117, Total Avg Loss : 1.4171
# Avg Regression Loss : 0.0856
# Avg Classification Loss : 1.3315
#
# Epoch : 118, Total Avg Loss : 1.4415
# Avg Regression Loss : 0.1042
# Avg Classification Loss : 1.3374
#
# Epoch : 119, Total Avg Loss : 1.4321
# Avg Regression Loss : 0.0940
# Avg Classification Loss : 1.3380
#
# Epoch : 120, Total Avg Loss : 1.4091
# Avg Regression Loss : 0.0739
# Avg Classification Loss : 1.3351
#
# Epoch : 121, Total Avg Loss : 1.4083
# Avg Regression Loss : 0.0734
# Avg Classification Loss : 1.3348
#
# Epoch : 122, Total Avg Loss : 1.3950
# Avg Regression Loss : 0.0650
# Avg Classification Loss : 1.3300
#
# Epoch : 123, Total Avg Loss : 1.3986
# Avg Regression Loss : 0.0671
# Avg Classification Loss : 1.3315
#
# Epoch : 124, Total Avg Loss : 1.4066
# Avg Regression Loss : 0.0727
# Avg Classification Loss : 1.3340
#
# Epoch : 125, Total Avg Loss : 1.4100
# Avg Regression Loss : 0.0719
# Avg Classification Loss : 1.3382
#
# Epoch : 126, Total Avg Loss : 1.4059
# Avg Regression Loss : 0.0689
# Avg Classification Loss : 1.3371
#
# Epoch : 127, Total Avg Loss : 1.4080
# Avg Regression Loss : 0.0740
# Avg Classification Loss : 1.3340
#
# Epoch : 128, Total Avg Loss : 1.4170
# Avg Regression Loss : 0.0825
# Avg Classification Loss : 1.3345
#
# Epoch : 129, Total Avg Loss : 1.4065
# Avg Regression Loss : 0.0740
# Avg Classification Loss : 1.3325
#
# Epoch : 130, Total Avg Loss : 1.4068
# Avg Regression Loss : 0.0707
# Avg Classification Loss : 1.3362
#
# Epoch : 131, Total Avg Loss : 1.4222
# Avg Regression Loss : 0.0809
# Avg Classification Loss : 1.3413
#
# Epoch : 132, Total Avg Loss : 1.4298
# Avg Regression Loss : 0.0836
# Avg Classification Loss : 1.3462
#
# Epoch : 133, Total Avg Loss : 1.4168
# Avg Regression Loss : 0.0786
# Avg Classification Loss : 1.3382
#
# Epoch : 134, Total Avg Loss : 1.4112
# Avg Regression Loss : 0.0757
# Avg Classification Loss : 1.3355
#
# Epoch : 135, Total Avg Loss : 1.4049
# Avg Regression Loss : 0.0703
# Avg Classification Loss : 1.3346
#
# Epoch : 136, Total Avg Loss : 1.4150
# Avg Regression Loss : 0.0836
# Avg Classification Loss : 1.3313
#
# Epoch : 137, Total Avg Loss : 1.4127
# Avg Regression Loss : 0.0791
# Avg Classification Loss : 1.3336
#
# Epoch : 138, Total Avg Loss : 1.4065
# Avg Regression Loss : 0.0690
# Avg Classification Loss : 1.3376
#
# Epoch : 139, Total Avg Loss : 1.4273
# Avg Regression Loss : 0.0844
# Avg Classification Loss : 1.3429
#
# Epoch : 140, Total Avg Loss : 1.4169
# Avg Regression Loss : 0.0762
# Avg Classification Loss : 1.3407
#
# Epoch : 141, Total Avg Loss : 1.4093
# Avg Regression Loss : 0.0711
# Avg Classification Loss : 1.3382
#
# Epoch : 142, Total Avg Loss : 1.4117
# Avg Regression Loss : 0.0726
# Avg Classification Loss : 1.3390
#
# Epoch : 143, Total Avg Loss : 1.3982
# Avg Regression Loss : 0.0632
# Avg Classification Loss : 1.3350
#
# Epoch : 144, Total Avg Loss : 1.3945
# Avg Regression Loss : 0.0614
# Avg Classification Loss : 1.3331
#
# Epoch : 145, Total Avg Loss : 1.3934
# Avg Regression Loss : 0.0609
# Avg Classification Loss : 1.3325
#
# Epoch : 146, Total Avg Loss : 1.3907
# Avg Regression Loss : 0.0588
# Avg Classification Loss : 1.3318
#
# Epoch : 147, Total Avg Loss : 1.3993
# Avg Regression Loss : 0.0657
# Avg Classification Loss : 1.3336
#
# Epoch : 148, Total Avg Loss : 1.3972
# Avg Regression Loss : 0.0638
# Avg Classification Loss : 1.3334
#
# Epoch : 149, Total Avg Loss : 1.3991
# Avg Regression Loss : 0.0649
# Avg Classification Loss : 1.3341
#
# Epoch : 150, Total Avg Loss : 1.4010
# Avg Regression Loss : 0.0661
# Avg Classification Loss : 1.3350
#
# Epoch : 151, Total Avg Loss : 1.4016
# Avg Regression Loss : 0.0653
# Avg Classification Loss : 1.3363
#
# Epoch : 152, Total Avg Loss : 1.4171
# Avg Regression Loss : 0.0775
# Avg Classification Loss : 1.3396
#
# Epoch : 153, Total Avg Loss : 1.4050
# Avg Regression Loss : 0.0663
# Avg Classification Loss : 1.3387
#
# Epoch : 154, Total Avg Loss : 1.4103
# Avg Regression Loss : 0.0662
# Avg Classification Loss : 1.3441
#
# Epoch : 155, Total Avg Loss : 1.4615
# Avg Regression Loss : 0.0857
# Avg Classification Loss : 1.3758
#
# Epoch : 156, Total Avg Loss : 1.4935
# Avg Regression Loss : 0.1184
# Avg Classification Loss : 1.3751
#
# Epoch : 157, Total Avg Loss : 1.4624
# Avg Regression Loss : 0.1167
# Avg Classification Loss : 1.3457
#
# Epoch : 158, Total Avg Loss : 1.4236
# Avg Regression Loss : 0.0905
# Avg Classification Loss : 1.3332
#
# Epoch : 159, Total Avg Loss : 1.4618
# Avg Regression Loss : 0.1194
# Avg Classification Loss : 1.3424
#
# Epoch : 160, Total Avg Loss : 1.4376
# Avg Regression Loss : 0.0945
# Avg Classification Loss : 1.3431
#
# Epoch : 161, Total Avg Loss : 1.4497
# Avg Regression Loss : 0.0996
# Avg Classification Loss : 1.3501
#
# Epoch : 162, Total Avg Loss : 1.4134
# Avg Regression Loss : 0.0744
# Avg Classification Loss : 1.3390
#
# Epoch : 163, Total Avg Loss : 1.4291
# Avg Regression Loss : 0.0842
# Avg Classification Loss : 1.3448
#
# Epoch : 164, Total Avg Loss : 1.4179
# Avg Regression Loss : 0.0740
# Avg Classification Loss : 1.3438
#
# Epoch : 165, Total Avg Loss : 1.4287
# Avg Regression Loss : 0.0815
# Avg Classification Loss : 1.3472
#
# Epoch : 166, Total Avg Loss : 1.4162
# Avg Regression Loss : 0.0719
# Avg Classification Loss : 1.3443
#
# Epoch : 167, Total Avg Loss : 1.4169
# Avg Regression Loss : 0.0730
# Avg Classification Loss : 1.3439
#
# Epoch : 168, Total Avg Loss : 1.4081
# Avg Regression Loss : 0.0674
# Avg Classification Loss : 1.3407
#
# Epoch : 169, Total Avg Loss : 1.4151
# Avg Regression Loss : 0.0723
# Avg Classification Loss : 1.3427
#
# Epoch : 170, Total Avg Loss : 1.4069
# Avg Regression Loss : 0.0660
# Avg Classification Loss : 1.3409
#
# Epoch : 171, Total Avg Loss : 1.4114
# Avg Regression Loss : 0.0684
# Avg Classification Loss : 1.3430
#
# Epoch : 172, Total Avg Loss : 1.4058
# Avg Regression Loss : 0.0634
# Avg Classification Loss : 1.3424
#
# Epoch : 173, Total Avg Loss : 1.4127
# Avg Regression Loss : 0.0672
# Avg Classification Loss : 1.3454
#
# Epoch : 174, Total Avg Loss : 1.4070
# Avg Regression Loss : 0.0627
# Avg Classification Loss : 1.3442
#
# Epoch : 175, Total Avg Loss : 1.4082
# Avg Regression Loss : 0.0651
# Avg Classification Loss : 1.3430
#
# Epoch : 176, Total Avg Loss : 1.4033
# Avg Regression Loss : 0.0638
# Avg Classification Loss : 1.3395
#
# Epoch : 177, Total Avg Loss : 1.4005
# Avg Regression Loss : 0.0638
# Avg Classification Loss : 1.3367
#
# Epoch : 178, Total Avg Loss : 1.3940
# Avg Regression Loss : 0.0602
# Avg Classification Loss : 1.3338
#
# Epoch : 179, Total Avg Loss : 1.3983
# Avg Regression Loss : 0.0621
# Avg Classification Loss : 1.3362
#
# Epoch : 180, Total Avg Loss : 1.3958
# Avg Regression Loss : 0.0586
# Avg Classification Loss : 1.3372
#
# Epoch : 181, Total Avg Loss : 1.4043
# Avg Regression Loss : 0.0618
# Avg Classification Loss : 1.3425
#
# Epoch : 182, Total Avg Loss : 1.4040
# Avg Regression Loss : 0.0585
# Avg Classification Loss : 1.3455
#
# Epoch : 183, Total Avg Loss : 1.4103
# Avg Regression Loss : 0.0611
# Avg Classification Loss : 1.3492
#
# Epoch : 184, Total Avg Loss : 1.4165
# Avg Regression Loss : 0.0639
# Avg Classification Loss : 1.3526
#
# Epoch : 185, Total Avg Loss : 1.4453
# Avg Regression Loss : 0.0776
# Avg Classification Loss : 1.3678
#
# Epoch : 186, Total Avg Loss : 1.4726
# Avg Regression Loss : 0.0895
# Avg Classification Loss : 1.3831
#
# Epoch : 187, Total Avg Loss : 1.4516
# Avg Regression Loss : 0.0791
# Avg Classification Loss : 1.3725
#
# Epoch : 188, Total Avg Loss : 1.4318
# Avg Regression Loss : 0.0736
# Avg Classification Loss : 1.3581
#
# Epoch : 189, Total Avg Loss : 1.4171
# Avg Regression Loss : 0.0708
# Avg Classification Loss : 1.3463
#
# Epoch : 190, Total Avg Loss : 1.4096
# Avg Regression Loss : 0.0690
# Avg Classification Loss : 1.3407
#
# Epoch : 191, Total Avg Loss : 1.4027
# Avg Regression Loss : 0.0655
# Avg Classification Loss : 1.3373
#
# Epoch : 192, Total Avg Loss : 1.4002
# Avg Regression Loss : 0.0635
# Avg Classification Loss : 1.3368
#
# Epoch : 193, Total Avg Loss : 1.3998
# Avg Regression Loss : 0.0632
# Avg Classification Loss : 1.3365
#
# Epoch : 194, Total Avg Loss : 1.3993
# Avg Regression Loss : 0.0629
# Avg Classification Loss : 1.3365
#
# Epoch : 195, Total Avg Loss : 1.3995
# Avg Regression Loss : 0.0630
# Avg Classification Loss : 1.3365
#
# Epoch : 196, Total Avg Loss : 1.3996
# Avg Regression Loss : 0.0633
# Avg Classification Loss : 1.3363
#
# Epoch : 197, Total Avg Loss : 1.3999
# Avg Regression Loss : 0.0634
# Avg Classification Loss : 1.3365
#
# Epoch : 198, Total Avg Loss : 1.3999
# Avg Regression Loss : 0.0633
# Avg Classification Loss : 1.3365
#
# Epoch : 199, Total Avg Loss : 1.3995
# Avg Regression Loss : 0.0631
# Avg Classification Loss : 1.3364
#
# Epoch : 200, Total Avg Loss : 1.4000
# Avg Regression Loss : 0.0632
# Avg Classification Loss : 1.3368

# %%
from torchinfo import summary

summary(model, (1024,7,12))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# dann                                     [1024, 1]                 --
# ├─lstm: 1-1                              [1024, 100]               --
# │    └─LSTM: 2-1                         [1024, 7, 64]             19,968
# │    └─BatchNorm1d: 2-2                  [1024, 7, 64]             14
# │    └─Tanh: 2-3                         [1024, 7, 64]             --
# │    └─LSTM: 2-4                         [1024, 7, 64]             33,280
# │    └─BatchNorm1d: 2-5                  [1024, 7, 64]             14
# │    └─Tanh: 2-6                         [1024, 7, 64]             --
# │    └─LSTM: 2-7                         [1024, 7, 64]             33,280
# │    └─BatchNorm1d: 2-8                  [1024, 7, 64]             (recursive)
# │    └─Tanh: 2-9                         [1024, 7, 64]             --
# │    └─Linear: 2-10                      [1024, 7, 64]             4,096
# │    └─BatchNorm1d: 2-11                 [1024, 7, 64]             14
# │    └─Linear: 2-12                      [1024, 100]               6,400
# │    └─Dropout: 2-13                     [1024, 100]               --
# │    └─Swish: 2-14                       [1024, 100]               --
# │    │    └─Sigmoid: 3-1                 [1024, 100]               --
# ├─domain_regression: 1-2                 [1024, 1]                 --
# │    └─Linear: 2-15                      [1024, 100]               10,100
# │    └─Swish: 2-16                       [1024, 100]               --
# │    │    └─Sigmoid: 3-2                 [1024, 100]               --
# │    └─Linear: 2-17                      [1024, 100]               10,100
# │    └─Swish: 2-18                       [1024, 100]               --
# │    │    └─Sigmoid: 3-3                 [1024, 100]               --
# │    └─Linear: 2-19                      [1024, 100]               10,100
# │    └─Swish: 2-20                       [1024, 100]               --
# │    │    └─Sigmoid: 3-4                 [1024, 100]               --
# │    └─Linear: 2-21                      [1024, 1]                 101
# │    └─Swish: 2-22                       [1024, 1]                 --
# │    │    └─Sigmoid: 3-5                 [1024, 1]                 --
# ├─domain_classfication: 1-3              [1024, 1]                 --
# │    └─GradientReversalLayer: 2-23       [1024, 100]               --
# │    └─Linear: 2-24                      [1024, 100]               10,100
# │    └─Swish: 2-25                       [1024, 100]               --
# │    │    └─Sigmoid: 3-6                 [1024, 100]               --
# │    └─Linear: 2-26                      [1024, 100]               10,100
# │    └─Swish: 2-27                       [1024, 100]               --
# │    │    └─Sigmoid: 3-7                 [1024, 100]               --
# │    └─Linear: 2-28                      [1024, 100]               10,100
# │    └─Swish: 2-29                       [1024, 100]               --
# │    │    └─Sigmoid: 3-8                 [1024, 100]               --
# │    └─Linear: 2-30                      [1024, 1]                 101
# ==========================================================================================
# Total params: 157,868
# Trainable params: 157,868
# Non-trainable params: 0
# Total mult-adds (M): 693.30
# ==========================================================================================
# Input size (MB): 0.34
# Forward/backward pass size (MB): 35.11
# Params size (MB): 0.63
# Estimated Total Size (MB): 36.09
# ==========================================================================================

# %% [markdown]
# # train 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('0810hoxyhoxy7.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []
s_d_pred = []
t_d_pred = []

for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    source_domain_label_pred, source_pred = best_source_model2(sourcex)
    target_domain_label_pred, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())
    s_d_pred.extend(source_domain_label_pred.detach().cpu().numpy())
    t_d_pred.extend(target_domain_label_pred.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: 0.7746184566644856
# TARGET R2 Score: 0.9326994183937473

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# # test 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('0810hoxyhoxy7.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []


for step, (source_data, target_data) in enumerate(zip(NELEC_test, DHW_test)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    _, source_pred = best_source_model2(sourcex)
    _, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: 0.803730667478866
# TARGET R2 Score: 0.933546914828034

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# ### Domain Embedding Space 시각화

# %%
# 가장 앞 batch의 250개씩의 데이터만 샘플링
source_tsne = DataLoader(nelec_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

target_tsne = DataLoader(dhw_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

source_tsne2 = next(iter(source_tsne))
target_tsne2 = next(iter(target_tsne))

source_x_TNSE = source_tsne2[0].to(device)
source_y_TNSE = source_tsne2[1].to(device)

target_x_TNSE = target_tsne2[0].to(device)
target_y_TNSE = target_tsne2[1].to(device)

# 학습된 모델의 LSTM 부분만 활용 (100차원 임베딩 벡터를 받아오는 과정)
source_vector = model.lstm(source_x_TNSE)
target_vector = model.lstm(target_x_TNSE)

# %%
from sklearn.manifold import TSNE

df = pd.DataFrame(np.concatenate([source_vector.cpu().detach().numpy(), target_vector.cpu().detach().numpy()]))

tsne_np = TSNE(n_components=2).fit_transform(df)
tsne_df = pd.DataFrame(tsne_np, columns=['component 0', 'component 1'])

# %%
tsne_df_0 = tsne_df.loc[:1000]
tsne_df_1 = tsne_df.loc[1000:]

plt.scatter(tsne_df_0['component 0'], tsne_df_0['component 1'], color='green', label='NELEC', alpha=0.5)
plt.scatter(tsne_df_1['component 0'], tsne_df_1['component 1'], color='black', label='DHW', alpha=0.5)

plt.title('alpha = '+ str(alpha))
plt.xlabel('component 0')
plt.ylabel('component 1')
plt.legend()
plt.show()
