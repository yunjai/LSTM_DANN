# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.utils.data as data_util
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import MinMaxScaler
from torchsummary import summary
from sklearn.metrics import r2_score

# %%
CUDA = torch.cuda.is_available()
print(CUDA)

device = torch.device('cuda:0' if CUDA else 'cpu')
# Out:
# True

# %%
elec = pd.read_csv('elec_merge.csv')
nelec = pd.read_csv('n_elec_merge.csv')
dhw = pd.read_csv('dhw_merge.csv')

# %%
elec = elec.drop(['YEAR'], axis=1)
nelec = nelec.drop(['YEAR'], axis=1)
dhw = dhw.drop(['YEAR'], axis=1)

# %%
scaler_nelec = MinMaxScaler()
scaler_elec = MinMaxScaler()
scaler_dhw = MinMaxScaler()

scaler_nelec.fit(nelec)
scaler_elec.fit(elec)
scaler_dhw.fit(dhw)

scaled_nelec = scaler_nelec.transform(nelec)
scaled_elec = scaler_elec.transform(elec)
scaled_dhw = scaler_dhw.transform(dhw)

new_nelec = pd.DataFrame(scaled_nelec, index=nelec.index, columns=nelec.columns)
new_elec = pd.DataFrame(scaled_elec, index=elec.index, columns=elec.columns)
new_dhw = pd.DataFrame(scaled_dhw, index=dhw.index, columns=dhw.columns)

# %%
input_nelec = new_nelec.iloc[:-1,].reset_index(drop=True)
output_nelec = new_nelec[['n_elec']].iloc[1:].reset_index(drop=True)
output_nelec.columns = ['nelec']

input_elec = new_elec.iloc[:-1,].reset_index(drop=True)
output_elec = new_elec[['ELEC']].iloc[1:].reset_index(drop=True)
output_elec.columns = ['elec']

input_dhw = new_dhw.iloc[:-1,].reset_index(drop=True)
output_dhw = new_dhw[['DHW']].iloc[1:].reset_index(drop=True)
output_dhw.columns = ['dhw']

nelec = pd.concat([input_nelec, output_nelec], axis=1)
elec = pd.concat([input_elec, output_elec], axis=1)
dhw = pd.concat([input_dhw, output_dhw], axis=1)

# %%
standard_nelec = int(len(nelec) * 0.7)
standard_elec = int(len(elec) * 0.7)
standard_dhw = int(len(dhw) * 0.7)

nelec_train = nelec.iloc[:standard_nelec]
nelec_test = nelec.iloc[standard_nelec:].reset_index(drop=True)

elec_train = elec.iloc[:standard_elec]
elec_test = elec.iloc[standard_elec:].reset_index(drop=True)

dhw_train = dhw.iloc[:standard_dhw]
dhw_test = dhw.iloc[standard_dhw:].reset_index(drop=True)

# %%
nelec_trainx = nelec_train.drop(['nelec'], axis=1)
nelec_trainy = nelec_train[['nelec']]

nelec_testx = nelec_test.drop(['nelec'], axis=1)
nelec_testy = nelec_test[['nelec']]

elec_trainx = elec_train.drop(['elec'], axis=1)
elec_trainy = elec_train[['elec']]

elec_testx = elec_test.drop(['elec'], axis=1)
elec_testy = elec_test[['elec']]

dhw_trainx = dhw_train.drop(['dhw'], axis=1)
dhw_trainy = dhw_train[['dhw']]

dhw_testx = dhw_test.drop(['dhw'], axis=1)
dhw_testy = dhw_test[['dhw']]

# %%
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-1]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

nelec_trainx, nelec_trainy = buildDataSet(nelec_trainx, nelec_trainy, 24)
nelec_testx, nelec_testy = buildDataSet(nelec_testx, nelec_testy, 24)

elec_trainx, elec_trainy = buildDataSet(elec_trainx, elec_trainy, 24)
elec_testx, elec_testy = buildDataSet(elec_testx, elec_testy, 24)

dhw_trainx, dhw_trainy = buildDataSet(dhw_trainx, dhw_trainy, 24)
dhw_testx, dhw_testy = buildDataSet(dhw_testx, dhw_testy, 24)

# %%
print(nelec_trainx.shape)
print(nelec_trainy.shape)
print(nelec_testx.shape)
print(nelec_testy.shape)
print(elec_trainx.shape)
print(elec_trainy.shape)
print(elec_testx.shape)
print(elec_testy.shape)
print(dhw_trainx.shape)
print(dhw_trainy.shape)
print(dhw_testx.shape)
print(dhw_testy.shape)
# Out:
# (20392, 24, 12)
# (20392, 1)
# (8727, 24, 12)
# (8727, 1)
# (2967, 24, 12)
# (2967, 1)
# (1258, 24, 12)
# (1258, 1)
# (20392, 24, 12)
# (20392, 1)
# (8727, 24, 12)
# (8727, 1)

# %%
# 텐서로 변환
nelec_trainx_tensor = torch.FloatTensor(nelec_trainx)
nelec_trainy_tensor = torch.FloatTensor(nelec_trainy)

nelec_testx_tensor = torch.FloatTensor(nelec_testx)
nelec_testy_tensor = torch.FloatTensor(nelec_testy)

elec_trainx_tensor = torch.FloatTensor(elec_trainx)
elec_trainy_tensor = torch.FloatTensor(elec_trainy)

elec_testx_tensor = torch.FloatTensor(elec_testx)
elec_testy_tensor = torch.FloatTensor(elec_testy)

dhw_trainx_tensor = torch.FloatTensor(dhw_trainx)
dhw_trainy_tensor = torch.FloatTensor(dhw_trainy)

dhw_testx_tensor = torch.FloatTensor(dhw_testx)
dhw_testy_tensor = torch.FloatTensor(dhw_testy)

# %%
# 텐서 형태로 데이터 정의
nelec_train = TensorDataset(nelec_trainx_tensor, nelec_trainy_tensor)
nelec_test = TensorDataset(nelec_testx_tensor, nelec_testy_tensor)

elec_train = TensorDataset(elec_trainx_tensor, elec_trainy_tensor)
elec_test = TensorDataset(elec_testx_tensor, elec_testy_tensor)

dhw_train = TensorDataset(dhw_trainx_tensor, dhw_trainy_tensor)
dhw_test = TensorDataset(dhw_testx_tensor, dhw_testy_tensor)

# %%
batch_for_nelec_train = len(nelec_trainx)
batch_for_nelec_test = len(nelec_testx)
batch_for_elec_train = len(elec_trainx)
batch_for_elec_test = len(elec_testx)
batch_for_dhw_train = len(dhw_trainx)
batch_for_dhw_test = len(dhw_testx)

NELEC_train = DataLoader(nelec_train,
                        batch_size=batch_for_nelec_train,
                        shuffle=False,  
                        drop_last=True)

NELEC_test = DataLoader(nelec_test,
                        batch_size=batch_for_nelec_test,
                        shuffle=False,  
                        drop_last=True)

ELEC_train = DataLoader(elec_train,
                        batch_size=batch_for_elec_train,
                        shuffle=False,  
                        drop_last=True)

ELEC_test = DataLoader(elec_test,
                        batch_size=batch_for_elec_test,
                        shuffle=False,  
                        drop_last=True)

DHW_train = DataLoader(dhw_train,
                        batch_size=batch_for_dhw_train,
                        shuffle=False,  
                        drop_last=True)

DHW_test = DataLoader(dhw_test,
                        batch_size=batch_for_dhw_test,
                        shuffle=False,  
                        drop_last=True)

# %%
# 데이터셋의 개수를 가정하여 변수에 저장
nelec_train_size = len(nelec_train)
nelec_test_size = len(nelec_test)
elec_train_size = len(elec_train)
elec_test_size = len(elec_test)
dhw_train_size = len(dhw_train)
dhw_test_size = len(dhw_test)

# 각 DataLoader에서 생성되는 배치의 개수 계산
nelec_train_batches = nelec_train_size // batch_for_nelec_train
nelec_test_batches = nelec_test_size // batch_for_nelec_test
elec_train_batches = elec_train_size // batch_for_elec_train
elec_test_batches = elec_test_size // batch_for_elec_test
dhw_train_batches = dhw_train_size // batch_for_dhw_train
dhw_test_batches = dhw_test_size // batch_for_dhw_test

# 결과 출력
print("nelec_train batches:", nelec_train_batches)
print("nelec_test batches:", nelec_test_batches)
print("elec_train batches:", elec_train_batches)
print("elec_test batches:", elec_test_batches)
print("dhw_train batches:", dhw_train_batches)
print("dhw_test batches:", dhw_test_batches)
# Out:
# nelec_train batches: 1
# nelec_test batches: 1
# elec_train batches: 1
# elec_test batches: 1
# dhw_train batches: 1
# dhw_test batches: 1

# %% [markdown]
# # 모델 구조 선언

# %%
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ### GradientReversalLayer

# %%
# class GradientReversalLayer(torch.autograd.Function):
#     def forward(self, x):
#         return x.view_as(x)

#     def backward(self, grad_output):
#         return (grad_output * -1)

class GradientReversalFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, x):
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return (grad_output * -1), None

class GradientReversalLayer(torch.nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x):
        return GradientReversalFunction.apply(x)

# %% [markdown]
# ### LSTM for Feature Extraction

# %%
class lstm(nn.Module):
    def __init__(self):
        super(lstm, self).__init__()
        self.lstm1 = nn.LSTM(12, 64, batch_first=True)
        self.bn1 = nn.BatchNorm1d(24)
        
        self.lstm2 = nn.LSTM(64, 64, batch_first=True)
        self.bn2 = nn.BatchNorm1d(24)
        
        self.fc = nn.Linear(64, 100, bias=False)
        self.fc2 = nn.Linear(100, 64, bias=False)
        self.bn3 = nn.BatchNorm1d(24)
        self.dropout = nn.Dropout(0.5)
        self.gelu = nn.GELU()
        
    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.bn1(x)
        x = self.gelu(x)

        x, _ = self.lstm2(x)
        x = self.bn2(x)
        x = self.gelu(x)

        x = self.fc(x)
        x = self.bn3(x)
        x = self.fc2(x[:,-1,:])
        x = self.dropout(x)
        #x = x.view(-1, 100)
        return x

# %%
hoxy = lstm()
cnnx = torch.randn(512,24,12)
hoxy2 = hoxy(cnnx)
print(hoxy2.shape)
# Out:
# torch.Size([512, 64])

# %%
class domain_regression(nn.Module):
    def __init__(self):
        super(domain_regression, self).__init__()
        self.regression_layer1 = nn.Linear(64, 128)
        self.regression_layer2 = nn.Linear(128, 128)
        self.regression_layer3 = nn.Linear(128, 128)
        self.regression_layer4 = nn.Linear(128, 1)
        
    def forward(self, x):
        x = F.relu(self.regression_layer1(x))
        x = F.relu(self.regression_layer2(x))
        x = F.relu(self.regression_layer3(x))
        x = F.relu(self.regression_layer4(x))
        return x

# %% [markdown]
# ### Domain Classification

# %%
class domain_classfication(nn.Module):
    def __init__(self):
        super(domain_classfication, self).__init__()
        self.classification_layer0 = GradientReversalLayer()
        self.classification_layer1 = nn.Linear(64, 100)
        self.classification_layer2 = nn.Linear(100, 1)
        
    def forward(self, x):
        x = self.classification_layer0(x)
        x = F.relu(self.classification_layer1(x))
        x = torch.sigmoid(self.classification_layer2(x))
        return x

# %% [markdown]
# ### Set the DANN

# %%
class dann(nn.Module):
    def __init__(self, lstm):
        super(dann, self).__init__()
        self.lstm = lstm
        self.regression = domain_regression()
        self.classification = domain_classfication()
        
    def forward(self, x):
        feature = self.lstm(x)
        reg_output = self.regression(feature)
        cla_output = self.classification(feature)
        
        return reg_output, cla_output

# %% [markdown]
# ### Loss 선언

# %%
class dann_loss(nn.Module):
    def __init__(self):
        super(dann_loss, self).__init__()
        self.reg = nn.L1Loss() # 회귀 L1 손실 == MAE
        self.cla = nn.BCEWithLogitsLoss() # 도메인 분류
        
    def forward(self, result, reg_real, domain_num, alpha=1):
        reg_output, cla_output = result
        batch_size = reg_output.shape[0]
        cla_target = torch.FloatTensor([domain_num] * batch_size).unsqueeze(1).to(device)
        
        reg_loss = self.reg(reg_output, reg_real)
        cla_loss = self.cla(cla_output, cla_target)
        loss = reg_loss * alpha + cla_loss * alpha
        return loss, reg_loss, cla_loss

# %% [markdown]
# # 훈련

# %%
from torch.optim.lr_scheduler import LinearLR

alpha = 0.5

my_lstm = lstm().to(device)
model = dann(my_lstm).to(device)
loss_fn = dann_loss().to(device)

epochs = 200

model.train() # 훈련 모드 설정

optimizer= torch.optim.Adamax(model.parameters(), lr=0.01)#lr = 0.001, weight_decay=0.01)
scheduler = LinearLR(optimizer, start_factor=1.0, end_factor=0.0, total_iters = epochs * len(NELEC_train))

best_source_loss = float('inf')
best_model_state_dict = None

for i in range(1, epochs + 1):
    total_loss = 0
    source_total_loss = 0
    target_total_loss = 0
    src_reg_total = 0
    src_cla_total = 0
    tar_reg_total = 0
    tar_cal_total = 0
    for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
        source_x = source_data[0].to(device)
        source_y = source_data[1].to(device)
        target_x = target_data[0].to(device)
        target_y = target_data[1].to(device)
        #print(source_x.shape)
        #print(source_y.shape)
        #print(target_x.shape)
        #print(target_y.shape)
        # 순전파
        source_result = model(source_x)
        target_result = model(target_x)
        #print(source_result[0].shape)
        #print(target_result[0].shape)
        #print(source_result[1].shape)
        #print(target_result[1].shape)
        # 순전파 loss
        source_loss, source_reg_loss, source_cla_loss = loss_fn(source_result, source_y, 0, alpha=alpha) # 소스 도메인 레이블 0
        target_loss, target_reg_loss, target_cla_loss = loss_fn(target_result, target_y, 1, alpha=alpha) # 타겟 도메인 레이블 1
        loss = source_loss + target_loss
        
        src_reg_total += source_reg_loss.item()
        src_cla_total += source_cla_loss.item()
        tar_reg_total += target_reg_loss.item()
        tar_cal_total += target_cla_loss.item()
        
        source_total_loss += source_loss.item()
        target_total_loss += target_loss.item()
        total_loss += loss.item()
        
        # 그래디언트 계산 및 업데이트
        optimizer.zero_grad()
        loss.backward()
        
        optimizer.step()
        scheduler.step()

    print('Epoch : %d, Total Avg Loss : %.4f' % (i, total_loss / len(NELEC_train)))     
    #print('Source Avg Loss : %.4f' % (source_total_loss / len(NELEC_train)))
    #print('Target Avg Loss : %.4f' % (target_total_loss / len(NELEC_train)))
    print('Source Avg reg Loss : %.4f' % (src_reg_total / len(NELEC_train)))
    print('Target Avg reg Loss : %.4f' % (tar_reg_total / len(NELEC_train)))
    print('Source Avg cla Loss : %.4f' % (src_cla_total / len(NELEC_train)))
    print('Target Avg cla Loss : %.4f' % (tar_cal_total / len(NELEC_train)))
    print('')
    
    # source_loss가 가장 낮은 경우 모델 가중치 저장
    if source_total_loss / len(NELEC_train) < best_source_loss:
        best_source_loss = source_total_loss / len(NELEC_train)
        best_model_state_dict = model.state_dict()

# 최상의 모델을 파일로 저장
if best_model_state_dict is not None:
    torch.save(best_model_state_dict, 'hoxy_model2.pth')
    #torch.save(model, "model.pth")
# Out:
# Epoch : 1, Total Avg Loss : 1.0267
# Source Avg reg Loss : 0.3831
# Target Avg reg Loss : 0.2168
# Source Avg cla Loss : 0.9835
# Target Avg cla Loss : 0.4700
#
# Epoch : 2, Total Avg Loss : 2.2356
# Source Avg reg Loss : 1.4177
# Target Avg reg Loss : 1.6446
# Source Avg cla Loss : 0.8517
# Target Avg cla Loss : 0.5571
#
# Epoch : 3, Total Avg Loss : 0.9204
# Source Avg reg Loss : 0.1653
# Target Avg reg Loss : 0.2346
# Source Avg cla Loss : 0.9548
# Target Avg cla Loss : 0.4862
#
# Epoch : 4, Total Avg Loss : 0.9339
# Source Avg reg Loss : 0.1661
# Target Avg reg Loss : 0.2336
# Source Avg cla Loss : 1.0202
# Target Avg cla Loss : 0.4479
#
# Epoch : 5, Total Avg Loss : 0.9362
# Source Avg reg Loss : 0.1424
# Target Avg reg Loss : 0.2622
# Source Avg cla Loss : 1.0195
# Target Avg cla Loss : 0.4483
#
# Epoch : 6, Total Avg Loss : 0.9230
# Source Avg reg Loss : 0.1776
# Target Avg reg Loss : 0.2244
# Source Avg cla Loss : 0.9614
# Target Avg cla Loss : 0.4826
#
# Epoch : 7, Total Avg Loss : 0.9061
# Source Avg reg Loss : 0.1769
# Target Avg reg Loss : 0.2223
# Source Avg cla Loss : 0.8677
# Target Avg cla Loss : 0.5452
#
# Epoch : 8, Total Avg Loss : 0.8920
# Source Avg reg Loss : 0.1450
# Target Avg reg Loss : 0.2453
# Source Avg cla Loss : 0.7784
# Target Avg cla Loss : 0.6153
#
# Epoch : 9, Total Avg Loss : 0.8885
# Source Avg reg Loss : 0.1386
# Target Avg reg Loss : 0.2505
# Source Avg cla Loss : 0.7292
# Target Avg cla Loss : 0.6586
#
# Epoch : 10, Total Avg Loss : 0.8808
# Source Avg reg Loss : 0.1543
# Target Avg reg Loss : 0.2210
# Source Avg cla Loss : 0.7092
# Target Avg cla Loss : 0.6772
#
# Epoch : 11, Total Avg Loss : 0.8729
# Source Avg reg Loss : 0.1599
# Target Avg reg Loss : 0.2006
# Source Avg cla Loss : 0.7017
# Target Avg cla Loss : 0.6834
#
# Epoch : 12, Total Avg Loss : 0.8539
# Source Avg reg Loss : 0.1403
# Target Avg reg Loss : 0.1847
# Source Avg cla Loss : 0.7010
# Target Avg cla Loss : 0.6818
#
# Epoch : 13, Total Avg Loss : 0.8385
# Source Avg reg Loss : 0.1245
# Target Avg reg Loss : 0.1739
# Source Avg cla Loss : 0.7082
# Target Avg cla Loss : 0.6705
#
# Epoch : 14, Total Avg Loss : 0.8257
# Source Avg reg Loss : 0.1603
# Target Avg reg Loss : 0.1174
# Source Avg cla Loss : 0.7455
# Target Avg cla Loss : 0.6283
#
# Epoch : 15, Total Avg Loss : 0.8402
# Source Avg reg Loss : 0.1616
# Target Avg reg Loss : 0.1534
# Source Avg cla Loss : 0.7361
# Target Avg cla Loss : 0.6293
#
# Epoch : 16, Total Avg Loss : 0.8828
# Source Avg reg Loss : 0.2389
# Target Avg reg Loss : 0.1215
# Source Avg cla Loss : 0.7768
# Target Avg cla Loss : 0.6283
#
# Epoch : 17, Total Avg Loss : 0.8227
# Source Avg reg Loss : 0.1694
# Target Avg reg Loss : 0.0992
# Source Avg cla Loss : 0.7496
# Target Avg cla Loss : 0.6271
#
# Epoch : 18, Total Avg Loss : 0.8096
# Source Avg reg Loss : 0.1279
# Target Avg reg Loss : 0.1329
# Source Avg cla Loss : 0.7160
# Target Avg cla Loss : 0.6425
#
# Epoch : 19, Total Avg Loss : 0.8065
# Source Avg reg Loss : 0.1245
# Target Avg reg Loss : 0.1255
# Source Avg cla Loss : 0.7080
# Target Avg cla Loss : 0.6550
#
# Epoch : 20, Total Avg Loss : 0.8168
# Source Avg reg Loss : 0.1370
# Target Avg reg Loss : 0.1278
# Source Avg cla Loss : 0.7032
# Target Avg cla Loss : 0.6655
#
# Epoch : 21, Total Avg Loss : 0.8199
# Source Avg reg Loss : 0.1256
# Target Avg reg Loss : 0.1382
# Source Avg cla Loss : 0.6978
# Target Avg cla Loss : 0.6783
#
# Epoch : 22, Total Avg Loss : 0.8205
# Source Avg reg Loss : 0.1064
# Target Avg reg Loss : 0.1539
# Source Avg cla Loss : 0.6951
# Target Avg cla Loss : 0.6857
#
# Epoch : 23, Total Avg Loss : 0.8158
# Source Avg reg Loss : 0.1012
# Target Avg reg Loss : 0.1489
# Source Avg cla Loss : 0.6945
# Target Avg cla Loss : 0.6869
#
# Epoch : 24, Total Avg Loss : 0.8010
# Source Avg reg Loss : 0.1140
# Target Avg reg Loss : 0.1097
# Source Avg cla Loss : 0.6951
# Target Avg cla Loss : 0.6832
#
# Epoch : 25, Total Avg Loss : 0.7984
# Source Avg reg Loss : 0.1311
# Target Avg reg Loss : 0.0888
# Source Avg cla Loss : 0.6958
# Target Avg cla Loss : 0.6811
#
# Epoch : 26, Total Avg Loss : 0.7921
# Source Avg reg Loss : 0.1023
# Target Avg reg Loss : 0.1028
# Source Avg cla Loss : 0.6943
# Target Avg cla Loss : 0.6848
#
# Epoch : 27, Total Avg Loss : 0.7901
# Source Avg reg Loss : 0.1039
# Target Avg reg Loss : 0.0955
# Source Avg cla Loss : 0.6940
# Target Avg cla Loss : 0.6868
#
# Epoch : 28, Total Avg Loss : 0.7965
# Source Avg reg Loss : 0.1269
# Target Avg reg Loss : 0.0833
# Source Avg cla Loss : 0.6940
# Target Avg cla Loss : 0.6888
#
# Epoch : 29, Total Avg Loss : 0.7913
# Source Avg reg Loss : 0.0881
# Target Avg reg Loss : 0.1097
# Source Avg cla Loss : 0.6933
# Target Avg cla Loss : 0.6915
#
# Epoch : 30, Total Avg Loss : 0.7789
# Source Avg reg Loss : 0.0859
# Target Avg reg Loss : 0.0867
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6920
#
# Epoch : 31, Total Avg Loss : 0.7861
# Source Avg reg Loss : 0.1026
# Target Avg reg Loss : 0.0843
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6921
#
# Epoch : 32, Total Avg Loss : 0.7848
# Source Avg reg Loss : 0.0790
# Target Avg reg Loss : 0.1048
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6926
#
# Epoch : 33, Total Avg Loss : 0.7724
# Source Avg reg Loss : 0.0814
# Target Avg reg Loss : 0.0781
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6921
#
# Epoch : 34, Total Avg Loss : 0.7743
# Source Avg reg Loss : 0.0867
# Target Avg reg Loss : 0.0770
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6916
#
# Epoch : 35, Total Avg Loss : 0.7868
# Source Avg reg Loss : 0.0870
# Target Avg reg Loss : 0.1014
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6921
#
# Epoch : 36, Total Avg Loss : 0.7743
# Source Avg reg Loss : 0.0867
# Target Avg reg Loss : 0.0775
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6912
#
# Epoch : 37, Total Avg Loss : 0.7692
# Source Avg reg Loss : 0.0800
# Target Avg reg Loss : 0.0737
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6915
#
# Epoch : 38, Total Avg Loss : 0.7775
# Source Avg reg Loss : 0.0772
# Target Avg reg Loss : 0.0923
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6922
#
# Epoch : 39, Total Avg Loss : 0.7678
# Source Avg reg Loss : 0.0777
# Target Avg reg Loss : 0.0729
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6917
#
# Epoch : 40, Total Avg Loss : 0.7720
# Source Avg reg Loss : 0.0859
# Target Avg reg Loss : 0.0738
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6912
#
# Epoch : 41, Total Avg Loss : 0.7664
# Source Avg reg Loss : 0.0733
# Target Avg reg Loss : 0.0747
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6915
#
# Epoch : 42, Total Avg Loss : 0.7671
# Source Avg reg Loss : 0.0733
# Target Avg reg Loss : 0.0765
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6913
#
# Epoch : 43, Total Avg Loss : 0.7654
# Source Avg reg Loss : 0.0769
# Target Avg reg Loss : 0.0704
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6903
#
# Epoch : 44, Total Avg Loss : 0.7619
# Source Avg reg Loss : 0.0724
# Target Avg reg Loss : 0.0676
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6905
#
# Epoch : 45, Total Avg Loss : 0.7645
# Source Avg reg Loss : 0.0719
# Target Avg reg Loss : 0.0726
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6913
#
# Epoch : 46, Total Avg Loss : 0.7594
# Source Avg reg Loss : 0.0696
# Target Avg reg Loss : 0.0649
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6912
#
# Epoch : 47, Total Avg Loss : 0.7617
# Source Avg reg Loss : 0.0741
# Target Avg reg Loss : 0.0651
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6910
#
# Epoch : 48, Total Avg Loss : 0.7587
# Source Avg reg Loss : 0.0687
# Target Avg reg Loss : 0.0638
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6917
#
# Epoch : 49, Total Avg Loss : 0.7584
# Source Avg reg Loss : 0.0680
# Target Avg reg Loss : 0.0639
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6917
#
# Epoch : 50, Total Avg Loss : 0.7569
# Source Avg reg Loss : 0.0691
# Target Avg reg Loss : 0.0607
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6910
#
# Epoch : 51, Total Avg Loss : 0.7549
# Source Avg reg Loss : 0.0676
# Target Avg reg Loss : 0.0581
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6910
#
# Epoch : 52, Total Avg Loss : 0.7557
# Source Avg reg Loss : 0.0681
# Target Avg reg Loss : 0.0587
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6914
#
# Epoch : 53, Total Avg Loss : 0.7527
# Source Avg reg Loss : 0.0667
# Target Avg reg Loss : 0.0546
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6909
#
# Epoch : 54, Total Avg Loss : 0.7515
# Source Avg reg Loss : 0.0659
# Target Avg reg Loss : 0.0529
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6911
#
# Epoch : 55, Total Avg Loss : 0.7523
# Source Avg reg Loss : 0.0659
# Target Avg reg Loss : 0.0538
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6916
#
# Epoch : 56, Total Avg Loss : 0.7486
# Source Avg reg Loss : 0.0643
# Target Avg reg Loss : 0.0486
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6912
#
# Epoch : 57, Total Avg Loss : 0.7479
# Source Avg reg Loss : 0.0657
# Target Avg reg Loss : 0.0463
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6906
#
# Epoch : 58, Total Avg Loss : 0.7469
# Source Avg reg Loss : 0.0650
# Target Avg reg Loss : 0.0448
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6909
#
# Epoch : 59, Total Avg Loss : 0.7449
# Source Avg reg Loss : 0.0642
# Target Avg reg Loss : 0.0422
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6902
#
# Epoch : 60, Total Avg Loss : 0.7445
# Source Avg reg Loss : 0.0644
# Target Avg reg Loss : 0.0416
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6899
#
# Epoch : 61, Total Avg Loss : 0.7443
# Source Avg reg Loss : 0.0631
# Target Avg reg Loss : 0.0416
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6906
#
# Epoch : 62, Total Avg Loss : 0.7441
# Source Avg reg Loss : 0.0630
# Target Avg reg Loss : 0.0414
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6907
#
# Epoch : 63, Total Avg Loss : 0.7436
# Source Avg reg Loss : 0.0631
# Target Avg reg Loss : 0.0403
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6907
#
# Epoch : 64, Total Avg Loss : 0.7436
# Source Avg reg Loss : 0.0621
# Target Avg reg Loss : 0.0410
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6909
#
# Epoch : 65, Total Avg Loss : 0.7432
# Source Avg reg Loss : 0.0619
# Target Avg reg Loss : 0.0406
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6908
#
# Epoch : 66, Total Avg Loss : 0.7424
# Source Avg reg Loss : 0.0617
# Target Avg reg Loss : 0.0395
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6904
#
# Epoch : 67, Total Avg Loss : 0.7424
# Source Avg reg Loss : 0.0611
# Target Avg reg Loss : 0.0398
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6906
#
# Epoch : 68, Total Avg Loss : 0.7422
# Source Avg reg Loss : 0.0606
# Target Avg reg Loss : 0.0397
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6908
#
# Epoch : 69, Total Avg Loss : 0.7421
# Source Avg reg Loss : 0.0605
# Target Avg reg Loss : 0.0397
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6909
#
# Epoch : 70, Total Avg Loss : 0.7422
# Source Avg reg Loss : 0.0595
# Target Avg reg Loss : 0.0402
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6915
#
# Epoch : 71, Total Avg Loss : 0.7420
# Source Avg reg Loss : 0.0595
# Target Avg reg Loss : 0.0401
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6914
#
# Epoch : 72, Total Avg Loss : 0.7418
# Source Avg reg Loss : 0.0597
# Target Avg reg Loss : 0.0394
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6912
#
# Epoch : 73, Total Avg Loss : 0.7412
# Source Avg reg Loss : 0.0590
# Target Avg reg Loss : 0.0390
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6911
#
# Epoch : 74, Total Avg Loss : 0.7411
# Source Avg reg Loss : 0.0591
# Target Avg reg Loss : 0.0389
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6909
#
# Epoch : 75, Total Avg Loss : 0.7405
# Source Avg reg Loss : 0.0586
# Target Avg reg Loss : 0.0386
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6907
#
# Epoch : 76, Total Avg Loss : 0.7407
# Source Avg reg Loss : 0.0585
# Target Avg reg Loss : 0.0386
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6911
#
# Epoch : 77, Total Avg Loss : 0.7403
# Source Avg reg Loss : 0.0577
# Target Avg reg Loss : 0.0387
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6910
#
# Epoch : 78, Total Avg Loss : 0.7397
# Source Avg reg Loss : 0.0574
# Target Avg reg Loss : 0.0380
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6909
#
# Epoch : 79, Total Avg Loss : 0.7400
# Source Avg reg Loss : 0.0576
# Target Avg reg Loss : 0.0383
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6909
#
# Epoch : 80, Total Avg Loss : 0.7394
# Source Avg reg Loss : 0.0577
# Target Avg reg Loss : 0.0373
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6905
#
# Epoch : 81, Total Avg Loss : 0.7388
# Source Avg reg Loss : 0.0567
# Target Avg reg Loss : 0.0373
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6904
#
# Epoch : 82, Total Avg Loss : 0.7392
# Source Avg reg Loss : 0.0573
# Target Avg reg Loss : 0.0374
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6905
#
# Epoch : 83, Total Avg Loss : 0.7385
# Source Avg reg Loss : 0.0569
# Target Avg reg Loss : 0.0369
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6901
#
# Epoch : 84, Total Avg Loss : 0.7389
# Source Avg reg Loss : 0.0569
# Target Avg reg Loss : 0.0374
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6903
#
# Epoch : 85, Total Avg Loss : 0.7384
# Source Avg reg Loss : 0.0566
# Target Avg reg Loss : 0.0370
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6900
#
# Epoch : 86, Total Avg Loss : 0.7378
# Source Avg reg Loss : 0.0560
# Target Avg reg Loss : 0.0365
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6898
#
# Epoch : 87, Total Avg Loss : 0.7382
# Source Avg reg Loss : 0.0560
# Target Avg reg Loss : 0.0374
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6899
#
# Epoch : 88, Total Avg Loss : 0.7375
# Source Avg reg Loss : 0.0562
# Target Avg reg Loss : 0.0365
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6891
#
# Epoch : 89, Total Avg Loss : 0.7381
# Source Avg reg Loss : 0.0564
# Target Avg reg Loss : 0.0369
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6896
#
# Epoch : 90, Total Avg Loss : 0.7375
# Source Avg reg Loss : 0.0559
# Target Avg reg Loss : 0.0368
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6891
#
# Epoch : 91, Total Avg Loss : 0.7370
# Source Avg reg Loss : 0.0555
# Target Avg reg Loss : 0.0362
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6891
#
# Epoch : 92, Total Avg Loss : 0.7371
# Source Avg reg Loss : 0.0552
# Target Avg reg Loss : 0.0367
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6892
#
# Epoch : 93, Total Avg Loss : 0.7365
# Source Avg reg Loss : 0.0552
# Target Avg reg Loss : 0.0363
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6883
#
# Epoch : 94, Total Avg Loss : 0.7377
# Source Avg reg Loss : 0.0553
# Target Avg reg Loss : 0.0378
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6892
#
# Epoch : 95, Total Avg Loss : 0.7364
# Source Avg reg Loss : 0.0555
# Target Avg reg Loss : 0.0362
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6880
#
# Epoch : 96, Total Avg Loss : 0.7364
# Source Avg reg Loss : 0.0546
# Target Avg reg Loss : 0.0367
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6883
#
# Epoch : 97, Total Avg Loss : 0.7361
# Source Avg reg Loss : 0.0548
# Target Avg reg Loss : 0.0365
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6878
#
# Epoch : 98, Total Avg Loss : 0.7359
# Source Avg reg Loss : 0.0549
# Target Avg reg Loss : 0.0362
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6875
#
# Epoch : 99, Total Avg Loss : 0.7368
# Source Avg reg Loss : 0.0555
# Target Avg reg Loss : 0.0369
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6879
#
# Epoch : 100, Total Avg Loss : 0.7356
# Source Avg reg Loss : 0.0561
# Target Avg reg Loss : 0.0355
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6864
#
# Epoch : 101, Total Avg Loss : 0.7365
# Source Avg reg Loss : 0.0551
# Target Avg reg Loss : 0.0371
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6875
#
# Epoch : 102, Total Avg Loss : 0.7356
# Source Avg reg Loss : 0.0552
# Target Avg reg Loss : 0.0363
# Source Avg cla Loss : 0.6933
# Target Avg cla Loss : 0.6864
#
# Epoch : 103, Total Avg Loss : 0.7354
# Source Avg reg Loss : 0.0552
# Target Avg reg Loss : 0.0362
# Source Avg cla Loss : 0.6933
# Target Avg cla Loss : 0.6861
#
# Epoch : 104, Total Avg Loss : 0.7366
# Source Avg reg Loss : 0.0553
# Target Avg reg Loss : 0.0380
# Source Avg cla Loss : 0.6933
# Target Avg cla Loss : 0.6867
#
# Epoch : 105, Total Avg Loss : 0.7349
# Source Avg reg Loss : 0.0552
# Target Avg reg Loss : 0.0363
# Source Avg cla Loss : 0.6933
# Target Avg cla Loss : 0.6850
#
# Epoch : 106, Total Avg Loss : 0.7362
# Source Avg reg Loss : 0.0552
# Target Avg reg Loss : 0.0381
# Source Avg cla Loss : 0.6933
# Target Avg cla Loss : 0.6857
#
# Epoch : 107, Total Avg Loss : 0.7344
# Source Avg reg Loss : 0.0549
# Target Avg reg Loss : 0.0359
# Source Avg cla Loss : 0.6934
# Target Avg cla Loss : 0.6847
#
# Epoch : 108, Total Avg Loss : 0.7344
# Source Avg reg Loss : 0.0554
# Target Avg reg Loss : 0.0360
# Source Avg cla Loss : 0.6934
# Target Avg cla Loss : 0.6840
#
# Epoch : 109, Total Avg Loss : 0.7363
# Source Avg reg Loss : 0.0554
# Target Avg reg Loss : 0.0388
# Source Avg cla Loss : 0.6934
# Target Avg cla Loss : 0.6851
#
# Epoch : 110, Total Avg Loss : 0.7346
# Source Avg reg Loss : 0.0563
# Target Avg reg Loss : 0.0367
# Source Avg cla Loss : 0.6935
# Target Avg cla Loss : 0.6828
#
# Epoch : 111, Total Avg Loss : 0.7368
# Source Avg reg Loss : 0.0554
# Target Avg reg Loss : 0.0400
# Source Avg cla Loss : 0.6935
# Target Avg cla Loss : 0.6848
#
# Epoch : 112, Total Avg Loss : 0.7337
# Source Avg reg Loss : 0.0554
# Target Avg reg Loss : 0.0362
# Source Avg cla Loss : 0.6935
# Target Avg cla Loss : 0.6823
#
# Epoch : 113, Total Avg Loss : 0.7338
# Source Avg reg Loss : 0.0554
# Target Avg reg Loss : 0.0364
# Source Avg cla Loss : 0.6936
# Target Avg cla Loss : 0.6821
#
# Epoch : 114, Total Avg Loss : 0.7360
# Source Avg reg Loss : 0.0554
# Target Avg reg Loss : 0.0398
# Source Avg cla Loss : 0.6936
# Target Avg cla Loss : 0.6831
#
# Epoch : 115, Total Avg Loss : 0.7338
# Source Avg reg Loss : 0.0567
# Target Avg reg Loss : 0.0368
# Source Avg cla Loss : 0.6937
# Target Avg cla Loss : 0.6803
#
# Epoch : 116, Total Avg Loss : 0.7354
# Source Avg reg Loss : 0.0555
# Target Avg reg Loss : 0.0397
# Source Avg cla Loss : 0.6937
# Target Avg cla Loss : 0.6820
#
# Epoch : 117, Total Avg Loss : 0.7339
# Source Avg reg Loss : 0.0559
# Target Avg reg Loss : 0.0375
# Source Avg cla Loss : 0.6938
# Target Avg cla Loss : 0.6806
#
# Epoch : 118, Total Avg Loss : 0.7340
# Source Avg reg Loss : 0.0564
# Target Avg reg Loss : 0.0376
# Source Avg cla Loss : 0.6939
# Target Avg cla Loss : 0.6801
#
# Epoch : 119, Total Avg Loss : 0.7346
# Source Avg reg Loss : 0.0562
# Target Avg reg Loss : 0.0388
# Source Avg cla Loss : 0.6940
# Target Avg cla Loss : 0.6802
#
# Epoch : 120, Total Avg Loss : 0.7335
# Source Avg reg Loss : 0.0566
# Target Avg reg Loss : 0.0376
# Source Avg cla Loss : 0.6942
# Target Avg cla Loss : 0.6785
#
# Epoch : 121, Total Avg Loss : 0.7332
# Source Avg reg Loss : 0.0566
# Target Avg reg Loss : 0.0377
# Source Avg cla Loss : 0.6943
# Target Avg cla Loss : 0.6779
#
# Epoch : 122, Total Avg Loss : 0.7342
# Source Avg reg Loss : 0.0565
# Target Avg reg Loss : 0.0394
# Source Avg cla Loss : 0.6944
# Target Avg cla Loss : 0.6781
#
# Epoch : 123, Total Avg Loss : 0.7333
# Source Avg reg Loss : 0.0573
# Target Avg reg Loss : 0.0381
# Source Avg cla Loss : 0.6947
# Target Avg cla Loss : 0.6766
#
# Epoch : 124, Total Avg Loss : 0.7336
# Source Avg reg Loss : 0.0569
# Target Avg reg Loss : 0.0390
# Source Avg cla Loss : 0.6948
# Target Avg cla Loss : 0.6764
#
# Epoch : 125, Total Avg Loss : 0.7328
# Source Avg reg Loss : 0.0571
# Target Avg reg Loss : 0.0390
# Source Avg cla Loss : 0.6951
# Target Avg cla Loss : 0.6744
#
# Epoch : 126, Total Avg Loss : 0.7330
# Source Avg reg Loss : 0.0582
# Target Avg reg Loss : 0.0388
# Source Avg cla Loss : 0.6954
# Target Avg cla Loss : 0.6736
#
# Epoch : 127, Total Avg Loss : 0.7321
# Source Avg reg Loss : 0.0577
# Target Avg reg Loss : 0.0385
# Source Avg cla Loss : 0.6956
# Target Avg cla Loss : 0.6723
#
# Epoch : 128, Total Avg Loss : 0.7325
# Source Avg reg Loss : 0.0580
# Target Avg reg Loss : 0.0390
# Source Avg cla Loss : 0.6961
# Target Avg cla Loss : 0.6718
#
# Epoch : 129, Total Avg Loss : 0.7329
# Source Avg reg Loss : 0.0582
# Target Avg reg Loss : 0.0396
# Source Avg cla Loss : 0.6966
# Target Avg cla Loss : 0.6714
#
# Epoch : 130, Total Avg Loss : 0.7317
# Source Avg reg Loss : 0.0581
# Target Avg reg Loss : 0.0391
# Source Avg cla Loss : 0.6971
# Target Avg cla Loss : 0.6690
#
# Epoch : 131, Total Avg Loss : 0.7327
# Source Avg reg Loss : 0.0590
# Target Avg reg Loss : 0.0399
# Source Avg cla Loss : 0.6978
# Target Avg cla Loss : 0.6687
#
# Epoch : 132, Total Avg Loss : 0.7323
# Source Avg reg Loss : 0.0593
# Target Avg reg Loss : 0.0396
# Source Avg cla Loss : 0.6984
# Target Avg cla Loss : 0.6672
#
# Epoch : 133, Total Avg Loss : 0.7323
# Source Avg reg Loss : 0.0601
# Target Avg reg Loss : 0.0395
# Source Avg cla Loss : 0.6993
# Target Avg cla Loss : 0.6657
#
# Epoch : 134, Total Avg Loss : 0.7324
# Source Avg reg Loss : 0.0595
# Target Avg reg Loss : 0.0402
# Source Avg cla Loss : 0.7004
# Target Avg cla Loss : 0.6647
#
# Epoch : 135, Total Avg Loss : 0.7322
# Source Avg reg Loss : 0.0594
# Target Avg reg Loss : 0.0406
# Source Avg cla Loss : 0.7018
# Target Avg cla Loss : 0.6627
#
# Epoch : 136, Total Avg Loss : 0.7322
# Source Avg reg Loss : 0.0599
# Target Avg reg Loss : 0.0404
# Source Avg cla Loss : 0.7033
# Target Avg cla Loss : 0.6608
#
# Epoch : 137, Total Avg Loss : 0.7321
# Source Avg reg Loss : 0.0602
# Target Avg reg Loss : 0.0403
# Source Avg cla Loss : 0.7050
# Target Avg cla Loss : 0.6586
#
# Epoch : 138, Total Avg Loss : 0.7327
# Source Avg reg Loss : 0.0603
# Target Avg reg Loss : 0.0412
# Source Avg cla Loss : 0.7073
# Target Avg cla Loss : 0.6566
#
# Epoch : 139, Total Avg Loss : 0.7323
# Source Avg reg Loss : 0.0598
# Target Avg reg Loss : 0.0407
# Source Avg cla Loss : 0.7104
# Target Avg cla Loss : 0.6537
#
# Epoch : 140, Total Avg Loss : 0.7332
# Source Avg reg Loss : 0.0607
# Target Avg reg Loss : 0.0410
# Source Avg cla Loss : 0.7137
# Target Avg cla Loss : 0.6510
#
# Epoch : 141, Total Avg Loss : 0.7343
# Source Avg reg Loss : 0.0605
# Target Avg reg Loss : 0.0414
# Source Avg cla Loss : 0.7178
# Target Avg cla Loss : 0.6488
#
# Epoch : 142, Total Avg Loss : 0.7349
# Source Avg reg Loss : 0.0600
# Target Avg reg Loss : 0.0412
# Source Avg cla Loss : 0.7218
# Target Avg cla Loss : 0.6468
#
# Epoch : 143, Total Avg Loss : 0.7363
# Source Avg reg Loss : 0.0601
# Target Avg reg Loss : 0.0410
# Source Avg cla Loss : 0.7266
# Target Avg cla Loss : 0.6450
#
# Epoch : 144, Total Avg Loss : 0.7383
# Source Avg reg Loss : 0.0602
# Target Avg reg Loss : 0.0407
# Source Avg cla Loss : 0.7306
# Target Avg cla Loss : 0.6450
#
# Epoch : 145, Total Avg Loss : 0.7403
# Source Avg reg Loss : 0.0601
# Target Avg reg Loss : 0.0401
# Source Avg cla Loss : 0.7354
# Target Avg cla Loss : 0.6451
#
# Epoch : 146, Total Avg Loss : 0.7426
# Source Avg reg Loss : 0.0598
# Target Avg reg Loss : 0.0400
# Source Avg cla Loss : 0.7373
# Target Avg cla Loss : 0.6480
#
# Epoch : 147, Total Avg Loss : 0.7449
# Source Avg reg Loss : 0.0606
# Target Avg reg Loss : 0.0389
# Source Avg cla Loss : 0.7400
# Target Avg cla Loss : 0.6502
#
# Epoch : 148, Total Avg Loss : 0.7464
# Source Avg reg Loss : 0.0595
# Target Avg reg Loss : 0.0392
# Source Avg cla Loss : 0.7418
# Target Avg cla Loss : 0.6523
#
# Epoch : 149, Total Avg Loss : 0.7461
# Source Avg reg Loss : 0.0578
# Target Avg reg Loss : 0.0385
# Source Avg cla Loss : 0.7429
# Target Avg cla Loss : 0.6529
#
# Epoch : 150, Total Avg Loss : 0.7459
# Source Avg reg Loss : 0.0576
# Target Avg reg Loss : 0.0372
# Source Avg cla Loss : 0.7426
# Target Avg cla Loss : 0.6544
#
# Epoch : 151, Total Avg Loss : 0.7450
# Source Avg reg Loss : 0.0561
# Target Avg reg Loss : 0.0366
# Source Avg cla Loss : 0.7425
# Target Avg cla Loss : 0.6548
#
# Epoch : 152, Total Avg Loss : 0.7450
# Source Avg reg Loss : 0.0550
# Target Avg reg Loss : 0.0357
# Source Avg cla Loss : 0.7446
# Target Avg cla Loss : 0.6547
#
# Epoch : 153, Total Avg Loss : 0.7434
# Source Avg reg Loss : 0.0542
# Target Avg reg Loss : 0.0351
# Source Avg cla Loss : 0.7447
# Target Avg cla Loss : 0.6529
#
# Epoch : 154, Total Avg Loss : 0.7432
# Source Avg reg Loss : 0.0536
# Target Avg reg Loss : 0.0346
# Source Avg cla Loss : 0.7460
# Target Avg cla Loss : 0.6521
#
# Epoch : 155, Total Avg Loss : 0.7419
# Source Avg reg Loss : 0.0530
# Target Avg reg Loss : 0.0340
# Source Avg cla Loss : 0.7461
# Target Avg cla Loss : 0.6508
#
# Epoch : 156, Total Avg Loss : 0.7404
# Source Avg reg Loss : 0.0527
# Target Avg reg Loss : 0.0338
# Source Avg cla Loss : 0.7462
# Target Avg cla Loss : 0.6482
#
# Epoch : 157, Total Avg Loss : 0.7394
# Source Avg reg Loss : 0.0526
# Target Avg reg Loss : 0.0331
# Source Avg cla Loss : 0.7456
# Target Avg cla Loss : 0.6473
#
# Epoch : 158, Total Avg Loss : 0.7378
# Source Avg reg Loss : 0.0529
# Target Avg reg Loss : 0.0327
# Source Avg cla Loss : 0.7446
# Target Avg cla Loss : 0.6454
#
# Epoch : 159, Total Avg Loss : 0.7371
# Source Avg reg Loss : 0.0529
# Target Avg reg Loss : 0.0326
# Source Avg cla Loss : 0.7440
# Target Avg cla Loss : 0.6447
#
# Epoch : 160, Total Avg Loss : 0.7363
# Source Avg reg Loss : 0.0528
# Target Avg reg Loss : 0.0329
# Source Avg cla Loss : 0.7419
# Target Avg cla Loss : 0.6450
#
# Epoch : 161, Total Avg Loss : 0.7340
# Source Avg reg Loss : 0.0523
# Target Avg reg Loss : 0.0323
# Source Avg cla Loss : 0.7389
# Target Avg cla Loss : 0.6445
#
# Epoch : 162, Total Avg Loss : 0.7324
# Source Avg reg Loss : 0.0521
# Target Avg reg Loss : 0.0321
# Source Avg cla Loss : 0.7359
# Target Avg cla Loss : 0.6447
#
# Epoch : 163, Total Avg Loss : 0.7321
# Source Avg reg Loss : 0.0523
# Target Avg reg Loss : 0.0327
# Source Avg cla Loss : 0.7333
# Target Avg cla Loss : 0.6460
#
# Epoch : 164, Total Avg Loss : 0.7310
# Source Avg reg Loss : 0.0523
# Target Avg reg Loss : 0.0320
# Source Avg cla Loss : 0.7310
# Target Avg cla Loss : 0.6467
#
# Epoch : 165, Total Avg Loss : 0.7306
# Source Avg reg Loss : 0.0528
# Target Avg reg Loss : 0.0325
# Source Avg cla Loss : 0.7277
# Target Avg cla Loss : 0.6481
#
# Epoch : 166, Total Avg Loss : 0.7305
# Source Avg reg Loss : 0.0528
# Target Avg reg Loss : 0.0333
# Source Avg cla Loss : 0.7251
# Target Avg cla Loss : 0.6498
#
# Epoch : 167, Total Avg Loss : 0.7311
# Source Avg reg Loss : 0.0520
# Target Avg reg Loss : 0.0345
# Source Avg cla Loss : 0.7230
# Target Avg cla Loss : 0.6525
#
# Epoch : 168, Total Avg Loss : 0.7319
# Source Avg reg Loss : 0.0523
# Target Avg reg Loss : 0.0356
# Source Avg cla Loss : 0.7212
# Target Avg cla Loss : 0.6547
#
# Epoch : 169, Total Avg Loss : 0.7326
# Source Avg reg Loss : 0.0529
# Target Avg reg Loss : 0.0365
# Source Avg cla Loss : 0.7192
# Target Avg cla Loss : 0.6565
#
# Epoch : 170, Total Avg Loss : 0.7335
# Source Avg reg Loss : 0.0525
# Target Avg reg Loss : 0.0380
# Source Avg cla Loss : 0.7185
# Target Avg cla Loss : 0.6580
#
# Epoch : 171, Total Avg Loss : 0.7342
# Source Avg reg Loss : 0.0527
# Target Avg reg Loss : 0.0388
# Source Avg cla Loss : 0.7172
# Target Avg cla Loss : 0.6596
#
# Epoch : 172, Total Avg Loss : 0.7336
# Source Avg reg Loss : 0.0525
# Target Avg reg Loss : 0.0384
# Source Avg cla Loss : 0.7167
# Target Avg cla Loss : 0.6595
#
# Epoch : 173, Total Avg Loss : 0.7336
# Source Avg reg Loss : 0.0532
# Target Avg reg Loss : 0.0382
# Source Avg cla Loss : 0.7169
# Target Avg cla Loss : 0.6588
#
# Epoch : 174, Total Avg Loss : 0.7331
# Source Avg reg Loss : 0.0527
# Target Avg reg Loss : 0.0379
# Source Avg cla Loss : 0.7173
# Target Avg cla Loss : 0.6583
#
# Epoch : 175, Total Avg Loss : 0.7337
# Source Avg reg Loss : 0.0534
# Target Avg reg Loss : 0.0374
# Source Avg cla Loss : 0.7184
# Target Avg cla Loss : 0.6583
#
# Epoch : 176, Total Avg Loss : 0.7341
# Source Avg reg Loss : 0.0535
# Target Avg reg Loss : 0.0373
# Source Avg cla Loss : 0.7194
# Target Avg cla Loss : 0.6579
#
# Epoch : 177, Total Avg Loss : 0.7343
# Source Avg reg Loss : 0.0538
# Target Avg reg Loss : 0.0373
# Source Avg cla Loss : 0.7199
# Target Avg cla Loss : 0.6577
#
# Epoch : 178, Total Avg Loss : 0.7349
# Source Avg reg Loss : 0.0539
# Target Avg reg Loss : 0.0374
# Source Avg cla Loss : 0.7209
# Target Avg cla Loss : 0.6575
#
# Epoch : 179, Total Avg Loss : 0.7355
# Source Avg reg Loss : 0.0543
# Target Avg reg Loss : 0.0376
# Source Avg cla Loss : 0.7224
# Target Avg cla Loss : 0.6567
#
# Epoch : 180, Total Avg Loss : 0.7364
# Source Avg reg Loss : 0.0543
# Target Avg reg Loss : 0.0380
# Source Avg cla Loss : 0.7226
# Target Avg cla Loss : 0.6579
#
# Epoch : 181, Total Avg Loss : 0.7372
# Source Avg reg Loss : 0.0546
# Target Avg reg Loss : 0.0378
# Source Avg cla Loss : 0.7247
# Target Avg cla Loss : 0.6572
#
# Epoch : 182, Total Avg Loss : 0.7373
# Source Avg reg Loss : 0.0547
# Target Avg reg Loss : 0.0375
# Source Avg cla Loss : 0.7256
# Target Avg cla Loss : 0.6568
#
# Epoch : 183, Total Avg Loss : 0.7382
# Source Avg reg Loss : 0.0543
# Target Avg reg Loss : 0.0377
# Source Avg cla Loss : 0.7272
# Target Avg cla Loss : 0.6572
#
# Epoch : 184, Total Avg Loss : 0.7397
# Source Avg reg Loss : 0.0553
# Target Avg reg Loss : 0.0379
# Source Avg cla Loss : 0.7294
# Target Avg cla Loss : 0.6567
#
# Epoch : 185, Total Avg Loss : 0.7409
# Source Avg reg Loss : 0.0555
# Target Avg reg Loss : 0.0381
# Source Avg cla Loss : 0.7318
# Target Avg cla Loss : 0.6564
#
# Epoch : 186, Total Avg Loss : 0.7417
# Source Avg reg Loss : 0.0555
# Target Avg reg Loss : 0.0381
# Source Avg cla Loss : 0.7345
# Target Avg cla Loss : 0.6554
#
# Epoch : 187, Total Avg Loss : 0.7425
# Source Avg reg Loss : 0.0558
# Target Avg reg Loss : 0.0384
# Source Avg cla Loss : 0.7366
# Target Avg cla Loss : 0.6543
#
# Epoch : 188, Total Avg Loss : 0.7440
# Source Avg reg Loss : 0.0567
# Target Avg reg Loss : 0.0380
# Source Avg cla Loss : 0.7403
# Target Avg cla Loss : 0.6529
#
# Epoch : 189, Total Avg Loss : 0.7449
# Source Avg reg Loss : 0.0566
# Target Avg reg Loss : 0.0378
# Source Avg cla Loss : 0.7440
# Target Avg cla Loss : 0.6514
#
# Epoch : 190, Total Avg Loss : 0.7462
# Source Avg reg Loss : 0.0567
# Target Avg reg Loss : 0.0387
# Source Avg cla Loss : 0.7470
# Target Avg cla Loss : 0.6499
#
# Epoch : 191, Total Avg Loss : 0.7477
# Source Avg reg Loss : 0.0576
# Target Avg reg Loss : 0.0388
# Source Avg cla Loss : 0.7505
# Target Avg cla Loss : 0.6485
#
# Epoch : 192, Total Avg Loss : 0.7492
# Source Avg reg Loss : 0.0579
# Target Avg reg Loss : 0.0384
# Source Avg cla Loss : 0.7548
# Target Avg cla Loss : 0.6474
#
# Epoch : 193, Total Avg Loss : 0.7503
# Source Avg reg Loss : 0.0582
# Target Avg reg Loss : 0.0389
# Source Avg cla Loss : 0.7578
# Target Avg cla Loss : 0.6457
#
# Epoch : 194, Total Avg Loss : 0.7522
# Source Avg reg Loss : 0.0588
# Target Avg reg Loss : 0.0390
# Source Avg cla Loss : 0.7625
# Target Avg cla Loss : 0.6441
#
# Epoch : 195, Total Avg Loss : 0.7537
# Source Avg reg Loss : 0.0593
# Target Avg reg Loss : 0.0393
# Source Avg cla Loss : 0.7661
# Target Avg cla Loss : 0.6428
#
# Epoch : 196, Total Avg Loss : 0.7559
# Source Avg reg Loss : 0.0606
# Target Avg reg Loss : 0.0396
# Source Avg cla Loss : 0.7703
# Target Avg cla Loss : 0.6413
#
# Epoch : 197, Total Avg Loss : 0.7566
# Source Avg reg Loss : 0.0607
# Target Avg reg Loss : 0.0393
# Source Avg cla Loss : 0.7731
# Target Avg cla Loss : 0.6401
#
# Epoch : 198, Total Avg Loss : 0.7576
# Source Avg reg Loss : 0.0609
# Target Avg reg Loss : 0.0394
# Source Avg cla Loss : 0.7758
# Target Avg cla Loss : 0.6391
#
# Epoch : 199, Total Avg Loss : 0.7585
# Source Avg reg Loss : 0.0613
# Target Avg reg Loss : 0.0397
# Source Avg cla Loss : 0.7778
# Target Avg cla Loss : 0.6382
#
# Epoch : 200, Total Avg Loss : 0.7594
# Source Avg reg Loss : 0.0611
# Target Avg reg Loss : 0.0406
# Source Avg cla Loss : 0.7788
# Target Avg cla Loss : 0.6383

# %%
# from torchinfo import summary

# summary(model, (64,3,13))

# %% [markdown]
# # train 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('hoxy_model2.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []


for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    _, source_pred = best_source_model2(sourcex)
    _, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: -4.973696006909851
# TARGET R2 Score: -0.40665144043418455

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# # test 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('hoxy_model2.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []


for step, (source_data, target_data) in enumerate(zip(NELEC_test, DHW_test)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    _, source_pred = best_source_model2(sourcex)
    _, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: -4.410619403407507
# TARGET R2 Score: -0.18892229792157988

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# ### Domain Embedding Space 시각화

# %%
# 가장 앞 batch의 250개씩의 데이터만 샘플링
source_tsne = DataLoader(nelec_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

target_tsne = DataLoader(elec_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

source_tsne2 = next(iter(source_tsne))
target_tsne2 = next(iter(target_tsne))

source_x_TNSE = source_tsne2[0].to(device)
source_y_TNSE = source_tsne2[1].to(device)

target_x_TNSE = target_tsne2[0].to(device)
target_y_TNSE = target_tsne2[1].to(device)

# 학습된 모델의 LSTM 부분만 활용 (100차원 임베딩 벡터를 받아오는 과정)
source_vector = model.lstm(source_x_TNSE)
target_vector = model.lstm(target_x_TNSE)

# %%
from sklearn.manifold import TSNE

df = pd.DataFrame(np.concatenate([source_vector.cpu().detach().numpy(), target_vector.cpu().detach().numpy()]))

tsne_np = TSNE(n_components=2).fit_transform(df)
tsne_df = pd.DataFrame(tsne_np, columns=['component 0', 'component 1'])

# %%
tsne_df_0 = tsne_df.loc[:1000]
tsne_df_1 = tsne_df.loc[1000:]

plt.scatter(tsne_df_0['component 0'], tsne_df_0['component 1'], color='green', label='NELEC', alpha=0.5)
plt.scatter(tsne_df_1['component 0'], tsne_df_1['component 1'], color='red', label='ELEC', alpha=0.5)

plt.title('alpha = '+ str(alpha))
plt.xlabel('component 0')
plt.ylabel('component 1')
plt.legend()
plt.show()
