# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.utils.data as data_util
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import MinMaxScaler
from torchsummary import summary
from sklearn.metrics import r2_score

# %%
CUDA = torch.cuda.is_available()
print(CUDA)

device = torch.device('cuda:0' if CUDA else 'cpu')
# Out:
# True

# %%
elec = pd.read_csv('elec_merge.csv')
nelec = pd.read_csv('n_elec_merge.csv')
dhw = pd.read_csv('dhw_merge.csv')

# %%
elec = elec.drop(['YEAR'], axis=1)
nelec = nelec.drop(['YEAR'], axis=1)
dhw = dhw.drop(['YEAR'], axis=1)

# %%
scaler_nelec = MinMaxScaler()
scaler_elec = MinMaxScaler()
scaler_dhw = MinMaxScaler()

scaler_nelec.fit(nelec)
scaler_elec.fit(elec)
scaler_dhw.fit(dhw)

scaled_nelec = scaler_nelec.transform(nelec)
scaled_elec = scaler_elec.transform(elec)
scaled_dhw = scaler_dhw.transform(dhw)

new_nelec = pd.DataFrame(scaled_nelec, index=nelec.index, columns=nelec.columns)
new_elec = pd.DataFrame(scaled_elec, index=elec.index, columns=elec.columns)
new_dhw = pd.DataFrame(scaled_dhw, index=dhw.index, columns=dhw.columns)

# %%
input_nelec = new_nelec.iloc[:-1,].reset_index(drop=True)
output_nelec = new_nelec[['n_elec']].iloc[1:].reset_index(drop=True)
output_nelec.columns = ['nelec']

input_elec = new_elec.iloc[:-1,].reset_index(drop=True)
output_elec = new_elec[['ELEC']].iloc[1:].reset_index(drop=True)
output_elec.columns = ['elec']

input_dhw = new_dhw.iloc[:-1,].reset_index(drop=True)
output_dhw = new_dhw[['DHW']].iloc[1:].reset_index(drop=True)
output_dhw.columns = ['dhw']

nelec = pd.concat([input_nelec, output_nelec], axis=1)
elec = pd.concat([input_elec, output_elec], axis=1)
dhw = pd.concat([input_dhw, output_dhw], axis=1)

# %%
standard_nelec = int(len(nelec) * 0.7)
standard_elec = int(len(elec) * 0.7)
standard_dhw = int(len(dhw) * 0.7)

nelec_train = nelec.iloc[:standard_nelec]
nelec_test = nelec.iloc[standard_nelec:].reset_index(drop=True)

elec_train = elec.iloc[:standard_elec]
elec_test = elec.iloc[standard_elec:].reset_index(drop=True)

dhw_train = dhw.iloc[:standard_dhw]
dhw_test = dhw.iloc[standard_dhw:].reset_index(drop=True)

# %%
nelec_trainx = nelec_train.drop(['nelec'], axis=1)
nelec_trainy = nelec_train[['nelec']]

nelec_testx = nelec_test.drop(['nelec'], axis=1)
nelec_testy = nelec_test[['nelec']]

elec_trainx = elec_train.drop(['elec'], axis=1)
elec_trainy = elec_train[['elec']]

elec_testx = elec_test.drop(['elec'], axis=1)
elec_testy = elec_test[['elec']]

dhw_trainx = dhw_train.drop(['dhw'], axis=1)
dhw_trainy = dhw_train[['dhw']]

dhw_testx = dhw_test.drop(['dhw'], axis=1)
dhw_testy = dhw_test[['dhw']]

# %%
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-1]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

nelec_trainx, nelec_trainy = buildDataSet(nelec_trainx, nelec_trainy, 24)
nelec_testx, nelec_testy = buildDataSet(nelec_testx, nelec_testy, 24)

elec_trainx, elec_trainy = buildDataSet(elec_trainx, elec_trainy, 24)
elec_testx, elec_testy = buildDataSet(elec_testx, elec_testy, 24)

dhw_trainx, dhw_trainy = buildDataSet(dhw_trainx, dhw_trainy, 24)
dhw_testx, dhw_testy = buildDataSet(dhw_testx, dhw_testy, 24)

# %%
print(nelec_trainx.shape)
print(nelec_trainy.shape)
print(nelec_testx.shape)
print(nelec_testy.shape)
print(elec_trainx.shape)
print(elec_trainy.shape)
print(elec_testx.shape)
print(elec_testy.shape)
print(dhw_trainx.shape)
print(dhw_trainy.shape)
print(dhw_testx.shape)
print(dhw_testy.shape)
# Out:
# (20392, 24, 12)
# (20392, 1)
# (8727, 24, 12)
# (8727, 1)
# (2967, 24, 12)
# (2967, 1)
# (1258, 24, 12)
# (1258, 1)
# (20392, 24, 12)
# (20392, 1)
# (8727, 24, 12)
# (8727, 1)

# %%
# 텐서로 변환
nelec_trainx_tensor = torch.FloatTensor(nelec_trainx)
nelec_trainy_tensor = torch.FloatTensor(nelec_trainy)

nelec_testx_tensor = torch.FloatTensor(nelec_testx)
nelec_testy_tensor = torch.FloatTensor(nelec_testy)

elec_trainx_tensor = torch.FloatTensor(elec_trainx)
elec_trainy_tensor = torch.FloatTensor(elec_trainy)

elec_testx_tensor = torch.FloatTensor(elec_testx)
elec_testy_tensor = torch.FloatTensor(elec_testy)

dhw_trainx_tensor = torch.FloatTensor(dhw_trainx)
dhw_trainy_tensor = torch.FloatTensor(dhw_trainy)

dhw_testx_tensor = torch.FloatTensor(dhw_testx)
dhw_testy_tensor = torch.FloatTensor(dhw_testy)

# %%
# 텐서 형태로 데이터 정의
nelec_train = TensorDataset(nelec_trainx_tensor, nelec_trainy_tensor)
nelec_test = TensorDataset(nelec_testx_tensor, nelec_testy_tensor)

elec_train = TensorDataset(elec_trainx_tensor, elec_trainy_tensor)
elec_test = TensorDataset(elec_testx_tensor, elec_testy_tensor)

dhw_train = TensorDataset(dhw_trainx_tensor, dhw_trainy_tensor)
dhw_test = TensorDataset(dhw_testx_tensor, dhw_testy_tensor)

# %%
batch_for_nelec_train = len(nelec_trainx)
batch_for_nelec_test = len(nelec_testx)
batch_for_elec_train = len(elec_trainx)
batch_for_elec_test = len(elec_testx)
batch_for_dhw_train = len(dhw_trainx)
batch_for_dhw_test = len(dhw_testx)

NELEC_train = DataLoader(nelec_train,
                        batch_size=batch_for_nelec_train,
                        shuffle=False,  
                        drop_last=True)

NELEC_test = DataLoader(nelec_test,
                        batch_size=batch_for_nelec_test,
                        shuffle=False,  
                        drop_last=True)

ELEC_train = DataLoader(elec_train,
                        batch_size=batch_for_elec_train,
                        shuffle=False,  
                        drop_last=True)

ELEC_test = DataLoader(elec_test,
                        batch_size=batch_for_elec_test,
                        shuffle=False,  
                        drop_last=True)

DHW_train = DataLoader(dhw_train,
                        batch_size=batch_for_dhw_train,
                        shuffle=False,  
                        drop_last=True)

DHW_test = DataLoader(dhw_test,
                        batch_size=batch_for_dhw_test,
                        shuffle=False,  
                        drop_last=True)

# %%
# 데이터셋의 개수를 가정하여 변수에 저장
nelec_train_size = len(nelec_train)
nelec_test_size = len(nelec_test)
elec_train_size = len(elec_train)
elec_test_size = len(elec_test)
dhw_train_size = len(dhw_train)
dhw_test_size = len(dhw_test)

# 각 DataLoader에서 생성되는 배치의 개수 계산
nelec_train_batches = nelec_train_size // batch_for_nelec_train
nelec_test_batches = nelec_test_size // batch_for_nelec_test
elec_train_batches = elec_train_size // batch_for_elec_train
elec_test_batches = elec_test_size // batch_for_elec_test
dhw_train_batches = dhw_train_size // batch_for_dhw_train
dhw_test_batches = dhw_test_size // batch_for_dhw_test

# 결과 출력
print("nelec_train batches:", nelec_train_batches)
print("nelec_test batches:", nelec_test_batches)
print("elec_train batches:", elec_train_batches)
print("elec_test batches:", elec_test_batches)
print("dhw_train batches:", dhw_train_batches)
print("dhw_test batches:", dhw_test_batches)
# Out:
# nelec_train batches: 1
# nelec_test batches: 1
# elec_train batches: 1
# elec_test batches: 1
# dhw_train batches: 1
# dhw_test batches: 1

# %% [markdown]
# # 모델 구조 선언

# %%
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ### GradientReversalLayer

# %%
# class GradientReversalLayer(torch.autograd.Function):
#     def forward(self, x):
#         return x.view_as(x)

#     def backward(self, grad_output):
#         return (grad_output * -1)

class GradientReversalFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, x):
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return (grad_output * -1), None

class GradientReversalLayer(torch.nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x):
        return GradientReversalFunction.apply(x)

# %% [markdown]
# ### LSTM for Feature Extraction

# %%
class lstm(nn.Module):
    def __init__(self):
        super(lstm, self).__init__()
        self.lstm1 = nn.LSTM(12, 64, batch_first=True)
        self.bn1 = nn.BatchNorm1d(24)
        
        self.lstm2 = nn.LSTM(64, 64, batch_first=True)
        self.bn2 = nn.BatchNorm1d(24)
        
        self.fc = nn.Linear(64, 64, bias=False)
        self.fc2 = nn.Linear(64, 100, bias=False)
        self.bn3 = nn.BatchNorm1d(24)
        self.dropout = nn.Dropout(0.5)
        self.gelu = nn.GELU()
        
    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.bn1(x)
        x = self.gelu(x)

        x, _ = self.lstm2(x)
        x = self.bn2(x)
        x = self.gelu(x)

        x = self.fc(x)
        x = self.bn3(x)
        x = self.fc2(x[:,-1,:])
        x = self.dropout(x)
        #x = x.view(-1, 100)
        return x

# %%
hoxy = lstm()
cnnx = torch.randn(512,24,12)
hoxy2 = hoxy(cnnx)
print(hoxy2.shape)
# Out:
# torch.Size([512, 100])

# %%
class domain_regression(nn.Module):
    def __init__(self):
        super(domain_regression, self).__init__()
        self.regression_layer1 = nn.Linear(100, 128)
        self.regression_layer2 = nn.Linear(128, 128)
        self.regression_layer3 = nn.Linear(128, 128)
        self.regression_layer4 = nn.Linear(128, 1)
        
    def forward(self, x):
        x = F.relu(self.regression_layer1(x))
        x = F.relu(self.regression_layer2(x))
        x = F.relu(self.regression_layer3(x))
        x = F.relu(self.regression_layer4(x))
        return x

# %% [markdown]
# ### Domain Classification

# %%
class domain_classfication(nn.Module):
    def __init__(self):
        super(domain_classfication, self).__init__()
        self.classification_layer0 = GradientReversalLayer()
        self.classification_layer1 = nn.Linear(100, 128)
        self.classification_layer2 = nn.Linear(128,128)
        #self.classification_layer3 = nn.Linear(128,128)
        self.classification_layer4 = nn.Linear(128, 1)
        
    def forward(self, x):
        x = self.classification_layer0(x)
        x = F.relu(self.classification_layer1(x))
        x = F.relu(self.classification_layer2(x))
        #x = F.relu(self.classification_layer3(x))
        x = torch.sigmoid(self.classification_layer4(x))
        return x

# %% [markdown]
# ### Set the DANN

# %%
class dann(nn.Module):
    def __init__(self, lstm):
        super(dann, self).__init__()
        self.lstm = lstm
        self.regression = domain_regression()
        self.classification = domain_classfication()
        
    def forward(self, x):
        feature = self.lstm(x)
        reg_output = self.regression(feature)
        cla_output = self.classification(feature)
        
        return reg_output, cla_output

# %% [markdown]
# ### Loss 선언

# %%
class dann_loss(nn.Module):
    def __init__(self):
        super(dann_loss, self).__init__()
        self.reg = nn.L1Loss() # 회귀 L1 손실 == MAE
        self.cla = nn.BCEWithLogitsLoss() # 도메인 분류
        
    def forward(self, result, reg_real, domain_num, alpha=1):
        reg_output, cla_output = result
        batch_size = reg_output.shape[0]
        cla_target = torch.FloatTensor([domain_num] * batch_size).unsqueeze(1).to(device)
        
        reg_loss = self.reg(reg_output, reg_real)
        cla_loss = self.cla(cla_output, cla_target)
        loss = reg_loss * alpha + cla_loss * alpha
        return loss, reg_loss, cla_loss

# %%
my_lstm = lstm().to(device)
model = dann(my_lstm).to(device)
loss_fn = dann_loss().to(device)

# %% [markdown]
# # 훈련

# %%
from torch.optim.lr_scheduler import LinearLR

alpha = 1

my_lstm = lstm().to(device)
model = dann(my_lstm).to(device)
loss_fn = dann_loss().to(device)

epochs = 200

model.train() # 훈련 모드 설정

optimizer= torch.optim.Adamax(model.parameters(), lr=0.01)#lr = 0.001, weight_decay=0.01)
scheduler = LinearLR(optimizer, start_factor=1.0, end_factor=0.0, total_iters = epochs * len(NELEC_train))

best_source_loss = float('inf')
best_model_state_dict = None

for i in range(1, epochs + 1):
    total_loss = 0
    source_total_loss = 0
    target_total_loss = 0
    src_reg_total = 0
    src_cla_total = 0
    tar_reg_total = 0
    tar_cal_total = 0
    for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
        source_x = source_data[0].to(device)
        source_y = source_data[1].to(device)
        target_x = target_data[0].to(device)
        target_y = target_data[1].to(device)
        #print(source_x.shape)
        #print(source_y.shape)
        #print(target_x.shape)
        #print(target_y.shape)
        # 순전파
        source_result = model(source_x)
        target_result = model(target_x)
        #print(source_result[0].shape)
        #print(target_result[0].shape)
        #print(source_result[1].shape)
        #print(target_result[1].shape)
        # 순전파 loss
        source_loss, source_reg_loss, source_cla_loss = loss_fn(source_result, source_y, 0, alpha=alpha) # 소스 도메인 레이블 0
        target_loss, target_reg_loss, target_cla_loss = loss_fn(target_result, target_y, 1, alpha=alpha) # 타겟 도메인 레이블 1
        loss = source_loss + target_loss
        
        src_reg_total += source_reg_loss.item()
        src_cla_total += source_cla_loss.item()
        tar_reg_total += target_reg_loss.item()
        tar_cal_total += target_cla_loss.item()
        
        source_total_loss += source_loss.item()
        target_total_loss += target_loss.item()
        total_loss += loss.item()
        
        # 그래디언트 계산 및 업데이트
        optimizer.zero_grad()
        loss.backward()
        
        optimizer.step()
        scheduler.step()

    print('Epoch : %d, Total Avg Loss : %.4f' % (i, total_loss / len(NELEC_train)))     
    #print('Source Avg Loss : %.4f' % (source_total_loss / len(NELEC_train)))
    #print('Target Avg Loss : %.4f' % (target_total_loss / len(NELEC_train)))
    print('Source Avg reg Loss : %.4f' % (src_reg_total / len(NELEC_train)))
    print('Target Avg reg Loss : %.4f' % (tar_reg_total / len(NELEC_train)))
    print('Source Avg cla Loss : %.4f' % (src_cla_total / len(NELEC_train)))
    print('Target Avg cla Loss : %.4f' % (tar_cal_total / len(NELEC_train)))
    print('')
    
    # source_loss가 가장 낮은 경우 모델 가중치 저장
    if total_loss / len(NELEC_train) < best_source_loss:
        best_source_loss = total_loss / len(NELEC_train)
        best_model_state_dict = model.state_dict()

# 최상의 모델을 파일로 저장
if best_model_state_dict is not None:
    torch.save(best_model_state_dict, 'hoxy_model4.pth')
    #torch.save(model, "model.pth")
# Out:
# Epoch : 1, Total Avg Loss : 2.1342
# Source Avg reg Loss : 0.4529
# Target Avg reg Loss : 0.2304
# Source Avg cla Loss : 0.9800
# Target Avg cla Loss : 0.4708
#
# Epoch : 2, Total Avg Loss : 2.5734
# Source Avg reg Loss : 0.4702
# Target Avg reg Loss : 0.6975
# Source Avg cla Loss : 0.8371
# Target Avg cla Loss : 0.5686
#
# Epoch : 3, Total Avg Loss : 1.9328
# Source Avg reg Loss : 0.3325
# Target Avg reg Loss : 0.2100
# Source Avg cla Loss : 0.7553
# Target Avg cla Loss : 0.6350
#
# Epoch : 4, Total Avg Loss : 1.8307
# Source Avg reg Loss : 0.2346
# Target Avg reg Loss : 0.2097
# Source Avg cla Loss : 0.7003
# Target Avg cla Loss : 0.6861
#
# Epoch : 5, Total Avg Loss : 1.8509
# Source Avg reg Loss : 0.1501
# Target Avg reg Loss : 0.3145
# Source Avg cla Loss : 0.6939
# Target Avg cla Loss : 0.6924
#
# Epoch : 6, Total Avg Loss : 1.7813
# Source Avg reg Loss : 0.1699
# Target Avg reg Loss : 0.2251
# Source Avg cla Loss : 0.6933
# Target Avg cla Loss : 0.6930
#
# Epoch : 7, Total Avg Loss : 1.8090
# Source Avg reg Loss : 0.2153
# Target Avg reg Loss : 0.2075
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6931
#
# Epoch : 8, Total Avg Loss : 1.7956
# Source Avg reg Loss : 0.2040
# Target Avg reg Loss : 0.2054
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6931
#
# Epoch : 9, Total Avg Loss : 1.7571
# Source Avg reg Loss : 0.1551
# Target Avg reg Loss : 0.2157
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6931
#
# Epoch : 10, Total Avg Loss : 1.7647
# Source Avg reg Loss : 0.1305
# Target Avg reg Loss : 0.2479
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6931
#
# Epoch : 11, Total Avg Loss : 1.7266
# Source Avg reg Loss : 0.1274
# Target Avg reg Loss : 0.2129
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6931
#
# Epoch : 12, Total Avg Loss : 1.6912
# Source Avg reg Loss : 0.1546
# Target Avg reg Loss : 0.1504
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6931
#
# Epoch : 13, Total Avg Loss : 1.6941
# Source Avg reg Loss : 0.1907
# Target Avg reg Loss : 0.1172
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6931
#
# Epoch : 14, Total Avg Loss : 1.6788
# Source Avg reg Loss : 0.1977
# Target Avg reg Loss : 0.0954
# Source Avg cla Loss : 0.6933
# Target Avg cla Loss : 0.6925
#
# Epoch : 15, Total Avg Loss : 1.6671
# Source Avg reg Loss : 0.1749
# Target Avg reg Loss : 0.1077
# Source Avg cla Loss : 0.6934
# Target Avg cla Loss : 0.6911
#
# Epoch : 16, Total Avg Loss : 1.6516
# Source Avg reg Loss : 0.1415
# Target Avg reg Loss : 0.1257
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6912
#
# Epoch : 17, Total Avg Loss : 1.6542
# Source Avg reg Loss : 0.1428
# Target Avg reg Loss : 0.1266
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6916
#
# Epoch : 18, Total Avg Loss : 1.6500
# Source Avg reg Loss : 0.1546
# Target Avg reg Loss : 0.1120
# Source Avg cla Loss : 0.6932
# Target Avg cla Loss : 0.6903
#
# Epoch : 19, Total Avg Loss : 1.6168
# Source Avg reg Loss : 0.1539
# Target Avg reg Loss : 0.0866
# Source Avg cla Loss : 0.6933
# Target Avg cla Loss : 0.6829
#
# Epoch : 20, Total Avg Loss : 1.5952
# Source Avg reg Loss : 0.1481
# Target Avg reg Loss : 0.0744
# Source Avg cla Loss : 0.6942
# Target Avg cla Loss : 0.6785
#
# Epoch : 21, Total Avg Loss : 1.6147
# Source Avg reg Loss : 0.1501
# Target Avg reg Loss : 0.0836
# Source Avg cla Loss : 0.6952
# Target Avg cla Loss : 0.6858
#
# Epoch : 22, Total Avg Loss : 1.5968
# Source Avg reg Loss : 0.1309
# Target Avg reg Loss : 0.0849
# Source Avg cla Loss : 0.6943
# Target Avg cla Loss : 0.6868
#
# Epoch : 23, Total Avg Loss : 1.5735
# Source Avg reg Loss : 0.1157
# Target Avg reg Loss : 0.0783
# Source Avg cla Loss : 0.6936
# Target Avg cla Loss : 0.6860
#
# Epoch : 24, Total Avg Loss : 1.5719
# Source Avg reg Loss : 0.1205
# Target Avg reg Loss : 0.0705
# Source Avg cla Loss : 0.6934
# Target Avg cla Loss : 0.6875
#
# Epoch : 25, Total Avg Loss : 1.5673
# Source Avg reg Loss : 0.1213
# Target Avg reg Loss : 0.0623
# Source Avg cla Loss : 0.6935
# Target Avg cla Loss : 0.6901
#
# Epoch : 26, Total Avg Loss : 1.5529
# Source Avg reg Loss : 0.1036
# Target Avg reg Loss : 0.0641
# Source Avg cla Loss : 0.6937
# Target Avg cla Loss : 0.6915
#
# Epoch : 27, Total Avg Loss : 1.5508
# Source Avg reg Loss : 0.0872
# Target Avg reg Loss : 0.0786
# Source Avg cla Loss : 0.6937
# Target Avg cla Loss : 0.6913
#
# Epoch : 28, Total Avg Loss : 1.5446
# Source Avg reg Loss : 0.0918
# Target Avg reg Loss : 0.0669
# Source Avg cla Loss : 0.6941
# Target Avg cla Loss : 0.6918
#
# Epoch : 29, Total Avg Loss : 1.5295
# Source Avg reg Loss : 0.0822
# Target Avg reg Loss : 0.0626
# Source Avg cla Loss : 0.6937
# Target Avg cla Loss : 0.6910
#
# Epoch : 30, Total Avg Loss : 1.5265
# Source Avg reg Loss : 0.0834
# Target Avg reg Loss : 0.0593
# Source Avg cla Loss : 0.6937
# Target Avg cla Loss : 0.6901
#
# Epoch : 31, Total Avg Loss : 1.5232
# Source Avg reg Loss : 0.0816
# Target Avg reg Loss : 0.0586
# Source Avg cla Loss : 0.6938
# Target Avg cla Loss : 0.6892
#
# Epoch : 32, Total Avg Loss : 1.5150
# Source Avg reg Loss : 0.0781
# Target Avg reg Loss : 0.0545
# Source Avg cla Loss : 0.6941
# Target Avg cla Loss : 0.6884
#
# Epoch : 33, Total Avg Loss : 1.5133
# Source Avg reg Loss : 0.0807
# Target Avg reg Loss : 0.0508
# Source Avg cla Loss : 0.6945
# Target Avg cla Loss : 0.6873
#
# Epoch : 34, Total Avg Loss : 1.5498
# Source Avg reg Loss : 0.0904
# Target Avg reg Loss : 0.0766
# Source Avg cla Loss : 0.6967
# Target Avg cla Loss : 0.6861
#
# Epoch : 35, Total Avg Loss : 1.5386
# Source Avg reg Loss : 0.1036
# Target Avg reg Loss : 0.0583
# Source Avg cla Loss : 0.6951
# Target Avg cla Loss : 0.6815
#
# Epoch : 36, Total Avg Loss : 1.4957
# Source Avg reg Loss : 0.0744
# Target Avg reg Loss : 0.0456
# Source Avg cla Loss : 0.6965
# Target Avg cla Loss : 0.6792
#
# Epoch : 37, Total Avg Loss : 1.5182
# Source Avg reg Loss : 0.0840
# Target Avg reg Loss : 0.0608
# Source Avg cla Loss : 0.6986
# Target Avg cla Loss : 0.6748
#
# Epoch : 38, Total Avg Loss : 1.4825
# Source Avg reg Loss : 0.0729
# Target Avg reg Loss : 0.0452
# Source Avg cla Loss : 0.6973
# Target Avg cla Loss : 0.6671
#
# Epoch : 39, Total Avg Loss : 1.4857
# Source Avg reg Loss : 0.0755
# Target Avg reg Loss : 0.0506
# Source Avg cla Loss : 0.6973
# Target Avg cla Loss : 0.6622
#
# Epoch : 40, Total Avg Loss : 1.4818
# Source Avg reg Loss : 0.0736
# Target Avg reg Loss : 0.0484
# Source Avg cla Loss : 0.7007
# Target Avg cla Loss : 0.6591
#
# Epoch : 41, Total Avg Loss : 1.4785
# Source Avg reg Loss : 0.0718
# Target Avg reg Loss : 0.0493
# Source Avg cla Loss : 0.7028
# Target Avg cla Loss : 0.6546
#
# Epoch : 42, Total Avg Loss : 1.4726
# Source Avg reg Loss : 0.0761
# Target Avg reg Loss : 0.0445
# Source Avg cla Loss : 0.7016
# Target Avg cla Loss : 0.6504
#
# Epoch : 43, Total Avg Loss : 1.4643
# Source Avg reg Loss : 0.0731
# Target Avg reg Loss : 0.0430
# Source Avg cla Loss : 0.7032
# Target Avg cla Loss : 0.6449
#
# Epoch : 44, Total Avg Loss : 1.4649
# Source Avg reg Loss : 0.0717
# Target Avg reg Loss : 0.0488
# Source Avg cla Loss : 0.7070
# Target Avg cla Loss : 0.6374
#
# Epoch : 45, Total Avg Loss : 1.4486
# Source Avg reg Loss : 0.0691
# Target Avg reg Loss : 0.0437
# Source Avg cla Loss : 0.7058
# Target Avg cla Loss : 0.6300
#
# Epoch : 46, Total Avg Loss : 1.4409
# Source Avg reg Loss : 0.0698
# Target Avg reg Loss : 0.0438
# Source Avg cla Loss : 0.7029
# Target Avg cla Loss : 0.6244
#
# Epoch : 47, Total Avg Loss : 1.4265
# Source Avg reg Loss : 0.0666
# Target Avg reg Loss : 0.0410
# Source Avg cla Loss : 0.7043
# Target Avg cla Loss : 0.6145
#
# Epoch : 48, Total Avg Loss : 1.4213
# Source Avg reg Loss : 0.0707
# Target Avg reg Loss : 0.0409
# Source Avg cla Loss : 0.7078
# Target Avg cla Loss : 0.6019
#
# Epoch : 49, Total Avg Loss : 1.4130
# Source Avg reg Loss : 0.0672
# Target Avg reg Loss : 0.0419
# Source Avg cla Loss : 0.7075
# Target Avg cla Loss : 0.5964
#
# Epoch : 50, Total Avg Loss : 1.4158
# Source Avg reg Loss : 0.0655
# Target Avg reg Loss : 0.0513
# Source Avg cla Loss : 0.7073
# Target Avg cla Loss : 0.5917
#
# Epoch : 51, Total Avg Loss : 1.3941
# Source Avg reg Loss : 0.0682
# Target Avg reg Loss : 0.0400
# Source Avg cla Loss : 0.7119
# Target Avg cla Loss : 0.5740
#
# Epoch : 52, Total Avg Loss : 1.3840
# Source Avg reg Loss : 0.0650
# Target Avg reg Loss : 0.0398
# Source Avg cla Loss : 0.7105
# Target Avg cla Loss : 0.5687
#
# Epoch : 53, Total Avg Loss : 1.3864
# Source Avg reg Loss : 0.0639
# Target Avg reg Loss : 0.0474
# Source Avg cla Loss : 0.7055
# Target Avg cla Loss : 0.5697
#
# Epoch : 54, Total Avg Loss : 1.3668
# Source Avg reg Loss : 0.0641
# Target Avg reg Loss : 0.0380
# Source Avg cla Loss : 0.7075
# Target Avg cla Loss : 0.5572
#
# Epoch : 55, Total Avg Loss : 1.3600
# Source Avg reg Loss : 0.0636
# Target Avg reg Loss : 0.0375
# Source Avg cla Loss : 0.7053
# Target Avg cla Loss : 0.5536
#
# Epoch : 56, Total Avg Loss : 1.3636
# Source Avg reg Loss : 0.0627
# Target Avg reg Loss : 0.0446
# Source Avg cla Loss : 0.7004
# Target Avg cla Loss : 0.5559
#
# Epoch : 57, Total Avg Loss : 1.3469
# Source Avg reg Loss : 0.0623
# Target Avg reg Loss : 0.0370
# Source Avg cla Loss : 0.7020
# Target Avg cla Loss : 0.5456
#
# Epoch : 58, Total Avg Loss : 1.3417
# Source Avg reg Loss : 0.0623
# Target Avg reg Loss : 0.0372
# Source Avg cla Loss : 0.7012
# Target Avg cla Loss : 0.5410
#
# Epoch : 59, Total Avg Loss : 1.3474
# Source Avg reg Loss : 0.0599
# Target Avg reg Loss : 0.0457
# Source Avg cla Loss : 0.6987
# Target Avg cla Loss : 0.5431
#
# Epoch : 60, Total Avg Loss : 1.3331
# Source Avg reg Loss : 0.0605
# Target Avg reg Loss : 0.0381
# Source Avg cla Loss : 0.7013
# Target Avg cla Loss : 0.5331
#
# Epoch : 61, Total Avg Loss : 1.3285
# Source Avg reg Loss : 0.0614
# Target Avg reg Loss : 0.0370
# Source Avg cla Loss : 0.7036
# Target Avg cla Loss : 0.5265
#
# Epoch : 62, Total Avg Loss : 1.3309
# Source Avg reg Loss : 0.0583
# Target Avg reg Loss : 0.0427
# Source Avg cla Loss : 0.7020
# Target Avg cla Loss : 0.5279
#
# Epoch : 63, Total Avg Loss : 1.3215
# Source Avg reg Loss : 0.0583
# Target Avg reg Loss : 0.0372
# Source Avg cla Loss : 0.7068
# Target Avg cla Loss : 0.5192
#
# Epoch : 64, Total Avg Loss : 1.3198
# Source Avg reg Loss : 0.0605
# Target Avg reg Loss : 0.0355
# Source Avg cla Loss : 0.7126
# Target Avg cla Loss : 0.5112
#
# Epoch : 65, Total Avg Loss : 1.3185
# Source Avg reg Loss : 0.0576
# Target Avg reg Loss : 0.0375
# Source Avg cla Loss : 0.7102
# Target Avg cla Loss : 0.5133
#
# Epoch : 66, Total Avg Loss : 1.3168
# Source Avg reg Loss : 0.0572
# Target Avg reg Loss : 0.0358
# Source Avg cla Loss : 0.7120
# Target Avg cla Loss : 0.5117
#
# Epoch : 67, Total Avg Loss : 1.3177
# Source Avg reg Loss : 0.0590
# Target Avg reg Loss : 0.0349
# Source Avg cla Loss : 0.7154
# Target Avg cla Loss : 0.5084
#
# Epoch : 68, Total Avg Loss : 1.3170
# Source Avg reg Loss : 0.0572
# Target Avg reg Loss : 0.0353
# Source Avg cla Loss : 0.7113
# Target Avg cla Loss : 0.5133
#
# Epoch : 69, Total Avg Loss : 1.3182
# Source Avg reg Loss : 0.0576
# Target Avg reg Loss : 0.0351
# Source Avg cla Loss : 0.7106
# Target Avg cla Loss : 0.5149
#
# Epoch : 70, Total Avg Loss : 1.3193
# Source Avg reg Loss : 0.0587
# Target Avg reg Loss : 0.0344
# Source Avg cla Loss : 0.7119
# Target Avg cla Loss : 0.5144
#
# Epoch : 71, Total Avg Loss : 1.3192
# Source Avg reg Loss : 0.0576
# Target Avg reg Loss : 0.0351
# Source Avg cla Loss : 0.7082
# Target Avg cla Loss : 0.5183
#
# Epoch : 72, Total Avg Loss : 1.3195
# Source Avg reg Loss : 0.0573
# Target Avg reg Loss : 0.0349
# Source Avg cla Loss : 0.7082
# Target Avg cla Loss : 0.5191
#
# Epoch : 73, Total Avg Loss : 1.3198
# Source Avg reg Loss : 0.0577
# Target Avg reg Loss : 0.0344
# Source Avg cla Loss : 0.7093
# Target Avg cla Loss : 0.5184
#
# Epoch : 74, Total Avg Loss : 1.3204
# Source Avg reg Loss : 0.0569
# Target Avg reg Loss : 0.0346
# Source Avg cla Loss : 0.7078
# Target Avg cla Loss : 0.5211
#
# Epoch : 75, Total Avg Loss : 1.3204
# Source Avg reg Loss : 0.0569
# Target Avg reg Loss : 0.0343
# Source Avg cla Loss : 0.7094
# Target Avg cla Loss : 0.5197
#
# Epoch : 76, Total Avg Loss : 1.3204
# Source Avg reg Loss : 0.0563
# Target Avg reg Loss : 0.0343
# Source Avg cla Loss : 0.7103
# Target Avg cla Loss : 0.5195
#
# Epoch : 77, Total Avg Loss : 1.3204
# Source Avg reg Loss : 0.0556
# Target Avg reg Loss : 0.0349
# Source Avg cla Loss : 0.7089
# Target Avg cla Loss : 0.5209
#
# Epoch : 78, Total Avg Loss : 1.3252
# Source Avg reg Loss : 0.0579
# Target Avg reg Loss : 0.0352
# Source Avg cla Loss : 0.7147
# Target Avg cla Loss : 0.5174
#
# Epoch : 79, Total Avg Loss : 1.3250
# Source Avg reg Loss : 0.0555
# Target Avg reg Loss : 0.0377
# Source Avg cla Loss : 0.7094
# Target Avg cla Loss : 0.5224
#
# Epoch : 80, Total Avg Loss : 1.3412
# Source Avg reg Loss : 0.0639
# Target Avg reg Loss : 0.0402
# Source Avg cla Loss : 0.7248
# Target Avg cla Loss : 0.5123
#
# Epoch : 81, Total Avg Loss : 1.3267
# Source Avg reg Loss : 0.0584
# Target Avg reg Loss : 0.0355
# Source Avg cla Loss : 0.7110
# Target Avg cla Loss : 0.5219
#
# Epoch : 82, Total Avg Loss : 1.3284
# Source Avg reg Loss : 0.0588
# Target Avg reg Loss : 0.0337
# Source Avg cla Loss : 0.7182
# Target Avg cla Loss : 0.5176
#
# Epoch : 83, Total Avg Loss : 1.3309
# Source Avg reg Loss : 0.0589
# Target Avg reg Loss : 0.0342
# Source Avg cla Loss : 0.7199
# Target Avg cla Loss : 0.5178
#
# Epoch : 84, Total Avg Loss : 1.3308
# Source Avg reg Loss : 0.0586
# Target Avg reg Loss : 0.0341
# Source Avg cla Loss : 0.7162
# Target Avg cla Loss : 0.5220
#
# Epoch : 85, Total Avg Loss : 1.3355
# Source Avg reg Loss : 0.0606
# Target Avg reg Loss : 0.0336
# Source Avg cla Loss : 0.7219
# Target Avg cla Loss : 0.5194
#
# Epoch : 86, Total Avg Loss : 1.3386
# Source Avg reg Loss : 0.0617
# Target Avg reg Loss : 0.0337
# Source Avg cla Loss : 0.7236
# Target Avg cla Loss : 0.5195
#
# Epoch : 87, Total Avg Loss : 1.3451
# Source Avg reg Loss : 0.0638
# Target Avg reg Loss : 0.0343
# Source Avg cla Loss : 0.7273
# Target Avg cla Loss : 0.5196
#
# Epoch : 88, Total Avg Loss : 1.3718
# Source Avg reg Loss : 0.0747
# Target Avg reg Loss : 0.0364
# Source Avg cla Loss : 0.7495
# Target Avg cla Loss : 0.5112
#
# Epoch : 89, Total Avg Loss : 1.3731
# Source Avg reg Loss : 0.0749
# Target Avg reg Loss : 0.0339
# Source Avg cla Loss : 0.7520
# Target Avg cla Loss : 0.5123
#
# Epoch : 90, Total Avg Loss : 1.4020
# Source Avg reg Loss : 0.0845
# Target Avg reg Loss : 0.0355
# Source Avg cla Loss : 0.7765
# Target Avg cla Loss : 0.5055
#
# Epoch : 91, Total Avg Loss : 1.4494
# Source Avg reg Loss : 0.1003
# Target Avg reg Loss : 0.0406
# Source Avg cla Loss : 0.8136
# Target Avg cla Loss : 0.4948
#
# Epoch : 92, Total Avg Loss : 1.4465
# Source Avg reg Loss : 0.0961
# Target Avg reg Loss : 0.0421
# Source Avg cla Loss : 0.8076
# Target Avg cla Loss : 0.5008
#
# Epoch : 93, Total Avg Loss : 1.5204
# Source Avg reg Loss : 0.1234
# Target Avg reg Loss : 0.0491
# Source Avg cla Loss : 0.8653
# Target Avg cla Loss : 0.4827
#
# Epoch : 94, Total Avg Loss : 1.4988
# Source Avg reg Loss : 0.1107
# Target Avg reg Loss : 0.0427
# Source Avg cla Loss : 0.8560
# Target Avg cla Loss : 0.4893
#
# Epoch : 95, Total Avg Loss : 1.5097
# Source Avg reg Loss : 0.1103
# Target Avg reg Loss : 0.0456
# Source Avg cla Loss : 0.8659
# Target Avg cla Loss : 0.4879
#
# Epoch : 96, Total Avg Loss : 1.5950
# Source Avg reg Loss : 0.1372
# Target Avg reg Loss : 0.0554
# Source Avg cla Loss : 0.9391
# Target Avg cla Loss : 0.4633
#
# Epoch : 97, Total Avg Loss : 1.6147
# Source Avg reg Loss : 0.1333
# Target Avg reg Loss : 0.0547
# Source Avg cla Loss : 0.9709
# Target Avg cla Loss : 0.4559
#
# Epoch : 98, Total Avg Loss : 1.6228
# Source Avg reg Loss : 0.1176
# Target Avg reg Loss : 0.0580
# Source Avg cla Loss : 0.9989
# Target Avg cla Loss : 0.4483
#
# Epoch : 99, Total Avg Loss : 1.7197
# Source Avg reg Loss : 0.1276
# Target Avg reg Loss : 0.0693
# Source Avg cla Loss : 1.1082
# Target Avg cla Loss : 0.4146
#
# Epoch : 100, Total Avg Loss : 1.7923
# Source Avg reg Loss : 0.1298
# Target Avg reg Loss : 0.0859
# Source Avg cla Loss : 1.1946
# Target Avg cla Loss : 0.3820
#
# Epoch : 101, Total Avg Loss : 1.8071
# Source Avg reg Loss : 0.1160
# Target Avg reg Loss : 0.1042
# Source Avg cla Loss : 1.2182
# Target Avg cla Loss : 0.3687
#
# Epoch : 102, Total Avg Loss : 1.8184
# Source Avg reg Loss : 0.1209
# Target Avg reg Loss : 0.1017
# Source Avg cla Loss : 1.2387
# Target Avg cla Loss : 0.3571
#
# Epoch : 103, Total Avg Loss : 1.8230
# Source Avg reg Loss : 0.1362
# Target Avg reg Loss : 0.0910
# Source Avg cla Loss : 1.2478
# Target Avg cla Loss : 0.3480
#
# Epoch : 104, Total Avg Loss : 1.8150
# Source Avg reg Loss : 0.1490
# Target Avg reg Loss : 0.0880
# Source Avg cla Loss : 1.2223
# Target Avg cla Loss : 0.3556
#
# Epoch : 105, Total Avg Loss : 1.7576
# Source Avg reg Loss : 0.1420
# Target Avg reg Loss : 0.0815
# Source Avg cla Loss : 1.1577
# Target Avg cla Loss : 0.3764
#
# Epoch : 106, Total Avg Loss : 1.7317
# Source Avg reg Loss : 0.1472
# Target Avg reg Loss : 0.0832
# Source Avg cla Loss : 1.1134
# Target Avg cla Loss : 0.3880
#
# Epoch : 107, Total Avg Loss : 1.7299
# Source Avg reg Loss : 0.1643
# Target Avg reg Loss : 0.0863
# Source Avg cla Loss : 1.0795
# Target Avg cla Loss : 0.3998
#
# Epoch : 108, Total Avg Loss : 1.7001
# Source Avg reg Loss : 0.1609
# Target Avg reg Loss : 0.0933
# Source Avg cla Loss : 1.0032
# Target Avg cla Loss : 0.4427
#
# Epoch : 109, Total Avg Loss : 1.6524
# Source Avg reg Loss : 0.1321
# Target Avg reg Loss : 0.1110
# Source Avg cla Loss : 0.8961
# Target Avg cla Loss : 0.5132
#
# Epoch : 110, Total Avg Loss : 1.6473
# Source Avg reg Loss : 0.1264
# Target Avg reg Loss : 0.1166
# Source Avg cla Loss : 0.8353
# Target Avg cla Loss : 0.5689
#
# Epoch : 111, Total Avg Loss : 1.6412
# Source Avg reg Loss : 0.1357
# Target Avg reg Loss : 0.1045
# Source Avg cla Loss : 0.7976
# Target Avg cla Loss : 0.6034
#
# Epoch : 112, Total Avg Loss : 1.6051
# Source Avg reg Loss : 0.1219
# Target Avg reg Loss : 0.0913
# Source Avg cla Loss : 0.7646
# Target Avg cla Loss : 0.6272
#
# Epoch : 113, Total Avg Loss : 1.5887
# Source Avg reg Loss : 0.1215
# Target Avg reg Loss : 0.0762
# Source Avg cla Loss : 0.7508
# Target Avg cla Loss : 0.6402
#
# Epoch : 114, Total Avg Loss : 1.5843
# Source Avg reg Loss : 0.1304
# Target Avg reg Loss : 0.0605
# Source Avg cla Loss : 0.7503
# Target Avg cla Loss : 0.6431
#
# Epoch : 115, Total Avg Loss : 1.5777
# Source Avg reg Loss : 0.1246
# Target Avg reg Loss : 0.0594
# Source Avg cla Loss : 0.7492
# Target Avg cla Loss : 0.6444
#
# Epoch : 116, Total Avg Loss : 1.5706
# Source Avg reg Loss : 0.1156
# Target Avg reg Loss : 0.0581
# Source Avg cla Loss : 0.7539
# Target Avg cla Loss : 0.6430
#
# Epoch : 117, Total Avg Loss : 1.5619
# Source Avg reg Loss : 0.1083
# Target Avg reg Loss : 0.0531
# Source Avg cla Loss : 0.7656
# Target Avg cla Loss : 0.6349
#
# Epoch : 118, Total Avg Loss : 1.5617
# Source Avg reg Loss : 0.0976
# Target Avg reg Loss : 0.0565
# Source Avg cla Loss : 0.7814
# Target Avg cla Loss : 0.6261
#
# Epoch : 119, Total Avg Loss : 1.5744
# Source Avg reg Loss : 0.0935
# Target Avg reg Loss : 0.0594
# Source Avg cla Loss : 0.8082
# Target Avg cla Loss : 0.6133
#
# Epoch : 120, Total Avg Loss : 1.5963
# Source Avg reg Loss : 0.0929
# Target Avg reg Loss : 0.0579
# Source Avg cla Loss : 0.8478
# Target Avg cla Loss : 0.5976
#
# Epoch : 121, Total Avg Loss : 1.6341
# Source Avg reg Loss : 0.0922
# Target Avg reg Loss : 0.0564
# Source Avg cla Loss : 0.8990
# Target Avg cla Loss : 0.5864
#
# Epoch : 122, Total Avg Loss : 1.6839
# Source Avg reg Loss : 0.0952
# Target Avg reg Loss : 0.0638
# Source Avg cla Loss : 0.9326
# Target Avg cla Loss : 0.5922
#
# Epoch : 123, Total Avg Loss : 1.6972
# Source Avg reg Loss : 0.1022
# Target Avg reg Loss : 0.0616
# Source Avg cla Loss : 0.9308
# Target Avg cla Loss : 0.6027
#
# Epoch : 124, Total Avg Loss : 1.6975
# Source Avg reg Loss : 0.1083
# Target Avg reg Loss : 0.0570
# Source Avg cla Loss : 0.9289
# Target Avg cla Loss : 0.6033
#
# Epoch : 125, Total Avg Loss : 1.6776
# Source Avg reg Loss : 0.0958
# Target Avg reg Loss : 0.0542
# Source Avg cla Loss : 0.9251
# Target Avg cla Loss : 0.6026
#
# Epoch : 126, Total Avg Loss : 1.6667
# Source Avg reg Loss : 0.0867
# Target Avg reg Loss : 0.0570
# Source Avg cla Loss : 0.9229
# Target Avg cla Loss : 0.6001
#
# Epoch : 127, Total Avg Loss : 1.6703
# Source Avg reg Loss : 0.0873
# Target Avg reg Loss : 0.0570
# Source Avg cla Loss : 0.9348
# Target Avg cla Loss : 0.5911
#
# Epoch : 128, Total Avg Loss : 1.6733
# Source Avg reg Loss : 0.0880
# Target Avg reg Loss : 0.0577
# Source Avg cla Loss : 0.9405
# Target Avg cla Loss : 0.5871
#
# Epoch : 129, Total Avg Loss : 1.6672
# Source Avg reg Loss : 0.0841
# Target Avg reg Loss : 0.0563
# Source Avg cla Loss : 0.9359
# Target Avg cla Loss : 0.5910
#
# Epoch : 130, Total Avg Loss : 1.6640
# Source Avg reg Loss : 0.0814
# Target Avg reg Loss : 0.0542
# Source Avg cla Loss : 0.9286
# Target Avg cla Loss : 0.5998
#
# Epoch : 131, Total Avg Loss : 1.6604
# Source Avg reg Loss : 0.0790
# Target Avg reg Loss : 0.0521
# Source Avg cla Loss : 0.9211
# Target Avg cla Loss : 0.6081
#
# Epoch : 132, Total Avg Loss : 1.6595
# Source Avg reg Loss : 0.0785
# Target Avg reg Loss : 0.0510
# Source Avg cla Loss : 0.9164
# Target Avg cla Loss : 0.6136
#
# Epoch : 133, Total Avg Loss : 1.6495
# Source Avg reg Loss : 0.0732
# Target Avg reg Loss : 0.0484
# Source Avg cla Loss : 0.9103
# Target Avg cla Loss : 0.6177
#
# Epoch : 134, Total Avg Loss : 1.6411
# Source Avg reg Loss : 0.0700
# Target Avg reg Loss : 0.0453
# Source Avg cla Loss : 0.9081
# Target Avg cla Loss : 0.6177
#
# Epoch : 135, Total Avg Loss : 1.6394
# Source Avg reg Loss : 0.0704
# Target Avg reg Loss : 0.0431
# Source Avg cla Loss : 0.9115
# Target Avg cla Loss : 0.6144
#
# Epoch : 136, Total Avg Loss : 1.6333
# Source Avg reg Loss : 0.0691
# Target Avg reg Loss : 0.0418
# Source Avg cla Loss : 0.9100
# Target Avg cla Loss : 0.6124
#
# Epoch : 137, Total Avg Loss : 1.6257
# Source Avg reg Loss : 0.0670
# Target Avg reg Loss : 0.0409
# Source Avg cla Loss : 0.9062
# Target Avg cla Loss : 0.6115
#
# Epoch : 138, Total Avg Loss : 1.6250
# Source Avg reg Loss : 0.0679
# Target Avg reg Loss : 0.0403
# Source Avg cla Loss : 0.9074
# Target Avg cla Loss : 0.6095
#
# Epoch : 139, Total Avg Loss : 1.6259
# Source Avg reg Loss : 0.0689
# Target Avg reg Loss : 0.0399
# Source Avg cla Loss : 0.9085
# Target Avg cla Loss : 0.6086
#
# Epoch : 140, Total Avg Loss : 1.6229
# Source Avg reg Loss : 0.0673
# Target Avg reg Loss : 0.0393
# Source Avg cla Loss : 0.9035
# Target Avg cla Loss : 0.6128
#
# Epoch : 141, Total Avg Loss : 1.6228
# Source Avg reg Loss : 0.0662
# Target Avg reg Loss : 0.0402
# Source Avg cla Loss : 0.8970
# Target Avg cla Loss : 0.6194
#
# Epoch : 142, Total Avg Loss : 1.6271
# Source Avg reg Loss : 0.0673
# Target Avg reg Loss : 0.0398
# Source Avg cla Loss : 0.8965
# Target Avg cla Loss : 0.6234
#
# Epoch : 143, Total Avg Loss : 1.6324
# Source Avg reg Loss : 0.0692
# Target Avg reg Loss : 0.0399
# Source Avg cla Loss : 0.8957
# Target Avg cla Loss : 0.6275
#
# Epoch : 144, Total Avg Loss : 1.6308
# Source Avg reg Loss : 0.0666
# Target Avg reg Loss : 0.0411
# Source Avg cla Loss : 0.8879
# Target Avg cla Loss : 0.6352
#
# Epoch : 145, Total Avg Loss : 1.6330
# Source Avg reg Loss : 0.0662
# Target Avg reg Loss : 0.0420
# Source Avg cla Loss : 0.8852
# Target Avg cla Loss : 0.6396
#
# Epoch : 146, Total Avg Loss : 1.6414
# Source Avg reg Loss : 0.0699
# Target Avg reg Loss : 0.0424
# Source Avg cla Loss : 0.8894
# Target Avg cla Loss : 0.6398
#
# Epoch : 147, Total Avg Loss : 1.6450
# Source Avg reg Loss : 0.0698
# Target Avg reg Loss : 0.0433
# Source Avg cla Loss : 0.8877
# Target Avg cla Loss : 0.6442
#
# Epoch : 148, Total Avg Loss : 1.6456
# Source Avg reg Loss : 0.0678
# Target Avg reg Loss : 0.0462
# Source Avg cla Loss : 0.8803
# Target Avg cla Loss : 0.6513
#
# Epoch : 149, Total Avg Loss : 1.6531
# Source Avg reg Loss : 0.0702
# Target Avg reg Loss : 0.0465
# Source Avg cla Loss : 0.8838
# Target Avg cla Loss : 0.6526
#
# Epoch : 150, Total Avg Loss : 1.6599
# Source Avg reg Loss : 0.0731
# Target Avg reg Loss : 0.0469
# Source Avg cla Loss : 0.8867
# Target Avg cla Loss : 0.6531
#
# Epoch : 151, Total Avg Loss : 1.6627
# Source Avg reg Loss : 0.0717
# Target Avg reg Loss : 0.0486
# Source Avg cla Loss : 0.8831
# Target Avg cla Loss : 0.6593
#
# Epoch : 152, Total Avg Loss : 1.6646
# Source Avg reg Loss : 0.0714
# Target Avg reg Loss : 0.0488
# Source Avg cla Loss : 0.8838
# Target Avg cla Loss : 0.6606
#
# Epoch : 153, Total Avg Loss : 1.6672
# Source Avg reg Loss : 0.0730
# Target Avg reg Loss : 0.0475
# Source Avg cla Loss : 0.8889
# Target Avg cla Loss : 0.6577
#
# Epoch : 154, Total Avg Loss : 1.6688
# Source Avg reg Loss : 0.0721
# Target Avg reg Loss : 0.0483
# Source Avg cla Loss : 0.8871
# Target Avg cla Loss : 0.6612
#
# Epoch : 155, Total Avg Loss : 1.6714
# Source Avg reg Loss : 0.0707
# Target Avg reg Loss : 0.0507
# Source Avg cla Loss : 0.8825
# Target Avg cla Loss : 0.6675
#
# Epoch : 156, Total Avg Loss : 1.6742
# Source Avg reg Loss : 0.0735
# Target Avg reg Loss : 0.0475
# Source Avg cla Loss : 0.8882
# Target Avg cla Loss : 0.6650
#
# Epoch : 157, Total Avg Loss : 1.6763
# Source Avg reg Loss : 0.0738
# Target Avg reg Loss : 0.0470
# Source Avg cla Loss : 0.8881
# Target Avg cla Loss : 0.6674
#
# Epoch : 158, Total Avg Loss : 1.6771
# Source Avg reg Loss : 0.0711
# Target Avg reg Loss : 0.0493
# Source Avg cla Loss : 0.8840
# Target Avg cla Loss : 0.6727
#
# Epoch : 159, Total Avg Loss : 1.6780
# Source Avg reg Loss : 0.0723
# Target Avg reg Loss : 0.0479
# Source Avg cla Loss : 0.8862
# Target Avg cla Loss : 0.6716
#
# Epoch : 160, Total Avg Loss : 1.6804
# Source Avg reg Loss : 0.0727
# Target Avg reg Loss : 0.0474
# Source Avg cla Loss : 0.8866
# Target Avg cla Loss : 0.6737
#
# Epoch : 161, Total Avg Loss : 1.6820
# Source Avg reg Loss : 0.0722
# Target Avg reg Loss : 0.0480
# Source Avg cla Loss : 0.8836
# Target Avg cla Loss : 0.6782
#
# Epoch : 162, Total Avg Loss : 1.6860
# Source Avg reg Loss : 0.0739
# Target Avg reg Loss : 0.0476
# Source Avg cla Loss : 0.8850
# Target Avg cla Loss : 0.6795
#
# Epoch : 163, Total Avg Loss : 1.6871
# Source Avg reg Loss : 0.0744
# Target Avg reg Loss : 0.0473
# Source Avg cla Loss : 0.8852
# Target Avg cla Loss : 0.6802
#
# Epoch : 164, Total Avg Loss : 1.6876
# Source Avg reg Loss : 0.0727
# Target Avg reg Loss : 0.0490
# Source Avg cla Loss : 0.8832
# Target Avg cla Loss : 0.6826
#
# Epoch : 165, Total Avg Loss : 1.6889
# Source Avg reg Loss : 0.0741
# Target Avg reg Loss : 0.0489
# Source Avg cla Loss : 0.8825
# Target Avg cla Loss : 0.6834
#
# Epoch : 166, Total Avg Loss : 1.6879
# Source Avg reg Loss : 0.0737
# Target Avg reg Loss : 0.0485
# Source Avg cla Loss : 0.8817
# Target Avg cla Loss : 0.6840
#
# Epoch : 167, Total Avg Loss : 1.6885
# Source Avg reg Loss : 0.0748
# Target Avg reg Loss : 0.0479
# Source Avg cla Loss : 0.8799
# Target Avg cla Loss : 0.6859
#
# Epoch : 168, Total Avg Loss : 1.6868
# Source Avg reg Loss : 0.0744
# Target Avg reg Loss : 0.0480
# Source Avg cla Loss : 0.8771
# Target Avg cla Loss : 0.6873
#
# Epoch : 169, Total Avg Loss : 1.6839
# Source Avg reg Loss : 0.0739
# Target Avg reg Loss : 0.0472
# Source Avg cla Loss : 0.8759
# Target Avg cla Loss : 0.6868
#
# Epoch : 170, Total Avg Loss : 1.6811
# Source Avg reg Loss : 0.0728
# Target Avg reg Loss : 0.0467
# Source Avg cla Loss : 0.8747
# Target Avg cla Loss : 0.6869
#
# Epoch : 171, Total Avg Loss : 1.6796
# Source Avg reg Loss : 0.0734
# Target Avg reg Loss : 0.0462
# Source Avg cla Loss : 0.8720
# Target Avg cla Loss : 0.6881
#
# Epoch : 172, Total Avg Loss : 1.6760
# Source Avg reg Loss : 0.0723
# Target Avg reg Loss : 0.0453
# Source Avg cla Loss : 0.8698
# Target Avg cla Loss : 0.6887
#
# Epoch : 173, Total Avg Loss : 1.6747
# Source Avg reg Loss : 0.0729
# Target Avg reg Loss : 0.0449
# Source Avg cla Loss : 0.8684
# Target Avg cla Loss : 0.6885
#
# Epoch : 174, Total Avg Loss : 1.6716
# Source Avg reg Loss : 0.0714
# Target Avg reg Loss : 0.0450
# Source Avg cla Loss : 0.8660
# Target Avg cla Loss : 0.6892
#
# Epoch : 175, Total Avg Loss : 1.6682
# Source Avg reg Loss : 0.0708
# Target Avg reg Loss : 0.0444
# Source Avg cla Loss : 0.8635
# Target Avg cla Loss : 0.6895
#
# Epoch : 176, Total Avg Loss : 1.6656
# Source Avg reg Loss : 0.0697
# Target Avg reg Loss : 0.0445
# Source Avg cla Loss : 0.8620
# Target Avg cla Loss : 0.6893
#
# Epoch : 177, Total Avg Loss : 1.6628
# Source Avg reg Loss : 0.0690
# Target Avg reg Loss : 0.0439
# Source Avg cla Loss : 0.8606
# Target Avg cla Loss : 0.6893
#
# Epoch : 178, Total Avg Loss : 1.6613
# Source Avg reg Loss : 0.0689
# Target Avg reg Loss : 0.0440
# Source Avg cla Loss : 0.8587
# Target Avg cla Loss : 0.6897
#
# Epoch : 179, Total Avg Loss : 1.6601
# Source Avg reg Loss : 0.0690
# Target Avg reg Loss : 0.0438
# Source Avg cla Loss : 0.8571
# Target Avg cla Loss : 0.6902
#
# Epoch : 180, Total Avg Loss : 1.6563
# Source Avg reg Loss : 0.0675
# Target Avg reg Loss : 0.0436
# Source Avg cla Loss : 0.8547
# Target Avg cla Loss : 0.6905
#
# Epoch : 181, Total Avg Loss : 1.6535
# Source Avg reg Loss : 0.0669
# Target Avg reg Loss : 0.0429
# Source Avg cla Loss : 0.8535
# Target Avg cla Loss : 0.6902
#
# Epoch : 182, Total Avg Loss : 1.6515
# Source Avg reg Loss : 0.0666
# Target Avg reg Loss : 0.0428
# Source Avg cla Loss : 0.8519
# Target Avg cla Loss : 0.6902
#
# Epoch : 183, Total Avg Loss : 1.6487
# Source Avg reg Loss : 0.0653
# Target Avg reg Loss : 0.0427
# Source Avg cla Loss : 0.8505
# Target Avg cla Loss : 0.6902
#
# Epoch : 184, Total Avg Loss : 1.6477
# Source Avg reg Loss : 0.0657
# Target Avg reg Loss : 0.0427
# Source Avg cla Loss : 0.8492
# Target Avg cla Loss : 0.6901
#
# Epoch : 185, Total Avg Loss : 1.6449
# Source Avg reg Loss : 0.0647
# Target Avg reg Loss : 0.0425
# Source Avg cla Loss : 0.8475
# Target Avg cla Loss : 0.6901
#
# Epoch : 186, Total Avg Loss : 1.6437
# Source Avg reg Loss : 0.0646
# Target Avg reg Loss : 0.0423
# Source Avg cla Loss : 0.8462
# Target Avg cla Loss : 0.6906
#
# Epoch : 187, Total Avg Loss : 1.6418
# Source Avg reg Loss : 0.0644
# Target Avg reg Loss : 0.0421
# Source Avg cla Loss : 0.8450
# Target Avg cla Loss : 0.6903
#
# Epoch : 188, Total Avg Loss : 1.6409
# Source Avg reg Loss : 0.0636
# Target Avg reg Loss : 0.0423
# Source Avg cla Loss : 0.8448
# Target Avg cla Loss : 0.6903
#
# Epoch : 189, Total Avg Loss : 1.6399
# Source Avg reg Loss : 0.0639
# Target Avg reg Loss : 0.0418
# Source Avg cla Loss : 0.8440
# Target Avg cla Loss : 0.6902
#
# Epoch : 190, Total Avg Loss : 1.6378
# Source Avg reg Loss : 0.0633
# Target Avg reg Loss : 0.0418
# Source Avg cla Loss : 0.8425
# Target Avg cla Loss : 0.6903
#
# Epoch : 191, Total Avg Loss : 1.6370
# Source Avg reg Loss : 0.0632
# Target Avg reg Loss : 0.0418
# Source Avg cla Loss : 0.8417
# Target Avg cla Loss : 0.6904
#
# Epoch : 192, Total Avg Loss : 1.6369
# Source Avg reg Loss : 0.0631
# Target Avg reg Loss : 0.0420
# Source Avg cla Loss : 0.8412
# Target Avg cla Loss : 0.6906
#
# Epoch : 193, Total Avg Loss : 1.6352
# Source Avg reg Loss : 0.0628
# Target Avg reg Loss : 0.0414
# Source Avg cla Loss : 0.8404
# Target Avg cla Loss : 0.6906
#
# Epoch : 194, Total Avg Loss : 1.6354
# Source Avg reg Loss : 0.0632
# Target Avg reg Loss : 0.0418
# Source Avg cla Loss : 0.8400
# Target Avg cla Loss : 0.6905
#
# Epoch : 195, Total Avg Loss : 1.6346
# Source Avg reg Loss : 0.0632
# Target Avg reg Loss : 0.0414
# Source Avg cla Loss : 0.8394
# Target Avg cla Loss : 0.6906
#
# Epoch : 196, Total Avg Loss : 1.6340
# Source Avg reg Loss : 0.0627
# Target Avg reg Loss : 0.0415
# Source Avg cla Loss : 0.8393
# Target Avg cla Loss : 0.6905
#
# Epoch : 197, Total Avg Loss : 1.6334
# Source Avg reg Loss : 0.0628
# Target Avg reg Loss : 0.0415
# Source Avg cla Loss : 0.8386
# Target Avg cla Loss : 0.6904
#
# Epoch : 198, Total Avg Loss : 1.6328
# Source Avg reg Loss : 0.0623
# Target Avg reg Loss : 0.0415
# Source Avg cla Loss : 0.8385
# Target Avg cla Loss : 0.6905
#
# Epoch : 199, Total Avg Loss : 1.6325
# Source Avg reg Loss : 0.0626
# Target Avg reg Loss : 0.0413
# Source Avg cla Loss : 0.8381
# Target Avg cla Loss : 0.6906
#
# Epoch : 200, Total Avg Loss : 1.6326
# Source Avg reg Loss : 0.0631
# Target Avg reg Loss : 0.0410
# Source Avg cla Loss : 0.8380
# Target Avg cla Loss : 0.6905

# %%
# from torchinfo import summary

# summary(model, (64,3,13))

# %% [markdown]
# # train 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('hoxy_model4.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []


for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    _, source_pred = best_source_model2(sourcex)
    _, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: -4.320203544755567
# TARGET R2 Score: -0.37208789407817733

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# # test 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('hoxy_model4.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []


for step, (source_data, target_data) in enumerate(zip(NELEC_test, DHW_test)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    _, source_pred = best_source_model2(sourcex)
    _, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: -4.100192745035084
# TARGET R2 Score: -0.1934104748176233

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# ### Domain Embedding Space 시각화

# %%
# 가장 앞 batch의 250개씩의 데이터만 샘플링
source_tsne = DataLoader(nelec_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

target_tsne = DataLoader(elec_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

source_tsne2 = next(iter(source_tsne))
target_tsne2 = next(iter(target_tsne))

source_x_TNSE = source_tsne2[0].to(device)
source_y_TNSE = source_tsne2[1].to(device)

target_x_TNSE = target_tsne2[0].to(device)
target_y_TNSE = target_tsne2[1].to(device)

# 학습된 모델의 LSTM 부분만 활용 (100차원 임베딩 벡터를 받아오는 과정)
source_vector = model.lstm(source_x_TNSE)
target_vector = model.lstm(target_x_TNSE)

# %%
from sklearn.manifold import TSNE

df = pd.DataFrame(np.concatenate([source_vector.cpu().detach().numpy(), target_vector.cpu().detach().numpy()]))

tsne_np = TSNE(n_components=2).fit_transform(df)
tsne_df = pd.DataFrame(tsne_np, columns=['component 0', 'component 1'])

# %%
tsne_df_0 = tsne_df.loc[:1000]
tsne_df_1 = tsne_df.loc[1000:]

plt.scatter(tsne_df_0['component 0'], tsne_df_0['component 1'], color='green', label='NELEC', alpha=0.5)
plt.scatter(tsne_df_1['component 0'], tsne_df_1['component 1'], color='red', label='ELEC', alpha=0.5)

plt.title('alpha = '+ str(alpha))
plt.xlabel('component 0')
plt.ylabel('component 1')
plt.legend()
plt.show()
