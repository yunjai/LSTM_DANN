# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.utils.data as data_util
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import MinMaxScaler
from torchsummary import summary
from sklearn.metrics import r2_score

# %%
CUDA = torch.cuda.is_available()
print(CUDA)

device = torch.device('cuda:0' if CUDA else 'cpu')
# Out:
# True

# %%
elec = pd.read_csv('elec_merge.csv')
nelec = pd.read_csv('n_elec_merge.csv')
dhw = pd.read_csv('dhw_merge.csv')

# %%
elec = elec.drop(['YEAR'], axis=1)
nelec = nelec.drop(['YEAR'], axis=1)
dhw = dhw.drop(['YEAR'], axis=1)

# %%
input_nelec = nelec.iloc[:-1,].reset_index(drop=True)
output_nelec = nelec[['n_elec']].iloc[1:].reset_index(drop=True)
output_nelec.columns = ['nelec']

input_elec = elec.iloc[:-1,].reset_index(drop=True)
output_elec = elec[['ELEC']].iloc[1:].reset_index(drop=True)
output_elec.columns = ['elec']

input_dhw = dhw.iloc[:-1,].reset_index(drop=True)
output_dhw = dhw[['DHW']].iloc[1:].reset_index(drop=True)
output_dhw.columns = ['dhw']

nelec = pd.concat([input_nelec, output_nelec], axis=1)
elec = pd.concat([input_elec, output_elec], axis=1)
dhw = pd.concat([input_dhw, output_dhw], axis=1)

# input_nelec = nelec.iloc[:-1,:-1].reset_index(drop=True)
# output_nelec = nelec[['n_elec']].iloc[:-1].reset_index(drop=True)
# output_nelec2 = nelec['n_elec'][1:].reset_index(drop=True)
# output_nelec['nelec'] = output_nelec2

# input_elec = elec.iloc[:-1,:-1].reset_index(drop=True)
# output_elec = elec[['ELEC']].iloc[:-1].reset_index(drop=True)
# output_elec2= elec['ELEC'][1:].reset_index(drop=True)
# output_elec['elec'] = output_elec2

# input_dhw = dhw.iloc[:-1,:-1].reset_index(drop=True)
# output_dhw = dhw[['DHW']].iloc[:-1].reset_index(drop=True)
# output_dhw2 = dhw['DHW'][1:].reset_index(drop=True)
# output_dhw['dhw'] = output_dhw2

# %%
scaler_nelec = MinMaxScaler()
scaler_elec = MinMaxScaler()
scaler_dhw = MinMaxScaler()

scaler_nelec.fit(nelec)
scaler_elec.fit(elec)
scaler_dhw.fit(dhw)

scaled_nelec = scaler_nelec.transform(nelec)
scaled_elec = scaler_elec.transform(elec)
scaled_dhw = scaler_dhw.transform(dhw)

nelec = pd.DataFrame(scaled_nelec, index=nelec.index, columns=nelec.columns)
elec = pd.DataFrame(scaled_elec, index=elec.index, columns=elec.columns)
dhw = pd.DataFrame(scaled_dhw, index=dhw.index, columns=dhw.columns)

# scaler_nelec = MinMaxScaler()
# scaler_elec = MinMaxScaler()
# scaler_dhw = MinMaxScaler()

# scaler_nelec.fit(input_nelec)
# scaler_elec.fit(input_elec)
# scaler_dhw.fit(input_dhw)

# scaled_nelec = scaler_nelec.transform(input_nelec)
# scaled_elec = scaler_elec.transform(input_elec)
# scaled_dhw = scaler_dhw.transform(input_dhw)

# nelec_x = pd.DataFrame(scaled_nelec, index=input_nelec.index, columns=input_nelec.columns)
# elec_x = pd.DataFrame(scaled_elec, index=input_elec.index, columns=input_elec.columns)
# dhw_x = pd.DataFrame(scaled_dhw, index=input_dhw.index, columns=input_dhw.columns)

# nelec = pd.concat([nelec_x, output_nelec], axis=1)
# elec = pd.concat([elec_x, output_elec], axis=1)
# dhw = pd.concat([dhw_x, output_dhw], axis=1)

# %%
standard_nelec = int(len(nelec) * 0.7)
standard_elec = int(len(elec) * 0.7)
standard_dhw = int(len(dhw) * 0.7)

nelec_train = nelec.iloc[:standard_nelec]
nelec_test = nelec.iloc[standard_nelec:].reset_index(drop=True)

elec_train = elec.iloc[:standard_elec]
elec_test = elec.iloc[standard_elec:].reset_index(drop=True)

dhw_train = dhw.iloc[:standard_dhw]
dhw_test = dhw.iloc[standard_dhw:].reset_index(drop=True)

# %%
nelec_trainx = nelec_train.drop(['nelec'], axis=1)
nelec_trainy = nelec_train[['nelec']]

nelec_testx = nelec_test.drop(['nelec'], axis=1)
nelec_testy = nelec_test[['nelec']]

elec_trainx = elec_train.drop(['elec'], axis=1)
elec_trainy = elec_train[['elec']]

elec_testx = elec_test.drop(['elec'], axis=1)
elec_testy = elec_test[['elec']]

dhw_trainx = dhw_train.drop(['dhw'], axis=1)
dhw_trainy = dhw_train[['dhw']]

dhw_testx = dhw_test.drop(['dhw'], axis=1)
dhw_testy = dhw_test[['dhw']]

# %%
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-7]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

nelec_trainx, nelec_trainy = buildDataSet(nelec_trainx, nelec_trainy, 7)
nelec_testx, nelec_testy = buildDataSet(nelec_testx, nelec_testy, 7)

elec_trainx, elec_trainy = buildDataSet(elec_trainx, elec_trainy, 7)
elec_testx, elec_testy = buildDataSet(elec_testx, elec_testy, 7)

dhw_trainx, dhw_trainy = buildDataSet(dhw_trainx, dhw_trainy, 7)
dhw_testx, dhw_testy = buildDataSet(dhw_testx, dhw_testy, 7)

# %%
print(nelec_trainx.shape)
print(nelec_trainy.shape)
print(nelec_testx.shape)
print(nelec_testy.shape)
print(elec_trainx.shape)
print(elec_trainy.shape)
print(elec_testx.shape)
print(elec_testy.shape)
print(dhw_trainx.shape)
print(dhw_trainy.shape)
print(dhw_testx.shape)
print(dhw_testy.shape)
# Out:
# (20409, 7, 12)
# (20409, 1)
# (8744, 7, 12)
# (8744, 1)
# (2984, 7, 12)
# (2984, 1)
# (1275, 7, 12)
# (1275, 1)
# (20409, 7, 12)
# (20409, 1)
# (8744, 7, 12)
# (8744, 1)

# %%
# 텐서로 변환
nelec_trainx_tensor = torch.FloatTensor(nelec_trainx)
nelec_trainy_tensor = torch.FloatTensor(nelec_trainy)

nelec_testx_tensor = torch.FloatTensor(nelec_testx)
nelec_testy_tensor = torch.FloatTensor(nelec_testy)

elec_trainx_tensor = torch.FloatTensor(elec_trainx)
elec_trainy_tensor = torch.FloatTensor(elec_trainy)

elec_testx_tensor = torch.FloatTensor(elec_testx)
elec_testy_tensor = torch.FloatTensor(elec_testy)

dhw_trainx_tensor = torch.FloatTensor(dhw_trainx)
dhw_trainy_tensor = torch.FloatTensor(dhw_trainy)

dhw_testx_tensor = torch.FloatTensor(dhw_testx)
dhw_testy_tensor = torch.FloatTensor(dhw_testy)

# %%
# 텐서 형태로 데이터 정의
nelec_train = TensorDataset(nelec_trainx_tensor, nelec_trainy_tensor)
nelec_test = TensorDataset(nelec_testx_tensor, nelec_testy_tensor)

elec_train = TensorDataset(elec_trainx_tensor, elec_trainy_tensor)
elec_test = TensorDataset(elec_testx_tensor, elec_testy_tensor)

dhw_train = TensorDataset(dhw_trainx_tensor, dhw_trainy_tensor)
dhw_test = TensorDataset(dhw_testx_tensor, dhw_testy_tensor)

# %%
batch_for_nelec_train = len(nelec_trainx)
batch_for_nelec_test = len(nelec_testx)
batch_for_elec_train = len(elec_trainx)
batch_for_elec_test = len(elec_testx)
batch_for_dhw_train = len(dhw_trainx)
batch_for_dhw_test = len(dhw_testx)

NELEC_train = DataLoader(nelec_train,
                        batch_size=1024,#batch_for_nelec_train,
                        shuffle=False,  
                        drop_last=True)

NELEC_test = DataLoader(nelec_test,
                        batch_size=1024,#batch_for_nelec_test,
                        shuffle=False,  
                        drop_last=True)

ELEC_train = DataLoader(elec_train,
                        batch_size=1024,#batch_for_elec_train,
                        shuffle=False,  
                        drop_last=True)

ELEC_test = DataLoader(elec_test,
                        batch_size=1024,#batch_for_elec_test,
                        shuffle=False,  
                        drop_last=True)

DHW_train = DataLoader(dhw_train,
                        batch_size=1024,#batch_for_dhw_train,
                        shuffle=False,  
                        drop_last=True)

DHW_test = DataLoader(dhw_test,
                        batch_size=1024,#batch_for_dhw_test,
                        shuffle=False,  
                        drop_last=True)

# %%
# # 데이터셋의 개수를 가정하여 변수에 저장
# nelec_train_size = len(nelec_train)
# nelec_test_size = len(nelec_test)
# elec_train_size = len(elec_train)
# elec_test_size = len(elec_test)
# dhw_train_size = len(dhw_train)
# dhw_test_size = len(dhw_test)

# # 각 DataLoader에서 생성되는 배치의 개수 계산
# nelec_train_batches = nelec_train_size // batch_for_nelec_train
# nelec_test_batches = nelec_test_size // batch_for_nelec_test
# elec_train_batches = elec_train_size // batch_for_elec_train
# elec_test_batches = elec_test_size // batch_for_elec_test
# dhw_train_batches = dhw_train_size // batch_for_dhw_train
# dhw_test_batches = dhw_test_size // batch_for_dhw_test

# # 결과 출력
# print("nelec_train batches:", nelec_train_batches)
# print("nelec_test batches:", nelec_test_batches)
# print("elec_train batches:", elec_train_batches)
# print("elec_test batches:", elec_test_batches)
# print("dhw_train batches:", dhw_train_batches)
# print("dhw_test batches:", dhw_test_batches)

# %% [markdown]
# # 모델 구조 선언

# %%
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ### GradientReversalLayer

# %%
class GradientReversalFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, x):
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return (grad_output * -1), None

class GradientReversalLayer(torch.nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x):
        return GradientReversalFunction.apply(x)

# %% [markdown]
# ### LSTM for Feature Extraction

# %%
class Swish(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return x * self.sigmoid(x)

# %%
class lstm(nn.Module):
    def __init__(self):
        super(lstm, self).__init__()
        self.lstm1 = nn.LSTM(12, 64, batch_first=True)
        self.bn1 = nn.BatchNorm1d(7)
        
        self.lstm2 = nn.LSTM(64, 64, batch_first=True)
        self.bn2 = nn.BatchNorm1d(7)
        
        self.lstm3 = nn.LSTM(64,64, batch_first=True)
        
        self.fc = nn.Linear(64, 64, bias=False)
        self.fc2 = nn.Linear(64, 100, bias=False)
        self.bn3 = nn.BatchNorm1d(7)
        
        self.dropout = nn.Dropout(0.5)
        self.swish = Swish()
        self.tanh = nn.Tanh()

        
    def forward(self, x):
        x, (h,c) = self.lstm1(x)
        x = self.bn1(x)
        x = self.tanh(x)

        x, (h, c) = self.lstm2(x, (h, c))
        x = self.bn2(x)
        x = self.tanh(x)
        
        x, _ = self.lstm3(x, (h, c))
        x = self.bn2(x)
        x = self.tanh(x)
        
        x = self.fc(x)
        x = self.bn3(x)
        x = self.fc2(x[:,-1,:])
        x = self.dropout(x)
        x = self.swish(x)
        return x

# %%
hoxy = lstm()
inputx = torch.randn(1024,7,12)
hoxy2 = hoxy(inputx)
print(hoxy2.shape)
# Out:
# torch.Size([1024, 100])

# %%
class domain_regression(nn.Module):
    def __init__(self):
        super(domain_regression, self).__init__()
        self.regression_layer1 = nn.Linear(100, 128)
        self.regression_layer2 = nn.Linear(128, 128)
        self.regression_layer3 = nn.Linear(128, 128)
        self.regression_layer4 = nn.Linear(128, 1)
        
    def forward(self, x):
        x = F.relu(self.regression_layer1(x))
        x = F.relu(self.regression_layer2(x))
        x = F.relu(self.regression_layer3(x))
        x = F.relu(self.regression_layer4(x))
        return x

# %% [markdown]
# ### Domain Classification

# %%
class domain_classfication(nn.Module):
    def __init__(self):
        super(domain_classfication, self).__init__()
        self.classification_layer0 = GradientReversalLayer()
        self.classification_layer1 = nn.Linear(100, 128)
        self.classification_layer2 = nn.Linear(128,128)
        #self.classification_layer3 = nn.Linear(128,128)
        self.classification_layer4 = nn.Linear(128, 1)
        
    def forward(self, x):
        x = self.classification_layer0(x)
        x = F.relu(self.classification_layer1(x))
        x = F.relu(self.classification_layer2(x))
        #x = F.relu(self.classification_layer3(x))
        x = torch.sigmoid(self.classification_layer4(x))
        return x

# %% [markdown]
# ### Set the DANN

# %%
class dann(nn.Module):
    def __init__(self, lstm):
        super(dann, self).__init__()
        self.lstm = lstm
        self.regression = domain_regression()
        self.classification = domain_classfication()
        
    def forward(self, x):
        feature = self.lstm(x)
        reg_output = self.regression(feature)
        cla_output = self.classification(feature)
        
        return reg_output, cla_output

# %% [markdown]
# ### Loss 선언

# %%
class dann_loss(nn.Module):
    def __init__(self):
        super(dann_loss, self).__init__()
        self.reg = nn.L1Loss() # 회귀 L1 손실 == MAE
        self.cla = nn.BCEWithLogitsLoss() # 도메인 분류
        
    def forward(self, result, reg_real, domain_num, alpha=1):
        reg_output, cla_output = result
        batch_size = reg_output.shape[0]
        cla_target = torch.FloatTensor([domain_num] * batch_size).unsqueeze(1).to(device)
        
        reg_loss = self.reg(reg_output, reg_real)
        cla_loss = self.cla(cla_output, cla_target)
        cla_loss2 = cla_loss * alpha
        
        loss = reg_loss + cla_loss2
        
        return loss, reg_loss, cla_loss2

# %%
my_lstm = lstm().to(device)
model = dann(my_lstm).to(device)
loss_fn = dann_loss().to(device)

# %% [markdown]
# # 훈련

# %%
from torch.optim.lr_scheduler import LinearLR

alpha = 1.0
epochs = 1000

model.train() # 훈련 모드 설정

optimizer= torch.optim.Adamax(model.parameters(), lr=0.01)#, weight_decay=0.01)
scheduler = LinearLR(optimizer, start_factor=1.0, end_factor=0.0, total_iters = epochs * len(NELEC_train))

patience = 200  # Early stopping을 위한 기다리는 최대 epoch 수
best_loss = float('inf')
best_source_loss = float('inf')
best_model_state_dict = None
counter = 10  # Early stopping 카운터

for i in range(1, epochs + 1):
    total_loss = 0
    source_total_loss = 0
    target_total_loss = 0
    src_reg_total = 0
    src_cla_total = 0
    tar_reg_total = 0
    tar_cal_total = 0
    reg_loss_total = 0
    cla_loss_total = 0
    for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
        source_x = source_data[0].to(device)
        source_y = source_data[1].to(device)
        target_x = target_data[0].to(device)
        target_y = target_data[1].to(device)
        #print(source_x.shape)
        #print(source_y.shape)
        #print(target_x.shape)
        #print(target_y.shape)
        # 순전파
        source_result = model(source_x)
        target_result = model(target_x)
        #print(source_result[0].shape)
        #print(target_result[0].shape)
        #print(source_result[1].shape)
        #print(target_result[1].shape)
        # 순전파 loss
        source_loss, source_reg_loss, source_cla_loss = loss_fn(source_result, source_y, 1, alpha=alpha) # 소스 도메인 레이블 1
        target_loss, target_reg_loss, target_cla_loss = loss_fn(target_result, target_y, 0, alpha=alpha) # 타겟 도메인 레이블 0
        
        loss = source_loss + target_loss
        reg_loss = source_reg_loss + target_reg_loss
        cla_loss = source_cla_loss + target_cla_loss
        
        src_reg_total += source_reg_loss.item()
        src_cla_total += source_cla_loss.item()
        tar_reg_total += target_reg_loss.item()
        tar_cal_total += target_cla_loss.item()
        
        source_total_loss += source_loss.item()
        target_total_loss += target_loss.item()
        
        reg_loss_total += reg_loss.item()
        cla_loss_total += cla_loss.item()
        
        total_loss += loss.item()
        
        # 그래디언트 계산 및 업데이트
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()
        
        # Early stopping 확인
    if reg_loss_total / len(NELEC_train) < best_loss:
        best_loss = reg_loss_total / len(NELEC_train)
        best_model_state_dict = model.state_dict()
        counter = 0  # Counter 초기화
    else:
        counter += 1
        if counter >= patience:
            print(f'Early stopping at epoch {i}')
            break

    print('Epoch : %d, Total Avg Loss : %.4f' % (i, total_loss / len(NELEC_train)))     
    print('Source Avg Loss : %.4f' % (source_total_loss / len(NELEC_train)))
    print('Target Avg Loss : %.4f' % (target_total_loss / len(NELEC_train)))
    print('Source Avg reg Loss : %.4f' % (src_reg_total / len(NELEC_train)))
    print('Target Avg reg Loss : %.4f' % (tar_reg_total / len(NELEC_train)))
    print('Source Avg cla Loss : %.4f' % (src_cla_total / len(NELEC_train)))
    print('Target Avg cla Loss : %.4f' % (tar_cal_total / len(NELEC_train)))
    print('Avg Regression Loss : %.4f' % (reg_loss_total / len(NELEC_train)))
    print('Avg Classification Loss : %.4f' % (cla_loss_total / len(NELEC_train)))
    print('')
    
    # source_loss가 가장 낮은 경우 모델 가중치 저장
    if reg_loss_total / len(NELEC_train) < best_source_loss:
        best_source_loss = reg_loss_total / len(NELEC_train)
        best_model_state_dict = model.state_dict()

# 최상의 모델을 파일로 저장
if best_model_state_dict is not None:
    torch.save(best_model_state_dict, '0810hoxyhoxy.pth')
    #torch.save(model, "model.pth")
# Out:
# Epoch : 1, Total Avg Loss : 1.8927
# Source Avg Loss : 0.9204
# Target Avg Loss : 0.9723
# Source Avg reg Loss : 0.2624
# Target Avg reg Loss : 0.2378
# Source Avg cla Loss : 0.6580
# Target Avg cla Loss : 0.7345
# Avg Regression Loss : 0.5002
# Avg Classification Loss : 1.3925
#
# Epoch : 2, Total Avg Loss : 1.8726
# Source Avg Loss : 0.9256
# Target Avg Loss : 0.9470
# Source Avg reg Loss : 0.2326
# Target Avg reg Loss : 0.2538
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.4863
# Avg Classification Loss : 1.3863
#
# Epoch : 3, Total Avg Loss : 1.8090
# Source Avg Loss : 0.8571
# Target Avg Loss : 0.9519
# Source Avg reg Loss : 0.1640
# Target Avg reg Loss : 0.2587
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.4227
# Avg Classification Loss : 1.3863
#
# Epoch : 4, Total Avg Loss : 1.7841
# Source Avg Loss : 0.8410
# Target Avg Loss : 0.9431
# Source Avg reg Loss : 0.1480
# Target Avg reg Loss : 0.2499
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.3979
# Avg Classification Loss : 1.3863
#
# Epoch : 5, Total Avg Loss : 1.7837
# Source Avg Loss : 0.8404
# Target Avg Loss : 0.9433
# Source Avg reg Loss : 0.1473
# Target Avg reg Loss : 0.2501
# Source Avg cla Loss : 0.6930
# Target Avg cla Loss : 0.6933
# Avg Regression Loss : 0.3974
# Avg Classification Loss : 1.3863
#
# Epoch : 6, Total Avg Loss : 1.7828
# Source Avg Loss : 0.8401
# Target Avg Loss : 0.9427
# Source Avg reg Loss : 0.1471
# Target Avg reg Loss : 0.2494
# Source Avg cla Loss : 0.6930
# Target Avg cla Loss : 0.6933
# Avg Regression Loss : 0.3965
# Avg Classification Loss : 1.3863
#
# Epoch : 7, Total Avg Loss : 1.7823
# Source Avg Loss : 0.8399
# Target Avg Loss : 0.9424
# Source Avg reg Loss : 0.1469
# Target Avg reg Loss : 0.2491
# Source Avg cla Loss : 0.6930
# Target Avg cla Loss : 0.6933
# Avg Regression Loss : 0.3960
# Avg Classification Loss : 1.3863
#
# Epoch : 8, Total Avg Loss : 1.7818
# Source Avg Loss : 0.8395
# Target Avg Loss : 0.9423
# Source Avg reg Loss : 0.1465
# Target Avg reg Loss : 0.2490
# Source Avg cla Loss : 0.6930
# Target Avg cla Loss : 0.6933
# Avg Regression Loss : 0.3955
# Avg Classification Loss : 1.3863
#
# Epoch : 9, Total Avg Loss : 1.7818
# Source Avg Loss : 0.8394
# Target Avg Loss : 0.9424
# Source Avg reg Loss : 0.1464
# Target Avg reg Loss : 0.2491
# Source Avg cla Loss : 0.6930
# Target Avg cla Loss : 0.6933
# Avg Regression Loss : 0.3955
# Avg Classification Loss : 1.3863
#
# Epoch : 10, Total Avg Loss : 1.7814
# Source Avg Loss : 0.8396
# Target Avg Loss : 0.9419
# Source Avg reg Loss : 0.1465
# Target Avg reg Loss : 0.2486
# Source Avg cla Loss : 0.6930
# Target Avg cla Loss : 0.6933
# Avg Regression Loss : 0.3952
# Avg Classification Loss : 1.3863
#
# Epoch : 11, Total Avg Loss : 1.7814
# Source Avg Loss : 0.8391
# Target Avg Loss : 0.9423
# Source Avg reg Loss : 0.1461
# Target Avg reg Loss : 0.2489
# Source Avg cla Loss : 0.6930
# Target Avg cla Loss : 0.6933
# Avg Regression Loss : 0.3951
# Avg Classification Loss : 1.3863
#
# Epoch : 12, Total Avg Loss : 1.7812
# Source Avg Loss : 0.8391
# Target Avg Loss : 0.9421
# Source Avg reg Loss : 0.1461
# Target Avg reg Loss : 0.2487
# Source Avg cla Loss : 0.6930
# Target Avg cla Loss : 0.6933
# Avg Regression Loss : 0.3949
# Avg Classification Loss : 1.3863
#
# Epoch : 13, Total Avg Loss : 1.7810
# Source Avg Loss : 0.8392
# Target Avg Loss : 0.9419
# Source Avg reg Loss : 0.1462
# Target Avg reg Loss : 0.2485
# Source Avg cla Loss : 0.6929
# Target Avg cla Loss : 0.6933
# Avg Regression Loss : 0.3948
# Avg Classification Loss : 1.3863
#
# Epoch : 14, Total Avg Loss : 1.7810
# Source Avg Loss : 0.8391
# Target Avg Loss : 0.9418
# Source Avg reg Loss : 0.1463
# Target Avg reg Loss : 0.2484
# Source Avg cla Loss : 0.6929
# Target Avg cla Loss : 0.6934
# Avg Regression Loss : 0.3947
# Avg Classification Loss : 1.3863
#
# Epoch : 15, Total Avg Loss : 1.7809
# Source Avg Loss : 0.8390
# Target Avg Loss : 0.9418
# Source Avg reg Loss : 0.1462
# Target Avg reg Loss : 0.2484
# Source Avg cla Loss : 0.6929
# Target Avg cla Loss : 0.6934
# Avg Regression Loss : 0.3946
# Avg Classification Loss : 1.3863
#
# Epoch : 16, Total Avg Loss : 1.7808
# Source Avg Loss : 0.8389
# Target Avg Loss : 0.9420
# Source Avg reg Loss : 0.1460
# Target Avg reg Loss : 0.2485
# Source Avg cla Loss : 0.6929
# Target Avg cla Loss : 0.6934
# Avg Regression Loss : 0.3945
# Avg Classification Loss : 1.3863
#
# Epoch : 17, Total Avg Loss : 1.7807
# Source Avg Loss : 0.8389
# Target Avg Loss : 0.9418
# Source Avg reg Loss : 0.1460
# Target Avg reg Loss : 0.2484
# Source Avg cla Loss : 0.6929
# Target Avg cla Loss : 0.6934
# Avg Regression Loss : 0.3944
# Avg Classification Loss : 1.3863
#
# Epoch : 18, Total Avg Loss : 1.7806
# Source Avg Loss : 0.8389
# Target Avg Loss : 0.9417
# Source Avg reg Loss : 0.1461
# Target Avg reg Loss : 0.2482
# Source Avg cla Loss : 0.6928
# Target Avg cla Loss : 0.6935
# Avg Regression Loss : 0.3943
# Avg Classification Loss : 1.3863
#
# Epoch : 19, Total Avg Loss : 1.7806
# Source Avg Loss : 0.8388
# Target Avg Loss : 0.9418
# Source Avg reg Loss : 0.1460
# Target Avg reg Loss : 0.2483
# Source Avg cla Loss : 0.6928
# Target Avg cla Loss : 0.6935
# Avg Regression Loss : 0.3943
# Avg Classification Loss : 1.3863
#
# Epoch : 20, Total Avg Loss : 1.7806
# Source Avg Loss : 0.8387
# Target Avg Loss : 0.9419
# Source Avg reg Loss : 0.1460
# Target Avg reg Loss : 0.2483
# Source Avg cla Loss : 0.6928
# Target Avg cla Loss : 0.6935
# Avg Regression Loss : 0.3943
# Avg Classification Loss : 1.3863
#
# Epoch : 21, Total Avg Loss : 1.7805
# Source Avg Loss : 0.8387
# Target Avg Loss : 0.9419
# Source Avg reg Loss : 0.1460
# Target Avg reg Loss : 0.2483
# Source Avg cla Loss : 0.6927
# Target Avg cla Loss : 0.6936
# Avg Regression Loss : 0.3943
# Avg Classification Loss : 1.3863
#
# Epoch : 22, Total Avg Loss : 1.7805
# Source Avg Loss : 0.8385
# Target Avg Loss : 0.9420
# Source Avg reg Loss : 0.1459
# Target Avg reg Loss : 0.2483
# Source Avg cla Loss : 0.6925
# Target Avg cla Loss : 0.6938
# Avg Regression Loss : 0.3942
# Avg Classification Loss : 1.3863
#
# Epoch : 23, Total Avg Loss : 1.7805
# Source Avg Loss : 0.8385
# Target Avg Loss : 0.9420
# Source Avg reg Loss : 0.1458
# Target Avg reg Loss : 0.2483
# Source Avg cla Loss : 0.6926
# Target Avg cla Loss : 0.6937
# Avg Regression Loss : 0.3941
# Avg Classification Loss : 1.3863
#
# Epoch : 24, Total Avg Loss : 1.7804
# Source Avg Loss : 0.8386
# Target Avg Loss : 0.9418
# Source Avg reg Loss : 0.1459
# Target Avg reg Loss : 0.2482
# Source Avg cla Loss : 0.6927
# Target Avg cla Loss : 0.6936
# Avg Regression Loss : 0.3941
# Avg Classification Loss : 1.3863
#
# Epoch : 25, Total Avg Loss : 1.7804
# Source Avg Loss : 0.8388
# Target Avg Loss : 0.9416
# Source Avg reg Loss : 0.1459
# Target Avg reg Loss : 0.2481
# Source Avg cla Loss : 0.6928
# Target Avg cla Loss : 0.6934
# Avg Regression Loss : 0.3941
# Avg Classification Loss : 1.3863
#
# Epoch : 26, Total Avg Loss : 1.7804
# Source Avg Loss : 0.8387
# Target Avg Loss : 0.9417
# Source Avg reg Loss : 0.1458
# Target Avg reg Loss : 0.2483
# Source Avg cla Loss : 0.6929
# Target Avg cla Loss : 0.6934
# Avg Regression Loss : 0.3941
# Avg Classification Loss : 1.3863
#
# Epoch : 27, Total Avg Loss : 1.7803
# Source Avg Loss : 0.8387
# Target Avg Loss : 0.9416
# Source Avg reg Loss : 0.1458
# Target Avg reg Loss : 0.2482
# Source Avg cla Loss : 0.6929
# Target Avg cla Loss : 0.6934
# Avg Regression Loss : 0.3940
# Avg Classification Loss : 1.3863
#
# Epoch : 28, Total Avg Loss : 1.7803
# Source Avg Loss : 0.8386
# Target Avg Loss : 0.9418
# Source Avg reg Loss : 0.1459
# Target Avg reg Loss : 0.2482
# Source Avg cla Loss : 0.6927
# Target Avg cla Loss : 0.6936
# Avg Regression Loss : 0.3940
# Avg Classification Loss : 1.3863
#
# Epoch : 29, Total Avg Loss : 1.7803
# Source Avg Loss : 0.8387
# Target Avg Loss : 0.9416
# Source Avg reg Loss : 0.1459
# Target Avg reg Loss : 0.2481
# Source Avg cla Loss : 0.6928
# Target Avg cla Loss : 0.6936
# Avg Regression Loss : 0.3940
# Avg Classification Loss : 1.3863
#
# Epoch : 30, Total Avg Loss : 1.7803
# Source Avg Loss : 0.8387
# Target Avg Loss : 0.9416
# Source Avg reg Loss : 0.1458
# Target Avg reg Loss : 0.2482
# Source Avg cla Loss : 0.6929
# Target Avg cla Loss : 0.6934
# Avg Regression Loss : 0.3940
# Avg Classification Loss : 1.3863
#
# Epoch : 31, Total Avg Loss : 1.7802
# Source Avg Loss : 0.8388
# Target Avg Loss : 0.9414
# Source Avg reg Loss : 0.1459
# Target Avg reg Loss : 0.2481
# Source Avg cla Loss : 0.6930
# Target Avg cla Loss : 0.6933
# Avg Regression Loss : 0.3939
# Avg Classification Loss : 1.3863
#
# Epoch : 32, Total Avg Loss : 1.7803
# Source Avg Loss : 0.8387
# Target Avg Loss : 0.9415
# Source Avg reg Loss : 0.1458
# Target Avg reg Loss : 0.2482
# Source Avg cla Loss : 0.6929
# Target Avg cla Loss : 0.6933
# Avg Regression Loss : 0.3940
# Avg Classification Loss : 1.3863
#
# Epoch : 33, Total Avg Loss : 1.7802
# Source Avg Loss : 0.8387
# Target Avg Loss : 0.9415
# Source Avg reg Loss : 0.1458
# Target Avg reg Loss : 0.2481
# Source Avg cla Loss : 0.6929
# Target Avg cla Loss : 0.6934
# Avg Regression Loss : 0.3939
# Avg Classification Loss : 1.3863
#
# Epoch : 34, Total Avg Loss : 1.7802
# Source Avg Loss : 0.8388
# Target Avg Loss : 0.9414
# Source Avg reg Loss : 0.1458
# Target Avg reg Loss : 0.2481
# Source Avg cla Loss : 0.6930
# Target Avg cla Loss : 0.6933
# Avg Regression Loss : 0.3939
# Avg Classification Loss : 1.3863
#
# Epoch : 35, Total Avg Loss : 1.7802
# Source Avg Loss : 0.8389
# Target Avg Loss : 0.9414
# Source Avg reg Loss : 0.1459
# Target Avg reg Loss : 0.2480
# Source Avg cla Loss : 0.6930
# Target Avg cla Loss : 0.6933
# Avg Regression Loss : 0.3939
# Avg Classification Loss : 1.3863
#
# Epoch : 36, Total Avg Loss : 1.7802
# Source Avg Loss : 0.8389
# Target Avg Loss : 0.9413
# Source Avg reg Loss : 0.1459
# Target Avg reg Loss : 0.2480
# Source Avg cla Loss : 0.6930
# Target Avg cla Loss : 0.6933
# Avg Regression Loss : 0.3939
# Avg Classification Loss : 1.3863
#
# Epoch : 37, Total Avg Loss : 1.7802
# Source Avg Loss : 0.8388
# Target Avg Loss : 0.9414
# Source Avg reg Loss : 0.1458
# Target Avg reg Loss : 0.2481
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.3939
# Avg Classification Loss : 1.3863
#
# Epoch : 38, Total Avg Loss : 1.7802
# Source Avg Loss : 0.8389
# Target Avg Loss : 0.9412
# Source Avg reg Loss : 0.1459
# Target Avg reg Loss : 0.2480
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.3939
# Avg Classification Loss : 1.3863
#
# Epoch : 39, Total Avg Loss : 1.7802
# Source Avg Loss : 0.8389
# Target Avg Loss : 0.9413
# Source Avg reg Loss : 0.1458
# Target Avg reg Loss : 0.2480
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.3939
# Avg Classification Loss : 1.3863
#
# Epoch : 40, Total Avg Loss : 1.7801
# Source Avg Loss : 0.8389
# Target Avg Loss : 0.9413
# Source Avg reg Loss : 0.1458
# Target Avg reg Loss : 0.2481
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.3939
# Avg Classification Loss : 1.3863
#
# Epoch : 41, Total Avg Loss : 1.7801
# Source Avg Loss : 0.8389
# Target Avg Loss : 0.9412
# Source Avg reg Loss : 0.1458
# Target Avg reg Loss : 0.2480
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.3939
# Avg Classification Loss : 1.3863
#
# Epoch : 42, Total Avg Loss : 1.7802
# Source Avg Loss : 0.8389
# Target Avg Loss : 0.9413
# Source Avg reg Loss : 0.1458
# Target Avg reg Loss : 0.2481
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.3939
# Avg Classification Loss : 1.3863
#
# Epoch : 43, Total Avg Loss : 1.7801
# Source Avg Loss : 0.8389
# Target Avg Loss : 0.9412
# Source Avg reg Loss : 0.1458
# Target Avg reg Loss : 0.2480
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.3938
# Avg Classification Loss : 1.3863
#
# Epoch : 44, Total Avg Loss : 1.7801
# Source Avg Loss : 0.8389
# Target Avg Loss : 0.9412
# Source Avg reg Loss : 0.1458
# Target Avg reg Loss : 0.2480
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.3938
# Avg Classification Loss : 1.3863
#
# Epoch : 45, Total Avg Loss : 1.7801
# Source Avg Loss : 0.8389
# Target Avg Loss : 0.9412
# Source Avg reg Loss : 0.1458
# Target Avg reg Loss : 0.2480
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.3938
# Avg Classification Loss : 1.3863
#
# Epoch : 46, Total Avg Loss : 1.7801
# Source Avg Loss : 0.8388
# Target Avg Loss : 0.9412
# Source Avg reg Loss : 0.1457
# Target Avg reg Loss : 0.2480
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.3938
# Avg Classification Loss : 1.3863
#
# Epoch : 47, Total Avg Loss : 1.7799
# Source Avg Loss : 0.8389
# Target Avg Loss : 0.9410
# Source Avg reg Loss : 0.1457
# Target Avg reg Loss : 0.2479
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.3936
# Avg Classification Loss : 1.3863
#
# Epoch : 48, Total Avg Loss : 1.7796
# Source Avg Loss : 0.8387
# Target Avg Loss : 0.9408
# Source Avg reg Loss : 0.1456
# Target Avg reg Loss : 0.2476
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.3933
# Avg Classification Loss : 1.3863
#
# Epoch : 49, Total Avg Loss : 1.7768
# Source Avg Loss : 0.8380
# Target Avg Loss : 0.9387
# Source Avg reg Loss : 0.1449
# Target Avg reg Loss : 0.2456
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.3905
# Avg Classification Loss : 1.3863
#
# Epoch : 50, Total Avg Loss : 1.6867
# Source Avg Loss : 0.8303
# Target Avg Loss : 0.8564
# Source Avg reg Loss : 0.1372
# Target Avg reg Loss : 0.1631
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.3004
# Avg Classification Loss : 1.3863
#
# Epoch : 51, Total Avg Loss : 1.5826
# Source Avg Loss : 0.8076
# Target Avg Loss : 0.7751
# Source Avg reg Loss : 0.1145
# Target Avg reg Loss : 0.0818
# Source Avg cla Loss : 0.6931
# Target Avg cla Loss : 0.6932
# Avg Regression Loss : 0.1963
# Avg Classification Loss : 1.3863
#
# Epoch : 52, Total Avg Loss : 1.6018
# Source Avg Loss : 0.8121
# Target Avg Loss : 0.7898
# Source Avg reg Loss : 0.1193
# Target Avg reg Loss : 0.0963
# Source Avg cla Loss : 0.6928
# Target Avg cla Loss : 0.6935
# Avg Regression Loss : 0.2156
# Avg Classification Loss : 1.3863
#
# Epoch : 53, Total Avg Loss : 1.5585
# Source Avg Loss : 0.7899
# Target Avg Loss : 0.7686
# Source Avg reg Loss : 0.1002
# Target Avg reg Loss : 0.0731
# Source Avg cla Loss : 0.6897
# Target Avg cla Loss : 0.6955
# Avg Regression Loss : 0.1734
# Avg Classification Loss : 1.3851
#
# Epoch : 54, Total Avg Loss : 1.5011
# Source Avg Loss : 0.7438
# Target Avg Loss : 0.7573
# Source Avg reg Loss : 0.0817
# Target Avg reg Loss : 0.0472
# Source Avg cla Loss : 0.6621
# Target Avg cla Loss : 0.7101
# Avg Regression Loss : 0.1290
# Avg Classification Loss : 1.3722
#
# Epoch : 55, Total Avg Loss : 1.4785
# Source Avg Loss : 0.6156
# Target Avg Loss : 0.8629
# Source Avg reg Loss : 0.0903
# Target Avg reg Loss : 0.0591
# Source Avg cla Loss : 0.5253
# Target Avg cla Loss : 0.8038
# Avg Regression Loss : 0.1494
# Avg Classification Loss : 1.3291
#
# Epoch : 56, Total Avg Loss : 1.5133
# Source Avg Loss : 0.5758
# Target Avg Loss : 0.9375
# Source Avg reg Loss : 0.0992
# Target Avg reg Loss : 0.0692
# Source Avg cla Loss : 0.4766
# Target Avg cla Loss : 0.8683
# Avg Regression Loss : 0.1684
# Avg Classification Loss : 1.3449
#
# Epoch : 57, Total Avg Loss : 1.7547
# Source Avg Loss : 0.5787
# Target Avg Loss : 1.1760
# Source Avg reg Loss : 0.1014
# Target Avg reg Loss : 0.2114
# Source Avg cla Loss : 0.4774
# Target Avg cla Loss : 0.9646
# Avg Regression Loss : 0.3127
# Avg Classification Loss : 1.4420
#
# Epoch : 58, Total Avg Loss : 1.6014
# Source Avg Loss : 0.6541
# Target Avg Loss : 0.9474
# Source Avg reg Loss : 0.1010
# Target Avg reg Loss : 0.0893
# Source Avg cla Loss : 0.5530
# Target Avg cla Loss : 0.8580
# Avg Regression Loss : 0.1903
# Avg Classification Loss : 1.4111
#
# Epoch : 59, Total Avg Loss : 1.5733
# Source Avg Loss : 0.7513
# Target Avg Loss : 0.8220
# Source Avg reg Loss : 0.0910
# Target Avg reg Loss : 0.0742
# Source Avg cla Loss : 0.6602
# Target Avg cla Loss : 0.7478
# Avg Regression Loss : 0.1652
# Avg Classification Loss : 1.4081
#
# Epoch : 60, Total Avg Loss : 1.5697
# Source Avg Loss : 0.6903
# Target Avg Loss : 0.8794
# Source Avg reg Loss : 0.1049
# Target Avg reg Loss : 0.0735
# Source Avg cla Loss : 0.5854
# Target Avg cla Loss : 0.8059
# Avg Regression Loss : 0.1784
# Avg Classification Loss : 1.3913
#
# Epoch : 61, Total Avg Loss : 1.6000
# Source Avg Loss : 0.6429
# Target Avg Loss : 0.9571
# Source Avg reg Loss : 0.1081
# Target Avg reg Loss : 0.1139
# Source Avg cla Loss : 0.5348
# Target Avg cla Loss : 0.8432
# Avg Regression Loss : 0.2220
# Avg Classification Loss : 1.3780
#
# Epoch : 62, Total Avg Loss : 1.4832
# Source Avg Loss : 0.6439
# Target Avg Loss : 0.8394
# Source Avg reg Loss : 0.0872
# Target Avg reg Loss : 0.0578
# Source Avg cla Loss : 0.5567
# Target Avg cla Loss : 0.7815
# Avg Regression Loss : 0.1451
# Avg Classification Loss : 1.3382
#
# Epoch : 63, Total Avg Loss : 1.4643
# Source Avg Loss : 0.6094
# Target Avg Loss : 0.8550
# Source Avg reg Loss : 0.0774
# Target Avg reg Loss : 0.0612
# Source Avg cla Loss : 0.5320
# Target Avg cla Loss : 0.7937
# Avg Regression Loss : 0.1386
# Avg Classification Loss : 1.3257
#
# Epoch : 64, Total Avg Loss : 1.6754
# Source Avg Loss : 0.5919
# Target Avg Loss : 1.0835
# Source Avg reg Loss : 0.0884
# Target Avg reg Loss : 0.1741
# Source Avg cla Loss : 0.5035
# Target Avg cla Loss : 0.9094
# Avg Regression Loss : 0.2626
# Avg Classification Loss : 1.4129
#
# Epoch : 65, Total Avg Loss : 1.5746
# Source Avg Loss : 0.6521
# Target Avg Loss : 0.9225
# Source Avg reg Loss : 0.0836
# Target Avg reg Loss : 0.1102
# Source Avg cla Loss : 0.5685
# Target Avg cla Loss : 0.8124
# Avg Regression Loss : 0.1938
# Avg Classification Loss : 1.3809
#
# Epoch : 66, Total Avg Loss : 1.5159
# Source Avg Loss : 0.6648
# Target Avg Loss : 0.8510
# Source Avg reg Loss : 0.0830
# Target Avg reg Loss : 0.0841
# Source Avg cla Loss : 0.5818
# Target Avg cla Loss : 0.7670
# Avg Regression Loss : 0.1671
# Avg Classification Loss : 1.3488
#
# Epoch : 67, Total Avg Loss : 1.4636
# Source Avg Loss : 0.5907
# Target Avg Loss : 0.8729
# Source Avg reg Loss : 0.0709
# Target Avg reg Loss : 0.0567
# Source Avg cla Loss : 0.5198
# Target Avg cla Loss : 0.8161
# Avg Regression Loss : 0.1276
# Avg Classification Loss : 1.3359
#
# Epoch : 68, Total Avg Loss : 1.5128
# Source Avg Loss : 0.6228
# Target Avg Loss : 0.8900
# Source Avg reg Loss : 0.0948
# Target Avg reg Loss : 0.0715
# Source Avg cla Loss : 0.5280
# Target Avg cla Loss : 0.8185
# Avg Regression Loss : 0.1663
# Avg Classification Loss : 1.3466
#
# Epoch : 69, Total Avg Loss : 1.4604
# Source Avg Loss : 0.6020
# Target Avg Loss : 0.8584
# Source Avg reg Loss : 0.0724
# Target Avg reg Loss : 0.0471
# Source Avg cla Loss : 0.5296
# Target Avg cla Loss : 0.8113
# Avg Regression Loss : 0.1195
# Avg Classification Loss : 1.3409
#
# Epoch : 70, Total Avg Loss : 1.5092
# Source Avg Loss : 0.5913
# Target Avg Loss : 0.9179
# Source Avg reg Loss : 0.0775
# Target Avg reg Loss : 0.0771
# Source Avg cla Loss : 0.5139
# Target Avg cla Loss : 0.8408
# Avg Regression Loss : 0.1545
# Avg Classification Loss : 1.3547
#
# Epoch : 71, Total Avg Loss : 1.5140
# Source Avg Loss : 0.6539
# Target Avg Loss : 0.8601
# Source Avg reg Loss : 0.0894
# Target Avg reg Loss : 0.0659
# Source Avg cla Loss : 0.5645
# Target Avg cla Loss : 0.7942
# Avg Regression Loss : 0.1554
# Avg Classification Loss : 1.3586
#
# Epoch : 72, Total Avg Loss : 1.4421
# Source Avg Loss : 0.5908
# Target Avg Loss : 0.8514
# Source Avg reg Loss : 0.0595
# Target Avg reg Loss : 0.0459
# Source Avg cla Loss : 0.5313
# Target Avg cla Loss : 0.8054
# Avg Regression Loss : 0.1054
# Avg Classification Loss : 1.3367
#
# Epoch : 73, Total Avg Loss : 1.4533
# Source Avg Loss : 0.5699
# Target Avg Loss : 0.8834
# Source Avg reg Loss : 0.0613
# Target Avg reg Loss : 0.0460
# Source Avg cla Loss : 0.5085
# Target Avg cla Loss : 0.8375
# Avg Regression Loss : 0.1073
# Avg Classification Loss : 1.3460
#
# Epoch : 74, Total Avg Loss : 1.4786
# Source Avg Loss : 0.6193
# Target Avg Loss : 0.8593
# Source Avg reg Loss : 0.0634
# Target Avg reg Loss : 0.0683
# Source Avg cla Loss : 0.5559
# Target Avg cla Loss : 0.7910
# Avg Regression Loss : 0.1317
# Avg Classification Loss : 1.3469
#
# Epoch : 75, Total Avg Loss : 1.4421
# Source Avg Loss : 0.5867
# Target Avg Loss : 0.8554
# Source Avg reg Loss : 0.0618
# Target Avg reg Loss : 0.0428
# Source Avg cla Loss : 0.5249
# Target Avg cla Loss : 0.8126
# Avg Regression Loss : 0.1046
# Avg Classification Loss : 1.3374
#
# Epoch : 76, Total Avg Loss : 1.4086
# Source Avg Loss : 0.5431
# Target Avg Loss : 0.8655
# Source Avg reg Loss : 0.0415
# Target Avg reg Loss : 0.0320
# Source Avg cla Loss : 0.5016
# Target Avg cla Loss : 0.8335
# Avg Regression Loss : 0.0735
# Avg Classification Loss : 1.3351
#
# Epoch : 77, Total Avg Loss : 1.3970
# Source Avg Loss : 0.5653
# Target Avg Loss : 0.8316
# Source Avg reg Loss : 0.0381
# Target Avg reg Loss : 0.0285
# Source Avg cla Loss : 0.5272
# Target Avg cla Loss : 0.8031
# Avg Regression Loss : 0.0666
# Avg Classification Loss : 1.3304
#
# Epoch : 78, Total Avg Loss : 1.5750
# Source Avg Loss : 0.5953
# Target Avg Loss : 0.9797
# Source Avg reg Loss : 0.0953
# Target Avg reg Loss : 0.1100
# Source Avg cla Loss : 0.5000
# Target Avg cla Loss : 0.8697
# Avg Regression Loss : 0.2053
# Avg Classification Loss : 1.3697
#
# Epoch : 79, Total Avg Loss : 1.4610
# Source Avg Loss : 0.6188
# Target Avg Loss : 0.8422
# Source Avg reg Loss : 0.0693
# Target Avg reg Loss : 0.0438
# Source Avg cla Loss : 0.5495
# Target Avg cla Loss : 0.7984
# Avg Regression Loss : 0.1132
# Avg Classification Loss : 1.3479
#
# Epoch : 80, Total Avg Loss : 1.4847
# Source Avg Loss : 0.5558
# Target Avg Loss : 0.9289
# Source Avg reg Loss : 0.0587
# Target Avg reg Loss : 0.0675
# Source Avg cla Loss : 0.4971
# Target Avg cla Loss : 0.8613
# Avg Regression Loss : 0.1263
# Avg Classification Loss : 1.3584
#
# Epoch : 81, Total Avg Loss : 1.5363
# Source Avg Loss : 0.6693
# Target Avg Loss : 0.8671
# Source Avg reg Loss : 0.0796
# Target Avg reg Loss : 0.0884
# Source Avg cla Loss : 0.5897
# Target Avg cla Loss : 0.7787
# Avg Regression Loss : 0.1680
# Avg Classification Loss : 1.3684
#
# Epoch : 82, Total Avg Loss : 1.4861
# Source Avg Loss : 0.6875
# Target Avg Loss : 0.7986
# Source Avg reg Loss : 0.0743
# Target Avg reg Loss : 0.0498
# Source Avg cla Loss : 0.6132
# Target Avg cla Loss : 0.7487
# Avg Regression Loss : 0.1241
# Avg Classification Loss : 1.3620
#
# Epoch : 83, Total Avg Loss : 1.4805
# Source Avg Loss : 0.5637
# Target Avg Loss : 0.9168
# Source Avg reg Loss : 0.0574
# Target Avg reg Loss : 0.0657
# Source Avg cla Loss : 0.5063
# Target Avg cla Loss : 0.8511
# Avg Regression Loss : 0.1231
# Avg Classification Loss : 1.3574
#
# Epoch : 84, Total Avg Loss : 1.4599
# Source Avg Loss : 0.6017
# Target Avg Loss : 0.8582
# Source Avg reg Loss : 0.0720
# Target Avg reg Loss : 0.0531
# Source Avg cla Loss : 0.5297
# Target Avg cla Loss : 0.8051
# Avg Regression Loss : 0.1251
# Avg Classification Loss : 1.3348
#
# Epoch : 85, Total Avg Loss : 1.4272
# Source Avg Loss : 0.5443
# Target Avg Loss : 0.8829
# Source Avg reg Loss : 0.0530
# Target Avg reg Loss : 0.0428
# Source Avg cla Loss : 0.4913
# Target Avg cla Loss : 0.8401
# Avg Regression Loss : 0.0958
# Avg Classification Loss : 1.3314
#
# Epoch : 86, Total Avg Loss : 1.4652
# Source Avg Loss : 0.5840
# Target Avg Loss : 0.8812
# Source Avg reg Loss : 0.0706
# Target Avg reg Loss : 0.0536
# Source Avg cla Loss : 0.5134
# Target Avg cla Loss : 0.8276
# Avg Regression Loss : 0.1241
# Avg Classification Loss : 1.3410
#
# Epoch : 87, Total Avg Loss : 1.5290
# Source Avg Loss : 0.6111
# Target Avg Loss : 0.9179
# Source Avg reg Loss : 0.1146
# Target Avg reg Loss : 0.0748
# Source Avg cla Loss : 0.4965
# Target Avg cla Loss : 0.8431
# Avg Regression Loss : 0.1894
# Avg Classification Loss : 1.3396
#
# Epoch : 88, Total Avg Loss : 1.5639
# Source Avg Loss : 0.5822
# Target Avg Loss : 0.9817
# Source Avg reg Loss : 0.1010
# Target Avg reg Loss : 0.1034
# Source Avg cla Loss : 0.4813
# Target Avg cla Loss : 0.8783
# Avg Regression Loss : 0.2044
# Avg Classification Loss : 1.3595
#
# Epoch : 89, Total Avg Loss : 1.4482
# Source Avg Loss : 0.5539
# Target Avg Loss : 0.8943
# Source Avg reg Loss : 0.0641
# Target Avg reg Loss : 0.0493
# Source Avg cla Loss : 0.4898
# Target Avg cla Loss : 0.8450
# Avg Regression Loss : 0.1134
# Avg Classification Loss : 1.3348
#
# Epoch : 90, Total Avg Loss : 1.4195
# Source Avg Loss : 0.5461
# Target Avg Loss : 0.8733
# Source Avg reg Loss : 0.0469
# Target Avg reg Loss : 0.0368
# Source Avg cla Loss : 0.4993
# Target Avg cla Loss : 0.8366
# Avg Regression Loss : 0.0837
# Avg Classification Loss : 1.3358
#
# Epoch : 91, Total Avg Loss : 1.3994
# Source Avg Loss : 0.5390
# Target Avg Loss : 0.8605
# Source Avg reg Loss : 0.0383
# Target Avg reg Loss : 0.0315
# Source Avg cla Loss : 0.5007
# Target Avg cla Loss : 0.8289
# Avg Regression Loss : 0.0699
# Avg Classification Loss : 1.3296
#
# Epoch : 92, Total Avg Loss : 1.4290
# Source Avg Loss : 0.5472
# Target Avg Loss : 0.8818
# Source Avg reg Loss : 0.0553
# Target Avg reg Loss : 0.0375
# Source Avg cla Loss : 0.4919
# Target Avg cla Loss : 0.8442
# Avg Regression Loss : 0.0929
# Avg Classification Loss : 1.3362
#
# Epoch : 93, Total Avg Loss : 1.4015
# Source Avg Loss : 0.5200
# Target Avg Loss : 0.8815
# Source Avg reg Loss : 0.0356
# Target Avg reg Loss : 0.0312
# Source Avg cla Loss : 0.4844
# Target Avg cla Loss : 0.8503
# Avg Regression Loss : 0.0668
# Avg Classification Loss : 1.3346
#
# Epoch : 94, Total Avg Loss : 1.3911
# Source Avg Loss : 0.5261
# Target Avg Loss : 0.8650
# Source Avg reg Loss : 0.0330
# Target Avg reg Loss : 0.0296
# Source Avg cla Loss : 0.4931
# Target Avg cla Loss : 0.8353
# Avg Regression Loss : 0.0627
# Avg Classification Loss : 1.3284
#
# Epoch : 95, Total Avg Loss : 1.4400
# Source Avg Loss : 0.5544
# Target Avg Loss : 0.8857
# Source Avg reg Loss : 0.0610
# Target Avg reg Loss : 0.0369
# Source Avg cla Loss : 0.4934
# Target Avg cla Loss : 0.8488
# Avg Regression Loss : 0.0979
# Avg Classification Loss : 1.3422
#
# Epoch : 96, Total Avg Loss : 1.4083
# Source Avg Loss : 0.5188
# Target Avg Loss : 0.8895
# Source Avg reg Loss : 0.0344
# Target Avg reg Loss : 0.0342
# Source Avg cla Loss : 0.4844
# Target Avg cla Loss : 0.8553
# Avg Regression Loss : 0.0686
# Avg Classification Loss : 1.3397
#
# Epoch : 97, Total Avg Loss : 1.4228
# Source Avg Loss : 0.5356
# Target Avg Loss : 0.8872
# Source Avg reg Loss : 0.0490
# Target Avg reg Loss : 0.0393
# Source Avg cla Loss : 0.4866
# Target Avg cla Loss : 0.8479
# Avg Regression Loss : 0.0883
# Avg Classification Loss : 1.3345
#
# Epoch : 98, Total Avg Loss : 1.4169
# Source Avg Loss : 0.5229
# Target Avg Loss : 0.8940
# Source Avg reg Loss : 0.0446
# Target Avg reg Loss : 0.0389
# Source Avg cla Loss : 0.4783
# Target Avg cla Loss : 0.8551
# Avg Regression Loss : 0.0835
# Avg Classification Loss : 1.3334
#
# Epoch : 99, Total Avg Loss : 1.4618
# Source Avg Loss : 0.5475
# Target Avg Loss : 0.9144
# Source Avg reg Loss : 0.0669
# Target Avg reg Loss : 0.0526
# Source Avg cla Loss : 0.4806
# Target Avg cla Loss : 0.8618
# Avg Regression Loss : 0.1194
# Avg Classification Loss : 1.3424
#
# Epoch : 100, Total Avg Loss : 1.4470
# Source Avg Loss : 0.5394
# Target Avg Loss : 0.9076
# Source Avg reg Loss : 0.0535
# Target Avg reg Loss : 0.0451
# Source Avg cla Loss : 0.4859
# Target Avg cla Loss : 0.8626
# Avg Regression Loss : 0.0985
# Avg Classification Loss : 1.3485
#
# Epoch : 101, Total Avg Loss : 1.4245
# Source Avg Loss : 0.5342
# Target Avg Loss : 0.8903
# Source Avg reg Loss : 0.0434
# Target Avg reg Loss : 0.0391
# Source Avg cla Loss : 0.4908
# Target Avg cla Loss : 0.8512
# Avg Regression Loss : 0.0825
# Avg Classification Loss : 1.3420
#
# Epoch : 102, Total Avg Loss : 1.4162
# Source Avg Loss : 0.5315
# Target Avg Loss : 0.8846
# Source Avg reg Loss : 0.0352
# Target Avg reg Loss : 0.0401
# Source Avg cla Loss : 0.4964
# Target Avg cla Loss : 0.8445
# Avg Regression Loss : 0.0753
# Avg Classification Loss : 1.3409
#
# Epoch : 103, Total Avg Loss : 1.4034
# Source Avg Loss : 0.5325
# Target Avg Loss : 0.8709
# Source Avg reg Loss : 0.0320
# Target Avg reg Loss : 0.0316
# Source Avg cla Loss : 0.5005
# Target Avg cla Loss : 0.8393
# Avg Regression Loss : 0.0635
# Avg Classification Loss : 1.3398
#
# Epoch : 104, Total Avg Loss : 1.4046
# Source Avg Loss : 0.5317
# Target Avg Loss : 0.8729
# Source Avg reg Loss : 0.0322
# Target Avg reg Loss : 0.0324
# Source Avg cla Loss : 0.4996
# Target Avg cla Loss : 0.8404
# Avg Regression Loss : 0.0646
# Avg Classification Loss : 1.3400
#
# Epoch : 105, Total Avg Loss : 1.4158
# Source Avg Loss : 0.5404
# Target Avg Loss : 0.8754
# Source Avg reg Loss : 0.0466
# Target Avg reg Loss : 0.0384
# Source Avg cla Loss : 0.4938
# Target Avg cla Loss : 0.8370
# Avg Regression Loss : 0.0850
# Avg Classification Loss : 1.3308
#
# Epoch : 106, Total Avg Loss : 1.4666
# Source Avg Loss : 0.5609
# Target Avg Loss : 0.9057
# Source Avg reg Loss : 0.0786
# Target Avg reg Loss : 0.0497
# Source Avg cla Loss : 0.4823
# Target Avg cla Loss : 0.8560
# Avg Regression Loss : 0.1283
# Avg Classification Loss : 1.3383
#
# Epoch : 107, Total Avg Loss : 1.4683
# Source Avg Loss : 0.5744
# Target Avg Loss : 0.8939
# Source Avg reg Loss : 0.0693
# Target Avg reg Loss : 0.0504
# Source Avg cla Loss : 0.5051
# Target Avg cla Loss : 0.8436
# Avg Regression Loss : 0.1197
# Avg Classification Loss : 1.3487
#
# Epoch : 108, Total Avg Loss : 1.4698
# Source Avg Loss : 0.5578
# Target Avg Loss : 0.9120
# Source Avg reg Loss : 0.0684
# Target Avg reg Loss : 0.0554
# Source Avg cla Loss : 0.4895
# Target Avg cla Loss : 0.8566
# Avg Regression Loss : 0.1238
# Avg Classification Loss : 1.3461
#
# Epoch : 109, Total Avg Loss : 1.4880
# Source Avg Loss : 0.5779
# Target Avg Loss : 0.9101
# Source Avg reg Loss : 0.0843
# Target Avg reg Loss : 0.0586
# Source Avg cla Loss : 0.4936
# Target Avg cla Loss : 0.8515
# Avg Regression Loss : 0.1429
# Avg Classification Loss : 1.3451
#
# Epoch : 110, Total Avg Loss : 1.4440
# Source Avg Loss : 0.5487
# Target Avg Loss : 0.8953
# Source Avg reg Loss : 0.0525
# Target Avg reg Loss : 0.0473
# Source Avg cla Loss : 0.4963
# Target Avg cla Loss : 0.8480
# Avg Regression Loss : 0.0997
# Avg Classification Loss : 1.3443
#
# Epoch : 111, Total Avg Loss : 1.4531
# Source Avg Loss : 0.5795
# Target Avg Loss : 0.8736
# Source Avg reg Loss : 0.0573
# Target Avg reg Loss : 0.0441
# Source Avg cla Loss : 0.5222
# Target Avg cla Loss : 0.8295
# Avg Regression Loss : 0.1014
# Avg Classification Loss : 1.3517
#
# Epoch : 112, Total Avg Loss : 1.4712
# Source Avg Loss : 0.5872
# Target Avg Loss : 0.8840
# Source Avg reg Loss : 0.0653
# Target Avg reg Loss : 0.0533
# Source Avg cla Loss : 0.5219
# Target Avg cla Loss : 0.8307
# Avg Regression Loss : 0.1186
# Avg Classification Loss : 1.3526
#
# Epoch : 113, Total Avg Loss : 1.4977
# Source Avg Loss : 0.6213
# Target Avg Loss : 0.8764
# Source Avg reg Loss : 0.0846
# Target Avg reg Loss : 0.0618
# Source Avg cla Loss : 0.5367
# Target Avg cla Loss : 0.8146
# Avg Regression Loss : 0.1464
# Avg Classification Loss : 1.3513
#
# Epoch : 114, Total Avg Loss : 1.5104
# Source Avg Loss : 0.6185
# Target Avg Loss : 0.8918
# Source Avg reg Loss : 0.0859
# Target Avg reg Loss : 0.0724
# Source Avg cla Loss : 0.5327
# Target Avg cla Loss : 0.8194
# Avg Regression Loss : 0.1583
# Avg Classification Loss : 1.3521
#
# Epoch : 115, Total Avg Loss : 1.4728
# Source Avg Loss : 0.5698
# Target Avg Loss : 0.9030
# Source Avg reg Loss : 0.0699
# Target Avg reg Loss : 0.0659
# Source Avg cla Loss : 0.4999
# Target Avg cla Loss : 0.8371
# Avg Regression Loss : 0.1358
# Avg Classification Loss : 1.3370
#
# Epoch : 116, Total Avg Loss : 1.4280
# Source Avg Loss : 0.5199
# Target Avg Loss : 0.9081
# Source Avg reg Loss : 0.0458
# Target Avg reg Loss : 0.0480
# Source Avg cla Loss : 0.4741
# Target Avg cla Loss : 0.8601
# Avg Regression Loss : 0.0938
# Avg Classification Loss : 1.3342
#
# Epoch : 117, Total Avg Loss : 1.4313
# Source Avg Loss : 0.5213
# Target Avg Loss : 0.9101
# Source Avg reg Loss : 0.0421
# Target Avg reg Loss : 0.0441
# Source Avg cla Loss : 0.4792
# Target Avg cla Loss : 0.8660
# Avg Regression Loss : 0.0861
# Avg Classification Loss : 1.3452
#
# Epoch : 118, Total Avg Loss : 1.4503
# Source Avg Loss : 0.5180
# Target Avg Loss : 0.9323
# Source Avg reg Loss : 0.0348
# Target Avg reg Loss : 0.0508
# Source Avg cla Loss : 0.4832
# Target Avg cla Loss : 0.8815
# Avg Regression Loss : 0.0856
# Avg Classification Loss : 1.3647
#
# Epoch : 119, Total Avg Loss : 1.4439
# Source Avg Loss : 0.5247
# Target Avg Loss : 0.9192
# Source Avg reg Loss : 0.0456
# Target Avg reg Loss : 0.0355
# Source Avg cla Loss : 0.4791
# Target Avg cla Loss : 0.8837
# Avg Regression Loss : 0.0811
# Avg Classification Loss : 1.3628
#
# Epoch : 120, Total Avg Loss : 1.4094
# Source Avg Loss : 0.5367
# Target Avg Loss : 0.8727
# Source Avg reg Loss : 0.0345
# Target Avg reg Loss : 0.0312
# Source Avg cla Loss : 0.5023
# Target Avg cla Loss : 0.8415
# Avg Regression Loss : 0.0657
# Avg Classification Loss : 1.3437
#
# Epoch : 121, Total Avg Loss : 1.4472
# Source Avg Loss : 0.5791
# Target Avg Loss : 0.8681
# Source Avg reg Loss : 0.0664
# Target Avg reg Loss : 0.0482
# Source Avg cla Loss : 0.5127
# Target Avg cla Loss : 0.8199
# Avg Regression Loss : 0.1146
# Avg Classification Loss : 1.3326
#
# Epoch : 122, Total Avg Loss : 1.4159
# Source Avg Loss : 0.5244
# Target Avg Loss : 0.8915
# Source Avg reg Loss : 0.0534
# Target Avg reg Loss : 0.0367
# Source Avg cla Loss : 0.4710
# Target Avg cla Loss : 0.8548
# Avg Regression Loss : 0.0902
# Avg Classification Loss : 1.3257
#
# Epoch : 123, Total Avg Loss : 1.4152
# Source Avg Loss : 0.5075
# Target Avg Loss : 0.9076
# Source Avg reg Loss : 0.0503
# Target Avg reg Loss : 0.0353
# Source Avg cla Loss : 0.4572
# Target Avg cla Loss : 0.8724
# Avg Regression Loss : 0.0856
# Avg Classification Loss : 1.3296
#
# Epoch : 124, Total Avg Loss : 1.4069
# Source Avg Loss : 0.5065
# Target Avg Loss : 0.9005
# Source Avg reg Loss : 0.0416
# Target Avg reg Loss : 0.0301
# Source Avg cla Loss : 0.4648
# Target Avg cla Loss : 0.8703
# Avg Regression Loss : 0.0718
# Avg Classification Loss : 1.3351
#
# Epoch : 125, Total Avg Loss : 1.3896
# Source Avg Loss : 0.5008
# Target Avg Loss : 0.8888
# Source Avg reg Loss : 0.0300
# Target Avg reg Loss : 0.0297
# Source Avg cla Loss : 0.4708
# Target Avg cla Loss : 0.8591
# Avg Regression Loss : 0.0597
# Avg Classification Loss : 1.3298
#
# Epoch : 126, Total Avg Loss : 1.4093
# Source Avg Loss : 0.5219
# Target Avg Loss : 0.8874
# Source Avg reg Loss : 0.0458
# Target Avg reg Loss : 0.0266
# Source Avg cla Loss : 0.4761
# Target Avg cla Loss : 0.8608
# Avg Regression Loss : 0.0724
# Avg Classification Loss : 1.3369
#
# Epoch : 127, Total Avg Loss : 1.3944
# Source Avg Loss : 0.5090
# Target Avg Loss : 0.8854
# Source Avg reg Loss : 0.0319
# Target Avg reg Loss : 0.0303
# Source Avg cla Loss : 0.4771
# Target Avg cla Loss : 0.8552
# Avg Regression Loss : 0.0622
# Avg Classification Loss : 1.3323
#
# Epoch : 128, Total Avg Loss : 1.3867
# Source Avg Loss : 0.5124
# Target Avg Loss : 0.8743
# Source Avg reg Loss : 0.0282
# Target Avg reg Loss : 0.0278
# Source Avg cla Loss : 0.4842
# Target Avg cla Loss : 0.8465
# Avg Regression Loss : 0.0560
# Avg Classification Loss : 1.3307
#
# Epoch : 129, Total Avg Loss : 1.4375
# Source Avg Loss : 0.5455
# Target Avg Loss : 0.8920
# Source Avg reg Loss : 0.0599
# Target Avg reg Loss : 0.0349
# Source Avg cla Loss : 0.4856
# Target Avg cla Loss : 0.8571
# Avg Regression Loss : 0.0948
# Avg Classification Loss : 1.3427
#
# Epoch : 130, Total Avg Loss : 1.4283
# Source Avg Loss : 0.5379
# Target Avg Loss : 0.8904
# Source Avg reg Loss : 0.0495
# Target Avg reg Loss : 0.0366
# Source Avg cla Loss : 0.4884
# Target Avg cla Loss : 0.8538
# Avg Regression Loss : 0.0860
# Avg Classification Loss : 1.3423
#
# Epoch : 131, Total Avg Loss : 1.4162
# Source Avg Loss : 0.5291
# Target Avg Loss : 0.8872
# Source Avg reg Loss : 0.0391
# Target Avg reg Loss : 0.0371
# Source Avg cla Loss : 0.4900
# Target Avg cla Loss : 0.8501
# Avg Regression Loss : 0.0762
# Avg Classification Loss : 1.3400
#
# Epoch : 132, Total Avg Loss : 1.4570
# Source Avg Loss : 0.5607
# Target Avg Loss : 0.8963
# Source Avg reg Loss : 0.0703
# Target Avg reg Loss : 0.0491
# Source Avg cla Loss : 0.4904
# Target Avg cla Loss : 0.8472
# Avg Regression Loss : 0.1194
# Avg Classification Loss : 1.3376
#
# Epoch : 133, Total Avg Loss : 1.4096
# Source Avg Loss : 0.5278
# Target Avg Loss : 0.8818
# Source Avg reg Loss : 0.0372
# Target Avg reg Loss : 0.0362
# Source Avg cla Loss : 0.4907
# Target Avg cla Loss : 0.8456
# Avg Regression Loss : 0.0733
# Avg Classification Loss : 1.3363
#
# Epoch : 134, Total Avg Loss : 1.4159
# Source Avg Loss : 0.5276
# Target Avg Loss : 0.8882
# Source Avg reg Loss : 0.0429
# Target Avg reg Loss : 0.0311
# Source Avg cla Loss : 0.4847
# Target Avg cla Loss : 0.8572
# Avg Regression Loss : 0.0740
# Avg Classification Loss : 1.3419
#
# Epoch : 135, Total Avg Loss : 1.4146
# Source Avg Loss : 0.5183
# Target Avg Loss : 0.8963
# Source Avg reg Loss : 0.0401
# Target Avg reg Loss : 0.0339
# Source Avg cla Loss : 0.4781
# Target Avg cla Loss : 0.8624
# Avg Regression Loss : 0.0740
# Avg Classification Loss : 1.3406
#
# Epoch : 136, Total Avg Loss : 1.4084
# Source Avg Loss : 0.5190
# Target Avg Loss : 0.8895
# Source Avg reg Loss : 0.0373
# Target Avg reg Loss : 0.0325
# Source Avg cla Loss : 0.4817
# Target Avg cla Loss : 0.8569
# Avg Regression Loss : 0.0698
# Avg Classification Loss : 1.3386
#
# Epoch : 137, Total Avg Loss : 1.3887
# Source Avg Loss : 0.5110
# Target Avg Loss : 0.8778
# Source Avg reg Loss : 0.0283
# Target Avg reg Loss : 0.0274
# Source Avg cla Loss : 0.4826
# Target Avg cla Loss : 0.8503
# Avg Regression Loss : 0.0558
# Avg Classification Loss : 1.3330
#
# Epoch : 138, Total Avg Loss : 1.3748
# Source Avg Loss : 0.5037
# Target Avg Loss : 0.8711
# Source Avg reg Loss : 0.0219
# Target Avg reg Loss : 0.0228
# Source Avg cla Loss : 0.4817
# Target Avg cla Loss : 0.8483
# Avg Regression Loss : 0.0447
# Avg Classification Loss : 1.3301
#
# Epoch : 139, Total Avg Loss : 1.3770
# Source Avg Loss : 0.5145
# Target Avg Loss : 0.8625
# Source Avg reg Loss : 0.0255
# Target Avg reg Loss : 0.0239
# Source Avg cla Loss : 0.4890
# Target Avg cla Loss : 0.8386
# Avg Regression Loss : 0.0494
# Avg Classification Loss : 1.3276
#
# Epoch : 140, Total Avg Loss : 1.3796
# Source Avg Loss : 0.5106
# Target Avg Loss : 0.8690
# Source Avg reg Loss : 0.0240
# Target Avg reg Loss : 0.0245
# Source Avg cla Loss : 0.4865
# Target Avg cla Loss : 0.8445
# Avg Regression Loss : 0.0485
# Avg Classification Loss : 1.3311
#
# Epoch : 141, Total Avg Loss : 1.4037
# Source Avg Loss : 0.5239
# Target Avg Loss : 0.8799
# Source Avg reg Loss : 0.0348
# Target Avg reg Loss : 0.0321
# Source Avg cla Loss : 0.4891
# Target Avg cla Loss : 0.8477
# Avg Regression Loss : 0.0669
# Avg Classification Loss : 1.3368
#
# Epoch : 142, Total Avg Loss : 1.3923
# Source Avg Loss : 0.5165
# Target Avg Loss : 0.8758
# Source Avg reg Loss : 0.0292
# Target Avg reg Loss : 0.0294
# Source Avg cla Loss : 0.4873
# Target Avg cla Loss : 0.8464
# Avg Regression Loss : 0.0586
# Avg Classification Loss : 1.3337
#
# Epoch : 143, Total Avg Loss : 1.4246
# Source Avg Loss : 0.5325
# Target Avg Loss : 0.8922
# Source Avg reg Loss : 0.0511
# Target Avg reg Loss : 0.0387
# Source Avg cla Loss : 0.4814
# Target Avg cla Loss : 0.8535
# Avg Regression Loss : 0.0898
# Avg Classification Loss : 1.3348
#
# Epoch : 144, Total Avg Loss : 1.4115
# Source Avg Loss : 0.5191
# Target Avg Loss : 0.8924
# Source Avg reg Loss : 0.0411
# Target Avg reg Loss : 0.0329
# Source Avg cla Loss : 0.4780
# Target Avg cla Loss : 0.8595
# Avg Regression Loss : 0.0740
# Avg Classification Loss : 1.3374
#
# Epoch : 145, Total Avg Loss : 1.4095
# Source Avg Loss : 0.5213
# Target Avg Loss : 0.8882
# Source Avg reg Loss : 0.0403
# Target Avg reg Loss : 0.0297
# Source Avg cla Loss : 0.4809
# Target Avg cla Loss : 0.8585
# Avg Regression Loss : 0.0700
# Avg Classification Loss : 1.3395
#
# Epoch : 146, Total Avg Loss : 1.3893
# Source Avg Loss : 0.5119
# Target Avg Loss : 0.8774
# Source Avg reg Loss : 0.0270
# Target Avg reg Loss : 0.0304
# Source Avg cla Loss : 0.4849
# Target Avg cla Loss : 0.8471
# Avg Regression Loss : 0.0573
# Avg Classification Loss : 1.3320
#
# Epoch : 147, Total Avg Loss : 1.4300
# Source Avg Loss : 0.5428
# Target Avg Loss : 0.8873
# Source Avg reg Loss : 0.0556
# Target Avg reg Loss : 0.0357
# Source Avg cla Loss : 0.4872
# Target Avg cla Loss : 0.8515
# Avg Regression Loss : 0.0913
# Avg Classification Loss : 1.3388
#
# Epoch : 148, Total Avg Loss : 1.4334
# Source Avg Loss : 0.5429
# Target Avg Loss : 0.8904
# Source Avg reg Loss : 0.0629
# Target Avg reg Loss : 0.0396
# Source Avg cla Loss : 0.4800
# Target Avg cla Loss : 0.8508
# Avg Regression Loss : 0.1025
# Avg Classification Loss : 1.3308
#
# Epoch : 149, Total Avg Loss : 1.4176
# Source Avg Loss : 0.5271
# Target Avg Loss : 0.8905
# Source Avg reg Loss : 0.0412
# Target Avg reg Loss : 0.0396
# Source Avg cla Loss : 0.4859
# Target Avg cla Loss : 0.8510
# Avg Regression Loss : 0.0807
# Avg Classification Loss : 1.3368
#
# Epoch : 150, Total Avg Loss : 1.4061
# Source Avg Loss : 0.5273
# Target Avg Loss : 0.8788
# Source Avg reg Loss : 0.0339
# Target Avg reg Loss : 0.0323
# Source Avg cla Loss : 0.4934
# Target Avg cla Loss : 0.8465
# Avg Regression Loss : 0.0663
# Avg Classification Loss : 1.3399
#
# Epoch : 151, Total Avg Loss : 1.3896
# Source Avg Loss : 0.5173
# Target Avg Loss : 0.8723
# Source Avg reg Loss : 0.0299
# Target Avg reg Loss : 0.0288
# Source Avg cla Loss : 0.4874
# Target Avg cla Loss : 0.8435
# Avg Regression Loss : 0.0587
# Avg Classification Loss : 1.3309
#
# Epoch : 152, Total Avg Loss : 1.4237
# Source Avg Loss : 0.5332
# Target Avg Loss : 0.8904
# Source Avg reg Loss : 0.0486
# Target Avg reg Loss : 0.0354
# Source Avg cla Loss : 0.4846
# Target Avg cla Loss : 0.8550
# Avg Regression Loss : 0.0840
# Avg Classification Loss : 1.3396
#
# Epoch : 153, Total Avg Loss : 1.4206
# Source Avg Loss : 0.5441
# Target Avg Loss : 0.8765
# Source Avg reg Loss : 0.0534
# Target Avg reg Loss : 0.0335
# Source Avg cla Loss : 0.4907
# Target Avg cla Loss : 0.8430
# Avg Regression Loss : 0.0869
# Avg Classification Loss : 1.3337
#
# Epoch : 154, Total Avg Loss : 1.3958
# Source Avg Loss : 0.5171
# Target Avg Loss : 0.8787
# Source Avg reg Loss : 0.0283
# Target Avg reg Loss : 0.0315
# Source Avg cla Loss : 0.4888
# Target Avg cla Loss : 0.8472
# Avg Regression Loss : 0.0598
# Avg Classification Loss : 1.3360
#
# Epoch : 155, Total Avg Loss : 1.3972
# Source Avg Loss : 0.5237
# Target Avg Loss : 0.8734
# Source Avg reg Loss : 0.0311
# Target Avg reg Loss : 0.0285
# Source Avg cla Loss : 0.4926
# Target Avg cla Loss : 0.8449
# Avg Regression Loss : 0.0596
# Avg Classification Loss : 1.3376
#
# Epoch : 156, Total Avg Loss : 1.3912
# Source Avg Loss : 0.5141
# Target Avg Loss : 0.8770
# Source Avg reg Loss : 0.0271
# Target Avg reg Loss : 0.0306
# Source Avg cla Loss : 0.4870
# Target Avg cla Loss : 0.8464
# Avg Regression Loss : 0.0577
# Avg Classification Loss : 1.3334
#
# Epoch : 157, Total Avg Loss : 1.4195
# Source Avg Loss : 0.5318
# Target Avg Loss : 0.8877
# Source Avg reg Loss : 0.0447
# Target Avg reg Loss : 0.0349
# Source Avg cla Loss : 0.4871
# Target Avg cla Loss : 0.8528
# Avg Regression Loss : 0.0795
# Avg Classification Loss : 1.3399
#
# Epoch : 158, Total Avg Loss : 1.4395
# Source Avg Loss : 0.5530
# Target Avg Loss : 0.8866
# Source Avg reg Loss : 0.0612
# Target Avg reg Loss : 0.0433
# Source Avg cla Loss : 0.4918
# Target Avg cla Loss : 0.8433
# Avg Regression Loss : 0.1045
# Avg Classification Loss : 1.3351
#
# Epoch : 159, Total Avg Loss : 1.4028
# Source Avg Loss : 0.5184
# Target Avg Loss : 0.8844
# Source Avg reg Loss : 0.0302
# Target Avg reg Loss : 0.0369
# Source Avg cla Loss : 0.4882
# Target Avg cla Loss : 0.8475
# Avg Regression Loss : 0.0672
# Avg Classification Loss : 1.3356
#
# Epoch : 160, Total Avg Loss : 1.4086
# Source Avg Loss : 0.5301
# Target Avg Loss : 0.8785
# Source Avg reg Loss : 0.0358
# Target Avg reg Loss : 0.0322
# Source Avg cla Loss : 0.4943
# Target Avg cla Loss : 0.8464
# Avg Regression Loss : 0.0679
# Avg Classification Loss : 1.3407
#
# Epoch : 161, Total Avg Loss : 1.4036
# Source Avg Loss : 0.5261
# Target Avg Loss : 0.8775
# Source Avg reg Loss : 0.0360
# Target Avg reg Loss : 0.0304
# Source Avg cla Loss : 0.4901
# Target Avg cla Loss : 0.8471
# Avg Regression Loss : 0.0665
# Avg Classification Loss : 1.3372
#
# Epoch : 162, Total Avg Loss : 1.4211
# Source Avg Loss : 0.5330
# Target Avg Loss : 0.8881
# Source Avg reg Loss : 0.0453
# Target Avg reg Loss : 0.0355
# Source Avg cla Loss : 0.4877
# Target Avg cla Loss : 0.8526
# Avg Regression Loss : 0.0809
# Avg Classification Loss : 1.3403
#
# Epoch : 163, Total Avg Loss : 1.4382
# Source Avg Loss : 0.5476
# Target Avg Loss : 0.8907
# Source Avg reg Loss : 0.0571
# Target Avg reg Loss : 0.0453
# Source Avg cla Loss : 0.4905
# Target Avg cla Loss : 0.8454
# Avg Regression Loss : 0.1023
# Avg Classification Loss : 1.3359
#
# Epoch : 164, Total Avg Loss : 1.4178
# Source Avg Loss : 0.5325
# Target Avg Loss : 0.8853
# Source Avg reg Loss : 0.0453
# Target Avg reg Loss : 0.0385
# Source Avg cla Loss : 0.4873
# Target Avg cla Loss : 0.8468
# Avg Regression Loss : 0.0837
# Avg Classification Loss : 1.3341
#
# Epoch : 165, Total Avg Loss : 1.4364
# Source Avg Loss : 0.5396
# Target Avg Loss : 0.8968
# Source Avg reg Loss : 0.0543
# Target Avg reg Loss : 0.0428
# Source Avg cla Loss : 0.4853
# Target Avg cla Loss : 0.8540
# Avg Regression Loss : 0.0971
# Avg Classification Loss : 1.3393
#
# Epoch : 166, Total Avg Loss : 1.4718
# Source Avg Loss : 0.5707
# Target Avg Loss : 0.9010
# Source Avg reg Loss : 0.0724
# Target Avg reg Loss : 0.0591
# Source Avg cla Loss : 0.4984
# Target Avg cla Loss : 0.8419
# Avg Regression Loss : 0.1315
# Avg Classification Loss : 1.3403
#
# Epoch : 167, Total Avg Loss : 1.4640
# Source Avg Loss : 0.5693
# Target Avg Loss : 0.8947
# Source Avg reg Loss : 0.0676
# Target Avg reg Loss : 0.0547
# Source Avg cla Loss : 0.5017
# Target Avg cla Loss : 0.8400
# Avg Regression Loss : 0.1224
# Avg Classification Loss : 1.3416
#
# Epoch : 168, Total Avg Loss : 1.4593
# Source Avg Loss : 0.5687
# Target Avg Loss : 0.8906
# Source Avg reg Loss : 0.0628
# Target Avg reg Loss : 0.0528
# Source Avg cla Loss : 0.5059
# Target Avg cla Loss : 0.8378
# Avg Regression Loss : 0.1157
# Avg Classification Loss : 1.3436
#
# Epoch : 169, Total Avg Loss : 1.4839
# Source Avg Loss : 0.5993
# Target Avg Loss : 0.8846
# Source Avg reg Loss : 0.0696
# Target Avg reg Loss : 0.0560
# Source Avg cla Loss : 0.5298
# Target Avg cla Loss : 0.8285
# Avg Regression Loss : 0.1256
# Avg Classification Loss : 1.3583
#
# Epoch : 170, Total Avg Loss : 1.5033
# Source Avg Loss : 0.6125
# Target Avg Loss : 0.8909
# Source Avg reg Loss : 0.0698
# Target Avg reg Loss : 0.0647
# Source Avg cla Loss : 0.5427
# Target Avg cla Loss : 0.8262
# Avg Regression Loss : 0.1345
# Avg Classification Loss : 1.3689
#
# Epoch : 171, Total Avg Loss : 1.4882
# Source Avg Loss : 0.6189
# Target Avg Loss : 0.8693
# Source Avg reg Loss : 0.0647
# Target Avg reg Loss : 0.0566
# Source Avg cla Loss : 0.5542
# Target Avg cla Loss : 0.8127
# Avg Regression Loss : 0.1213
# Avg Classification Loss : 1.3669
#
# Epoch : 172, Total Avg Loss : 1.4852
# Source Avg Loss : 0.6242
# Target Avg Loss : 0.8609
# Source Avg reg Loss : 0.0655
# Target Avg reg Loss : 0.0534
# Source Avg cla Loss : 0.5587
# Target Avg cla Loss : 0.8075
# Avg Regression Loss : 0.1189
# Avg Classification Loss : 1.3662
#
# Epoch : 173, Total Avg Loss : 1.4775
# Source Avg Loss : 0.6223
# Target Avg Loss : 0.8553
# Source Avg reg Loss : 0.0656
# Target Avg reg Loss : 0.0521
# Source Avg cla Loss : 0.5567
# Target Avg cla Loss : 0.8031
# Avg Regression Loss : 0.1178
# Avg Classification Loss : 1.3598
#
# Epoch : 174, Total Avg Loss : 1.4539
# Source Avg Loss : 0.6072
# Target Avg Loss : 0.8468
# Source Avg reg Loss : 0.0582
# Target Avg reg Loss : 0.0451
# Source Avg cla Loss : 0.5490
# Target Avg cla Loss : 0.8017
# Avg Regression Loss : 0.1033
# Avg Classification Loss : 1.3507
#
# Epoch : 175, Total Avg Loss : 1.4539
# Source Avg Loss : 0.5652
# Target Avg Loss : 0.8887
# Source Avg reg Loss : 0.0573
# Target Avg reg Loss : 0.0465
# Source Avg cla Loss : 0.5079
# Target Avg cla Loss : 0.8423
# Avg Regression Loss : 0.1037
# Avg Classification Loss : 1.3502
#
# Epoch : 176, Total Avg Loss : 1.4978
# Source Avg Loss : 0.5952
# Target Avg Loss : 0.9027
# Source Avg reg Loss : 0.0650
# Target Avg reg Loss : 0.0692
# Source Avg cla Loss : 0.5302
# Target Avg cla Loss : 0.8334
# Avg Regression Loss : 0.1342
# Avg Classification Loss : 1.3636
#
# Epoch : 177, Total Avg Loss : 1.4350
# Source Avg Loss : 0.5771
# Target Avg Loss : 0.8579
# Source Avg reg Loss : 0.0537
# Target Avg reg Loss : 0.0405
# Source Avg cla Loss : 0.5234
# Target Avg cla Loss : 0.8174
# Avg Regression Loss : 0.0941
# Avg Classification Loss : 1.3409
#
# Epoch : 178, Total Avg Loss : 1.4316
# Source Avg Loss : 0.5613
# Target Avg Loss : 0.8703
# Source Avg reg Loss : 0.0516
# Target Avg reg Loss : 0.0381
# Source Avg cla Loss : 0.5097
# Target Avg cla Loss : 0.8322
# Avg Regression Loss : 0.0897
# Avg Classification Loss : 1.3419
#
# Epoch : 179, Total Avg Loss : 1.4417
# Source Avg Loss : 0.5479
# Target Avg Loss : 0.8938
# Source Avg reg Loss : 0.0485
# Target Avg reg Loss : 0.0404
# Source Avg cla Loss : 0.4994
# Target Avg cla Loss : 0.8534
# Avg Regression Loss : 0.0889
# Avg Classification Loss : 1.3528
#
# Epoch : 180, Total Avg Loss : 1.5412
# Source Avg Loss : 0.5395
# Target Avg Loss : 1.0017
# Source Avg reg Loss : 0.0476
# Target Avg reg Loss : 0.0741
# Source Avg cla Loss : 0.4919
# Target Avg cla Loss : 0.9276
# Avg Regression Loss : 0.1216
# Avg Classification Loss : 1.4195
#
# Epoch : 181, Total Avg Loss : 1.5199
# Source Avg Loss : 0.5929
# Target Avg Loss : 0.9269
# Source Avg reg Loss : 0.0529
# Target Avg reg Loss : 0.0783
# Source Avg cla Loss : 0.5401
# Target Avg cla Loss : 0.8486
# ...
#
# Epoch : 383, Total Avg Loss : 1.4302
# Source Avg Loss : 0.5740
# Target Avg Loss : 0.8562
# Source Avg reg Loss : 0.0451
# Target Avg reg Loss : 0.0303
# Source Avg cla Loss : 0.5289
# Target Avg cla Loss : 0.8259
# Avg Regression Loss : 0.0754
# Avg Classification Loss : 1.3549
#
# Epoch : 384, Total Avg Loss : 1.4614
# Source Avg Loss : 0.6429
# Target Avg Loss : 0.8185
# Source Avg reg Loss : 0.0485
# Target Avg reg Loss : 0.0388
# Source Avg cla Loss : 0.5944
# Target Avg cla Loss : 0.7796
# Avg Regression Loss : 0.0873
# Avg Classification Loss : 1.3741
#
# Epoch : 385, Total Avg Loss : 1.4592
# Source Avg Loss : 0.6865
# Target Avg Loss : 0.7727
# Source Avg reg Loss : 0.0488
# Target Avg reg Loss : 0.0364
# Source Avg cla Loss : 0.6377
# Target Avg cla Loss : 0.7363
# Avg Regression Loss : 0.0852
# Avg Classification Loss : 1.3740
#
# Epoch : 386, Total Avg Loss : 1.4161
# Source Avg Loss : 0.5752
# Target Avg Loss : 0.8409
# Source Avg reg Loss : 0.0369
# Target Avg reg Loss : 0.0277
# Source Avg cla Loss : 0.5384
# Target Avg cla Loss : 0.8132
# Avg Regression Loss : 0.0645
# Avg Classification Loss : 1.3515
#
# Epoch : 387, Total Avg Loss : 1.4259
# Source Avg Loss : 0.5670
# Target Avg Loss : 0.8590
# Source Avg reg Loss : 0.0409
# Target Avg reg Loss : 0.0350
# Source Avg cla Loss : 0.5261
# Target Avg cla Loss : 0.8239
# Avg Regression Loss : 0.0759
# Avg Classification Loss : 1.3500
#
# Epoch : 388, Total Avg Loss : 1.4811
# Source Avg Loss : 0.5993
# Target Avg Loss : 0.8818
# Source Avg reg Loss : 0.0731
# Target Avg reg Loss : 0.0541
# Source Avg cla Loss : 0.5262
# Target Avg cla Loss : 0.8278
# Avg Regression Loss : 0.1271
# Avg Classification Loss : 1.3540
#
# Epoch : 389, Total Avg Loss : 1.4478
# Source Avg Loss : 0.5641
# Target Avg Loss : 0.8837
# Source Avg reg Loss : 0.0503
# Target Avg reg Loss : 0.0466
# Source Avg cla Loss : 0.5138
# Target Avg cla Loss : 0.8370
# Avg Regression Loss : 0.0969
# Avg Classification Loss : 1.3509
#
# Epoch : 390, Total Avg Loss : 1.4803
# Source Avg Loss : 0.5835
# Target Avg Loss : 0.8968
# Source Avg reg Loss : 0.0705
# Target Avg reg Loss : 0.0591
# Source Avg cla Loss : 0.5130
# Target Avg cla Loss : 0.8377
# Avg Regression Loss : 0.1296
# Avg Classification Loss : 1.3507
#
# Epoch : 391, Total Avg Loss : 1.4545
# Source Avg Loss : 0.5774
# Target Avg Loss : 0.8770
# Source Avg reg Loss : 0.0636
# Target Avg reg Loss : 0.0442
# Source Avg cla Loss : 0.5139
# Target Avg cla Loss : 0.8328
# Avg Regression Loss : 0.1078
# Avg Classification Loss : 1.3467
#
# Epoch : 392, Total Avg Loss : 1.4527
# Source Avg Loss : 0.5707
# Target Avg Loss : 0.8820
# Source Avg reg Loss : 0.0454
# Target Avg reg Loss : 0.0446
# Source Avg cla Loss : 0.5253
# Target Avg cla Loss : 0.8374
# Avg Regression Loss : 0.0900
# Avg Classification Loss : 1.3627
#
# Epoch : 393, Total Avg Loss : 1.4179
# Source Avg Loss : 0.5528
# Target Avg Loss : 0.8651
# Source Avg reg Loss : 0.0386
# Target Avg reg Loss : 0.0313
# Source Avg cla Loss : 0.5142
# Target Avg cla Loss : 0.8338
# Avg Regression Loss : 0.0699
# Avg Classification Loss : 1.3480
#
# Epoch : 394, Total Avg Loss : 1.4375
# Source Avg Loss : 0.5793
# Target Avg Loss : 0.8581
# Source Avg reg Loss : 0.0497
# Target Avg reg Loss : 0.0339
# Source Avg cla Loss : 0.5297
# Target Avg cla Loss : 0.8242
# Avg Regression Loss : 0.0835
# Avg Classification Loss : 1.3539
#
# Epoch : 395, Total Avg Loss : 1.4167
# Source Avg Loss : 0.5710
# Target Avg Loss : 0.8457
# Source Avg reg Loss : 0.0393
# Target Avg reg Loss : 0.0294
# Source Avg cla Loss : 0.5318
# Target Avg cla Loss : 0.8162
# Avg Regression Loss : 0.0687
# Avg Classification Loss : 1.3480
#
# Epoch : 396, Total Avg Loss : 1.4018
# Source Avg Loss : 0.5643
# Target Avg Loss : 0.8375
# Source Avg reg Loss : 0.0298
# Target Avg reg Loss : 0.0237
# Source Avg cla Loss : 0.5346
# Target Avg cla Loss : 0.8138
# Avg Regression Loss : 0.0534
# Avg Classification Loss : 1.3484
#
# Epoch : 397, Total Avg Loss : 1.4183
# Source Avg Loss : 0.5844
# Target Avg Loss : 0.8339
# Source Avg reg Loss : 0.0330
# Target Avg reg Loss : 0.0234
# Source Avg cla Loss : 0.5514
# Target Avg cla Loss : 0.8106
# Avg Regression Loss : 0.0564
# Avg Classification Loss : 1.3620
#
# Epoch : 398, Total Avg Loss : 1.4161
# Source Avg Loss : 0.5668
# Target Avg Loss : 0.8493
# Source Avg reg Loss : 0.0355
# Target Avg reg Loss : 0.0261
# Source Avg cla Loss : 0.5313
# Target Avg cla Loss : 0.8232
# Avg Regression Loss : 0.0615
# Avg Classification Loss : 1.3545
#
# Epoch : 399, Total Avg Loss : 1.4389
# Source Avg Loss : 0.5782
# Target Avg Loss : 0.8608
# Source Avg reg Loss : 0.0462
# Target Avg reg Loss : 0.0386
# Source Avg cla Loss : 0.5320
# Target Avg cla Loss : 0.8222
# Avg Regression Loss : 0.0847
# Avg Classification Loss : 1.3542
#
# Epoch : 400, Total Avg Loss : 1.4818
# Source Avg Loss : 0.5930
# Target Avg Loss : 0.8888
# Source Avg reg Loss : 0.0754
# Target Avg reg Loss : 0.0562
# Source Avg cla Loss : 0.5176
# Target Avg cla Loss : 0.8326
# Avg Regression Loss : 0.1316
# Avg Classification Loss : 1.3502
#
# Epoch : 401, Total Avg Loss : 1.4735
# Source Avg Loss : 0.5859
# Target Avg Loss : 0.8876
# Source Avg reg Loss : 0.0613
# Target Avg reg Loss : 0.0571
# Source Avg cla Loss : 0.5246
# Target Avg cla Loss : 0.8305
# Avg Regression Loss : 0.1184
# Avg Classification Loss : 1.3551
#
# Epoch : 402, Total Avg Loss : 1.4558
# Source Avg Loss : 0.5730
# Target Avg Loss : 0.8828
# Source Avg reg Loss : 0.0574
# Target Avg reg Loss : 0.0459
# Source Avg cla Loss : 0.5157
# Target Avg cla Loss : 0.8369
# Avg Regression Loss : 0.1033
# Avg Classification Loss : 1.3526
#
# Epoch : 403, Total Avg Loss : 1.4311
# Source Avg Loss : 0.5836
# Target Avg Loss : 0.8475
# Source Avg reg Loss : 0.0401
# Target Avg reg Loss : 0.0324
# Source Avg cla Loss : 0.5435
# Target Avg cla Loss : 0.8151
# Avg Regression Loss : 0.0726
# Avg Classification Loss : 1.3586
#
# Epoch : 404, Total Avg Loss : 1.4254
# Source Avg Loss : 0.5777
# Target Avg Loss : 0.8477
# Source Avg reg Loss : 0.0434
# Target Avg reg Loss : 0.0329
# Source Avg cla Loss : 0.5343
# Target Avg cla Loss : 0.8148
# Avg Regression Loss : 0.0763
# Avg Classification Loss : 1.3491
#
# Epoch : 405, Total Avg Loss : 1.4182
# Source Avg Loss : 0.5791
# Target Avg Loss : 0.8390
# Source Avg reg Loss : 0.0348
# Target Avg reg Loss : 0.0270
# Source Avg cla Loss : 0.5444
# Target Avg cla Loss : 0.8120
# Avg Regression Loss : 0.0618
# Avg Classification Loss : 1.3564
#
# Epoch : 406, Total Avg Loss : 1.4111
# Source Avg Loss : 0.5587
# Target Avg Loss : 0.8524
# Source Avg reg Loss : 0.0331
# Target Avg reg Loss : 0.0266
# Source Avg cla Loss : 0.5256
# Target Avg cla Loss : 0.8258
# Avg Regression Loss : 0.0597
# Avg Classification Loss : 1.3514
#
# Epoch : 407, Total Avg Loss : 1.4169
# Source Avg Loss : 0.5625
# Target Avg Loss : 0.8544
# Source Avg reg Loss : 0.0342
# Target Avg reg Loss : 0.0283
# Source Avg cla Loss : 0.5284
# Target Avg cla Loss : 0.8260
# Avg Regression Loss : 0.0625
# Avg Classification Loss : 1.3544
#
# Epoch : 408, Total Avg Loss : 1.4509
# Source Avg Loss : 0.6115
# Target Avg Loss : 0.8394
# Source Avg reg Loss : 0.0529
# Target Avg reg Loss : 0.0376
# Source Avg cla Loss : 0.5586
# Target Avg cla Loss : 0.8019
# Avg Regression Loss : 0.0905
# Avg Classification Loss : 1.3605
#
# Epoch : 409, Total Avg Loss : 1.4212
# Source Avg Loss : 0.5803
# Target Avg Loss : 0.8409
# Source Avg reg Loss : 0.0387
# Target Avg reg Loss : 0.0306
# Source Avg cla Loss : 0.5416
# Target Avg cla Loss : 0.8103
# Avg Regression Loss : 0.0693
# Avg Classification Loss : 1.3519
#
# Epoch : 410, Total Avg Loss : 1.4289
# Source Avg Loss : 0.6058
# Target Avg Loss : 0.8231
# Source Avg reg Loss : 0.0363
# Target Avg reg Loss : 0.0278
# Source Avg cla Loss : 0.5695
# Target Avg cla Loss : 0.7953
# Avg Regression Loss : 0.0641
# Avg Classification Loss : 1.3648
#
# Epoch : 411, Total Avg Loss : 1.4373
# Source Avg Loss : 0.5941
# Target Avg Loss : 0.8432
# Source Avg reg Loss : 0.0386
# Target Avg reg Loss : 0.0312
# Source Avg cla Loss : 0.5555
# Target Avg cla Loss : 0.8120
# Avg Regression Loss : 0.0698
# Avg Classification Loss : 1.3675
#
# Epoch : 412, Total Avg Loss : 1.4460
# Source Avg Loss : 0.6135
# Target Avg Loss : 0.8325
# Source Avg reg Loss : 0.0480
# Target Avg reg Loss : 0.0376
# Source Avg cla Loss : 0.5656
# Target Avg cla Loss : 0.7949
# Avg Regression Loss : 0.0856
# Avg Classification Loss : 1.3605
#
# Epoch : 413, Total Avg Loss : 1.4386
# Source Avg Loss : 0.5877
# Target Avg Loss : 0.8508
# Source Avg reg Loss : 0.0460
# Target Avg reg Loss : 0.0346
# Source Avg cla Loss : 0.5417
# Target Avg cla Loss : 0.8162
# Avg Regression Loss : 0.0806
# Avg Classification Loss : 1.3579
#
# Epoch : 414, Total Avg Loss : 1.4331
# Source Avg Loss : 0.6062
# Target Avg Loss : 0.8269
# Source Avg reg Loss : 0.0391
# Target Avg reg Loss : 0.0306
# Source Avg cla Loss : 0.5671
# Target Avg cla Loss : 0.7962
# Avg Regression Loss : 0.0697
# Avg Classification Loss : 1.3633
#
# Epoch : 415, Total Avg Loss : 1.4211
# Source Avg Loss : 0.5828
# Target Avg Loss : 0.8383
# Source Avg reg Loss : 0.0424
# Target Avg reg Loss : 0.0346
# Source Avg cla Loss : 0.5404
# Target Avg cla Loss : 0.8037
# Avg Regression Loss : 0.0770
# Avg Classification Loss : 1.3441
#
# Epoch : 416, Total Avg Loss : 1.4841
# Source Avg Loss : 0.7264
# Target Avg Loss : 0.7577
# Source Avg reg Loss : 0.0564
# Target Avg reg Loss : 0.0396
# Source Avg cla Loss : 0.6700
# Target Avg cla Loss : 0.7181
# Avg Regression Loss : 0.0960
# Avg Classification Loss : 1.3882
#
# Epoch : 417, Total Avg Loss : 1.4520
# Source Avg Loss : 0.7277
# Target Avg Loss : 0.7243
# Source Avg reg Loss : 0.0385
# Target Avg reg Loss : 0.0288
# Source Avg cla Loss : 0.6892
# Target Avg cla Loss : 0.6955
# Avg Regression Loss : 0.0673
# Avg Classification Loss : 1.3847
#
# Epoch : 418, Total Avg Loss : 1.4533
# Source Avg Loss : 0.7280
# Target Avg Loss : 0.7253
# Source Avg reg Loss : 0.0386
# Target Avg reg Loss : 0.0298
# Source Avg cla Loss : 0.6894
# Target Avg cla Loss : 0.6955
# Avg Regression Loss : 0.0684
# Avg Classification Loss : 1.3849
#
# Epoch : 419, Total Avg Loss : 1.4556
# Source Avg Loss : 0.7286
# Target Avg Loss : 0.7270
# Source Avg reg Loss : 0.0421
# Target Avg reg Loss : 0.0285
# Source Avg cla Loss : 0.6865
# Target Avg cla Loss : 0.6985
# Avg Regression Loss : 0.0706
# Avg Classification Loss : 1.3850
#
# Epoch : 420, Total Avg Loss : 1.4353
# Source Avg Loss : 0.7133
# Target Avg Loss : 0.7219
# Source Avg reg Loss : 0.0313
# Target Avg reg Loss : 0.0205
# Source Avg cla Loss : 0.6821
# Target Avg cla Loss : 0.7014
# Avg Regression Loss : 0.0518
# Avg Classification Loss : 1.3835
#
# Epoch : 421, Total Avg Loss : 1.4153
# Source Avg Loss : 0.6519
# Target Avg Loss : 0.7633
# Source Avg reg Loss : 0.0242
# Target Avg reg Loss : 0.0180
# Source Avg cla Loss : 0.6277
# Target Avg cla Loss : 0.7454
# Avg Regression Loss : 0.0422
# Avg Classification Loss : 1.3731
#
# Epoch : 422, Total Avg Loss : 1.3896
# Source Avg Loss : 0.5259
# Target Avg Loss : 0.8637
# Source Avg reg Loss : 0.0296
# Target Avg reg Loss : 0.0227
# Source Avg cla Loss : 0.4963
# Target Avg cla Loss : 0.8410
# Avg Regression Loss : 0.0523
# Avg Classification Loss : 1.3373
#
# Epoch : 423, Total Avg Loss : 1.4267
# Source Avg Loss : 0.6211
# Target Avg Loss : 0.8056
# Source Avg reg Loss : 0.0310
# Target Avg reg Loss : 0.0236
# Source Avg cla Loss : 0.5901
# Target Avg cla Loss : 0.7820
# Avg Regression Loss : 0.0546
# Avg Classification Loss : 1.3721
#
# Epoch : 424, Total Avg Loss : 1.4253
# Source Avg Loss : 0.5700
# Target Avg Loss : 0.8554
# Source Avg reg Loss : 0.0372
# Target Avg reg Loss : 0.0271
# Source Avg cla Loss : 0.5327
# Target Avg cla Loss : 0.8282
# Avg Regression Loss : 0.0644
# Avg Classification Loss : 1.3610
#
# Epoch : 425, Total Avg Loss : 1.4134
# Source Avg Loss : 0.5886
# Target Avg Loss : 0.8249
# Source Avg reg Loss : 0.0296
# Target Avg reg Loss : 0.0224
# Source Avg cla Loss : 0.5589
# Target Avg cla Loss : 0.8025
# Avg Regression Loss : 0.0520
# Avg Classification Loss : 1.3614
#
# Epoch : 426, Total Avg Loss : 1.4443
# Source Avg Loss : 0.6083
# Target Avg Loss : 0.8360
# Source Avg reg Loss : 0.0485
# Target Avg reg Loss : 0.0346
# Source Avg cla Loss : 0.5598
# Target Avg cla Loss : 0.8014
# Avg Regression Loss : 0.0831
# Avg Classification Loss : 1.3612
#
# Epoch : 427, Total Avg Loss : 1.4874
# Source Avg Loss : 0.6219
# Target Avg Loss : 0.8655
# Source Avg reg Loss : 0.0855
# Target Avg reg Loss : 0.0624
# Source Avg cla Loss : 0.5364
# Target Avg cla Loss : 0.8030
# Avg Regression Loss : 0.1480
# Avg Classification Loss : 1.3394
#
# Epoch : 428, Total Avg Loss : 1.4986
# Source Avg Loss : 0.6419
# Target Avg Loss : 0.8568
# Source Avg reg Loss : 0.0811
# Target Avg reg Loss : 0.0523
# Source Avg cla Loss : 0.5607
# Target Avg cla Loss : 0.8045
# Avg Regression Loss : 0.1334
# Avg Classification Loss : 1.3652
#
# Epoch : 429, Total Avg Loss : 1.4884
# Source Avg Loss : 0.5672
# Target Avg Loss : 0.9212
# Source Avg reg Loss : 0.0667
# Target Avg reg Loss : 0.0536
# Source Avg cla Loss : 0.5005
# Target Avg cla Loss : 0.8676
# Avg Regression Loss : 0.1203
# Avg Classification Loss : 1.3681
#
# Epoch : 430, Total Avg Loss : 1.4143
# Source Avg Loss : 0.5726
# Target Avg Loss : 0.8416
# Source Avg reg Loss : 0.0366
# Target Avg reg Loss : 0.0271
# Source Avg cla Loss : 0.5361
# Target Avg cla Loss : 0.8145
# Avg Regression Loss : 0.0637
# Avg Classification Loss : 1.3506
#
# Epoch : 431, Total Avg Loss : 1.4144
# Source Avg Loss : 0.5658
# Target Avg Loss : 0.8486
# Source Avg reg Loss : 0.0367
# Target Avg reg Loss : 0.0292
# Source Avg cla Loss : 0.5291
# Target Avg cla Loss : 0.8194
# Avg Regression Loss : 0.0659
# Avg Classification Loss : 1.3486
#
# Epoch : 432, Total Avg Loss : 1.4285
# Source Avg Loss : 0.5629
# Target Avg Loss : 0.8657
# Source Avg reg Loss : 0.0447
# Target Avg reg Loss : 0.0342
# Source Avg cla Loss : 0.5182
# Target Avg cla Loss : 0.8315
# Avg Regression Loss : 0.0788
# Avg Classification Loss : 1.3497
#
# Epoch : 433, Total Avg Loss : 1.4201
# Source Avg Loss : 0.5515
# Target Avg Loss : 0.8686
# Source Avg reg Loss : 0.0370
# Target Avg reg Loss : 0.0304
# Source Avg cla Loss : 0.5145
# Target Avg cla Loss : 0.8383
# Avg Regression Loss : 0.0674
# Avg Classification Loss : 1.3527
#
# Epoch : 434, Total Avg Loss : 1.4289
# Source Avg Loss : 0.6037
# Target Avg Loss : 0.8252
# Source Avg reg Loss : 0.0383
# Target Avg reg Loss : 0.0300
# Source Avg cla Loss : 0.5654
# Target Avg cla Loss : 0.7952
# Avg Regression Loss : 0.0682
# Avg Classification Loss : 1.3607
#
# Epoch : 435, Total Avg Loss : 1.4278
# Source Avg Loss : 0.5816
# Target Avg Loss : 0.8462
# Source Avg reg Loss : 0.0434
# Target Avg reg Loss : 0.0355
# Source Avg cla Loss : 0.5383
# Target Avg cla Loss : 0.8107
# Avg Regression Loss : 0.0788
# Avg Classification Loss : 1.3490
#
# Epoch : 436, Total Avg Loss : 1.4624
# Source Avg Loss : 0.6697
# Target Avg Loss : 0.7927
# Source Avg reg Loss : 0.0502
# Target Avg reg Loss : 0.0369
# Source Avg cla Loss : 0.6195
# Target Avg cla Loss : 0.7558
# Avg Regression Loss : 0.0871
# Avg Classification Loss : 1.3753
#
# Epoch : 437, Total Avg Loss : 1.4108
# Source Avg Loss : 0.5624
# Target Avg Loss : 0.8484
# Source Avg reg Loss : 0.0325
# Target Avg reg Loss : 0.0289
# Source Avg cla Loss : 0.5299
# Target Avg cla Loss : 0.8195
# Avg Regression Loss : 0.0614
# Avg Classification Loss : 1.3493
#
# Epoch : 438, Total Avg Loss : 1.4429
# Source Avg Loss : 0.6817
# Target Avg Loss : 0.7613
# Source Avg reg Loss : 0.0367
# Target Avg reg Loss : 0.0287
# Source Avg cla Loss : 0.6449
# Target Avg cla Loss : 0.7326
# Avg Regression Loss : 0.0654
# Avg Classification Loss : 1.3775
#
# Epoch : 439, Total Avg Loss : 1.4131
# Source Avg Loss : 0.6110
# Target Avg Loss : 0.8020
# Source Avg reg Loss : 0.0283
# Target Avg reg Loss : 0.0200
# Source Avg cla Loss : 0.5827
# Target Avg cla Loss : 0.7820
# Avg Regression Loss : 0.0484
# Avg Classification Loss : 1.3647
#
# Epoch : 440, Total Avg Loss : 1.4256
# Source Avg Loss : 0.5686
# Target Avg Loss : 0.8570
# Source Avg reg Loss : 0.0375
# Target Avg reg Loss : 0.0286
# Source Avg cla Loss : 0.5311
# Target Avg cla Loss : 0.8284
# Avg Regression Loss : 0.0661
# Avg Classification Loss : 1.3595
#
# Epoch : 441, Total Avg Loss : 1.4026
# Source Avg Loss : 0.5591
# Target Avg Loss : 0.8435
# Source Avg reg Loss : 0.0303
# Target Avg reg Loss : 0.0247
# Source Avg cla Loss : 0.5288
# Target Avg cla Loss : 0.8188
# Avg Regression Loss : 0.0550
# Avg Classification Loss : 1.3476
#
# Epoch : 442, Total Avg Loss : 1.4466
# Source Avg Loss : 0.6393
# Target Avg Loss : 0.8073
# Source Avg reg Loss : 0.0419
# Target Avg reg Loss : 0.0322
# Source Avg cla Loss : 0.5974
# Target Avg cla Loss : 0.7751
# Avg Regression Loss : 0.0741
# Avg Classification Loss : 1.3725
#
# Early stopping at epoch 443

# %%
# from torchinfo import summary

# summary(model, (512,3,12))

# %% [markdown]
# # train 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('0810hoxyhoxy.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []
s_d_pred = []
t_d_pred = []

for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    source_domain_label_pred, source_pred = best_source_model2(sourcex)
    target_domain_label_pred, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())
    s_d_pred.extend(source_domain_label_pred.detach().cpu().numpy())
    t_d_pred.extend(target_domain_label_pred.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: -0.539389251684899
# TARGET R2 Score: 0.6709544135354315

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# # test 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('0810hoxyhoxy.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []


for step, (source_data, target_data) in enumerate(zip(NELEC_test, DHW_test)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    _, source_pred = best_source_model2(sourcex)
    _, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: -0.6361989032011299
# TARGET R2 Score: 0.7210330858348509

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# ### Domain Embedding Space 시각화

# %%
# 가장 앞 batch의 250개씩의 데이터만 샘플링
source_tsne = DataLoader(nelec_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

target_tsne = DataLoader(dhw_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

source_tsne2 = next(iter(source_tsne))
target_tsne2 = next(iter(target_tsne))

source_x_TNSE = source_tsne2[0].to(device)
source_y_TNSE = source_tsne2[1].to(device)

target_x_TNSE = target_tsne2[0].to(device)
target_y_TNSE = target_tsne2[1].to(device)

# 학습된 모델의 LSTM 부분만 활용 (100차원 임베딩 벡터를 받아오는 과정)
source_vector = model.lstm(source_x_TNSE)
target_vector = model.lstm(target_x_TNSE)

# %%
from sklearn.manifold import TSNE

df = pd.DataFrame(np.concatenate([source_vector.cpu().detach().numpy(), target_vector.cpu().detach().numpy()]))

tsne_np = TSNE(n_components=2).fit_transform(df)
tsne_df = pd.DataFrame(tsne_np, columns=['component 0', 'component 1'])

# %%
tsne_df_0 = tsne_df.loc[:1000]
tsne_df_1 = tsne_df.loc[1000:]

plt.scatter(tsne_df_0['component 0'], tsne_df_0['component 1'], color='green', label='NELEC', alpha=0.5)
plt.scatter(tsne_df_1['component 0'], tsne_df_1['component 1'], color='black', label='DHW', alpha=0.5)

plt.title('alpha = '+ str(alpha))
plt.xlabel('component 0')
plt.ylabel('component 1')
plt.legend()
plt.show()
