# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.utils.data as data_util
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import MinMaxScaler
from torchsummary import summary
from sklearn.metrics import r2_score

# %%
CUDA = torch.cuda.is_available()
print(CUDA)

device = torch.device('cuda:0' if CUDA else 'cpu')
# Out:
# True

# %%
elec = pd.read_csv('elec_merge.csv')
nelec = pd.read_csv('n_elec_merge.csv')
dhw = pd.read_csv('dhw_merge.csv')

# %%
elec = elec.drop(['YEAR'], axis=1)
nelec = nelec.drop(['YEAR'], axis=1)
dhw = dhw.drop(['YEAR'], axis=1)

# %%
input_nelec = nelec.iloc[:-1,].reset_index(drop=True)
output_nelec = nelec[['n_elec']].iloc[1:].reset_index(drop=True)
output_nelec.columns = ['nelec']

input_elec = elec.iloc[:-1,].reset_index(drop=True)
output_elec = elec[['ELEC']].iloc[1:].reset_index(drop=True)
output_elec.columns = ['elec']

input_dhw = dhw.iloc[:-1,].reset_index(drop=True)
output_dhw = dhw[['DHW']].iloc[1:].reset_index(drop=True)
output_dhw.columns = ['dhw']

nelec = pd.concat([input_nelec, output_nelec], axis=1)
elec = pd.concat([input_elec, output_elec], axis=1)
dhw = pd.concat([input_dhw, output_dhw], axis=1)

# input_nelec = nelec.iloc[:-1,:-1].reset_index(drop=True)
# output_nelec = nelec[['n_elec']].iloc[:-1].reset_index(drop=True)
# output_nelec2 = nelec['n_elec'][1:].reset_index(drop=True)
# output_nelec['nelec'] = output_nelec2

# input_elec = elec.iloc[:-1,:-1].reset_index(drop=True)
# output_elec = elec[['ELEC']].iloc[:-1].reset_index(drop=True)
# output_elec2= elec['ELEC'][1:].reset_index(drop=True)
# output_elec['elec'] = output_elec2

# input_dhw = dhw.iloc[:-1,:-1].reset_index(drop=True)
# output_dhw = dhw[['DHW']].iloc[:-1].reset_index(drop=True)
# output_dhw2 = dhw['DHW'][1:].reset_index(drop=True)
# output_dhw['dhw'] = output_dhw2

# %%
scaler_nelec = MinMaxScaler()
scaler_elec = MinMaxScaler()
scaler_dhw = MinMaxScaler()

scaler_nelec.fit(nelec)
scaler_elec.fit(elec)
scaler_dhw.fit(dhw)

scaled_nelec = scaler_nelec.transform(nelec)
scaled_elec = scaler_elec.transform(elec)
scaled_dhw = scaler_dhw.transform(dhw)

nelec = pd.DataFrame(scaled_nelec, index=nelec.index, columns=nelec.columns)
elec = pd.DataFrame(scaled_elec, index=elec.index, columns=elec.columns)
dhw = pd.DataFrame(scaled_dhw, index=dhw.index, columns=dhw.columns)

# scaler_nelec = MinMaxScaler()
# scaler_elec = MinMaxScaler()
# scaler_dhw = MinMaxScaler()

# scaler_nelec.fit(input_nelec)
# scaler_elec.fit(input_elec)
# scaler_dhw.fit(input_dhw)

# scaled_nelec = scaler_nelec.transform(input_nelec)
# scaled_elec = scaler_elec.transform(input_elec)
# scaled_dhw = scaler_dhw.transform(input_dhw)

# nelec_x = pd.DataFrame(scaled_nelec, index=input_nelec.index, columns=input_nelec.columns)
# elec_x = pd.DataFrame(scaled_elec, index=input_elec.index, columns=input_elec.columns)
# dhw_x = pd.DataFrame(scaled_dhw, index=input_dhw.index, columns=input_dhw.columns)

# nelec = pd.concat([nelec_x, output_nelec], axis=1)
# elec = pd.concat([elec_x, output_elec], axis=1)
# dhw = pd.concat([dhw_x, output_dhw], axis=1)

# %%
standard_nelec = int(len(nelec) * 0.7)
standard_elec = int(len(elec) * 0.7)
standard_dhw = int(len(dhw) * 0.7)

nelec_train = nelec.iloc[:standard_nelec]
nelec_test = nelec.iloc[standard_nelec:].reset_index(drop=True)

elec_train = elec.iloc[:standard_elec]
elec_test = elec.iloc[standard_elec:].reset_index(drop=True)

dhw_train = dhw.iloc[:standard_dhw]
dhw_test = dhw.iloc[standard_dhw:].reset_index(drop=True)

# %%
nelec_trainx = nelec_train.drop(['nelec'], axis=1)
nelec_trainy = nelec_train[['nelec']]

nelec_testx = nelec_test.drop(['nelec'], axis=1)
nelec_testy = nelec_test[['nelec']]

elec_trainx = elec_train.drop(['elec'], axis=1)
elec_trainy = elec_train[['elec']]

elec_testx = elec_test.drop(['elec'], axis=1)
elec_testy = elec_test[['elec']]

dhw_trainx = dhw_train.drop(['dhw'], axis=1)
dhw_trainy = dhw_train[['dhw']]

dhw_testx = dhw_test.drop(['dhw'], axis=1)
dhw_testy = dhw_test[['dhw']]

# %%
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-7]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

nelec_trainx, nelec_trainy = buildDataSet(nelec_trainx, nelec_trainy, 7)
nelec_testx, nelec_testy = buildDataSet(nelec_testx, nelec_testy, 7)

elec_trainx, elec_trainy = buildDataSet(elec_trainx, elec_trainy, 7)
elec_testx, elec_testy = buildDataSet(elec_testx, elec_testy, 7)

dhw_trainx, dhw_trainy = buildDataSet(dhw_trainx, dhw_trainy, 7)
dhw_testx, dhw_testy = buildDataSet(dhw_testx, dhw_testy, 7)

# %%
print(nelec_trainx.shape)
print(nelec_trainy.shape)
print(nelec_testx.shape)
print(nelec_testy.shape)
print(elec_trainx.shape)
print(elec_trainy.shape)
print(elec_testx.shape)
print(elec_testy.shape)
print(dhw_trainx.shape)
print(dhw_trainy.shape)
print(dhw_testx.shape)
print(dhw_testy.shape)
# Out:
# (20409, 7, 12)
# (20409, 1)
# (8744, 7, 12)
# (8744, 1)
# (2984, 7, 12)
# (2984, 1)
# (1275, 7, 12)
# (1275, 1)
# (20409, 7, 12)
# (20409, 1)
# (8744, 7, 12)
# (8744, 1)

# %%
# 텐서로 변환
nelec_trainx_tensor = torch.FloatTensor(nelec_trainx)
nelec_trainy_tensor = torch.FloatTensor(nelec_trainy)

nelec_testx_tensor = torch.FloatTensor(nelec_testx)
nelec_testy_tensor = torch.FloatTensor(nelec_testy)

elec_trainx_tensor = torch.FloatTensor(elec_trainx)
elec_trainy_tensor = torch.FloatTensor(elec_trainy)

elec_testx_tensor = torch.FloatTensor(elec_testx)
elec_testy_tensor = torch.FloatTensor(elec_testy)

dhw_trainx_tensor = torch.FloatTensor(dhw_trainx)
dhw_trainy_tensor = torch.FloatTensor(dhw_trainy)

dhw_testx_tensor = torch.FloatTensor(dhw_testx)
dhw_testy_tensor = torch.FloatTensor(dhw_testy)

# %%
# 텐서 형태로 데이터 정의
nelec_train = TensorDataset(nelec_trainx_tensor, nelec_trainy_tensor)
nelec_test = TensorDataset(nelec_testx_tensor, nelec_testy_tensor)

elec_train = TensorDataset(elec_trainx_tensor, elec_trainy_tensor)
elec_test = TensorDataset(elec_testx_tensor, elec_testy_tensor)

dhw_train = TensorDataset(dhw_trainx_tensor, dhw_trainy_tensor)
dhw_test = TensorDataset(dhw_testx_tensor, dhw_testy_tensor)

# %%
batch_for_nelec_train = len(nelec_trainx)
batch_for_nelec_test = len(nelec_testx)
batch_for_elec_train = len(elec_trainx)
batch_for_elec_test = len(elec_testx)
batch_for_dhw_train = len(dhw_trainx)
batch_for_dhw_test = len(dhw_testx)

NELEC_train = DataLoader(nelec_train,
                        batch_size=1024,#batch_for_nelec_train,
                        shuffle=False,  
                        drop_last=True)

NELEC_test = DataLoader(nelec_test,
                        batch_size=1024,#batch_for_nelec_test,
                        shuffle=False,  
                        drop_last=True)

ELEC_train = DataLoader(elec_train,
                        batch_size=1024,#batch_for_elec_train,
                        shuffle=False,  
                        drop_last=True)

ELEC_test = DataLoader(elec_test,
                        batch_size=1024,#batch_for_elec_test,
                        shuffle=False,  
                        drop_last=True)

DHW_train = DataLoader(dhw_train,
                        batch_size=1024,#batch_for_dhw_train,
                        shuffle=False,  
                        drop_last=True)

DHW_test = DataLoader(dhw_test,
                        batch_size=1024,#batch_for_dhw_test,
                        shuffle=False,  
                        drop_last=True)

# %%
# # 데이터셋의 개수를 가정하여 변수에 저장
# nelec_train_size = len(nelec_train)
# nelec_test_size = len(nelec_test)
# elec_train_size = len(elec_train)
# elec_test_size = len(elec_test)
# dhw_train_size = len(dhw_train)
# dhw_test_size = len(dhw_test)

# # 각 DataLoader에서 생성되는 배치의 개수 계산
# nelec_train_batches = nelec_train_size // batch_for_nelec_train
# nelec_test_batches = nelec_test_size // batch_for_nelec_test
# elec_train_batches = elec_train_size // batch_for_elec_train
# elec_test_batches = elec_test_size // batch_for_elec_test
# dhw_train_batches = dhw_train_size // batch_for_dhw_train
# dhw_test_batches = dhw_test_size // batch_for_dhw_test

# # 결과 출력
# print("nelec_train batches:", nelec_train_batches)
# print("nelec_test batches:", nelec_test_batches)
# print("elec_train batches:", elec_train_batches)
# print("elec_test batches:", elec_test_batches)
# print("dhw_train batches:", dhw_train_batches)
# print("dhw_test batches:", dhw_test_batches)

# %% [markdown]
# # 모델 구조 선언

# %%
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ### GradientReversalLayer

# %%
class GradientReversalFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, x):
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return (grad_output * -1), None

class GradientReversalLayer(torch.nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x):
        return GradientReversalFunction.apply(x)

# %% [markdown]
# ### LSTM for Feature Extraction

# %%
class Swish(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return x * self.sigmoid(x)

# %%
class lstm(nn.Module):
    def __init__(self):
        super(lstm, self).__init__()
        self.lstm1 = nn.LSTM(12, 64, batch_first=True)
        self.bn1 = nn.BatchNorm1d(7)
        
        self.lstm2 = nn.LSTM(64, 64, batch_first=True)
        self.bn2 = nn.BatchNorm1d(7)
        
        self.lstm3 = nn.LSTM(64,64, batch_first=True)
        
        self.fc = nn.Linear(64, 64, bias=False)
        self.fc2 = nn.Linear(64, 100, bias=False)
        self.bn3 = nn.BatchNorm1d(7)
        
        self.dropout = nn.Dropout(0.5)
        self.swish = Swish()
        self.tanh = nn.Tanh()

        
    def forward(self, x):
        x, (h,c) = self.lstm1(x)
        x = self.bn1(x)
        x = self.tanh(x)

        x, (h, c) = self.lstm2(x, (h, c))
        x = self.bn2(x)
        x = self.tanh(x)
        
        x, _ = self.lstm3(x, (h, c))
        x = self.bn2(x)
        x = self.tanh(x)
        
        x = self.fc(x)
        x = self.bn3(x)
        x = self.fc2(x[:,-1,:])
        x = self.dropout(x)
        x = self.swish(x)
        return x

# %%
# hoxy = lstm()
# inputx = torch.randn(1024,7,12)
# hoxy2 = hoxy(inputx)
# print(hoxy2.shape)

# %%
class domain_regression(nn.Module):
    def __init__(self):
        super(domain_regression, self).__init__()
        self.regression_layer1 = nn.Linear(100, 128)
        self.regression_layer2 = nn.Linear(128, 128)
        self.regression_layer3 = nn.Linear(128, 128)
        self.regression_layer4 = nn.Linear(128, 1)
        
    def forward(self, x):
        x = F.relu(self.regression_layer1(x))
        x = F.relu(self.regression_layer2(x))
        x = F.relu(self.regression_layer3(x))
        x = F.relu(self.regression_layer4(x))
        return x

# %% [markdown]
# ### Domain Classification

# %%
class domain_classfication(nn.Module):
    def __init__(self):
        super(domain_classfication, self).__init__()
        self.classification_layer0 = GradientReversalLayer()
        self.classification_layer1 = nn.Linear(100, 128)
        self.classification_layer2 = nn.Linear(128,128)
        #self.classification_layer3 = nn.Linear(128,128)
        self.classification_layer4 = nn.Linear(128, 1)
        
    def forward(self, x):
        x = self.classification_layer0(x)
        x = F.relu(self.classification_layer1(x))
        x = F.relu(self.classification_layer2(x))
        #x = F.relu(self.classification_layer3(x))
        x = torch.sigmoid(self.classification_layer4(x))
        return x

# %% [markdown]
# ### Set the DANN

# %%
class dann(nn.Module):
    def __init__(self, lstm):
        super(dann, self).__init__()
        self.lstm = lstm
        self.regression = domain_regression()
        self.classification = domain_classfication()
        
    def forward(self, x):
        feature = self.lstm(x)
        reg_output = self.regression(feature)
        cla_output = self.classification(feature)
        
        return reg_output, cla_output

# %% [markdown]
# ### Loss 선언

# %%
class dann_loss(nn.Module):
    def __init__(self):
        super(dann_loss, self).__init__()
        self.reg = nn.L1Loss() # 회귀 L1 손실 == MAE
        self.cla = nn.BCEWithLogitsLoss() # 도메인 분류
        
    def forward(self, result, reg_real, domain_num, alpha=1):
        reg_output, cla_output = result
        batch_size = reg_output.shape[0]
        cla_target = torch.FloatTensor([domain_num] * batch_size).unsqueeze(1).to(device)
        
        reg_loss = self.reg(reg_output, reg_real)
        cla_loss = self.cla(cla_output, cla_target)
        cla_loss2 = cla_loss * alpha
        
        loss = reg_loss + cla_loss2
        
        return loss, reg_loss, cla_loss2

# %%
my_lstm = lstm().to(device)
model = dann(my_lstm).to(device)
loss_fn = dann_loss().to(device)

# %% [markdown]
# # 훈련

# %%
from torch.optim.lr_scheduler import LinearLR

alpha = 1.0
epochs = 1000

model.train() # 훈련 모드 설정

optimizer= torch.optim.Adamax(model.parameters(), lr=0.01)#, weight_decay=0.01)
scheduler = LinearLR(optimizer, start_factor=1.0, end_factor=0.0, total_iters = epochs * len(NELEC_train))

patience = 200  # Early stopping을 위한 기다리는 최대 epoch 수
best_loss = float('inf')
best_source_loss = float('inf')
best_model_state_dict = None
counter = 10  # Early stopping 카운터

for i in range(1, epochs + 1):
    total_loss = 0
    source_total_loss = 0
    target_total_loss = 0
    src_reg_total = 0
    src_cla_total = 0
    tar_reg_total = 0
    tar_cal_total = 0
    reg_loss_total = 0
    cla_loss_total = 0
    for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
        source_x = source_data[0].to(device)
        source_y = source_data[1].to(device)
        target_x = target_data[0].to(device)
        target_y = target_data[1].to(device)
        #print(source_x.shape)
        #print(source_y.shape)
        #print(target_x.shape)
        #print(target_y.shape)
        # 순전파
        source_result = model(source_x)
        target_result = model(target_x)
        #print(source_result[0].shape)
        #print(target_result[0].shape)
        #print(source_result[1].shape)
        #print(target_result[1].shape)
        # 순전파 loss
        source_loss, source_reg_loss, source_cla_loss = loss_fn(source_result, source_y, 1, alpha=alpha) # 소스 도메인 레이블 1
        target_loss, target_reg_loss, target_cla_loss = loss_fn(target_result, target_y, 0, alpha=alpha) # 타겟 도메인 레이블 0
        
        loss = source_loss + target_loss
        reg_loss = source_reg_loss + target_reg_loss
        cla_loss = source_cla_loss + target_cla_loss
        
        #src_reg_total += source_reg_loss.item()
        #src_cla_total += source_cla_loss.item()
        #tar_reg_total += target_reg_loss.item()
        #tar_cal_total += target_cla_loss.item()
        
        #source_total_loss += source_loss.item()
        #target_total_loss += target_loss.item()
        
        reg_loss_total += reg_loss.item()
        cla_loss_total += cla_loss.item()
        
        total_loss += loss.item()
        
        # 그래디언트 계산 및 업데이트
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()
        
        # Early stopping 확인
    if reg_loss_total / len(NELEC_train) < best_loss:
        best_loss = reg_loss_total / len(NELEC_train)
        best_model_state_dict = model.state_dict()
        counter = 0  # Counter 초기화
    else:
        counter += 1
        if counter >= patience:
            print(f'Early stopping at epoch {i}')
            break

    print('Epoch : %d, Total Avg Loss : %.4f' % (i, total_loss / len(NELEC_train)))     
    #print('Source Avg Loss : %.4f' % (source_total_loss / len(NELEC_train)))
    #print('Target Avg Loss : %.4f' % (target_total_loss / len(NELEC_train)))
    #print('Source Avg reg Loss : %.4f' % (src_reg_total / len(NELEC_train)))
    #print('Target Avg reg Loss : %.4f' % (tar_reg_total / len(NELEC_train)))
    #print('Source Avg cla Loss : %.4f' % (src_cla_total / len(NELEC_train)))
    #print('Target Avg cla Loss : %.4f' % (tar_cal_total / len(NELEC_train)))
    print('Avg Regression Loss : %.4f' % (reg_loss_total / len(NELEC_train)))
    print('Avg Classification Loss : %.4f' % (cla_loss_total / len(NELEC_train)))
    print('')
    
    # source_loss가 가장 낮은 경우 모델 가중치 저장
    if reg_loss_total / len(NELEC_train) < best_source_loss:
        best_source_loss = reg_loss_total / len(NELEC_train)
        best_model_state_dict = model.state_dict()

# 최상의 모델을 파일로 저장
if best_model_state_dict is not None:
    torch.save(best_model_state_dict, '0810hoxyhoxy2.pth')
    #torch.save(model, "model.pth")
# Out:
# Epoch : 1, Total Avg Loss : 2.0745
# Avg Regression Loss : 0.6827
# Avg Classification Loss : 1.3919
#
# Epoch : 2, Total Avg Loss : 1.8490
# Avg Regression Loss : 0.4627
# Avg Classification Loss : 1.3863
#
# Epoch : 3, Total Avg Loss : 1.8445
# Avg Regression Loss : 0.4582
# Avg Classification Loss : 1.3863
#
# Epoch : 4, Total Avg Loss : 1.8019
# Avg Regression Loss : 0.4156
# Avg Classification Loss : 1.3863
#
# Epoch : 5, Total Avg Loss : 1.7865
# Avg Regression Loss : 0.4002
# Avg Classification Loss : 1.3863
#
# Epoch : 6, Total Avg Loss : 1.7858
# Avg Regression Loss : 0.3995
# Avg Classification Loss : 1.3863
#
# Epoch : 7, Total Avg Loss : 1.7841
# Avg Regression Loss : 0.3978
# Avg Classification Loss : 1.3863
#
# Epoch : 8, Total Avg Loss : 1.7834
# Avg Regression Loss : 0.3971
# Avg Classification Loss : 1.3863
#
# Epoch : 9, Total Avg Loss : 1.7826
# Avg Regression Loss : 0.3964
# Avg Classification Loss : 1.3863
#
# Epoch : 10, Total Avg Loss : 1.7823
# Avg Regression Loss : 0.3960
# Avg Classification Loss : 1.3863
#
# Epoch : 11, Total Avg Loss : 1.7819
# Avg Regression Loss : 0.3956
# Avg Classification Loss : 1.3863
#
# Epoch : 12, Total Avg Loss : 1.7818
# Avg Regression Loss : 0.3955
# Avg Classification Loss : 1.3863
#
# Epoch : 13, Total Avg Loss : 1.7814
# Avg Regression Loss : 0.3951
# Avg Classification Loss : 1.3863
#
# Epoch : 14, Total Avg Loss : 1.7809
# Avg Regression Loss : 0.3946
# Avg Classification Loss : 1.3863
#
# Epoch : 15, Total Avg Loss : 1.7763
# Avg Regression Loss : 0.3896
# Avg Classification Loss : 1.3867
#
# Epoch : 16, Total Avg Loss : 1.7240
# Avg Regression Loss : 0.3379
# Avg Classification Loss : 1.3861
#
# Epoch : 17, Total Avg Loss : 1.5685
# Avg Regression Loss : 0.1932
# Avg Classification Loss : 1.3753
#
# Epoch : 18, Total Avg Loss : 1.6360
# Avg Regression Loss : 0.2700
# Avg Classification Loss : 1.3660
#
# Epoch : 19, Total Avg Loss : 1.6372
# Avg Regression Loss : 0.2892
# Avg Classification Loss : 1.3480
#
# Epoch : 20, Total Avg Loss : 1.5475
# Avg Regression Loss : 0.2123
# Avg Classification Loss : 1.3351
#
# Epoch : 21, Total Avg Loss : 1.5638
# Avg Regression Loss : 0.2254
# Avg Classification Loss : 1.3384
#
# Epoch : 22, Total Avg Loss : 1.5564
# Avg Regression Loss : 0.2156
# Avg Classification Loss : 1.3408
#
# Epoch : 23, Total Avg Loss : 1.7956
# Avg Regression Loss : 0.3595
# Avg Classification Loss : 1.4361
#
# Epoch : 24, Total Avg Loss : 1.7356
# Avg Regression Loss : 0.3352
# Avg Classification Loss : 1.4004
#
# Epoch : 25, Total Avg Loss : 1.6428
# Avg Regression Loss : 0.2612
# Avg Classification Loss : 1.3816
#
# Epoch : 26, Total Avg Loss : 1.6083
# Avg Regression Loss : 0.2346
# Avg Classification Loss : 1.3737
#
# Epoch : 27, Total Avg Loss : 1.5671
# Avg Regression Loss : 0.1931
# Avg Classification Loss : 1.3741
#
# Epoch : 28, Total Avg Loss : 1.5618
# Avg Regression Loss : 0.1951
# Avg Classification Loss : 1.3667
#
# Epoch : 29, Total Avg Loss : 1.6206
# Avg Regression Loss : 0.2141
# Avg Classification Loss : 1.4065
#
# Epoch : 30, Total Avg Loss : 1.6417
# Avg Regression Loss : 0.2390
# Avg Classification Loss : 1.4027
#
# Epoch : 31, Total Avg Loss : 1.5675
# Avg Regression Loss : 0.1939
# Avg Classification Loss : 1.3736
#
# Epoch : 32, Total Avg Loss : 1.4569
# Avg Regression Loss : 0.1205
# Avg Classification Loss : 1.3365
#
# Epoch : 33, Total Avg Loss : 1.4269
# Avg Regression Loss : 0.0976
# Avg Classification Loss : 1.3292
#
# Epoch : 34, Total Avg Loss : 1.4270
# Avg Regression Loss : 0.0945
# Avg Classification Loss : 1.3325
#
# Epoch : 35, Total Avg Loss : 1.4303
# Avg Regression Loss : 0.0903
# Avg Classification Loss : 1.3400
#
# Epoch : 36, Total Avg Loss : 1.5353
# Avg Regression Loss : 0.1740
# Avg Classification Loss : 1.3613
#
# Epoch : 37, Total Avg Loss : 1.5096
# Avg Regression Loss : 0.1643
# Avg Classification Loss : 1.3453
#
# Epoch : 38, Total Avg Loss : 1.4578
# Avg Regression Loss : 0.1170
# Avg Classification Loss : 1.3408
#
# Epoch : 39, Total Avg Loss : 1.4350
# Avg Regression Loss : 0.0953
# Avg Classification Loss : 1.3397
#
# Epoch : 40, Total Avg Loss : 1.4318
# Avg Regression Loss : 0.0980
# Avg Classification Loss : 1.3337
#
# Epoch : 41, Total Avg Loss : 1.4265
# Avg Regression Loss : 0.0909
# Avg Classification Loss : 1.3356
#
# Epoch : 42, Total Avg Loss : 1.4526
# Avg Regression Loss : 0.1102
# Avg Classification Loss : 1.3424
#
# Epoch : 43, Total Avg Loss : 1.4688
# Avg Regression Loss : 0.1280
# Avg Classification Loss : 1.3407
#
# Epoch : 44, Total Avg Loss : 1.5092
# Avg Regression Loss : 0.1464
# Avg Classification Loss : 1.3628
#
# Epoch : 45, Total Avg Loss : 1.4365
# Avg Regression Loss : 0.1013
# Avg Classification Loss : 1.3352
#
# Epoch : 46, Total Avg Loss : 1.5164
# Avg Regression Loss : 0.1689
# Avg Classification Loss : 1.3475
#
# Epoch : 47, Total Avg Loss : 1.5498
# Avg Regression Loss : 0.1822
# Avg Classification Loss : 1.3676
#
# Epoch : 48, Total Avg Loss : 1.5037
# Avg Regression Loss : 0.1650
# Avg Classification Loss : 1.3387
#
# Epoch : 49, Total Avg Loss : 1.4414
# Avg Regression Loss : 0.1044
# Avg Classification Loss : 1.3369
#
# Epoch : 50, Total Avg Loss : 1.4071
# Avg Regression Loss : 0.0735
# Avg Classification Loss : 1.3336
#
# Epoch : 51, Total Avg Loss : 1.3933
# Avg Regression Loss : 0.0637
# Avg Classification Loss : 1.3296
#
# Epoch : 52, Total Avg Loss : 1.4138
# Avg Regression Loss : 0.0812
# Avg Classification Loss : 1.3325
#
# Epoch : 53, Total Avg Loss : 1.4038
# Avg Regression Loss : 0.0720
# Avg Classification Loss : 1.3318
#
# Epoch : 54, Total Avg Loss : 1.4260
# Avg Regression Loss : 0.0876
# Avg Classification Loss : 1.3384
#
# Epoch : 55, Total Avg Loss : 1.4465
# Avg Regression Loss : 0.0910
# Avg Classification Loss : 1.3556
#
# Epoch : 56, Total Avg Loss : 1.4561
# Avg Regression Loss : 0.0931
# Avg Classification Loss : 1.3630
#
# Epoch : 57, Total Avg Loss : 1.4476
# Avg Regression Loss : 0.0959
# Avg Classification Loss : 1.3517
#
# Epoch : 58, Total Avg Loss : 1.5553
# Avg Regression Loss : 0.1832
# Avg Classification Loss : 1.3720
#
# Epoch : 59, Total Avg Loss : 1.4868
# Avg Regression Loss : 0.1222
# Avg Classification Loss : 1.3646
#
# Epoch : 60, Total Avg Loss : 1.4687
# Avg Regression Loss : 0.1010
# Avg Classification Loss : 1.3677
#
# Epoch : 61, Total Avg Loss : 1.4835
# Avg Regression Loss : 0.1183
# Avg Classification Loss : 1.3652
#
# Epoch : 62, Total Avg Loss : 1.5092
# Avg Regression Loss : 0.1366
# Avg Classification Loss : 1.3726
#
# Epoch : 63, Total Avg Loss : 1.5782
# Avg Regression Loss : 0.1333
# Avg Classification Loss : 1.4449
#
# Epoch : 64, Total Avg Loss : 1.4456
# Avg Regression Loss : 0.0880
# Avg Classification Loss : 1.3576
#
# Epoch : 65, Total Avg Loss : 1.4511
# Avg Regression Loss : 0.0769
# Avg Classification Loss : 1.3742
#
# Epoch : 66, Total Avg Loss : 1.4839
# Avg Regression Loss : 0.1024
# Avg Classification Loss : 1.3815
#
# Epoch : 67, Total Avg Loss : 1.5036
# Avg Regression Loss : 0.1252
# Avg Classification Loss : 1.3784
#
# Epoch : 68, Total Avg Loss : 1.4791
# Avg Regression Loss : 0.1019
# Avg Classification Loss : 1.3772
#
# Epoch : 69, Total Avg Loss : 1.4608
# Avg Regression Loss : 0.0892
# Avg Classification Loss : 1.3716
#
# Epoch : 70, Total Avg Loss : 1.5945
# Avg Regression Loss : 0.1279
# Avg Classification Loss : 1.4665
#
# Epoch : 71, Total Avg Loss : 1.6320
# Avg Regression Loss : 0.1678
# Avg Classification Loss : 1.4642
#
# Epoch : 72, Total Avg Loss : 1.4559
# Avg Regression Loss : 0.0831
# Avg Classification Loss : 1.3728
#
# Epoch : 73, Total Avg Loss : 1.4322
# Avg Regression Loss : 0.0615
# Avg Classification Loss : 1.3706
#
# Epoch : 74, Total Avg Loss : 1.4796
# Avg Regression Loss : 0.0989
# Avg Classification Loss : 1.3808
#
# Epoch : 75, Total Avg Loss : 1.5120
# Avg Regression Loss : 0.1332
# Avg Classification Loss : 1.3787
#
# Epoch : 76, Total Avg Loss : 1.5405
# Avg Regression Loss : 0.1545
# Avg Classification Loss : 1.3860
#
# Epoch : 77, Total Avg Loss : 1.4894
# Avg Regression Loss : 0.1037
# Avg Classification Loss : 1.3857
#
# Epoch : 78, Total Avg Loss : 1.4949
# Avg Regression Loss : 0.1096
# Avg Classification Loss : 1.3853
#
# Epoch : 79, Total Avg Loss : 1.4889
# Avg Regression Loss : 0.1044
# Avg Classification Loss : 1.3846
#
# Epoch : 80, Total Avg Loss : 1.4934
# Avg Regression Loss : 0.1092
# Avg Classification Loss : 1.3841
#
# Epoch : 81, Total Avg Loss : 1.4990
# Avg Regression Loss : 0.1145
# Avg Classification Loss : 1.3846
#
# Epoch : 82, Total Avg Loss : 1.4614
# Avg Regression Loss : 0.0766
# Avg Classification Loss : 1.3847
#
# Epoch : 83, Total Avg Loss : 1.4571
# Avg Regression Loss : 0.0711
# Avg Classification Loss : 1.3860
#
# Epoch : 84, Total Avg Loss : 1.4737
# Avg Regression Loss : 0.0884
# Avg Classification Loss : 1.3853
#
# Epoch : 85, Total Avg Loss : 1.4930
# Avg Regression Loss : 0.1077
# Avg Classification Loss : 1.3853
#
# Epoch : 86, Total Avg Loss : 1.4707
# Avg Regression Loss : 0.0861
# Avg Classification Loss : 1.3846
#
# Epoch : 87, Total Avg Loss : 1.4430
# Avg Regression Loss : 0.0569
# Avg Classification Loss : 1.3861
#
# Epoch : 88, Total Avg Loss : 1.4474
# Avg Regression Loss : 0.0610
# Avg Classification Loss : 1.3864
#
# Epoch : 89, Total Avg Loss : 1.4391
# Avg Regression Loss : 0.0544
# Avg Classification Loss : 1.3847
#
# Epoch : 90, Total Avg Loss : 1.4455
# Avg Regression Loss : 0.0593
# Avg Classification Loss : 1.3861
#
# Epoch : 91, Total Avg Loss : 1.4402
# Avg Regression Loss : 0.0557
# Avg Classification Loss : 1.3845
#
# Epoch : 92, Total Avg Loss : 1.4454
# Avg Regression Loss : 0.0590
# Avg Classification Loss : 1.3864
#
# Epoch : 93, Total Avg Loss : 1.4345
# Avg Regression Loss : 0.0506
# Avg Classification Loss : 1.3839
#
# Epoch : 94, Total Avg Loss : 1.4363
# Avg Regression Loss : 0.0504
# Avg Classification Loss : 1.3859
#
# Epoch : 95, Total Avg Loss : 1.4572
# Avg Regression Loss : 0.0699
# Avg Classification Loss : 1.3873
#
# Epoch : 96, Total Avg Loss : 1.4359
# Avg Regression Loss : 0.0505
# Avg Classification Loss : 1.3854
#
# Epoch : 97, Total Avg Loss : 1.4523
# Avg Regression Loss : 0.0638
# Avg Classification Loss : 1.3885
#
# Epoch : 98, Total Avg Loss : 1.4433
# Avg Regression Loss : 0.0592
# Avg Classification Loss : 1.3840
#
# Epoch : 99, Total Avg Loss : 1.4448
# Avg Regression Loss : 0.0547
# Avg Classification Loss : 1.3902
#
# Epoch : 100, Total Avg Loss : 1.4432
# Avg Regression Loss : 0.0521
# Avg Classification Loss : 1.3911
#
# Epoch : 101, Total Avg Loss : 1.4446
# Avg Regression Loss : 0.0550
# Avg Classification Loss : 1.3896
#
# Epoch : 102, Total Avg Loss : 1.4517
# Avg Regression Loss : 0.0584
# Avg Classification Loss : 1.3934
#
# Epoch : 103, Total Avg Loss : 1.4398
# Avg Regression Loss : 0.0489
# Avg Classification Loss : 1.3909
#
# Epoch : 104, Total Avg Loss : 1.4416
# Avg Regression Loss : 0.0504
# Avg Classification Loss : 1.3912
#
# Epoch : 105, Total Avg Loss : 1.4534
# Avg Regression Loss : 0.0626
# Avg Classification Loss : 1.3908
#
# Epoch : 106, Total Avg Loss : 1.4572
# Avg Regression Loss : 0.0737
# Avg Classification Loss : 1.3835
#
# Epoch : 107, Total Avg Loss : 1.4675
# Avg Regression Loss : 0.0822
# Avg Classification Loss : 1.3853
#
# Epoch : 108, Total Avg Loss : 1.4537
# Avg Regression Loss : 0.0735
# Avg Classification Loss : 1.3802
#
# Epoch : 109, Total Avg Loss : 1.4386
# Avg Regression Loss : 0.0664
# Avg Classification Loss : 1.3722
#
# Epoch : 110, Total Avg Loss : 1.4605
# Avg Regression Loss : 0.0795
# Avg Classification Loss : 1.3810
#
# Epoch : 111, Total Avg Loss : 1.5032
# Avg Regression Loss : 0.1157
# Avg Classification Loss : 1.3875
#
# Epoch : 112, Total Avg Loss : 1.4565
# Avg Regression Loss : 0.0868
# Avg Classification Loss : 1.3697
#
# Epoch : 113, Total Avg Loss : 1.4588
# Avg Regression Loss : 0.0772
# Avg Classification Loss : 1.3815
#
# Epoch : 114, Total Avg Loss : 1.4825
# Avg Regression Loss : 0.0973
# Avg Classification Loss : 1.3852
#
# Epoch : 115, Total Avg Loss : 1.5011
# Avg Regression Loss : 0.1140
# Avg Classification Loss : 1.3871
#
# Epoch : 116, Total Avg Loss : 1.4966
# Avg Regression Loss : 0.1104
# Avg Classification Loss : 1.3862
#
# Epoch : 117, Total Avg Loss : 1.5063
# Avg Regression Loss : 0.1192
# Avg Classification Loss : 1.3871
#
# Epoch : 118, Total Avg Loss : 1.4768
# Avg Regression Loss : 0.0860
# Avg Classification Loss : 1.3909
#
# Epoch : 119, Total Avg Loss : 1.4880
# Avg Regression Loss : 0.0923
# Avg Classification Loss : 1.3957
#
# Epoch : 120, Total Avg Loss : 1.4606
# Avg Regression Loss : 0.0716
# Avg Classification Loss : 1.3890
#
# Epoch : 121, Total Avg Loss : 1.4503
# Avg Regression Loss : 0.0581
# Avg Classification Loss : 1.3922
#
# Epoch : 122, Total Avg Loss : 1.4449
# Avg Regression Loss : 0.0537
# Avg Classification Loss : 1.3912
#
# Epoch : 123, Total Avg Loss : 1.4501
# Avg Regression Loss : 0.0547
# Avg Classification Loss : 1.3954
#
# Epoch : 124, Total Avg Loss : 1.4527
# Avg Regression Loss : 0.0550
# Avg Classification Loss : 1.3977
#
# Epoch : 125, Total Avg Loss : 1.4614
# Avg Regression Loss : 0.0627
# Avg Classification Loss : 1.3987
#
# Epoch : 126, Total Avg Loss : 1.4718
# Avg Regression Loss : 0.0819
# Avg Classification Loss : 1.3900
#
# Epoch : 127, Total Avg Loss : 1.4702
# Avg Regression Loss : 0.0790
# Avg Classification Loss : 1.3912
#
# Epoch : 128, Total Avg Loss : 1.4576
# Avg Regression Loss : 0.0715
# Avg Classification Loss : 1.3861
#
# Epoch : 129, Total Avg Loss : 1.4364
# Avg Regression Loss : 0.0505
# Avg Classification Loss : 1.3859
#
# Epoch : 130, Total Avg Loss : 1.4258
# Avg Regression Loss : 0.0399
# Avg Classification Loss : 1.3860
#
# Epoch : 131, Total Avg Loss : 1.4236
# Avg Regression Loss : 0.0381
# Avg Classification Loss : 1.3855
#
# Epoch : 132, Total Avg Loss : 1.4449
# Avg Regression Loss : 0.0594
# Avg Classification Loss : 1.3855
#
# Epoch : 133, Total Avg Loss : 1.4647
# Avg Regression Loss : 0.0804
# Avg Classification Loss : 1.3843
#
# Epoch : 134, Total Avg Loss : 1.4938
# Avg Regression Loss : 0.1096
# Avg Classification Loss : 1.3842
#
# Epoch : 135, Total Avg Loss : 1.4440
# Avg Regression Loss : 0.0618
# Avg Classification Loss : 1.3823
#
# Epoch : 136, Total Avg Loss : 1.4452
# Avg Regression Loss : 0.0636
# Avg Classification Loss : 1.3816
#
# Epoch : 137, Total Avg Loss : 1.4547
# Avg Regression Loss : 0.0756
# Avg Classification Loss : 1.3791
#
# Epoch : 138, Total Avg Loss : 1.4680
# Avg Regression Loss : 0.0843
# Avg Classification Loss : 1.3837
#
# Epoch : 139, Total Avg Loss : 1.4723
# Avg Regression Loss : 0.0714
# Avg Classification Loss : 1.4009
#
# Epoch : 140, Total Avg Loss : 1.4347
# Avg Regression Loss : 0.0516
# Avg Classification Loss : 1.3831
#
# Epoch : 141, Total Avg Loss : 1.4210
# Avg Regression Loss : 0.0373
# Avg Classification Loss : 1.3836
#
# Epoch : 142, Total Avg Loss : 1.4169
# Avg Regression Loss : 0.0332
# Avg Classification Loss : 1.3837
#
# Epoch : 143, Total Avg Loss : 1.4212
# Avg Regression Loss : 0.0375
# Avg Classification Loss : 1.3837
#
# Epoch : 144, Total Avg Loss : 1.4508
# Avg Regression Loss : 0.0669
# Avg Classification Loss : 1.3838
#
# Epoch : 145, Total Avg Loss : 1.4363
# Avg Regression Loss : 0.0542
# Avg Classification Loss : 1.3822
#
# Epoch : 146, Total Avg Loss : 1.4262
# Avg Regression Loss : 0.0445
# Avg Classification Loss : 1.3818
#
# Epoch : 147, Total Avg Loss : 1.4401
# Avg Regression Loss : 0.0582
# Avg Classification Loss : 1.3820
#
# Epoch : 148, Total Avg Loss : 1.4657
# Avg Regression Loss : 0.0822
# Avg Classification Loss : 1.3835
#
# Epoch : 149, Total Avg Loss : 1.4564
# Avg Regression Loss : 0.0727
# Avg Classification Loss : 1.3837
#
# Epoch : 150, Total Avg Loss : 1.4465
# Avg Regression Loss : 0.0615
# Avg Classification Loss : 1.3850
#
# Epoch : 151, Total Avg Loss : 1.4835
# Avg Regression Loss : 0.0993
# Avg Classification Loss : 1.3842
#
# Epoch : 152, Total Avg Loss : 1.4351
# Avg Regression Loss : 0.0548
# Avg Classification Loss : 1.3803
#
# Epoch : 153, Total Avg Loss : 1.4338
# Avg Regression Loss : 0.0488
# Avg Classification Loss : 1.3850
#
# Epoch : 154, Total Avg Loss : 1.4500
# Avg Regression Loss : 0.0654
# Avg Classification Loss : 1.3847
#
# Epoch : 155, Total Avg Loss : 1.4536
# Avg Regression Loss : 0.0702
# Avg Classification Loss : 1.3833
#
# Epoch : 156, Total Avg Loss : 1.4610
# Avg Regression Loss : 0.0791
# Avg Classification Loss : 1.3819
#
# Epoch : 157, Total Avg Loss : 1.4318
# Avg Regression Loss : 0.0493
# Avg Classification Loss : 1.3825
#
# Epoch : 158, Total Avg Loss : 1.4348
# Avg Regression Loss : 0.0493
# Avg Classification Loss : 1.3855
#
# Epoch : 159, Total Avg Loss : 1.4483
# Avg Regression Loss : 0.0643
# Avg Classification Loss : 1.3841
#
# Epoch : 160, Total Avg Loss : 1.4637
# Avg Regression Loss : 0.0799
# Avg Classification Loss : 1.3838
#
# Epoch : 161, Total Avg Loss : 1.4629
# Avg Regression Loss : 0.0779
# Avg Classification Loss : 1.3849
#
# Epoch : 162, Total Avg Loss : 1.4406
# Avg Regression Loss : 0.0564
# Avg Classification Loss : 1.3841
#
# Epoch : 163, Total Avg Loss : 1.4649
# Avg Regression Loss : 0.0814
# Avg Classification Loss : 1.3836
#
# Epoch : 164, Total Avg Loss : 1.4461
# Avg Regression Loss : 0.0643
# Avg Classification Loss : 1.3819
#
# Epoch : 165, Total Avg Loss : 1.4393
# Avg Regression Loss : 0.0528
# Avg Classification Loss : 1.3865
#
# Epoch : 166, Total Avg Loss : 1.4633
# Avg Regression Loss : 0.0750
# Avg Classification Loss : 1.3882
#
# Epoch : 167, Total Avg Loss : 1.4461
# Avg Regression Loss : 0.0617
# Avg Classification Loss : 1.3844
#
# Epoch : 168, Total Avg Loss : 1.4203
# Avg Regression Loss : 0.0358
# Avg Classification Loss : 1.3845
#
# Epoch : 169, Total Avg Loss : 1.4160
# Avg Regression Loss : 0.0332
# Avg Classification Loss : 1.3828
#
# Epoch : 170, Total Avg Loss : 1.4167
# Avg Regression Loss : 0.0340
# Avg Classification Loss : 1.3827
#
# Epoch : 171, Total Avg Loss : 1.5452
# Avg Regression Loss : 0.1024
# Avg Classification Loss : 1.4428
#
# Epoch : 172, Total Avg Loss : 1.4691
# Avg Regression Loss : 0.0904
# Avg Classification Loss : 1.3786
#
# Epoch : 173, Total Avg Loss : 1.4218
# Avg Regression Loss : 0.0473
# Avg Classification Loss : 1.3745
#
# Epoch : 174, Total Avg Loss : 1.4158
# Avg Regression Loss : 0.0424
# Avg Classification Loss : 1.3734
#
# Epoch : 175, Total Avg Loss : 1.4604
# Avg Regression Loss : 0.0776
# Avg Classification Loss : 1.3828
#
# Epoch : 176, Total Avg Loss : 1.4389
# Avg Regression Loss : 0.0563
# Avg Classification Loss : 1.3826
#
# Epoch : 177, Total Avg Loss : 1.4328
# Avg Regression Loss : 0.0507
# Avg Classification Loss : 1.3821
#
# Epoch : 178, Total Avg Loss : 1.4298
# Avg Regression Loss : 0.0508
# Avg Classification Loss : 1.3791
#
# Epoch : 179, Total Avg Loss : 1.4407
# Avg Regression Loss : 0.0603
# Avg Classification Loss : 1.3804
#
# Epoch : 180, Total Avg Loss : 1.4413
# Avg Regression Loss : 0.0665
# Avg Classification Loss : 1.3749
#
# Epoch : 181, Total Avg Loss : 1.4393
# Avg Regression Loss : 0.0651
# Avg Classification Loss : 1.3742
#
# Epoch : 182, Total Avg Loss : 1.4739
# Avg Regression Loss : 0.0969
# Avg Classification Loss : 1.3770
#
# Epoch : 183, Total Avg Loss : 1.4603
# Avg Regression Loss : 0.0821
# Avg Classification Loss : 1.3782
#
# Epoch : 184, Total Avg Loss : 1.4559
# Avg Regression Loss : 0.0766
# Avg Classification Loss : 1.3794
#
# Epoch : 185, Total Avg Loss : 1.4380
# Avg Regression Loss : 0.0610
# Avg Classification Loss : 1.3771
#
# Epoch : 186, Total Avg Loss : 1.4272
# Avg Regression Loss : 0.0506
# Avg Classification Loss : 1.3766
#
# Epoch : 187, Total Avg Loss : 1.4122
# Avg Regression Loss : 0.0366
# Avg Classification Loss : 1.3756
#
# Epoch : 188, Total Avg Loss : 1.4282
# Avg Regression Loss : 0.0519
# Avg Classification Loss : 1.3762
#
# Epoch : 189, Total Avg Loss : 1.4321
# Avg Regression Loss : 0.0601
# Avg Classification Loss : 1.3720
#
# Epoch : 190, Total Avg Loss : 1.4356
# Avg Regression Loss : 0.0641
# Avg Classification Loss : 1.3715
#
# Epoch : 191, Total Avg Loss : 1.4369
# Avg Regression Loss : 0.0631
# Avg Classification Loss : 1.3737
#
# Epoch : 192, Total Avg Loss : 1.4364
# Avg Regression Loss : 0.0677
# Avg Classification Loss : 1.3687
#
# Epoch : 193, Total Avg Loss : 1.4301
# Avg Regression Loss : 0.0652
# Avg Classification Loss : 1.3649
#
# Epoch : 194, Total Avg Loss : 1.4279
# Avg Regression Loss : 0.0575
# Avg Classification Loss : 1.3704
#
# Epoch : 195, Total Avg Loss : 1.4175
# Avg Regression Loss : 0.0726
# Avg Classification Loss : 1.3448
#
# Epoch : 196, Total Avg Loss : 1.4615
# Avg Regression Loss : 0.1057
# Avg Classification Loss : 1.3558
#
# Epoch : 197, Total Avg Loss : 1.4552
# Avg Regression Loss : 0.1192
# Avg Classification Loss : 1.3360
#
# Epoch : 198, Total Avg Loss : 1.3985
# Avg Regression Loss : 0.0619
# Avg Classification Loss : 1.3367
#
# Epoch : 199, Total Avg Loss : 1.4077
# Avg Regression Loss : 0.0680
# Avg Classification Loss : 1.3397
#
# Epoch : 200, Total Avg Loss : 1.4058
# Avg Regression Loss : 0.0682
# Avg Classification Loss : 1.3376
#
# Epoch : 201, Total Avg Loss : 1.3951
# Avg Regression Loss : 0.0577
# Avg Classification Loss : 1.3373
#
# Epoch : 202, Total Avg Loss : 1.3832
# Avg Regression Loss : 0.0448
# Avg Classification Loss : 1.3385
#
# Epoch : 203, Total Avg Loss : 1.3932
# Avg Regression Loss : 0.0535
# Avg Classification Loss : 1.3397
#
# Epoch : 204, Total Avg Loss : 1.4060
# Avg Regression Loss : 0.0663
# Avg Classification Loss : 1.3397
#
# Epoch : 205, Total Avg Loss : 1.3936
# Avg Regression Loss : 0.0606
# Avg Classification Loss : 1.3329
#
# Epoch : 206, Total Avg Loss : 1.4197
# Avg Regression Loss : 0.0816
# Avg Classification Loss : 1.3381
#
# Epoch : 207, Total Avg Loss : 1.4206
# Avg Regression Loss : 0.0835
# Avg Classification Loss : 1.3371
#
# Epoch : 208, Total Avg Loss : 1.4077
# Avg Regression Loss : 0.0675
# Avg Classification Loss : 1.3401
#
# Epoch : 209, Total Avg Loss : 1.3946
# Avg Regression Loss : 0.0600
# Avg Classification Loss : 1.3346
#
# Epoch : 210, Total Avg Loss : 1.4028
# Avg Regression Loss : 0.0646
# Avg Classification Loss : 1.3382
#
# Epoch : 211, Total Avg Loss : 1.3931
# Avg Regression Loss : 0.0567
# Avg Classification Loss : 1.3364
#
# Epoch : 212, Total Avg Loss : 1.4027
# Avg Regression Loss : 0.0658
# Avg Classification Loss : 1.3369
#
# Epoch : 213, Total Avg Loss : 1.4062
# Avg Regression Loss : 0.0644
# Avg Classification Loss : 1.3418
#
# Epoch : 214, Total Avg Loss : 1.3885
# Avg Regression Loss : 0.0513
# Avg Classification Loss : 1.3372
#
# Epoch : 215, Total Avg Loss : 1.3788
# Avg Regression Loss : 0.0478
# Avg Classification Loss : 1.3310
#
# Epoch : 216, Total Avg Loss : 1.3745
# Avg Regression Loss : 0.0412
# Avg Classification Loss : 1.3333
#
# Epoch : 217, Total Avg Loss : 1.4062
# Avg Regression Loss : 0.0680
# Avg Classification Loss : 1.3382
#
# Epoch : 218, Total Avg Loss : 1.3839
# Avg Regression Loss : 0.0500
# Avg Classification Loss : 1.3339
#
# Epoch : 219, Total Avg Loss : 1.3853
# Avg Regression Loss : 0.0495
# Avg Classification Loss : 1.3358
#
# Epoch : 220, Total Avg Loss : 1.3922
# Avg Regression Loss : 0.0577
# Avg Classification Loss : 1.3345
#
# Epoch : 221, Total Avg Loss : 1.3863
# Avg Regression Loss : 0.0536
# Avg Classification Loss : 1.3327
#
# Epoch : 222, Total Avg Loss : 1.4241
# Avg Regression Loss : 0.0849
# Avg Classification Loss : 1.3392
#
# Epoch : 223, Total Avg Loss : 1.4226
# Avg Regression Loss : 0.0862
# Avg Classification Loss : 1.3364
#
# Epoch : 224, Total Avg Loss : 1.3917
# Avg Regression Loss : 0.0579
# Avg Classification Loss : 1.3338
#
# Epoch : 225, Total Avg Loss : 1.3965
# Avg Regression Loss : 0.0597
# Avg Classification Loss : 1.3368
#
# Epoch : 226, Total Avg Loss : 1.4145
# Avg Regression Loss : 0.0757
# Avg Classification Loss : 1.3388
#
# Epoch : 227, Total Avg Loss : 1.4107
# Avg Regression Loss : 0.0746
# Avg Classification Loss : 1.3361
#
# Epoch : 228, Total Avg Loss : 1.4153
# Avg Regression Loss : 0.0800
# Avg Classification Loss : 1.3353
#
# Epoch : 229, Total Avg Loss : 1.4062
# Avg Regression Loss : 0.0735
# Avg Classification Loss : 1.3326
#
# Epoch : 230, Total Avg Loss : 1.3911
# Avg Regression Loss : 0.0559
# Avg Classification Loss : 1.3352
#
# Epoch : 231, Total Avg Loss : 1.3995
# Avg Regression Loss : 0.0599
# Avg Classification Loss : 1.3396
#
# Epoch : 232, Total Avg Loss : 1.4229
# Avg Regression Loss : 0.0835
# Avg Classification Loss : 1.3394
#
# Epoch : 233, Total Avg Loss : 1.4404
# Avg Regression Loss : 0.1030
# Avg Classification Loss : 1.3374
#
# Epoch : 234, Total Avg Loss : 1.4376
# Avg Regression Loss : 0.0939
# Avg Classification Loss : 1.3437
#
# Epoch : 235, Total Avg Loss : 1.4111
# Avg Regression Loss : 0.0701
# Avg Classification Loss : 1.3410
#
# Epoch : 236, Total Avg Loss : 1.3940
# Avg Regression Loss : 0.0550
# Avg Classification Loss : 1.3390
#
# Epoch : 237, Total Avg Loss : 1.4044
# Avg Regression Loss : 0.0623
# Avg Classification Loss : 1.3420
#
# Epoch : 238, Total Avg Loss : 1.4029
# Avg Regression Loss : 0.0624
# Avg Classification Loss : 1.3405
#
# Epoch : 239, Total Avg Loss : 1.3960
# Avg Regression Loss : 0.0567
# Avg Classification Loss : 1.3393
#
# Epoch : 240, Total Avg Loss : 1.3955
# Avg Regression Loss : 0.0587
# Avg Classification Loss : 1.3367
#
# Epoch : 241, Total Avg Loss : 1.3878
# Avg Regression Loss : 0.0517
# Avg Classification Loss : 1.3361
#
# Epoch : 242, Total Avg Loss : 1.3845
# Avg Regression Loss : 0.0486
# Avg Classification Loss : 1.3358
#
# Epoch : 243, Total Avg Loss : 1.3842
# Avg Regression Loss : 0.0494
# Avg Classification Loss : 1.3348
#
# Epoch : 244, Total Avg Loss : 1.3879
# Avg Regression Loss : 0.0501
# Avg Classification Loss : 1.3378
#
# Epoch : 245, Total Avg Loss : 1.3767
# Avg Regression Loss : 0.0432
# Avg Classification Loss : 1.3335
#
# Epoch : 246, Total Avg Loss : 1.3999
# Avg Regression Loss : 0.0600
# Avg Classification Loss : 1.3399
#
# Epoch : 247, Total Avg Loss : 1.3812
# Avg Regression Loss : 0.0447
# Avg Classification Loss : 1.3365
#
# Epoch : 248, Total Avg Loss : 1.3818
# Avg Regression Loss : 0.0455
# Avg Classification Loss : 1.3363
#
# Epoch : 249, Total Avg Loss : 1.3854
# Avg Regression Loss : 0.0515
# Avg Classification Loss : 1.3339
#
# Epoch : 250, Total Avg Loss : 1.3999
# Avg Regression Loss : 0.0614
# Avg Classification Loss : 1.3385
#
# Epoch : 251, Total Avg Loss : 1.3980
# Avg Regression Loss : 0.0603
# Avg Classification Loss : 1.3377
#
# Epoch : 252, Total Avg Loss : 1.3999
# Avg Regression Loss : 0.0633
# Avg Classification Loss : 1.3366
#
# Epoch : 253, Total Avg Loss : 1.4125
# Avg Regression Loss : 0.0734
# Avg Classification Loss : 1.3391
#
# Epoch : 254, Total Avg Loss : 1.3993
# Avg Regression Loss : 0.0630
# Avg Classification Loss : 1.3362
#
# Epoch : 255, Total Avg Loss : 1.3835
# Avg Regression Loss : 0.0500
# Avg Classification Loss : 1.3335
#
# Epoch : 256, Total Avg Loss : 1.3925
# Avg Regression Loss : 0.0522
# Avg Classification Loss : 1.3403
#
# Epoch : 257, Total Avg Loss : 1.3864
# Avg Regression Loss : 0.0509
# Avg Classification Loss : 1.3355
#
# Epoch : 258, Total Avg Loss : 1.3892
# Avg Regression Loss : 0.0513
# Avg Classification Loss : 1.3378
#
# Epoch : 259, Total Avg Loss : 1.3841
# Avg Regression Loss : 0.0448
# Avg Classification Loss : 1.3393
#
# Epoch : 260, Total Avg Loss : 1.3875
# Avg Regression Loss : 0.0485
# Avg Classification Loss : 1.3390
#
# Epoch : 261, Total Avg Loss : 1.3945
# Avg Regression Loss : 0.0588
# Avg Classification Loss : 1.3357
#
# Epoch : 262, Total Avg Loss : 1.4203
# Avg Regression Loss : 0.0771
# Avg Classification Loss : 1.3431
#
# Epoch : 263, Total Avg Loss : 1.4151
# Avg Regression Loss : 0.0746
# Avg Classification Loss : 1.3405
#
# Epoch : 264, Total Avg Loss : 1.3816
# Avg Regression Loss : 0.0474
# Avg Classification Loss : 1.3342
#
# Epoch : 265, Total Avg Loss : 1.3803
# Avg Regression Loss : 0.0460
# Avg Classification Loss : 1.3343
#
# Epoch : 266, Total Avg Loss : 1.3935
# Avg Regression Loss : 0.0550
# Avg Classification Loss : 1.3384
#
# Epoch : 267, Total Avg Loss : 1.4176
# Avg Regression Loss : 0.0785
# Avg Classification Loss : 1.3391
#
# Epoch : 268, Total Avg Loss : 1.4099
# Avg Regression Loss : 0.0685
# Avg Classification Loss : 1.3414
#
# Epoch : 269, Total Avg Loss : 1.3942
# Avg Regression Loss : 0.0519
# Avg Classification Loss : 1.3423
#
# Epoch : 270, Total Avg Loss : 1.3929
# Avg Regression Loss : 0.0506
# Avg Classification Loss : 1.3423
#
# Epoch : 271, Total Avg Loss : 1.3883
# Avg Regression Loss : 0.0523
# Avg Classification Loss : 1.3360
#
# Epoch : 272, Total Avg Loss : 1.4237
# Avg Regression Loss : 0.0830
# Avg Classification Loss : 1.3408
#
# Epoch : 273, Total Avg Loss : 1.4260
# Avg Regression Loss : 0.0866
# Avg Classification Loss : 1.3394
#
# Epoch : 274, Total Avg Loss : 1.4339
# Avg Regression Loss : 0.0880
# Avg Classification Loss : 1.3459
#
# Epoch : 275, Total Avg Loss : 1.4323
# Avg Regression Loss : 0.0834
# Avg Classification Loss : 1.3489
#
# Epoch : 276, Total Avg Loss : 1.4300
# Avg Regression Loss : 0.0795
# Avg Classification Loss : 1.3506
#
# Epoch : 277, Total Avg Loss : 1.3903
# Avg Regression Loss : 0.0483
# Avg Classification Loss : 1.3421
#
# Epoch : 278, Total Avg Loss : 1.3803
# Avg Regression Loss : 0.0483
# Avg Classification Loss : 1.3320
#
# Epoch : 279, Total Avg Loss : 1.4070
# Avg Regression Loss : 0.0691
# Avg Classification Loss : 1.3379
#
# Epoch : 280, Total Avg Loss : 1.4070
# Avg Regression Loss : 0.0654
# Avg Classification Loss : 1.3417
#
# Epoch : 281, Total Avg Loss : 1.3907
# Avg Regression Loss : 0.0519
# Avg Classification Loss : 1.3387
#
# Epoch : 282, Total Avg Loss : 1.3949
# Avg Regression Loss : 0.0587
# Avg Classification Loss : 1.3362
#
# Epoch : 283, Total Avg Loss : 1.3975
# Avg Regression Loss : 0.0596
# Avg Classification Loss : 1.3378
#
# Epoch : 284, Total Avg Loss : 1.3960
# Avg Regression Loss : 0.0584
# Avg Classification Loss : 1.3376
#
# Epoch : 285, Total Avg Loss : 1.3997
# Avg Regression Loss : 0.0672
# Avg Classification Loss : 1.3325
#
# Epoch : 286, Total Avg Loss : 1.3863
# Avg Regression Loss : 0.0533
# Avg Classification Loss : 1.3330
#
# Epoch : 287, Total Avg Loss : 1.4101
# Avg Regression Loss : 0.0714
# Avg Classification Loss : 1.3387
#
# Epoch : 288, Total Avg Loss : 1.3995
# Avg Regression Loss : 0.0613
# Avg Classification Loss : 1.3383
#
# Epoch : 289, Total Avg Loss : 1.4131
# Avg Regression Loss : 0.0734
# Avg Classification Loss : 1.3397
#
# Epoch : 290, Total Avg Loss : 1.4312
# Avg Regression Loss : 0.0930
# Avg Classification Loss : 1.3382
#
# Epoch : 291, Total Avg Loss : 1.4207
# Avg Regression Loss : 0.0800
# Avg Classification Loss : 1.3407
#
# Epoch : 292, Total Avg Loss : 1.4015
# Avg Regression Loss : 0.0619
# Avg Classification Loss : 1.3396
#
# Epoch : 293, Total Avg Loss : 1.3897
# Avg Regression Loss : 0.0504
# Avg Classification Loss : 1.3393
#
# Epoch : 294, Total Avg Loss : 1.3831
# Avg Regression Loss : 0.0460
# Avg Classification Loss : 1.3371
#
# Epoch : 295, Total Avg Loss : 1.3915
# Avg Regression Loss : 0.0554
# Avg Classification Loss : 1.3360
#
# Epoch : 296, Total Avg Loss : 1.3952
# Avg Regression Loss : 0.0578
# Avg Classification Loss : 1.3373
#
# Epoch : 297, Total Avg Loss : 1.4089
# Avg Regression Loss : 0.0735
# Avg Classification Loss : 1.3354
#
# Epoch : 298, Total Avg Loss : 1.3913
# Avg Regression Loss : 0.0516
# Avg Classification Loss : 1.3398
#
# Epoch : 299, Total Avg Loss : 1.4104
# Avg Regression Loss : 0.0668
# Avg Classification Loss : 1.3436
#
# Epoch : 300, Total Avg Loss : 1.3932
# Avg Regression Loss : 0.0545
# Avg Classification Loss : 1.3388
#
# Epoch : 301, Total Avg Loss : 1.3925
# Avg Regression Loss : 0.0499
# Avg Classification Loss : 1.3426
#
# Epoch : 302, Total Avg Loss : 1.3939
# Avg Regression Loss : 0.0508
# Avg Classification Loss : 1.3430
#
# Epoch : 303, Total Avg Loss : 1.4130
# Avg Regression Loss : 0.0626
# Avg Classification Loss : 1.3504
#
# Epoch : 304, Total Avg Loss : 1.4237
# Avg Regression Loss : 0.0785
# Avg Classification Loss : 1.3451
#
# Epoch : 305, Total Avg Loss : 1.4372
# Avg Regression Loss : 0.0891
# Avg Classification Loss : 1.3481
#
# Epoch : 306, Total Avg Loss : 1.4381
# Avg Regression Loss : 0.0903
# Avg Classification Loss : 1.3479
#
# Epoch : 307, Total Avg Loss : 1.4217
# Avg Regression Loss : 0.0744
# Avg Classification Loss : 1.3472
#
# Epoch : 308, Total Avg Loss : 1.4430
# Avg Regression Loss : 0.0854
# Avg Classification Loss : 1.3576
#
# Epoch : 309, Total Avg Loss : 1.4251
# Avg Regression Loss : 0.0627
# Avg Classification Loss : 1.3624
#
# Epoch : 310, Total Avg Loss : 1.4386
# Avg Regression Loss : 0.0754
# Avg Classification Loss : 1.3632
#
# Epoch : 311, Total Avg Loss : 1.4228
# Avg Regression Loss : 0.0659
# Avg Classification Loss : 1.3568
#
# Epoch : 312, Total Avg Loss : 1.3972
# Avg Regression Loss : 0.0524
# Avg Classification Loss : 1.3448
#
# Epoch : 313, Total Avg Loss : 1.3823
# Avg Regression Loss : 0.0476
# Avg Classification Loss : 1.3347
#
# Epoch : 314, Total Avg Loss : 1.3880
# Avg Regression Loss : 0.0511
# Avg Classification Loss : 1.3369
#
# Epoch : 315, Total Avg Loss : 1.4030
# Avg Regression Loss : 0.0625
# Avg Classification Loss : 1.3405
#
# Epoch : 316, Total Avg Loss : 1.3895
# Avg Regression Loss : 0.0490
# Avg Classification Loss : 1.3405
#
# Epoch : 317, Total Avg Loss : 1.4049
# Avg Regression Loss : 0.0570
# Avg Classification Loss : 1.3480
#
# Epoch : 318, Total Avg Loss : 1.4047
# Avg Regression Loss : 0.0637
# Avg Classification Loss : 1.3410
#
# Epoch : 319, Total Avg Loss : 1.4094
# Avg Regression Loss : 0.0665
# Avg Classification Loss : 1.3429
#
# Epoch : 320, Total Avg Loss : 1.3964
# Avg Regression Loss : 0.0525
# Avg Classification Loss : 1.3439
#
# Epoch : 321, Total Avg Loss : 1.4169
# Avg Regression Loss : 0.0737
# Avg Classification Loss : 1.3433
#
# Epoch : 322, Total Avg Loss : 1.4080
# Avg Regression Loss : 0.0674
# Avg Classification Loss : 1.3407
#
# Epoch : 323, Total Avg Loss : 1.4096
# Avg Regression Loss : 0.0700
# Avg Classification Loss : 1.3396
#
# Epoch : 324, Total Avg Loss : 1.3984
# Avg Regression Loss : 0.0604
# Avg Classification Loss : 1.3380
#
# Epoch : 325, Total Avg Loss : 1.4089
# Avg Regression Loss : 0.0687
# Avg Classification Loss : 1.3402
#
# Epoch : 326, Total Avg Loss : 1.4085
# Avg Regression Loss : 0.0687
# Avg Classification Loss : 1.3398
#
# Epoch : 327, Total Avg Loss : 1.4199
# Avg Regression Loss : 0.0779
# Avg Classification Loss : 1.3420
#
# Epoch : 328, Total Avg Loss : 1.4090
# Avg Regression Loss : 0.0677
# Avg Classification Loss : 1.3413
#
# Epoch : 329, Total Avg Loss : 1.4164
# Avg Regression Loss : 0.0770
# Avg Classification Loss : 1.3394
#
# Epoch : 330, Total Avg Loss : 1.3968
# Avg Regression Loss : 0.0599
# Avg Classification Loss : 1.3369
#
# Epoch : 331, Total Avg Loss : 1.4119
# Avg Regression Loss : 0.0704
# Avg Classification Loss : 1.3414
#
# Epoch : 332, Total Avg Loss : 1.4066
# Avg Regression Loss : 0.0635
# Avg Classification Loss : 1.3430
#
# Epoch : 333, Total Avg Loss : 1.4235
# Avg Regression Loss : 0.0760
# Avg Classification Loss : 1.3475
#
# Epoch : 334, Total Avg Loss : 1.4204
# Avg Regression Loss : 0.0738
# Avg Classification Loss : 1.3466
#
# Epoch : 335, Total Avg Loss : 1.4201
# Avg Regression Loss : 0.0745
# Avg Classification Loss : 1.3456
#
# Epoch : 336, Total Avg Loss : 1.3912
# Avg Regression Loss : 0.0508
# Avg Classification Loss : 1.3404
#
# Epoch : 337, Total Avg Loss : 1.4009
# Avg Regression Loss : 0.0483
# Avg Classification Loss : 1.3526
#
# Epoch : 338, Total Avg Loss : 1.4096
# Avg Regression Loss : 0.0532
# Avg Classification Loss : 1.3565
#
# Epoch : 339, Total Avg Loss : 1.4324
# Avg Regression Loss : 0.0862
# Avg Classification Loss : 1.3461
#
# Epoch : 340, Total Avg Loss : 1.4223
# Avg Regression Loss : 0.0804
# Avg Classification Loss : 1.3419
#
# Epoch : 341, Total Avg Loss : 1.4209
# Avg Regression Loss : 0.0766
# Avg Classification Loss : 1.3442
#
# Early stopping at epoch 342

# %%
# from torchinfo import summary

# summary(model, (512,3,12))

# %% [markdown]
# # train 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('0810hoxyhoxy2.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []
s_d_pred = []
t_d_pred = []

for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    source_domain_label_pred, source_pred = best_source_model2(sourcex)
    target_domain_label_pred, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())
    s_d_pred.extend(source_domain_label_pred.detach().cpu().numpy())
    t_d_pred.extend(target_domain_label_pred.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: 0.23253909918439153
# TARGET R2 Score: 0.6649780897892521

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# # test 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('0810hoxyhoxy2.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []


for step, (source_data, target_data) in enumerate(zip(NELEC_test, DHW_test)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    _, source_pred = best_source_model2(sourcex)
    _, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: 0.12384342419935934
# TARGET R2 Score: 0.6955873012339913

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# ### Domain Embedding Space 시각화

# %%
# 가장 앞 batch의 250개씩의 데이터만 샘플링
source_tsne = DataLoader(nelec_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

target_tsne = DataLoader(dhw_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

source_tsne2 = next(iter(source_tsne))
target_tsne2 = next(iter(target_tsne))

source_x_TNSE = source_tsne2[0].to(device)
source_y_TNSE = source_tsne2[1].to(device)

target_x_TNSE = target_tsne2[0].to(device)
target_y_TNSE = target_tsne2[1].to(device)

# 학습된 모델의 LSTM 부분만 활용 (100차원 임베딩 벡터를 받아오는 과정)
source_vector = model.lstm(source_x_TNSE)
target_vector = model.lstm(target_x_TNSE)

# %%
from sklearn.manifold import TSNE

df = pd.DataFrame(np.concatenate([source_vector.cpu().detach().numpy(), target_vector.cpu().detach().numpy()]))

tsne_np = TSNE(n_components=2).fit_transform(df)
tsne_df = pd.DataFrame(tsne_np, columns=['component 0', 'component 1'])

# %%
tsne_df_0 = tsne_df.loc[:1000]
tsne_df_1 = tsne_df.loc[1000:]

plt.scatter(tsne_df_0['component 0'], tsne_df_0['component 1'], color='green', label='NELEC', alpha=0.5)
plt.scatter(tsne_df_1['component 0'], tsne_df_1['component 1'], color='black', label='DHW', alpha=0.5)

plt.title('alpha = '+ str(alpha))
plt.xlabel('component 0')
plt.ylabel('component 1')
plt.legend()
plt.show()
