# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.utils.data as data_util
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import MinMaxScaler
from torchsummary import summary
from sklearn.metrics import r2_score

# %%
CUDA = torch.cuda.is_available()
print(CUDA)

device = torch.device('cuda:0' if CUDA else 'cpu')
# Out:
# True

# %%
elec = pd.read_csv('elec_merge.csv')
nelec = pd.read_csv('n_elec_merge.csv')
dhw = pd.read_csv('dhw_merge.csv')

# %%
elec = elec.drop(['YEAR'], axis=1)
nelec = nelec.drop(['YEAR'], axis=1)
dhw = dhw.drop(['YEAR'], axis=1)

# %%
input_nelec = nelec.iloc[:-1,].reset_index(drop=True)
output_nelec = nelec[['n_elec']].iloc[1:].reset_index(drop=True)
output_nelec.columns = ['nelec']

input_elec = elec.iloc[:-1,].reset_index(drop=True)
output_elec = elec[['ELEC']].iloc[1:].reset_index(drop=True)
output_elec.columns = ['elec']

input_dhw = dhw.iloc[:-1,].reset_index(drop=True)
output_dhw = dhw[['DHW']].iloc[1:].reset_index(drop=True)
output_dhw.columns = ['dhw']

nelec = pd.concat([input_nelec, output_nelec], axis=1)
elec = pd.concat([input_elec, output_elec], axis=1)
dhw = pd.concat([input_dhw, output_dhw], axis=1)

# input_nelec = nelec.iloc[:-1,:-1].reset_index(drop=True)
# output_nelec = nelec[['n_elec']].iloc[:-1].reset_index(drop=True)
# output_nelec2 = nelec['n_elec'][1:].reset_index(drop=True)
# output_nelec['nelec'] = output_nelec2

# input_elec = elec.iloc[:-1,:-1].reset_index(drop=True)
# output_elec = elec[['ELEC']].iloc[:-1].reset_index(drop=True)
# output_elec2= elec['ELEC'][1:].reset_index(drop=True)
# output_elec['elec'] = output_elec2

# input_dhw = dhw.iloc[:-1,:-1].reset_index(drop=True)
# output_dhw = dhw[['DHW']].iloc[:-1].reset_index(drop=True)
# output_dhw2 = dhw['DHW'][1:].reset_index(drop=True)
# output_dhw['dhw'] = output_dhw2

# %%
scaler_nelec = MinMaxScaler()
scaler_elec = MinMaxScaler()
scaler_dhw = MinMaxScaler()

scaler_nelec.fit(nelec)
scaler_elec.fit(elec)
scaler_dhw.fit(dhw)

scaled_nelec = scaler_nelec.transform(nelec)
scaled_elec = scaler_elec.transform(elec)
scaled_dhw = scaler_dhw.transform(dhw)

nelec = pd.DataFrame(scaled_nelec, index=nelec.index, columns=nelec.columns)
elec = pd.DataFrame(scaled_elec, index=elec.index, columns=elec.columns)
dhw = pd.DataFrame(scaled_dhw, index=dhw.index, columns=dhw.columns)

# scaler_nelec = MinMaxScaler()
# scaler_elec = MinMaxScaler()
# scaler_dhw = MinMaxScaler()

# scaler_nelec.fit(input_nelec)
# scaler_elec.fit(input_elec)
# scaler_dhw.fit(input_dhw)

# scaled_nelec = scaler_nelec.transform(input_nelec)
# scaled_elec = scaler_elec.transform(input_elec)
# scaled_dhw = scaler_dhw.transform(input_dhw)

# nelec_x = pd.DataFrame(scaled_nelec, index=input_nelec.index, columns=input_nelec.columns)
# elec_x = pd.DataFrame(scaled_elec, index=input_elec.index, columns=input_elec.columns)
# dhw_x = pd.DataFrame(scaled_dhw, index=input_dhw.index, columns=input_dhw.columns)

# nelec = pd.concat([nelec_x, output_nelec], axis=1)
# elec = pd.concat([elec_x, output_elec], axis=1)
# dhw = pd.concat([dhw_x, output_dhw], axis=1)

# %%
standard_nelec = int(len(nelec) * 0.7)
standard_elec = int(len(elec) * 0.7)
standard_dhw = int(len(dhw) * 0.7)

nelec_train = nelec.iloc[:standard_nelec]
nelec_test = nelec.iloc[standard_nelec:].reset_index(drop=True)

elec_train = elec.iloc[:standard_elec]
elec_test = elec.iloc[standard_elec:].reset_index(drop=True)

dhw_train = dhw.iloc[:standard_dhw]
dhw_test = dhw.iloc[standard_dhw:].reset_index(drop=True)

# %%
nelec_trainx = nelec_train.drop(['nelec'], axis=1)
nelec_trainy = nelec_train[['nelec']]

nelec_testx = nelec_test.drop(['nelec'], axis=1)
nelec_testy = nelec_test[['nelec']]

elec_trainx = elec_train.drop(['elec'], axis=1)
elec_trainy = elec_train[['elec']]

elec_testx = elec_test.drop(['elec'], axis=1)
elec_testy = elec_test[['elec']]

dhw_trainx = dhw_train.drop(['dhw'], axis=1)
dhw_trainy = dhw_train[['dhw']]

dhw_testx = dhw_test.drop(['dhw'], axis=1)
dhw_testy = dhw_test[['dhw']]

# %%
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-1]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

nelec_trainx, nelec_trainy = buildDataSet(nelec_trainx, nelec_trainy, 7)
nelec_testx, nelec_testy = buildDataSet(nelec_testx, nelec_testy, 7)

elec_trainx, elec_trainy = buildDataSet(elec_trainx, elec_trainy, 7)
elec_testx, elec_testy = buildDataSet(elec_testx, elec_testy, 7)

dhw_trainx, dhw_trainy = buildDataSet(dhw_trainx, dhw_trainy, 7)
dhw_testx, dhw_testy = buildDataSet(dhw_testx, dhw_testy, 7)

# %%
print(nelec_trainx.shape)
print(nelec_trainy.shape)
print(nelec_testx.shape)
print(nelec_testy.shape)
print(elec_trainx.shape)
print(elec_trainy.shape)
print(elec_testx.shape)
print(elec_testy.shape)
print(dhw_trainx.shape)
print(dhw_trainy.shape)
print(dhw_testx.shape)
print(dhw_testy.shape)
# Out:
# (20409, 7, 12)
# (20409, 1)
# (8744, 7, 12)
# (8744, 1)
# (2984, 7, 12)
# (2984, 1)
# (1275, 7, 12)
# (1275, 1)
# (20409, 7, 12)
# (20409, 1)
# (8744, 7, 12)
# (8744, 1)

# %%
# 텐서로 변환
nelec_trainx_tensor = torch.FloatTensor(nelec_trainx)
nelec_trainy_tensor = torch.FloatTensor(nelec_trainy)

nelec_testx_tensor = torch.FloatTensor(nelec_testx)
nelec_testy_tensor = torch.FloatTensor(nelec_testy)

elec_trainx_tensor = torch.FloatTensor(elec_trainx)
elec_trainy_tensor = torch.FloatTensor(elec_trainy)

elec_testx_tensor = torch.FloatTensor(elec_testx)
elec_testy_tensor = torch.FloatTensor(elec_testy)

dhw_trainx_tensor = torch.FloatTensor(dhw_trainx)
dhw_trainy_tensor = torch.FloatTensor(dhw_trainy)

dhw_testx_tensor = torch.FloatTensor(dhw_testx)
dhw_testy_tensor = torch.FloatTensor(dhw_testy)

# %%
# 텐서 형태로 데이터 정의
nelec_train = TensorDataset(nelec_trainx_tensor, nelec_trainy_tensor)
nelec_test = TensorDataset(nelec_testx_tensor, nelec_testy_tensor)

elec_train = TensorDataset(elec_trainx_tensor, elec_trainy_tensor)
elec_test = TensorDataset(elec_testx_tensor, elec_testy_tensor)

dhw_train = TensorDataset(dhw_trainx_tensor, dhw_trainy_tensor)
dhw_test = TensorDataset(dhw_testx_tensor, dhw_testy_tensor)

# %%
batch_for_nelec_train = len(nelec_trainx)
batch_for_nelec_test = len(nelec_testx)
batch_for_elec_train = len(elec_trainx)
batch_for_elec_test = len(elec_testx)
batch_for_dhw_train = len(dhw_trainx)
batch_for_dhw_test = len(dhw_testx)

NELEC_train = DataLoader(nelec_train,
                        batch_size=1024,#batch_for_nelec_train,
                        shuffle=False,  
                        drop_last=True)

NELEC_test = DataLoader(nelec_test,
                        batch_size=1024,#batch_for_nelec_test,
                        shuffle=False,  
                        drop_last=True)

ELEC_train = DataLoader(elec_train,
                        batch_size=1024,#batch_for_elec_train,
                        shuffle=False,  
                        drop_last=True)

ELEC_test = DataLoader(elec_test,
                        batch_size=1024,#batch_for_elec_test,
                        shuffle=False,  
                        drop_last=True)

DHW_train = DataLoader(dhw_train,
                        batch_size=1024,#batch_for_dhw_train,
                        shuffle=False,  
                        drop_last=True)

DHW_test = DataLoader(dhw_test,
                        batch_size=1024,#batch_for_dhw_test,
                        shuffle=False,  
                        drop_last=True)

# %%
# # 데이터셋의 개수를 가정하여 변수에 저장
# nelec_train_size = len(nelec_train)
# nelec_test_size = len(nelec_test)
# elec_train_size = len(elec_train)
# elec_test_size = len(elec_test)
# dhw_train_size = len(dhw_train)
# dhw_test_size = len(dhw_test)

# # 각 DataLoader에서 생성되는 배치의 개수 계산
# nelec_train_batches = nelec_train_size // batch_for_nelec_train
# nelec_test_batches = nelec_test_size // batch_for_nelec_test
# elec_train_batches = elec_train_size // batch_for_elec_train
# elec_test_batches = elec_test_size // batch_for_elec_test
# dhw_train_batches = dhw_train_size // batch_for_dhw_train
# dhw_test_batches = dhw_test_size // batch_for_dhw_test

# # 결과 출력
# print("nelec_train batches:", nelec_train_batches)
# print("nelec_test batches:", nelec_test_batches)
# print("elec_train batches:", elec_train_batches)
# print("elec_test batches:", elec_test_batches)
# print("dhw_train batches:", dhw_train_batches)
# print("dhw_test batches:", dhw_test_batches)

# %% [markdown]
# # 모델 구조 선언

# %%
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ### GradientReversalLayer

# %%
class GradientReversalFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, x):
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return (grad_output * -1), None

class GradientReversalLayer(torch.nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x):
        return GradientReversalFunction.apply(x)

# %% [markdown]
# ### LSTM for Feature Extraction

# %%
# class Swish(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.sigmoid = nn.Sigmoid()

#     def forward(self, x):
#         return x * self.sigmoid(x)

# %%
class lstm(nn.Module):
    def __init__(self):
        super(lstm, self).__init__()
        self.lstm1 = nn.LSTM(12, 64, batch_first=True)
        self.bn1 = nn.BatchNorm1d(7)
        
        self.lstm2 = nn.LSTM(64, 64, batch_first=True)
        self.bn2 = nn.BatchNorm1d(7)
        
        self.lstm3 = nn.LSTM(64,64, batch_first=True)
        
        self.fc = nn.Linear(64, 64, bias=False)
        self.fc2 = nn.Linear(64, 100, bias=False)
        self.bn3 = nn.BatchNorm1d(7)
        
        self.dropout = nn.Dropout(0.5)
        self.swish = nn.Hardswish()

        
    def forward(self, x):
        x, (h,c) = self.lstm1(x)
        x = self.bn1(x)

        x, (h, c) = self.lstm2(x, (h, c))
        x = self.bn2(x)
        
        x, _ = self.lstm3(x, (h, c))
        x = self.bn2(x)
        
        x = self.fc(x)
        x = self.bn3(x)
        x = self.fc2(x[:,-1,:])
        x = self.swish(x)
        x = self.dropout(x)
        return x

# %%
# hoxy = lstm()
# inputx = torch.randn(1024,7,12)
# hoxy2 = hoxy(inputx)
# print(hoxy2.shape)

# %%
class domain_regression(nn.Module):
    def __init__(self):
        super(domain_regression, self).__init__()
        self.regression_layer1 = nn.Linear(100, 100)
        self.regression_layer2 = nn.Linear(100, 100)
        self.regression_layer3 = nn.Linear(100, 100)
        self.regression_layer4 = nn.Linear(100, 1)
        self.swish = nn.Hardswish()
        
    def forward(self, x):
        x = self.swish(self.regression_layer1(x))
        x = self.swish(self.regression_layer2(x))
        x = self.swish(self.regression_layer3(x))
        x = self.swish(self.regression_layer4(x))
        return x

# %% [markdown]
# ### Domain Classification

# %%
class domain_classfication(nn.Module):
    def __init__(self):
        super(domain_classfication, self).__init__()
        self.classification_layer0 = GradientReversalLayer()
        self.classification_layer1 = nn.Linear(100,100,bias=False)
        self.classification_layer2 = nn.Linear(100,100,bias=False)
        self.classification_layer3 = nn.Linear(100,100,bias=False)
        self.classification_layer4 = nn.Linear(100, 1,bias=False)
        self.swish = nn.Hardswish()
        #self.dropout = nn.Dropout(0.25)
        self.h_sigmoid = nn.Hardsigmoid()
        
    def forward(self, x):
        x = self.swish(self.classification_layer0(x))
        x = self.swish(self.classification_layer1(x))
        x = self.swish(self.classification_layer2(x))
        x = self.swish(self.classification_layer3(x))
        #x = self.dropout(x)
        x = self.h_sigmoid(self.classification_layer4(x))
        return x

# %% [markdown]
# ### Set the DANN

# %%
class dann(nn.Module):
    def __init__(self, lstm):
        super(dann, self).__init__()
        self.lstm = lstm
        self.regression = domain_regression()
        self.classification = domain_classfication()
        
    def forward(self, x):
        feature = self.lstm(x)
        reg_output = self.regression(feature)
        cla_output = self.classification(feature)
        
        return reg_output, cla_output

# %% [markdown]
# ### Loss 선언

# %%
class dann_loss(nn.Module):
    def __init__(self):
        super(dann_loss, self).__init__()
        self.reg = nn.L1Loss() # 회귀 L1 손실 == MAE
        self.cla = nn.BCEWithLogitsLoss() # 도메인 분류
        
    def forward(self, result, reg_real, domain_num, alpha=1):
        reg_output, cla_output = result
        batch_size = reg_output.shape[0]
        cla_target = torch.FloatTensor([domain_num] * batch_size).unsqueeze(1).to(device)
        
        reg_loss = self.reg(reg_output, reg_real)
        cla_loss = self.cla(cla_output, cla_target)
        cla_loss2 = cla_loss * alpha
        
        loss = reg_loss + cla_loss2
        
        return loss, reg_loss, cla_loss2

# %%
my_lstm = lstm().to(device)
model = dann(my_lstm).to(device)
loss_fn = dann_loss().to(device)

# %% [markdown]
# # 훈련

# %%
from torch.optim.lr_scheduler import LinearLR

alpha = 1.0
epochs = 200

model.train() # 훈련 모드 설정

optimizer= torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)
scheduler = LinearLR(optimizer, start_factor=1.0, end_factor=0.0, total_iters = epochs * len(NELEC_train))

#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer,min_lr=1e-4,factor=0.45,patience=5,cooldown=0,verbose=1)
#scheduler.step(valid_loss)

patience = 100  # Early stopping을 위한 기다리는 최대 epoch 수
best_loss = float('inf')
best_source_loss = float('inf')
best_model_state_dict = None
counter = 10  # Early stopping 카운터

for i in range(1, epochs + 1):
    total_loss = 0
    source_total_loss = 0
    target_total_loss = 0
    src_reg_total = 0
    src_cla_total = 0
    tar_reg_total = 0
    tar_cal_total = 0
    reg_loss_total = 0
    cla_loss_total = 0
    for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
        source_x = source_data[0].to(device)
        source_y = source_data[1].to(device)
        target_x = target_data[0].to(device)
        target_y = target_data[1].to(device)
        #print(source_x.shape)
        #print(source_y.shape)
        #print(target_x.shape)
        #print(target_y.shape)
        # 순전파
        source_result = model(source_x)
        target_result = model(target_x)
        #print(source_result[0].shape)
        #print(target_result[0].shape)
        #print(source_result[1].shape)
        #print(target_result[1].shape)
        # 순전파 loss
        source_loss, source_reg_loss, source_cla_loss = loss_fn(source_result, source_y, 1, alpha=alpha) # 소스 도메인 레이블 1
        target_loss, target_reg_loss, target_cla_loss = loss_fn(target_result, target_y, 0, alpha=alpha) # 타겟 도메인 레이블 0
        
        loss = source_loss + target_loss
        reg_loss = source_reg_loss + target_reg_loss
        cla_loss = source_cla_loss + target_cla_loss
        
        #src_reg_total += source_reg_loss.item()
        #src_cla_total += source_cla_loss.item()
        #tar_reg_total += target_reg_loss.item()
        #tar_cal_total += target_cla_loss.item()
        
        #source_total_loss += source_loss.item()
        #target_total_loss += target_loss.item()
        
        reg_loss_total += reg_loss.item()
        cla_loss_total += cla_loss.item()
        
        total_loss += loss.item()
        
        # 그래디언트 계산 및 업데이트
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()
        
        # Early stopping 확인
    if reg_loss_total / len(NELEC_train) < best_loss:
        best_loss = reg_loss_total / len(NELEC_train)
        best_model_state_dict = model.state_dict()
        counter = 0  # Counter 초기화
    else:
        counter += 1
        if counter >= patience:
            print(f'Early stopping at epoch {i}')
            break

    print('Epoch : %d, Total Avg Loss : %.4f' % (i, total_loss / len(NELEC_train)))     
    #print('Source Avg Loss : %.4f' % (source_total_loss / len(NELEC_train)))
    #print('Target Avg Loss : %.4f' % (target_total_loss / len(NELEC_train)))
    #print('Source Avg reg Loss : %.4f' % (src_reg_total / len(NELEC_train)))
    #print('Target Avg reg Loss : %.4f' % (tar_reg_total / len(NELEC_train)))
    #print('Source Avg cla Loss : %.4f' % (src_cla_total / len(NELEC_train)))
    #print('Target Avg cla Loss : %.4f' % (tar_cal_total / len(NELEC_train)))
    print('Avg Regression Loss : %.4f' % (reg_loss_total / len(NELEC_train)))
    print('Avg Classification Loss : %.4f' % (cla_loss_total / len(NELEC_train)))
    print('')
    
    # source_loss가 가장 낮은 경우 모델 가중치 저장
    if reg_loss_total / len(NELEC_train) < best_source_loss:
        best_source_loss = reg_loss_total / len(NELEC_train)
        best_model_state_dict = model.state_dict()

# 최상의 모델을 파일로 저장
if best_model_state_dict is not None:
    torch.save(best_model_state_dict, '0811_experiment_1_revise_by_js.pth')
    #torch.save(model, "model.pth")
# Out:
# Epoch : 1, Total Avg Loss : 1.9946
# Avg Regression Loss : 0.5583
# Avg Classification Loss : 1.4364
#
# Epoch : 2, Total Avg Loss : 1.8179
# Avg Regression Loss : 0.3514
# Avg Classification Loss : 1.4665
#
# Epoch : 3, Total Avg Loss : 1.8458
# Avg Regression Loss : 0.3499
# Avg Classification Loss : 1.4959
#
# Epoch : 4, Total Avg Loss : 1.7174
# Avg Regression Loss : 0.2548
# Avg Classification Loss : 1.4626
#
# Epoch : 5, Total Avg Loss : 1.6000
# Avg Regression Loss : 0.1854
# Avg Classification Loss : 1.4146
#
# Epoch : 6, Total Avg Loss : 1.6138
# Avg Regression Loss : 0.1687
# Avg Classification Loss : 1.4451
#
# Epoch : 7, Total Avg Loss : 1.5988
# Avg Regression Loss : 0.1593
# Avg Classification Loss : 1.4395
#
# Epoch : 8, Total Avg Loss : 1.5910
# Avg Regression Loss : 0.1516
# Avg Classification Loss : 1.4394
#
# Epoch : 9, Total Avg Loss : 1.5931
# Avg Regression Loss : 0.1397
# Avg Classification Loss : 1.4534
#
# Epoch : 10, Total Avg Loss : 1.6236
# Avg Regression Loss : 0.1553
# Avg Classification Loss : 1.4683
#
# Epoch : 11, Total Avg Loss : 1.6167
# Avg Regression Loss : 0.1644
# Avg Classification Loss : 1.4523
#
# Epoch : 12, Total Avg Loss : 1.6332
# Avg Regression Loss : 0.1750
# Avg Classification Loss : 1.4582
#
# Epoch : 13, Total Avg Loss : 1.6143
# Avg Regression Loss : 0.1630
# Avg Classification Loss : 1.4513
#
# Epoch : 14, Total Avg Loss : 1.6049
# Avg Regression Loss : 0.1606
# Avg Classification Loss : 1.4444
#
# Epoch : 15, Total Avg Loss : 1.5737
# Avg Regression Loss : 0.1351
# Avg Classification Loss : 1.4386
#
# Epoch : 16, Total Avg Loss : 1.5944
# Avg Regression Loss : 0.1458
# Avg Classification Loss : 1.4486
#
# Epoch : 17, Total Avg Loss : 1.5908
# Avg Regression Loss : 0.1540
# Avg Classification Loss : 1.4368
#
# Epoch : 18, Total Avg Loss : 1.5844
# Avg Regression Loss : 0.1320
# Avg Classification Loss : 1.4524
#
# Epoch : 19, Total Avg Loss : 1.5788
# Avg Regression Loss : 0.1308
# Avg Classification Loss : 1.4480
#
# Epoch : 20, Total Avg Loss : 1.5643
# Avg Regression Loss : 0.1242
# Avg Classification Loss : 1.4400
#
# Epoch : 21, Total Avg Loss : 1.5539
# Avg Regression Loss : 0.1168
# Avg Classification Loss : 1.4372
#
# Epoch : 22, Total Avg Loss : 1.5607
# Avg Regression Loss : 0.1313
# Avg Classification Loss : 1.4294
#
# Epoch : 23, Total Avg Loss : 1.5734
# Avg Regression Loss : 0.1337
# Avg Classification Loss : 1.4396
#
# Epoch : 24, Total Avg Loss : 1.7387
# Avg Regression Loss : 0.1970
# Avg Classification Loss : 1.5417
#
# Epoch : 25, Total Avg Loss : 1.6138
# Avg Regression Loss : 0.1527
# Avg Classification Loss : 1.4611
#
# Epoch : 26, Total Avg Loss : 1.5638
# Avg Regression Loss : 0.1145
# Avg Classification Loss : 1.4494
#
# Epoch : 27, Total Avg Loss : 1.5728
# Avg Regression Loss : 0.1214
# Avg Classification Loss : 1.4514
#
# Epoch : 28, Total Avg Loss : 1.5468
# Avg Regression Loss : 0.0969
# Avg Classification Loss : 1.4499
#
# Epoch : 29, Total Avg Loss : 1.5649
# Avg Regression Loss : 0.1201
# Avg Classification Loss : 1.4448
#
# Epoch : 30, Total Avg Loss : 1.5646
# Avg Regression Loss : 0.1276
# Avg Classification Loss : 1.4370
#
# Epoch : 31, Total Avg Loss : 1.5619
# Avg Regression Loss : 0.1275
# Avg Classification Loss : 1.4345
#
# Epoch : 32, Total Avg Loss : 1.5477
# Avg Regression Loss : 0.1113
# Avg Classification Loss : 1.4363
#
# Epoch : 33, Total Avg Loss : 1.5217
# Avg Regression Loss : 0.1041
# Avg Classification Loss : 1.4176
#
# Epoch : 34, Total Avg Loss : 1.5607
# Avg Regression Loss : 0.0927
# Avg Classification Loss : 1.4680
#
# Epoch : 35, Total Avg Loss : 1.5721
# Avg Regression Loss : 0.1040
# Avg Classification Loss : 1.4681
#
# Epoch : 36, Total Avg Loss : 1.5487
# Avg Regression Loss : 0.0960
# Avg Classification Loss : 1.4527
#
# Epoch : 37, Total Avg Loss : 1.5441
# Avg Regression Loss : 0.1006
# Avg Classification Loss : 1.4435
#
# Epoch : 38, Total Avg Loss : 1.5160
# Avg Regression Loss : 0.0839
# Avg Classification Loss : 1.4321
#
# Epoch : 39, Total Avg Loss : 1.5261
# Avg Regression Loss : 0.0789
# Avg Classification Loss : 1.4473
#
# Epoch : 40, Total Avg Loss : 1.5512
# Avg Regression Loss : 0.0907
# Avg Classification Loss : 1.4605
#
# Epoch : 41, Total Avg Loss : 1.5420
# Avg Regression Loss : 0.0940
# Avg Classification Loss : 1.4480
#
# Epoch : 42, Total Avg Loss : 1.5452
# Avg Regression Loss : 0.1100
# Avg Classification Loss : 1.4352
#
# Epoch : 43, Total Avg Loss : 1.5771
# Avg Regression Loss : 0.1217
# Avg Classification Loss : 1.4555
#
# Epoch : 44, Total Avg Loss : 1.5780
# Avg Regression Loss : 0.1274
# Avg Classification Loss : 1.4506
#
# Epoch : 45, Total Avg Loss : 1.5664
# Avg Regression Loss : 0.1219
# Avg Classification Loss : 1.4445
#
# Epoch : 46, Total Avg Loss : 1.5458
# Avg Regression Loss : 0.0950
# Avg Classification Loss : 1.4509
#
# Epoch : 47, Total Avg Loss : 1.5449
# Avg Regression Loss : 0.0873
# Avg Classification Loss : 1.4577
#
# Epoch : 48, Total Avg Loss : 1.5489
# Avg Regression Loss : 0.0924
# Avg Classification Loss : 1.4565
#
# Epoch : 49, Total Avg Loss : 1.5366
# Avg Regression Loss : 0.0890
# Avg Classification Loss : 1.4476
#
# Epoch : 50, Total Avg Loss : 1.5444
# Avg Regression Loss : 0.1050
# Avg Classification Loss : 1.4394
#
# Epoch : 51, Total Avg Loss : 1.5507
# Avg Regression Loss : 0.1117
# Avg Classification Loss : 1.4389
#
# Epoch : 52, Total Avg Loss : 1.5404
# Avg Regression Loss : 0.0960
# Avg Classification Loss : 1.4444
#
# Epoch : 53, Total Avg Loss : 1.5242
# Avg Regression Loss : 0.0817
# Avg Classification Loss : 1.4425
#
# Epoch : 54, Total Avg Loss : 1.5102
# Avg Regression Loss : 0.0727
# Avg Classification Loss : 1.4375
#
# Epoch : 55, Total Avg Loss : 1.5086
# Avg Regression Loss : 0.0703
# Avg Classification Loss : 1.4383
#
# Epoch : 56, Total Avg Loss : 1.5110
# Avg Regression Loss : 0.0730
# Avg Classification Loss : 1.4380
#
# Epoch : 57, Total Avg Loss : 1.5214
# Avg Regression Loss : 0.0745
# Avg Classification Loss : 1.4469
#
# Epoch : 58, Total Avg Loss : 1.5456
# Avg Regression Loss : 0.0852
# Avg Classification Loss : 1.4605
#
# Epoch : 59, Total Avg Loss : 1.5336
# Avg Regression Loss : 0.0768
# Avg Classification Loss : 1.4568
#
# Epoch : 60, Total Avg Loss : 1.5383
# Avg Regression Loss : 0.0896
# Avg Classification Loss : 1.4487
#
# Epoch : 61, Total Avg Loss : 1.5371
# Avg Regression Loss : 0.0918
# Avg Classification Loss : 1.4453
#
# Epoch : 62, Total Avg Loss : 1.5520
# Avg Regression Loss : 0.1073
# Avg Classification Loss : 1.4447
#
# Epoch : 63, Total Avg Loss : 1.5630
# Avg Regression Loss : 0.1220
# Avg Classification Loss : 1.4411
#
# Epoch : 64, Total Avg Loss : 1.5473
# Avg Regression Loss : 0.1027
# Avg Classification Loss : 1.4445
#
# Epoch : 65, Total Avg Loss : 1.5227
# Avg Regression Loss : 0.0790
# Avg Classification Loss : 1.4437
#
# Epoch : 66, Total Avg Loss : 1.5330
# Avg Regression Loss : 0.0870
# Avg Classification Loss : 1.4460
#
# Epoch : 67, Total Avg Loss : 1.5365
# Avg Regression Loss : 0.0910
# Avg Classification Loss : 1.4455
#
# Epoch : 68, Total Avg Loss : 1.5427
# Avg Regression Loss : 0.0961
# Avg Classification Loss : 1.4466
#
# Epoch : 69, Total Avg Loss : 1.5313
# Avg Regression Loss : 0.0851
# Avg Classification Loss : 1.4463
#
# Epoch : 70, Total Avg Loss : 1.5293
# Avg Regression Loss : 0.0820
# Avg Classification Loss : 1.4472
#
# Epoch : 71, Total Avg Loss : 1.5212
# Avg Regression Loss : 0.0737
# Avg Classification Loss : 1.4475
#
# Epoch : 72, Total Avg Loss : 1.5202
# Avg Regression Loss : 0.0767
# Avg Classification Loss : 1.4435
#
# Epoch : 73, Total Avg Loss : 1.5304
# Avg Regression Loss : 0.0874
# Avg Classification Loss : 1.4430
#
# Epoch : 74, Total Avg Loss : 1.5293
# Avg Regression Loss : 0.0866
# Avg Classification Loss : 1.4428
#
# Epoch : 75, Total Avg Loss : 1.5365
# Avg Regression Loss : 0.0944
# Avg Classification Loss : 1.4421
#
# Epoch : 76, Total Avg Loss : 1.5219
# Avg Regression Loss : 0.0807
# Avg Classification Loss : 1.4412
#
# Epoch : 77, Total Avg Loss : 1.5230
# Avg Regression Loss : 0.0812
# Avg Classification Loss : 1.4417
#
# Epoch : 78, Total Avg Loss : 1.5243
# Avg Regression Loss : 0.0801
# Avg Classification Loss : 1.4442
#
# Epoch : 79, Total Avg Loss : 1.5296
# Avg Regression Loss : 0.0834
# Avg Classification Loss : 1.4461
#
# Epoch : 80, Total Avg Loss : 1.5301
# Avg Regression Loss : 0.0821
# Avg Classification Loss : 1.4480
#
# Epoch : 81, Total Avg Loss : 1.5323
# Avg Regression Loss : 0.0826
# Avg Classification Loss : 1.4497
#
# Epoch : 82, Total Avg Loss : 1.5202
# Avg Regression Loss : 0.0724
# Avg Classification Loss : 1.4478
#
# Epoch : 83, Total Avg Loss : 1.5268
# Avg Regression Loss : 0.0846
# Avg Classification Loss : 1.4422
#
# Epoch : 84, Total Avg Loss : 1.5177
# Avg Regression Loss : 0.0790
# Avg Classification Loss : 1.4388
#
# Epoch : 85, Total Avg Loss : 1.5198
# Avg Regression Loss : 0.0781
# Avg Classification Loss : 1.4418
#
# Epoch : 86, Total Avg Loss : 1.5230
# Avg Regression Loss : 0.0759
# Avg Classification Loss : 1.4471
#
# Epoch : 87, Total Avg Loss : 1.5387
# Avg Regression Loss : 0.0843
# Avg Classification Loss : 1.4545
#
# Epoch : 88, Total Avg Loss : 1.5280
# Avg Regression Loss : 0.0752
# Avg Classification Loss : 1.4528
#
# Epoch : 89, Total Avg Loss : 1.5286
# Avg Regression Loss : 0.0792
# Avg Classification Loss : 1.4495
#
# Epoch : 90, Total Avg Loss : 1.5210
# Avg Regression Loss : 0.0749
# Avg Classification Loss : 1.4462
#
# Epoch : 91, Total Avg Loss : 1.5259
# Avg Regression Loss : 0.0810
# Avg Classification Loss : 1.4450
#
# Epoch : 92, Total Avg Loss : 1.5135
# Avg Regression Loss : 0.0721
# Avg Classification Loss : 1.4414
#
# Epoch : 93, Total Avg Loss : 1.5183
# Avg Regression Loss : 0.0782
# Avg Classification Loss : 1.4401
#
# Epoch : 94, Total Avg Loss : 1.5103
# Avg Regression Loss : 0.0710
# Avg Classification Loss : 1.4393
#
# Epoch : 95, Total Avg Loss : 1.5194
# Avg Regression Loss : 0.0765
# Avg Classification Loss : 1.4429
#
# Epoch : 96, Total Avg Loss : 1.5136
# Avg Regression Loss : 0.0703
# Avg Classification Loss : 1.4433
#
# Epoch : 97, Total Avg Loss : 1.5217
# Avg Regression Loss : 0.0780
# Avg Classification Loss : 1.4436
#
# Epoch : 98, Total Avg Loss : 1.5106
# Avg Regression Loss : 0.0680
# Avg Classification Loss : 1.4426
#
# Epoch : 99, Total Avg Loss : 1.5180
# Avg Regression Loss : 0.0727
# Avg Classification Loss : 1.4453
#
# Epoch : 100, Total Avg Loss : 1.5132
# Avg Regression Loss : 0.0671
# Avg Classification Loss : 1.4460
#
# Epoch : 101, Total Avg Loss : 1.5226
# Avg Regression Loss : 0.0734
# Avg Classification Loss : 1.4491
#
# Epoch : 102, Total Avg Loss : 1.5160
# Avg Regression Loss : 0.0682
# Avg Classification Loss : 1.4478
#
# Epoch : 103, Total Avg Loss : 1.5206
# Avg Regression Loss : 0.0732
# Avg Classification Loss : 1.4475
#
# Epoch : 104, Total Avg Loss : 1.5099
# Avg Regression Loss : 0.0646
# Avg Classification Loss : 1.4453
#
# Epoch : 105, Total Avg Loss : 1.5156
# Avg Regression Loss : 0.0691
# Avg Classification Loss : 1.4464
#
# Epoch : 106, Total Avg Loss : 1.5083
# Avg Regression Loss : 0.0635
# Avg Classification Loss : 1.4448
#
# Epoch : 107, Total Avg Loss : 1.5165
# Avg Regression Loss : 0.0699
# Avg Classification Loss : 1.4466
#
# Epoch : 108, Total Avg Loss : 1.5089
# Avg Regression Loss : 0.0631
# Avg Classification Loss : 1.4457
#
# Epoch : 109, Total Avg Loss : 1.5178
# Avg Regression Loss : 0.0701
# Avg Classification Loss : 1.4477
#
# Epoch : 110, Total Avg Loss : 1.5109
# Avg Regression Loss : 0.0646
# Avg Classification Loss : 1.4463
#
# Epoch : 111, Total Avg Loss : 1.5167
# Avg Regression Loss : 0.0699
# Avg Classification Loss : 1.4468
#
# Epoch : 112, Total Avg Loss : 1.5094
# Avg Regression Loss : 0.0651
# Avg Classification Loss : 1.4442
#
# Epoch : 113, Total Avg Loss : 1.5116
# Avg Regression Loss : 0.0675
# Avg Classification Loss : 1.4442
#
# Epoch : 114, Total Avg Loss : 1.5052
# Avg Regression Loss : 0.0632
# Avg Classification Loss : 1.4421
#
# Epoch : 115, Total Avg Loss : 1.5107
# Avg Regression Loss : 0.0677
# Avg Classification Loss : 1.4430
#
# Epoch : 116, Total Avg Loss : 1.5024
# Avg Regression Loss : 0.0606
# Avg Classification Loss : 1.4418
#
# Epoch : 117, Total Avg Loss : 1.5085
# Avg Regression Loss : 0.0648
# Avg Classification Loss : 1.4438
#
# Epoch : 118, Total Avg Loss : 1.5037
# Avg Regression Loss : 0.0598
# Avg Classification Loss : 1.4439
#
# Epoch : 119, Total Avg Loss : 1.5111
# Avg Regression Loss : 0.0650
# Avg Classification Loss : 1.4461
#
# Epoch : 120, Total Avg Loss : 1.5049
# Avg Regression Loss : 0.0596
# Avg Classification Loss : 1.4453
#
# Epoch : 121, Total Avg Loss : 1.5094
# Avg Regression Loss : 0.0637
# Avg Classification Loss : 1.4458
#
# Epoch : 122, Total Avg Loss : 1.5032
# Avg Regression Loss : 0.0588
# Avg Classification Loss : 1.4444
#
# Epoch : 123, Total Avg Loss : 1.5092
# Avg Regression Loss : 0.0637
# Avg Classification Loss : 1.4455
#
# Epoch : 124, Total Avg Loss : 1.5019
# Avg Regression Loss : 0.0574
# Avg Classification Loss : 1.4445
#
# Epoch : 125, Total Avg Loss : 1.5074
# Avg Regression Loss : 0.0615
# Avg Classification Loss : 1.4459
#
# Epoch : 126, Total Avg Loss : 1.5014
# Avg Regression Loss : 0.0564
# Avg Classification Loss : 1.4451
#
# Epoch : 127, Total Avg Loss : 1.5105
# Avg Regression Loss : 0.0624
# Avg Classification Loss : 1.4482
#
# Epoch : 128, Total Avg Loss : 1.5070
# Avg Regression Loss : 0.0574
# Avg Classification Loss : 1.4496
#
# Epoch : 129, Total Avg Loss : 1.5219
# Avg Regression Loss : 0.0659
# Avg Classification Loss : 1.4560
#
# Epoch : 130, Total Avg Loss : 1.5170
# Avg Regression Loss : 0.0617
# Avg Classification Loss : 1.4553
#
# Epoch : 131, Total Avg Loss : 1.5261
# Avg Regression Loss : 0.0693
# Avg Classification Loss : 1.4567
#
# Epoch : 132, Total Avg Loss : 1.5171
# Avg Regression Loss : 0.0669
# Avg Classification Loss : 1.4502
#
# Epoch : 133, Total Avg Loss : 1.5179
# Avg Regression Loss : 0.0666
# Avg Classification Loss : 1.4513
#
# Epoch : 134, Total Avg Loss : 1.5049
# Avg Regression Loss : 0.0602
# Avg Classification Loss : 1.4447
#
# Epoch : 135, Total Avg Loss : 1.5072
# Avg Regression Loss : 0.0611
# Avg Classification Loss : 1.4461
#
# Epoch : 136, Total Avg Loss : 1.4974
# Avg Regression Loss : 0.0520
# Avg Classification Loss : 1.4453
#
# Epoch : 137, Total Avg Loss : 1.4947
# Avg Regression Loss : 0.0504
# Avg Classification Loss : 1.4443
#
# Epoch : 138, Total Avg Loss : 1.4936
# Avg Regression Loss : 0.0499
# Avg Classification Loss : 1.4437
#
# Epoch : 139, Total Avg Loss : 1.4963
# Avg Regression Loss : 0.0510
# Avg Classification Loss : 1.4453
#
# Epoch : 140, Total Avg Loss : 1.4956
# Avg Regression Loss : 0.0490
# Avg Classification Loss : 1.4466
#
# Epoch : 141, Total Avg Loss : 1.5001
# Avg Regression Loss : 0.0527
# Avg Classification Loss : 1.4474
#
# Epoch : 142, Total Avg Loss : 1.4955
# Avg Regression Loss : 0.0498
# Avg Classification Loss : 1.4457
#
# Epoch : 143, Total Avg Loss : 1.5008
# Avg Regression Loss : 0.0549
# Avg Classification Loss : 1.4459
#
# Epoch : 144, Total Avg Loss : 1.4958
# Avg Regression Loss : 0.0506
# Avg Classification Loss : 1.4451
#
# Epoch : 145, Total Avg Loss : 1.4990
# Avg Regression Loss : 0.0527
# Avg Classification Loss : 1.4464
#
# Epoch : 146, Total Avg Loss : 1.4953
# Avg Regression Loss : 0.0500
# Avg Classification Loss : 1.4452
#
# Epoch : 147, Total Avg Loss : 1.4965
# Avg Regression Loss : 0.0511
# Avg Classification Loss : 1.4454
#
# Epoch : 148, Total Avg Loss : 1.4937
# Avg Regression Loss : 0.0490
# Avg Classification Loss : 1.4447
#
# Epoch : 149, Total Avg Loss : 1.4954
# Avg Regression Loss : 0.0504
# Avg Classification Loss : 1.4451
#
# Epoch : 150, Total Avg Loss : 1.4925
# Avg Regression Loss : 0.0478
# Avg Classification Loss : 1.4446
#
# Epoch : 151, Total Avg Loss : 1.4938
# Avg Regression Loss : 0.0486
# Avg Classification Loss : 1.4451
#
# Epoch : 152, Total Avg Loss : 1.4915
# Avg Regression Loss : 0.0465
# Avg Classification Loss : 1.4450
#
# Epoch : 153, Total Avg Loss : 1.4930
# Avg Regression Loss : 0.0475
# Avg Classification Loss : 1.4455
#
# Epoch : 154, Total Avg Loss : 1.4908
# Avg Regression Loss : 0.0457
# Avg Classification Loss : 1.4451
#
# Epoch : 155, Total Avg Loss : 1.4929
# Avg Regression Loss : 0.0472
# Avg Classification Loss : 1.4457
#
# Epoch : 156, Total Avg Loss : 1.4910
# Avg Regression Loss : 0.0459
# Avg Classification Loss : 1.4452
#
# Epoch : 157, Total Avg Loss : 1.4923
# Avg Regression Loss : 0.0468
# Avg Classification Loss : 1.4455
#
# Epoch : 158, Total Avg Loss : 1.4907
# Avg Regression Loss : 0.0456
# Avg Classification Loss : 1.4450
#
# Epoch : 159, Total Avg Loss : 1.4919
# Avg Regression Loss : 0.0464
# Avg Classification Loss : 1.4454
#
# Epoch : 160, Total Avg Loss : 1.4904
# Avg Regression Loss : 0.0452
# Avg Classification Loss : 1.4453
#
# Epoch : 161, Total Avg Loss : 1.4909
# Avg Regression Loss : 0.0454
# Avg Classification Loss : 1.4455
#
# Epoch : 162, Total Avg Loss : 1.4910
# Avg Regression Loss : 0.0454
# Avg Classification Loss : 1.4456
#
# Epoch : 163, Total Avg Loss : 1.4913
# Avg Regression Loss : 0.0452
# Avg Classification Loss : 1.4461
#
# Epoch : 164, Total Avg Loss : 1.4915
# Avg Regression Loss : 0.0451
# Avg Classification Loss : 1.4464
#
# Epoch : 165, Total Avg Loss : 1.4918
# Avg Regression Loss : 0.0449
# Avg Classification Loss : 1.4469
#
# Epoch : 166, Total Avg Loss : 1.4911
# Avg Regression Loss : 0.0443
# Avg Classification Loss : 1.4468
#
# Epoch : 167, Total Avg Loss : 1.4917
# Avg Regression Loss : 0.0446
# Avg Classification Loss : 1.4471
#
# Epoch : 168, Total Avg Loss : 1.4917
# Avg Regression Loss : 0.0443
# Avg Classification Loss : 1.4473
#
# Epoch : 169, Total Avg Loss : 1.4911
# Avg Regression Loss : 0.0439
# Avg Classification Loss : 1.4473
#
# Epoch : 170, Total Avg Loss : 1.4914
# Avg Regression Loss : 0.0440
# Avg Classification Loss : 1.4474
#
# Epoch : 171, Total Avg Loss : 1.4906
# Avg Regression Loss : 0.0432
# Avg Classification Loss : 1.4473
#
# Epoch : 172, Total Avg Loss : 1.4904
# Avg Regression Loss : 0.0430
# Avg Classification Loss : 1.4474
#
# Epoch : 173, Total Avg Loss : 1.4903
# Avg Regression Loss : 0.0429
# Avg Classification Loss : 1.4474
#
# Epoch : 174, Total Avg Loss : 1.4903
# Avg Regression Loss : 0.0429
# Avg Classification Loss : 1.4473
#
# Epoch : 175, Total Avg Loss : 1.4902
# Avg Regression Loss : 0.0430
# Avg Classification Loss : 1.4473
#
# Epoch : 176, Total Avg Loss : 1.4899
# Avg Regression Loss : 0.0429
# Avg Classification Loss : 1.4471
#
# Epoch : 177, Total Avg Loss : 1.4898
# Avg Regression Loss : 0.0428
# Avg Classification Loss : 1.4470
#
# Epoch : 178, Total Avg Loss : 1.4897
# Avg Regression Loss : 0.0428
# Avg Classification Loss : 1.4469
#
# Epoch : 179, Total Avg Loss : 1.4890
# Avg Regression Loss : 0.0426
# Avg Classification Loss : 1.4465
#
# Epoch : 180, Total Avg Loss : 1.4892
# Avg Regression Loss : 0.0426
# Avg Classification Loss : 1.4466
#
# Epoch : 181, Total Avg Loss : 1.4887
# Avg Regression Loss : 0.0425
# Avg Classification Loss : 1.4463
#
# Epoch : 182, Total Avg Loss : 1.4885
# Avg Regression Loss : 0.0424
# Avg Classification Loss : 1.4461
#
# Epoch : 183, Total Avg Loss : 1.4884
# Avg Regression Loss : 0.0423
# Avg Classification Loss : 1.4460
#
# Epoch : 184, Total Avg Loss : 1.4882
# Avg Regression Loss : 0.0424
# Avg Classification Loss : 1.4458
#
# Epoch : 185, Total Avg Loss : 1.4885
# Avg Regression Loss : 0.0428
# Avg Classification Loss : 1.4457
#
# Epoch : 186, Total Avg Loss : 1.4885
# Avg Regression Loss : 0.0428
# Avg Classification Loss : 1.4457
#
# Epoch : 187, Total Avg Loss : 1.4881
# Avg Regression Loss : 0.0423
# Avg Classification Loss : 1.4457
#
# Epoch : 188, Total Avg Loss : 1.4878
# Avg Regression Loss : 0.0423
# Avg Classification Loss : 1.4455
#
# Epoch : 189, Total Avg Loss : 1.4878
# Avg Regression Loss : 0.0424
# Avg Classification Loss : 1.4454
#
# Epoch : 190, Total Avg Loss : 1.4878
# Avg Regression Loss : 0.0424
# Avg Classification Loss : 1.4453
#
# Epoch : 191, Total Avg Loss : 1.4871
# Avg Regression Loss : 0.0419
# Avg Classification Loss : 1.4452
#
# Epoch : 192, Total Avg Loss : 1.4869
# Avg Regression Loss : 0.0416
# Avg Classification Loss : 1.4453
#
# Epoch : 193, Total Avg Loss : 1.4867
# Avg Regression Loss : 0.0415
# Avg Classification Loss : 1.4452
#
# Epoch : 194, Total Avg Loss : 1.4868
# Avg Regression Loss : 0.0415
# Avg Classification Loss : 1.4453
#
# Epoch : 195, Total Avg Loss : 1.4866
# Avg Regression Loss : 0.0415
# Avg Classification Loss : 1.4452
#
# Epoch : 196, Total Avg Loss : 1.4862
# Avg Regression Loss : 0.0411
# Avg Classification Loss : 1.4452
#
# Epoch : 197, Total Avg Loss : 1.4866
# Avg Regression Loss : 0.0415
# Avg Classification Loss : 1.4451
#
# Epoch : 198, Total Avg Loss : 1.4867
# Avg Regression Loss : 0.0414
# Avg Classification Loss : 1.4453
#
# Epoch : 199, Total Avg Loss : 1.4867
# Avg Regression Loss : 0.0412
# Avg Classification Loss : 1.4454
#
# Epoch : 200, Total Avg Loss : 1.4864
# Avg Regression Loss : 0.0411
# Avg Classification Loss : 1.4453

# %%
# from torchinfo import summary

# summary(model, (512,3,12))

# %% [markdown]
# # train 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('0811_experiment_1_revise_by_js.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []
s_d_pred = []
t_d_pred = []

for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    source_domain_label_pred, source_pred = best_source_model2(sourcex)
    target_domain_label_pred, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())
    s_d_pred.extend(source_domain_label_pred.detach().cpu().numpy())
    t_d_pred.extend(target_domain_label_pred.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: -0.20749319794016663
# TARGET R2 Score: -1.1831569990622341

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# # test 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('0811_experiment_1_revise_by_js.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []


for step, (source_data, target_data) in enumerate(zip(NELEC_test, DHW_test)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    _, source_pred = best_source_model2(sourcex)
    _, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: -0.3817631178678844
# TARGET R2 Score: -1.755691395408658

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# ### Domain Embedding Space 시각화

# %%
# 가장 앞 batch의 250개씩의 데이터만 샘플링
source_tsne = DataLoader(nelec_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

target_tsne = DataLoader(dhw_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

source_tsne2 = next(iter(source_tsne))
target_tsne2 = next(iter(target_tsne))

source_x_TNSE = source_tsne2[0].to(device)
source_y_TNSE = source_tsne2[1].to(device)

target_x_TNSE = target_tsne2[0].to(device)
target_y_TNSE = target_tsne2[1].to(device)

# 학습된 모델의 LSTM 부분만 활용 (100차원 임베딩 벡터를 받아오는 과정)
source_vector = model.lstm(source_x_TNSE)
target_vector = model.lstm(target_x_TNSE)

# %%
from sklearn.manifold import TSNE

df = pd.DataFrame(np.concatenate([source_vector.cpu().detach().numpy(), target_vector.cpu().detach().numpy()]))

tsne_np = TSNE(n_components=2).fit_transform(df)
tsne_df = pd.DataFrame(tsne_np, columns=['component 0', 'component 1'])

# %%
tsne_df_0 = tsne_df.loc[:1000]
tsne_df_1 = tsne_df.loc[1000:]

plt.scatter(tsne_df_0['component 0'], tsne_df_0['component 1'], color='green', label='NELEC', alpha=0.5)
plt.scatter(tsne_df_1['component 0'], tsne_df_1['component 1'], color='black', label='DHW', alpha=0.5)

plt.title('alpha = '+ str(alpha))
plt.xlabel('component 0')
plt.ylabel('component 1')
plt.legend()
plt.show()
