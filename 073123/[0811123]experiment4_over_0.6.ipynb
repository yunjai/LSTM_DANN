# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.utils.data as data_util
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import MinMaxScaler
from torchsummary import summary
from sklearn.metrics import r2_score

# %%
CUDA = torch.cuda.is_available()
print(CUDA)

device = torch.device('cuda:0' if CUDA else 'cpu')
# Out:
# True

# %%
elec = pd.read_csv('elec_merge.csv')
nelec = pd.read_csv('n_elec_merge.csv')
dhw = pd.read_csv('dhw_merge.csv')

# %%
elec = elec.drop(['YEAR'], axis=1)
nelec = nelec.drop(['YEAR'], axis=1)
dhw = dhw.drop(['YEAR'], axis=1)

# %%
# input_nelec = nelec.iloc[:-1,].reset_index(drop=True)
# output_nelec = nelec[['n_elec']].iloc[1:].reset_index(drop=True)
# output_nelec.columns = ['nelec']

# input_elec = elec.iloc[:-1,].reset_index(drop=True)
# output_elec = elec[['ELEC']].iloc[1:].reset_index(drop=True)
# output_elec.columns = ['elec']

# input_dhw = dhw.iloc[:-1,].reset_index(drop=True)
# output_dhw = dhw[['DHW']].iloc[1:].reset_index(drop=True)
# output_dhw.columns = ['dhw']

# nelec = pd.concat([input_nelec, output_nelec], axis=1)
# elec = pd.concat([input_elec, output_elec], axis=1)
# dhw = pd.concat([input_dhw, output_dhw], axis=1)

input_nelec = nelec.iloc[:-1,:-1].reset_index(drop=True)
output_nelec = nelec[['n_elec']].iloc[:-1].reset_index(drop=True)
output_nelec2 = nelec['n_elec'][1:].reset_index(drop=True)
output_nelec['nelec'] = output_nelec2

input_elec = elec.iloc[:-1,:-1].reset_index(drop=True)
output_elec = elec[['ELEC']].iloc[:-1].reset_index(drop=True)
output_elec2= elec['ELEC'][1:].reset_index(drop=True)
output_elec['elec'] = output_elec2

input_dhw = dhw.iloc[:-1,:-1].reset_index(drop=True)
output_dhw = dhw[['DHW']].iloc[:-1].reset_index(drop=True)
output_dhw2 = dhw['DHW'][1:].reset_index(drop=True)
output_dhw['dhw'] = output_dhw2

# %%
# scaler_nelec = MinMaxScaler()
# scaler_elec = MinMaxScaler()
# scaler_dhw = MinMaxScaler()

# scaler_nelec.fit(nelec)
# scaler_elec.fit(elec)
# scaler_dhw.fit(dhw)

# scaled_nelec = scaler_nelec.transform(nelec)
# scaled_elec = scaler_elec.transform(elec)
# scaled_dhw = scaler_dhw.transform(dhw)

# nelec = pd.DataFrame(scaled_nelec, index=nelec.index, columns=nelec.columns)
# elec = pd.DataFrame(scaled_elec, index=elec.index, columns=elec.columns)
# dhw = pd.DataFrame(scaled_dhw, index=dhw.index, columns=dhw.columns)

scaler_nelec = MinMaxScaler()
scaler_elec = MinMaxScaler()
scaler_dhw = MinMaxScaler()

scaler_nelec.fit(input_nelec)
scaler_elec.fit(input_elec)
scaler_dhw.fit(input_dhw)

scaled_nelec = scaler_nelec.transform(input_nelec)
scaled_elec = scaler_elec.transform(input_elec)
scaled_dhw = scaler_dhw.transform(input_dhw)

nelec_x = pd.DataFrame(scaled_nelec, index=input_nelec.index, columns=input_nelec.columns)
elec_x = pd.DataFrame(scaled_elec, index=input_elec.index, columns=input_elec.columns)
dhw_x = pd.DataFrame(scaled_dhw, index=input_dhw.index, columns=input_dhw.columns)

nelec = pd.concat([nelec_x, output_nelec], axis=1)
elec = pd.concat([elec_x, output_elec], axis=1)
dhw = pd.concat([dhw_x, output_dhw], axis=1)

# %%
standard_nelec = int(len(nelec) * 0.7)
standard_elec = int(len(elec) * 0.7)
standard_dhw = int(len(dhw) * 0.7)

nelec_train = nelec.iloc[:standard_nelec]
nelec_test = nelec.iloc[standard_nelec:].reset_index(drop=True)

elec_train = elec.iloc[:standard_elec]
elec_test = elec.iloc[standard_elec:].reset_index(drop=True)

dhw_train = dhw.iloc[:standard_dhw]
dhw_test = dhw.iloc[standard_dhw:].reset_index(drop=True)

# %%
nelec_trainx = nelec_train.drop(['nelec'], axis=1)
nelec_trainy = nelec_train[['nelec']]

nelec_testx = nelec_test.drop(['nelec'], axis=1)
nelec_testy = nelec_test[['nelec']]

elec_trainx = elec_train.drop(['elec'], axis=1)
elec_trainy = elec_train[['elec']]

elec_testx = elec_test.drop(['elec'], axis=1)
elec_testy = elec_test[['elec']]

dhw_trainx = dhw_train.drop(['dhw'], axis=1)
dhw_trainy = dhw_train[['dhw']]

dhw_testx = dhw_test.drop(['dhw'], axis=1)
dhw_testy = dhw_test[['dhw']]

# %%
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-1]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

nelec_trainx, nelec_trainy = buildDataSet(nelec_trainx, nelec_trainy, 7)
nelec_testx, nelec_testy = buildDataSet(nelec_testx, nelec_testy, 7)

elec_trainx, elec_trainy = buildDataSet(elec_trainx, elec_trainy, 7)
elec_testx, elec_testy = buildDataSet(elec_testx, elec_testy, 7)

dhw_trainx, dhw_trainy = buildDataSet(dhw_trainx, dhw_trainy, 7)
dhw_testx, dhw_testy = buildDataSet(dhw_testx, dhw_testy, 7)

# %%
print(nelec_trainx.shape)
print(nelec_trainy.shape)
print(nelec_testx.shape)
print(nelec_testy.shape)
print(elec_trainx.shape)
print(elec_trainy.shape)
print(elec_testx.shape)
print(elec_testy.shape)
print(dhw_trainx.shape)
print(dhw_trainy.shape)
print(dhw_testx.shape)
print(dhw_testy.shape)
# Out:
# (20409, 7, 12)
# (20409, 1)
# (8744, 7, 12)
# (8744, 1)
# (2984, 7, 12)
# (2984, 1)
# (1275, 7, 12)
# (1275, 1)
# (20409, 7, 12)
# (20409, 1)
# (8744, 7, 12)
# (8744, 1)

# %%
# 텐서로 변환
nelec_trainx_tensor = torch.FloatTensor(nelec_trainx)
nelec_trainy_tensor = torch.FloatTensor(nelec_trainy)

nelec_testx_tensor = torch.FloatTensor(nelec_testx)
nelec_testy_tensor = torch.FloatTensor(nelec_testy)

elec_trainx_tensor = torch.FloatTensor(elec_trainx)
elec_trainy_tensor = torch.FloatTensor(elec_trainy)

elec_testx_tensor = torch.FloatTensor(elec_testx)
elec_testy_tensor = torch.FloatTensor(elec_testy)

dhw_trainx_tensor = torch.FloatTensor(dhw_trainx)
dhw_trainy_tensor = torch.FloatTensor(dhw_trainy)

dhw_testx_tensor = torch.FloatTensor(dhw_testx)
dhw_testy_tensor = torch.FloatTensor(dhw_testy)

# %%
# 텐서 형태로 데이터 정의
nelec_train = TensorDataset(nelec_trainx_tensor, nelec_trainy_tensor)
nelec_test = TensorDataset(nelec_testx_tensor, nelec_testy_tensor)

elec_train = TensorDataset(elec_trainx_tensor, elec_trainy_tensor)
elec_test = TensorDataset(elec_testx_tensor, elec_testy_tensor)

dhw_train = TensorDataset(dhw_trainx_tensor, dhw_trainy_tensor)
dhw_test = TensorDataset(dhw_testx_tensor, dhw_testy_tensor)

# %%
batch_for_nelec_train = len(nelec_trainx)
batch_for_nelec_test = len(nelec_testx)
batch_for_elec_train = len(elec_trainx)
batch_for_elec_test = len(elec_testx)
batch_for_dhw_train = len(dhw_trainx)
batch_for_dhw_test = len(dhw_testx)

NELEC_train = DataLoader(nelec_train,
                        batch_size=1024,#batch_for_nelec_train,
                        shuffle=False,  
                        drop_last=True)

NELEC_test = DataLoader(nelec_test,
                        batch_size=1024,#batch_for_nelec_test,
                        shuffle=False,  
                        drop_last=True)

ELEC_train = DataLoader(elec_train,
                        batch_size=1024,#batch_for_elec_train,
                        shuffle=False,  
                        drop_last=True)

ELEC_test = DataLoader(elec_test,
                        batch_size=1024,#batch_for_elec_test,
                        shuffle=False,  
                        drop_last=True)

DHW_train = DataLoader(dhw_train,
                        batch_size=1024,#batch_for_dhw_train,
                        shuffle=False,  
                        drop_last=True)

DHW_test = DataLoader(dhw_test,
                        batch_size=1024,#batch_for_dhw_test,
                        shuffle=False,  
                        drop_last=True)

# %%
# # 데이터셋의 개수를 가정하여 변수에 저장
# nelec_train_size = len(nelec_train)
# nelec_test_size = len(nelec_test)
# elec_train_size = len(elec_train)
# elec_test_size = len(elec_test)
# dhw_train_size = len(dhw_train)
# dhw_test_size = len(dhw_test)

# # 각 DataLoader에서 생성되는 배치의 개수 계산
# nelec_train_batches = nelec_train_size // batch_for_nelec_train
# nelec_test_batches = nelec_test_size // batch_for_nelec_test
# elec_train_batches = elec_train_size // batch_for_elec_train
# elec_test_batches = elec_test_size // batch_for_elec_test
# dhw_train_batches = dhw_train_size // batch_for_dhw_train
# dhw_test_batches = dhw_test_size // batch_for_dhw_test

# # 결과 출력
# print("nelec_train batches:", nelec_train_batches)
# print("nelec_test batches:", nelec_test_batches)
# print("elec_train batches:", elec_train_batches)
# print("elec_test batches:", elec_test_batches)
# print("dhw_train batches:", dhw_train_batches)
# print("dhw_test batches:", dhw_test_batches)

# %% [markdown]
# # 모델 구조 선언

# %%
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ### GradientReversalLayer

# %%
class GradientReversalFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, x):
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return (grad_output * -1), None

class GradientReversalLayer(torch.nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x):
        return GradientReversalFunction.apply(x)

# %% [markdown]
# ### LSTM for Feature Extraction

# %%
class Swish(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return x * self.sigmoid(x)

# %%
class lstm(nn.Module):
    def __init__(self):
        super(lstm, self).__init__()
        self.lstm1 = nn.LSTM(12, 64, batch_first=True)
        self.bn1 = nn.BatchNorm1d(7)
        
        self.lstm2 = nn.LSTM(64, 64, batch_first=True)
        self.bn2 = nn.BatchNorm1d(7)
        
        self.lstm3 = nn.LSTM(64,64, batch_first=True)
        
        self.fc = nn.Linear(64, 64, bias=False)
        self.fc2 = nn.Linear(64, 100, bias=False)
        self.bn3 = nn.BatchNorm1d(7)
        
        self.dropout = nn.Dropout(0.5)
        self.swish = Swish()
        self.tanh = nn.Tanh()

        
    def forward(self, x):
        x, (h,c) = self.lstm1(x)
        #x = self.bn1(x)
        x = self.tanh(x)

        x, (h, c) = self.lstm2(x, (h, c))
        #x = self.bn2(x)
        x = self.tanh(x)
        
        x, _ = self.lstm3(x, (h, c))
        #x = self.bn2(x)
        x = self.tanh(x)
        
        x = self.fc(x)
        #x = self.bn3(x)
        x = self.fc2(x[:,-1,:])
        x = self.dropout(x)
        x = self.swish(x)
        return x

# %%
# hoxy = lstm()
# inputx = torch.randn(1024,7,12)
# hoxy2 = hoxy(inputx)
# print(hoxy2.shape)

# %%
class domain_regression(nn.Module):
    def __init__(self):
        super(domain_regression, self).__init__()
        self.regression_layer1 = nn.Linear(100, 100)
        self.regression_layer2 = nn.Linear(100, 100)
        self.regression_layer3 = nn.Linear(100, 100)
        self.regression_layer4 = nn.Linear(100, 1)
        self.swish = Swish()
        
    def forward(self, x):
        x = self.swish(self.regression_layer1(x))
        x = self.swish(self.regression_layer2(x))
        x = self.swish(self.regression_layer3(x))
        x = self.swish(self.regression_layer4(x))
        return x

# %% [markdown]
# ### Domain Classification

# %%
class domain_classfication(nn.Module):
    def __init__(self):
        super(domain_classfication, self).__init__()
        self.classification_layer0 = GradientReversalLayer()
        self.classification_layer1 = nn.Linear(100, 100)
        self.classification_layer2 = nn.Linear(100,100)
        self.classification_layer3 = nn.Linear(100,100)
        self.classification_layer4 = nn.Linear(100, 1)
        self.swish = Swish()
        
    def forward(self, x):
        x = self.classification_layer0(x)
        x = self.swish(self.classification_layer1(x))
        x = self.swish(self.classification_layer2(x))
        x = self.swish(self.classification_layer3(x))
        x = torch.sigmoid(self.classification_layer4(x))
        return x

# %% [markdown]
# ### Set the DANN

# %%
class dann(nn.Module):
    def __init__(self, lstm):
        super(dann, self).__init__()
        self.lstm = lstm
        self.regression = domain_regression()
        self.classification = domain_classfication()
        
    def forward(self, x):
        feature = self.lstm(x)
        reg_output = self.regression(feature)
        cla_output = self.classification(feature)
        
        return reg_output, cla_output

# %% [markdown]
# ### Loss 선언

# %%
class dann_loss(nn.Module):
    def __init__(self):
        super(dann_loss, self).__init__()
        self.reg = nn.L1Loss() # 회귀 L1 손실 == MAE
        self.cla = nn.BCEWithLogitsLoss() # 도메인 분류
        
    def forward(self, result, reg_real, domain_num, alpha=1):
        reg_output, cla_output = result
        batch_size = reg_output.shape[0]
        cla_target = torch.FloatTensor([domain_num] * batch_size).unsqueeze(1).to(device)
        
        reg_loss = self.reg(reg_output, reg_real)
        cla_loss = self.cla(cla_output, cla_target)
        cla_loss2 = cla_loss * alpha
        
        loss = reg_loss + cla_loss2
        
        return loss, reg_loss, cla_loss2

# %%
my_lstm = lstm().to(device)
model = dann(my_lstm).to(device)
loss_fn = dann_loss().to(device)

# %% [markdown]
# # 훈련

# %%
from torch.optim.lr_scheduler import LinearLR

alpha = 1.0
epochs = 200

model.train() # 훈련 모드 설정

optimizer= torch.optim.Adamax(model.parameters(), lr=0.001, weight_decay=0.01)
scheduler = LinearLR(optimizer, start_factor=1.0, end_factor=0.0, total_iters = epochs * len(NELEC_train))

patience = 100  # Early stopping을 위한 기다리는 최대 epoch 수
best_loss = float('inf')
best_source_loss = float('inf')
best_model_state_dict = None
counter = 10  # Early stopping 카운터

for i in range(1, epochs + 1):
    total_loss = 0
    source_total_loss = 0
    target_total_loss = 0
    src_reg_total = 0
    src_cla_total = 0
    tar_reg_total = 0
    tar_cal_total = 0
    reg_loss_total = 0
    cla_loss_total = 0
    for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
        source_x = source_data[0].to(device)
        source_y = source_data[1].to(device)
        target_x = target_data[0].to(device)
        target_y = target_data[1].to(device)
        #print(source_x.shape)
        #print(source_y.shape)
        #print(target_x.shape)
        #print(target_y.shape)
        # 순전파
        source_result = model(source_x)
        target_result = model(target_x)
        #print(source_result[0].shape)
        #print(target_result[0].shape)
        #print(source_result[1].shape)
        #print(target_result[1].shape)
        # 순전파 loss
        source_loss, source_reg_loss, source_cla_loss = loss_fn(source_result, source_y, 1, alpha=alpha) # 소스 도메인 레이블 1
        target_loss, target_reg_loss, target_cla_loss = loss_fn(target_result, target_y, 0, alpha=alpha) # 타겟 도메인 레이블 0
        
        loss = source_loss + target_loss
        reg_loss = source_reg_loss + target_reg_loss
        cla_loss = source_cla_loss + target_cla_loss
        
        #src_reg_total += source_reg_loss.item()
        #src_cla_total += source_cla_loss.item()
        #tar_reg_total += target_reg_loss.item()
        #tar_cal_total += target_cla_loss.item()
        
        #source_total_loss += source_loss.item()
        #target_total_loss += target_loss.item()
        
        reg_loss_total += reg_loss.item()
        cla_loss_total += cla_loss.item()
        
        total_loss += loss.item()
        
        # 그래디언트 계산 및 업데이트
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()
        
        # Early stopping 확인
    if reg_loss_total / len(NELEC_train) < best_loss:
        best_loss = reg_loss_total / len(NELEC_train)
        best_model_state_dict = model.state_dict()
        counter = 0  # Counter 초기화
    else:
        counter += 1
        if counter >= patience:
            print(f'Early stopping at epoch {i}')
            break

    print('Epoch : %d, Total Avg Loss : %.4f' % (i, total_loss / len(NELEC_train)))     
    #print('Source Avg Loss : %.4f' % (source_total_loss / len(NELEC_train)))
    #print('Target Avg Loss : %.4f' % (target_total_loss / len(NELEC_train)))
    #print('Source Avg reg Loss : %.4f' % (src_reg_total / len(NELEC_train)))
    #print('Target Avg reg Loss : %.4f' % (tar_reg_total / len(NELEC_train)))
    #print('Source Avg cla Loss : %.4f' % (src_cla_total / len(NELEC_train)))
    #print('Target Avg cla Loss : %.4f' % (tar_cal_total / len(NELEC_train)))
    print('Avg Regression Loss : %.4f' % (reg_loss_total / len(NELEC_train)))
    print('Avg Classification Loss : %.4f' % (cla_loss_total / len(NELEC_train)))
    print('')
    
    # source_loss가 가장 낮은 경우 모델 가중치 저장
    if reg_loss_total / len(NELEC_train) < best_source_loss:
        best_source_loss = reg_loss_total / len(NELEC_train)
        best_model_state_dict = model.state_dict()

# 최상의 모델을 파일로 저장
if best_model_state_dict is not None:
    torch.save(best_model_state_dict, '0811_experiment_4.pth')
    #torch.save(model, "model.pth")
# Out:
# Epoch : 1, Total Avg Loss : 8.6013
# Avg Regression Loss : 7.1528
# Avg Classification Loss : 1.4485
#
# Epoch : 2, Total Avg Loss : 8.4762
# Avg Regression Loss : 7.0340
# Avg Classification Loss : 1.4422
#
# Epoch : 3, Total Avg Loss : 8.2690
# Avg Regression Loss : 6.8329
# Avg Classification Loss : 1.4362
#
# Epoch : 4, Total Avg Loss : 7.9186
# Avg Regression Loss : 6.4888
# Avg Classification Loss : 1.4299
#
# Epoch : 5, Total Avg Loss : 7.4742
# Avg Regression Loss : 6.0509
# Avg Classification Loss : 1.4233
#
# Epoch : 6, Total Avg Loss : 7.0967
# Avg Regression Loss : 5.6798
# Avg Classification Loss : 1.4169
#
# Epoch : 7, Total Avg Loss : 6.2909
# Avg Regression Loss : 4.8796
# Avg Classification Loss : 1.4113
#
# Epoch : 8, Total Avg Loss : 4.5786
# Avg Regression Loss : 3.1716
# Avg Classification Loss : 1.4070
#
# Epoch : 9, Total Avg Loss : 3.1525
# Avg Regression Loss : 1.7485
# Avg Classification Loss : 1.4039
#
# Epoch : 10, Total Avg Loss : 2.7594
# Avg Regression Loss : 1.3575
# Avg Classification Loss : 1.4019
#
# Epoch : 11, Total Avg Loss : 2.6323
# Avg Regression Loss : 1.2321
# Avg Classification Loss : 1.4002
#
# Epoch : 12, Total Avg Loss : 2.5278
# Avg Regression Loss : 1.1295
# Avg Classification Loss : 1.3982
#
# Epoch : 13, Total Avg Loss : 2.4337
# Avg Regression Loss : 1.0415
# Avg Classification Loss : 1.3922
#
# Epoch : 14, Total Avg Loss : 2.3254
# Avg Regression Loss : 0.9702
# Avg Classification Loss : 1.3552
#
# Epoch : 15, Total Avg Loss : 2.1049
# Avg Regression Loss : 0.9142
# Avg Classification Loss : 1.1906
#
# Epoch : 16, Total Avg Loss : 1.9721
# Avg Regression Loss : 0.8853
# Avg Classification Loss : 1.0868
#
# Epoch : 17, Total Avg Loss : 1.9314
# Avg Regression Loss : 0.8536
# Avg Classification Loss : 1.0778
#
# Epoch : 18, Total Avg Loss : 1.9072
# Avg Regression Loss : 0.8373
# Avg Classification Loss : 1.0700
#
# Epoch : 19, Total Avg Loss : 1.8875
# Avg Regression Loss : 0.8276
# Avg Classification Loss : 1.0598
#
# Epoch : 20, Total Avg Loss : 1.8591
# Avg Regression Loss : 0.8062
# Avg Classification Loss : 1.0529
#
# Epoch : 21, Total Avg Loss : 1.8444
# Avg Regression Loss : 0.7961
# Avg Classification Loss : 1.0484
#
# Epoch : 22, Total Avg Loss : 1.8296
# Avg Regression Loss : 0.7847
# Avg Classification Loss : 1.0449
#
# Epoch : 23, Total Avg Loss : 1.8147
# Avg Regression Loss : 0.7728
# Avg Classification Loss : 1.0419
#
# Epoch : 24, Total Avg Loss : 1.8075
# Avg Regression Loss : 0.7676
# Avg Classification Loss : 1.0399
#
# Epoch : 25, Total Avg Loss : 1.7952
# Avg Regression Loss : 0.7570
# Avg Classification Loss : 1.0383
#
# Epoch : 26, Total Avg Loss : 1.7773
# Avg Regression Loss : 0.7404
# Avg Classification Loss : 1.0369
#
# Epoch : 27, Total Avg Loss : 1.7744
# Avg Regression Loss : 0.7381
# Avg Classification Loss : 1.0363
#
# Epoch : 28, Total Avg Loss : 1.7702
# Avg Regression Loss : 0.7348
# Avg Classification Loss : 1.0355
#
# Epoch : 29, Total Avg Loss : 1.7709
# Avg Regression Loss : 0.7360
# Avg Classification Loss : 1.0349
#
# Epoch : 30, Total Avg Loss : 1.7618
# Avg Regression Loss : 0.7273
# Avg Classification Loss : 1.0345
#
# Epoch : 31, Total Avg Loss : 1.7532
# Avg Regression Loss : 0.7193
# Avg Classification Loss : 1.0339
#
# Epoch : 32, Total Avg Loss : 1.7466
# Avg Regression Loss : 0.7129
# Avg Classification Loss : 1.0338
#
# Epoch : 33, Total Avg Loss : 1.7424
# Avg Regression Loss : 0.7089
# Avg Classification Loss : 1.0336
#
# Epoch : 34, Total Avg Loss : 1.7395
# Avg Regression Loss : 0.7061
# Avg Classification Loss : 1.0334
#
# Epoch : 35, Total Avg Loss : 1.7294
# Avg Regression Loss : 0.6966
# Avg Classification Loss : 1.0327
#
# Epoch : 36, Total Avg Loss : 1.7146
# Avg Regression Loss : 0.6818
# Avg Classification Loss : 1.0328
#
# Epoch : 37, Total Avg Loss : 1.7097
# Avg Regression Loss : 0.6769
# Avg Classification Loss : 1.0328
#
# Epoch : 38, Total Avg Loss : 1.7078
# Avg Regression Loss : 0.6752
# Avg Classification Loss : 1.0326
#
# Epoch : 39, Total Avg Loss : 1.6943
# Avg Regression Loss : 0.6617
# Avg Classification Loss : 1.0326
#
# Epoch : 40, Total Avg Loss : 1.6884
# Avg Regression Loss : 0.6558
# Avg Classification Loss : 1.0327
#
# Epoch : 41, Total Avg Loss : 1.6925
# Avg Regression Loss : 0.6597
# Avg Classification Loss : 1.0328
#
# Epoch : 42, Total Avg Loss : 1.6745
# Avg Regression Loss : 0.6419
# Avg Classification Loss : 1.0326
#
# Epoch : 43, Total Avg Loss : 1.6628
# Avg Regression Loss : 0.6303
# Avg Classification Loss : 1.0325
#
# Epoch : 44, Total Avg Loss : 1.6622
# Avg Regression Loss : 0.6295
# Avg Classification Loss : 1.0327
#
# Epoch : 45, Total Avg Loss : 1.6531
# Avg Regression Loss : 0.6205
# Avg Classification Loss : 1.0326
#
# Epoch : 46, Total Avg Loss : 1.6374
# Avg Regression Loss : 0.6048
# Avg Classification Loss : 1.0326
#
# Epoch : 47, Total Avg Loss : 1.6417
# Avg Regression Loss : 0.6089
# Avg Classification Loss : 1.0328
#
# Epoch : 48, Total Avg Loss : 1.6336
# Avg Regression Loss : 0.6007
# Avg Classification Loss : 1.0329
#
# Epoch : 49, Total Avg Loss : 1.6195
# Avg Regression Loss : 0.5867
# Avg Classification Loss : 1.0327
#
# Epoch : 50, Total Avg Loss : 1.6177
# Avg Regression Loss : 0.5848
# Avg Classification Loss : 1.0329
#
# Epoch : 51, Total Avg Loss : 1.6061
# Avg Regression Loss : 0.5731
# Avg Classification Loss : 1.0330
#
# Epoch : 52, Total Avg Loss : 1.6054
# Avg Regression Loss : 0.5723
# Avg Classification Loss : 1.0331
#
# Epoch : 53, Total Avg Loss : 1.5901
# Avg Regression Loss : 0.5575
# Avg Classification Loss : 1.0327
#
# Epoch : 54, Total Avg Loss : 1.5730
# Avg Regression Loss : 0.5400
# Avg Classification Loss : 1.0330
#
# Epoch : 55, Total Avg Loss : 1.5663
# Avg Regression Loss : 0.5333
# Avg Classification Loss : 1.0329
#
# Epoch : 56, Total Avg Loss : 1.5503
# Avg Regression Loss : 0.5173
# Avg Classification Loss : 1.0330
#
# Epoch : 57, Total Avg Loss : 1.5452
# Avg Regression Loss : 0.5121
# Avg Classification Loss : 1.0331
#
# Epoch : 58, Total Avg Loss : 1.5371
# Avg Regression Loss : 0.5041
# Avg Classification Loss : 1.0330
#
# Epoch : 59, Total Avg Loss : 1.5345
# Avg Regression Loss : 0.5014
# Avg Classification Loss : 1.0331
#
# Epoch : 60, Total Avg Loss : 1.5224
# Avg Regression Loss : 0.4894
# Avg Classification Loss : 1.0330
#
# Epoch : 61, Total Avg Loss : 1.5197
# Avg Regression Loss : 0.4866
# Avg Classification Loss : 1.0331
#
# Epoch : 62, Total Avg Loss : 1.5076
# Avg Regression Loss : 0.4749
# Avg Classification Loss : 1.0327
#
# Epoch : 63, Total Avg Loss : 1.5055
# Avg Regression Loss : 0.4723
# Avg Classification Loss : 1.0332
#
# Epoch : 64, Total Avg Loss : 1.5046
# Avg Regression Loss : 0.4716
# Avg Classification Loss : 1.0330
#
# Epoch : 65, Total Avg Loss : 1.4999
# Avg Regression Loss : 0.4669
# Avg Classification Loss : 1.0329
#
# Epoch : 66, Total Avg Loss : 1.4983
# Avg Regression Loss : 0.4654
# Avg Classification Loss : 1.0329
#
# Epoch : 67, Total Avg Loss : 1.4961
# Avg Regression Loss : 0.4633
# Avg Classification Loss : 1.0328
#
# Epoch : 68, Total Avg Loss : 1.4928
# Avg Regression Loss : 0.4598
# Avg Classification Loss : 1.0329
#
# Epoch : 69, Total Avg Loss : 1.4894
# Avg Regression Loss : 0.4566
# Avg Classification Loss : 1.0328
#
# Epoch : 70, Total Avg Loss : 1.4851
# Avg Regression Loss : 0.4524
# Avg Classification Loss : 1.0326
#
# Epoch : 71, Total Avg Loss : 1.4869
# Avg Regression Loss : 0.4542
# Avg Classification Loss : 1.0327
#
# Epoch : 72, Total Avg Loss : 1.4867
# Avg Regression Loss : 0.4539
# Avg Classification Loss : 1.0328
#
# Epoch : 73, Total Avg Loss : 1.4845
# Avg Regression Loss : 0.4522
# Avg Classification Loss : 1.0323
#
# Epoch : 74, Total Avg Loss : 1.4762
# Avg Regression Loss : 0.4435
# Avg Classification Loss : 1.0327
#
# Epoch : 75, Total Avg Loss : 1.4872
# Avg Regression Loss : 0.4545
# Avg Classification Loss : 1.0326
#
# Epoch : 76, Total Avg Loss : 1.4765
# Avg Regression Loss : 0.4446
# Avg Classification Loss : 1.0319
#
# Epoch : 77, Total Avg Loss : 1.4711
# Avg Regression Loss : 0.4385
# Avg Classification Loss : 1.0326
#
# Epoch : 78, Total Avg Loss : 1.4713
# Avg Regression Loss : 0.4385
# Avg Classification Loss : 1.0328
#
# Epoch : 79, Total Avg Loss : 1.4738
# Avg Regression Loss : 0.4417
# Avg Classification Loss : 1.0321
#
# Epoch : 80, Total Avg Loss : 1.4675
# Avg Regression Loss : 0.4354
# Avg Classification Loss : 1.0321
#
# Epoch : 81, Total Avg Loss : 1.4671
# Avg Regression Loss : 0.4347
# Avg Classification Loss : 1.0324
#
# Epoch : 82, Total Avg Loss : 1.4724
# Avg Regression Loss : 0.4403
# Avg Classification Loss : 1.0321
#
# Epoch : 83, Total Avg Loss : 1.4607
# Avg Regression Loss : 0.4286
# Avg Classification Loss : 1.0321
#
# Epoch : 84, Total Avg Loss : 1.4699
# Avg Regression Loss : 0.4376
# Avg Classification Loss : 1.0324
#
# Epoch : 85, Total Avg Loss : 1.4562
# Avg Regression Loss : 0.4244
# Avg Classification Loss : 1.0318
#
# Epoch : 86, Total Avg Loss : 1.4588
# Avg Regression Loss : 0.4266
# Avg Classification Loss : 1.0322
#
# Epoch : 87, Total Avg Loss : 1.4541
# Avg Regression Loss : 0.4221
# Avg Classification Loss : 1.0319
#
# Epoch : 88, Total Avg Loss : 1.4566
# Avg Regression Loss : 0.4249
# Avg Classification Loss : 1.0318
#
# Epoch : 89, Total Avg Loss : 1.4580
# Avg Regression Loss : 0.4261
# Avg Classification Loss : 1.0320
#
# Epoch : 90, Total Avg Loss : 1.4508
# Avg Regression Loss : 0.4189
# Avg Classification Loss : 1.0319
#
# Epoch : 91, Total Avg Loss : 1.4503
# Avg Regression Loss : 0.4182
# Avg Classification Loss : 1.0321
#
# Epoch : 92, Total Avg Loss : 1.4500
# Avg Regression Loss : 0.4181
# Avg Classification Loss : 1.0319
#
# Epoch : 93, Total Avg Loss : 1.4524
# Avg Regression Loss : 0.4207
# Avg Classification Loss : 1.0318
#
# Epoch : 94, Total Avg Loss : 1.4484
# Avg Regression Loss : 0.4164
# Avg Classification Loss : 1.0320
#
# Epoch : 95, Total Avg Loss : 1.4469
# Avg Regression Loss : 0.4153
# Avg Classification Loss : 1.0316
#
# Epoch : 96, Total Avg Loss : 1.4431
# Avg Regression Loss : 0.4111
# Avg Classification Loss : 1.0319
#
# Epoch : 97, Total Avg Loss : 1.4524
# Avg Regression Loss : 0.4208
# Avg Classification Loss : 1.0316
#
# Epoch : 98, Total Avg Loss : 1.4409
# Avg Regression Loss : 0.4093
# Avg Classification Loss : 1.0315
#
# Epoch : 99, Total Avg Loss : 1.4490
# Avg Regression Loss : 0.4170
# Avg Classification Loss : 1.0321
#
# Epoch : 100, Total Avg Loss : 1.4415
# Avg Regression Loss : 0.4098
# Avg Classification Loss : 1.0318
#
# Epoch : 101, Total Avg Loss : 1.4502
# Avg Regression Loss : 0.4186
# Avg Classification Loss : 1.0316
#
# Epoch : 102, Total Avg Loss : 1.4402
# Avg Regression Loss : 0.4086
# Avg Classification Loss : 1.0316
#
# Epoch : 103, Total Avg Loss : 1.4436
# Avg Regression Loss : 0.4119
# Avg Classification Loss : 1.0317
#
# Epoch : 104, Total Avg Loss : 1.4392
# Avg Regression Loss : 0.4077
# Avg Classification Loss : 1.0316
#
# Epoch : 105, Total Avg Loss : 1.4389
# Avg Regression Loss : 0.4072
# Avg Classification Loss : 1.0317
#
# Epoch : 106, Total Avg Loss : 1.4402
# Avg Regression Loss : 0.4089
# Avg Classification Loss : 1.0313
#
# Epoch : 107, Total Avg Loss : 1.4387
# Avg Regression Loss : 0.4071
# Avg Classification Loss : 1.0316
#
# Epoch : 108, Total Avg Loss : 1.4383
# Avg Regression Loss : 0.4068
# Avg Classification Loss : 1.0315
#
# Epoch : 109, Total Avg Loss : 1.4390
# Avg Regression Loss : 0.4074
# Avg Classification Loss : 1.0316
#
# Epoch : 110, Total Avg Loss : 1.4380
# Avg Regression Loss : 0.4066
# Avg Classification Loss : 1.0314
#
# Epoch : 111, Total Avg Loss : 1.4388
# Avg Regression Loss : 0.4077
# Avg Classification Loss : 1.0311
#
# Epoch : 112, Total Avg Loss : 1.4347
# Avg Regression Loss : 0.4034
# Avg Classification Loss : 1.0313
#
# Epoch : 113, Total Avg Loss : 1.4347
# Avg Regression Loss : 0.4033
# Avg Classification Loss : 1.0315
#
# Epoch : 114, Total Avg Loss : 1.4346
# Avg Regression Loss : 0.4031
# Avg Classification Loss : 1.0315
#
# Epoch : 115, Total Avg Loss : 1.4313
# Avg Regression Loss : 0.4001
# Avg Classification Loss : 1.0311
#
# Epoch : 116, Total Avg Loss : 1.4373
# Avg Regression Loss : 0.4061
# Avg Classification Loss : 1.0312
#
# Epoch : 117, Total Avg Loss : 1.4349
# Avg Regression Loss : 0.4035
# Avg Classification Loss : 1.0313
#
# Epoch : 118, Total Avg Loss : 1.4288
# Avg Regression Loss : 0.3978
# Avg Classification Loss : 1.0310
#
# Epoch : 119, Total Avg Loss : 1.4317
# Avg Regression Loss : 0.4001
# Avg Classification Loss : 1.0315
#
# Epoch : 120, Total Avg Loss : 1.4257
# Avg Regression Loss : 0.3948
# Avg Classification Loss : 1.0309
#
# Epoch : 121, Total Avg Loss : 1.4314
# Avg Regression Loss : 0.4001
# Avg Classification Loss : 1.0312
#
# Epoch : 122, Total Avg Loss : 1.4281
# Avg Regression Loss : 0.3973
# Avg Classification Loss : 1.0308
#
# Epoch : 123, Total Avg Loss : 1.4349
# Avg Regression Loss : 0.4037
# Avg Classification Loss : 1.0311
#
# Epoch : 124, Total Avg Loss : 1.4281
# Avg Regression Loss : 0.3968
# Avg Classification Loss : 1.0312
#
# Epoch : 125, Total Avg Loss : 1.4283
# Avg Regression Loss : 0.3974
# Avg Classification Loss : 1.0309
#
# Epoch : 126, Total Avg Loss : 1.4299
# Avg Regression Loss : 0.3991
# Avg Classification Loss : 1.0309
#
# Epoch : 127, Total Avg Loss : 1.4268
# Avg Regression Loss : 0.3958
# Avg Classification Loss : 1.0310
#
# Epoch : 128, Total Avg Loss : 1.4267
# Avg Regression Loss : 0.3956
# Avg Classification Loss : 1.0311
#
# Epoch : 129, Total Avg Loss : 1.4295
# Avg Regression Loss : 0.3984
# Avg Classification Loss : 1.0310
#
# Epoch : 130, Total Avg Loss : 1.4251
# Avg Regression Loss : 0.3942
# Avg Classification Loss : 1.0309
#
# Epoch : 131, Total Avg Loss : 1.4298
# Avg Regression Loss : 0.3986
# Avg Classification Loss : 1.0311
#
# Epoch : 132, Total Avg Loss : 1.4250
# Avg Regression Loss : 0.3943
# Avg Classification Loss : 1.0307
#
# Epoch : 133, Total Avg Loss : 1.4259
# Avg Regression Loss : 0.3949
# Avg Classification Loss : 1.0310
#
# Epoch : 134, Total Avg Loss : 1.4286
# Avg Regression Loss : 0.3979
# Avg Classification Loss : 1.0307
#
# Epoch : 135, Total Avg Loss : 1.4268
# Avg Regression Loss : 0.3961
# Avg Classification Loss : 1.0307
#
# Epoch : 136, Total Avg Loss : 1.4249
# Avg Regression Loss : 0.3941
# Avg Classification Loss : 1.0308
#
# Epoch : 137, Total Avg Loss : 1.4269
# Avg Regression Loss : 0.3961
# Avg Classification Loss : 1.0309
#
# Epoch : 138, Total Avg Loss : 1.4233
# Avg Regression Loss : 0.3925
# Avg Classification Loss : 1.0308
#
# Epoch : 139, Total Avg Loss : 1.4271
# Avg Regression Loss : 0.3962
# Avg Classification Loss : 1.0308
#
# Epoch : 140, Total Avg Loss : 1.4398
# Avg Regression Loss : 0.4087
# Avg Classification Loss : 1.0311
#
# Epoch : 141, Total Avg Loss : 1.4499
# Avg Regression Loss : 0.4195
# Avg Classification Loss : 1.0304
#
# Epoch : 142, Total Avg Loss : 1.4436
# Avg Regression Loss : 0.4137
# Avg Classification Loss : 1.0299
#
# Epoch : 143, Total Avg Loss : 1.4276
# Avg Regression Loss : 0.3972
# Avg Classification Loss : 1.0303
#
# Epoch : 144, Total Avg Loss : 1.4295
# Avg Regression Loss : 0.3985
# Avg Classification Loss : 1.0311
#
# Epoch : 145, Total Avg Loss : 1.4261
# Avg Regression Loss : 0.3954
# Avg Classification Loss : 1.0308
#
# Epoch : 146, Total Avg Loss : 1.4245
# Avg Regression Loss : 0.3938
# Avg Classification Loss : 1.0307
#
# Epoch : 147, Total Avg Loss : 1.4258
# Avg Regression Loss : 0.3953
# Avg Classification Loss : 1.0304
#
# Epoch : 148, Total Avg Loss : 1.4278
# Avg Regression Loss : 0.3971
# Avg Classification Loss : 1.0306
#
# Epoch : 149, Total Avg Loss : 1.4293
# Avg Regression Loss : 0.3986
# Avg Classification Loss : 1.0306
#
# Epoch : 150, Total Avg Loss : 1.4273
# Avg Regression Loss : 0.3967
# Avg Classification Loss : 1.0306
#
# Epoch : 151, Total Avg Loss : 1.4264
# Avg Regression Loss : 0.3960
# Avg Classification Loss : 1.0304
#
# Epoch : 152, Total Avg Loss : 1.4246
# Avg Regression Loss : 0.3942
# Avg Classification Loss : 1.0304
#
# Epoch : 153, Total Avg Loss : 1.4266
# Avg Regression Loss : 0.3960
# Avg Classification Loss : 1.0306
#
# Epoch : 154, Total Avg Loss : 1.4225
# Avg Regression Loss : 0.3920
# Avg Classification Loss : 1.0306
#
# Epoch : 155, Total Avg Loss : 1.4277
# Avg Regression Loss : 0.3972
# Avg Classification Loss : 1.0305
#
# Epoch : 156, Total Avg Loss : 1.4245
# Avg Regression Loss : 0.3941
# Avg Classification Loss : 1.0304
#
# Epoch : 157, Total Avg Loss : 1.4203
# Avg Regression Loss : 0.3901
# Avg Classification Loss : 1.0302
#
# Epoch : 158, Total Avg Loss : 1.4200
# Avg Regression Loss : 0.3893
# Avg Classification Loss : 1.0307
#
# Epoch : 159, Total Avg Loss : 1.4215
# Avg Regression Loss : 0.3911
# Avg Classification Loss : 1.0304
#
# Epoch : 160, Total Avg Loss : 1.4238
# Avg Regression Loss : 0.3932
# Avg Classification Loss : 1.0306
#
# Epoch : 161, Total Avg Loss : 1.4226
# Avg Regression Loss : 0.3924
# Avg Classification Loss : 1.0302
#
# Epoch : 162, Total Avg Loss : 1.4184
# Avg Regression Loss : 0.3882
# Avg Classification Loss : 1.0303
#
# Epoch : 163, Total Avg Loss : 1.4237
# Avg Regression Loss : 0.3930
# Avg Classification Loss : 1.0307
#
# Epoch : 164, Total Avg Loss : 1.4215
# Avg Regression Loss : 0.3912
# Avg Classification Loss : 1.0303
#
# Epoch : 165, Total Avg Loss : 1.4212
# Avg Regression Loss : 0.3910
# Avg Classification Loss : 1.0303
#
# Epoch : 166, Total Avg Loss : 1.4198
# Avg Regression Loss : 0.3896
# Avg Classification Loss : 1.0302
#
# Epoch : 167, Total Avg Loss : 1.4208
# Avg Regression Loss : 0.3904
# Avg Classification Loss : 1.0304
#
# Epoch : 168, Total Avg Loss : 1.4206
# Avg Regression Loss : 0.3902
# Avg Classification Loss : 1.0304
#
# Epoch : 169, Total Avg Loss : 1.4176
# Avg Regression Loss : 0.3872
# Avg Classification Loss : 1.0304
#
# Epoch : 170, Total Avg Loss : 1.4194
# Avg Regression Loss : 0.3892
# Avg Classification Loss : 1.0301
#
# Epoch : 171, Total Avg Loss : 1.4186
# Avg Regression Loss : 0.3882
# Avg Classification Loss : 1.0303
#
# Epoch : 172, Total Avg Loss : 1.4178
# Avg Regression Loss : 0.3875
# Avg Classification Loss : 1.0302
#
# Epoch : 173, Total Avg Loss : 1.4212
# Avg Regression Loss : 0.3909
# Avg Classification Loss : 1.0303
#
# Epoch : 174, Total Avg Loss : 1.4179
# Avg Regression Loss : 0.3877
# Avg Classification Loss : 1.0302
#
# Epoch : 175, Total Avg Loss : 1.4199
# Avg Regression Loss : 0.3897
# Avg Classification Loss : 1.0303
#
# Epoch : 176, Total Avg Loss : 1.4167
# Avg Regression Loss : 0.3864
# Avg Classification Loss : 1.0303
#
# Epoch : 177, Total Avg Loss : 1.4183
# Avg Regression Loss : 0.3881
# Avg Classification Loss : 1.0301
#
# Epoch : 178, Total Avg Loss : 1.4178
# Avg Regression Loss : 0.3875
# Avg Classification Loss : 1.0303
#
# Epoch : 179, Total Avg Loss : 1.4176
# Avg Regression Loss : 0.3875
# Avg Classification Loss : 1.0301
#
# Epoch : 180, Total Avg Loss : 1.4163
# Avg Regression Loss : 0.3862
# Avg Classification Loss : 1.0301
#
# Epoch : 181, Total Avg Loss : 1.4169
# Avg Regression Loss : 0.3869
# Avg Classification Loss : 1.0300
#
# Epoch : 182, Total Avg Loss : 1.4150
# Avg Regression Loss : 0.3849
# Avg Classification Loss : 1.0302
#
# Epoch : 183, Total Avg Loss : 1.4166
# Avg Regression Loss : 0.3865
# Avg Classification Loss : 1.0301
#
# Epoch : 184, Total Avg Loss : 1.4141
# Avg Regression Loss : 0.3838
# Avg Classification Loss : 1.0303
#
# Epoch : 185, Total Avg Loss : 1.4177
# Avg Regression Loss : 0.3875
# Avg Classification Loss : 1.0302
#
# Epoch : 186, Total Avg Loss : 1.4175
# Avg Regression Loss : 0.3874
# Avg Classification Loss : 1.0302
#
# Epoch : 187, Total Avg Loss : 1.4156
# Avg Regression Loss : 0.3854
# Avg Classification Loss : 1.0302
#
# Epoch : 188, Total Avg Loss : 1.4140
# Avg Regression Loss : 0.3839
# Avg Classification Loss : 1.0300
#
# Epoch : 189, Total Avg Loss : 1.4150
# Avg Regression Loss : 0.3848
# Avg Classification Loss : 1.0302
#
# Epoch : 190, Total Avg Loss : 1.4139
# Avg Regression Loss : 0.3838
# Avg Classification Loss : 1.0301
#
# Epoch : 191, Total Avg Loss : 1.4150
# Avg Regression Loss : 0.3850
# Avg Classification Loss : 1.0300
#
# Epoch : 192, Total Avg Loss : 1.4161
# Avg Regression Loss : 0.3860
# Avg Classification Loss : 1.0301
#
# Epoch : 193, Total Avg Loss : 1.4149
# Avg Regression Loss : 0.3848
# Avg Classification Loss : 1.0301
#
# Epoch : 194, Total Avg Loss : 1.4152
# Avg Regression Loss : 0.3851
# Avg Classification Loss : 1.0300
#
# Epoch : 195, Total Avg Loss : 1.4163
# Avg Regression Loss : 0.3861
# Avg Classification Loss : 1.0302
#
# Epoch : 196, Total Avg Loss : 1.4145
# Avg Regression Loss : 0.3845
# Avg Classification Loss : 1.0301
#
# Epoch : 197, Total Avg Loss : 1.4175
# Avg Regression Loss : 0.3874
# Avg Classification Loss : 1.0302
#
# Epoch : 198, Total Avg Loss : 1.4116
# Avg Regression Loss : 0.3815
# Avg Classification Loss : 1.0301
#
# Epoch : 199, Total Avg Loss : 1.4143
# Avg Regression Loss : 0.3840
# Avg Classification Loss : 1.0303
#
# Epoch : 200, Total Avg Loss : 1.4143
# Avg Regression Loss : 0.3841
# Avg Classification Loss : 1.0302

# %%
# from torchinfo import summary

# summary(model, (512,3,12))

# %% [markdown]
# # train 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('0811_experiment_4.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []
s_d_pred = []
t_d_pred = []

for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    source_domain_label_pred, source_pred = best_source_model2(sourcex)
    target_domain_label_pred, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())
    s_d_pred.extend(source_domain_label_pred.detach().cpu().numpy())
    t_d_pred.extend(target_domain_label_pred.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: -38.89781096362424
# TARGET R2 Score: -0.8687347938472354

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# # test 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('0811_experiment_4.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []


for step, (source_data, target_data) in enumerate(zip(NELEC_test, DHW_test)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    _, source_pred = best_source_model2(sourcex)
    _, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: -36.53490823740001
# TARGET R2 Score: -0.5085321575907822

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# ### Domain Embedding Space 시각화

# %%
# 가장 앞 batch의 250개씩의 데이터만 샘플링
source_tsne = DataLoader(nelec_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

target_tsne = DataLoader(dhw_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

source_tsne2 = next(iter(source_tsne))
target_tsne2 = next(iter(target_tsne))

source_x_TNSE = source_tsne2[0].to(device)
source_y_TNSE = source_tsne2[1].to(device)

target_x_TNSE = target_tsne2[0].to(device)
target_y_TNSE = target_tsne2[1].to(device)

# 학습된 모델의 LSTM 부분만 활용 (100차원 임베딩 벡터를 받아오는 과정)
source_vector = model.lstm(source_x_TNSE)
target_vector = model.lstm(target_x_TNSE)

# %%
from sklearn.manifold import TSNE

df = pd.DataFrame(np.concatenate([source_vector.cpu().detach().numpy(), target_vector.cpu().detach().numpy()]))

tsne_np = TSNE(n_components=2).fit_transform(df)
tsne_df = pd.DataFrame(tsne_np, columns=['component 0', 'component 1'])

# %%
tsne_df_0 = tsne_df.loc[:1000]
tsne_df_1 = tsne_df.loc[1000:]

plt.scatter(tsne_df_0['component 0'], tsne_df_0['component 1'], color='green', label='NELEC', alpha=0.5)
plt.scatter(tsne_df_1['component 0'], tsne_df_1['component 1'], color='black', label='DHW', alpha=0.5)

plt.title('alpha = '+ str(alpha))
plt.xlabel('component 0')
plt.ylabel('component 1')
plt.legend()
plt.show()
