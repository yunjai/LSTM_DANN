# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.utils.data as data_util
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from torchsummary import summary
from sklearn.metrics import r2_score

# %%
CUDA = torch.cuda.is_available()
print(CUDA)

device = torch.device('cuda:0' if CUDA else 'cpu')
# Out:
# True

# %%
nelec = pd.read_csv('nelec_082323.csv')
dhw = pd.read_csv('dhw_merge.csv')

# %%
nelec = nelec.drop(['YEAR'], axis=1)
dhw = dhw.drop(['YEAR'], axis=1)

# %%
input_nelec = nelec.iloc[:-1,].reset_index(drop=True)
output_nelec = nelec[['n_elec']].iloc[1:].reset_index(drop=True)
output_nelec.columns = ['nelec']

input_dhw = dhw.iloc[:-1,].reset_index(drop=True)
output_dhw = dhw[['DHW']].iloc[1:].reset_index(drop=True)
output_dhw.columns = ['dhw']

nelec = pd.concat([input_nelec, output_nelec], axis=1)
dhw = pd.concat([input_dhw, output_dhw], axis=1)

# %%
scaler_nelec = MinMaxScaler()
scaler_dhw = MinMaxScaler()

# scaler_nelec = StandardScaler()
# scaler_dhw = StandardScaler()


scaler_nelec.fit(nelec)
scaler_dhw.fit(dhw)

scaled_nelec = scaler_nelec.transform(nelec)
scaled_dhw = scaler_dhw.transform(dhw)

nelec = pd.DataFrame(scaled_nelec, index=nelec.index, columns=nelec.columns)
dhw = pd.DataFrame(scaled_dhw, index=dhw.index, columns=dhw.columns)

# %%
standard_nelec = int(len(nelec) * 0.7)
standard_dhw = int(len(dhw) * 0.7)

nelec_train = nelec.iloc[:standard_nelec]
nelec_test = nelec.iloc[standard_nelec:].reset_index(drop=True)

dhw_train = dhw.iloc[:standard_dhw]
dhw_test = dhw.iloc[standard_dhw:].reset_index(drop=True)

# %%
nelec_trainx = nelec_train.drop(['nelec'], axis=1)
nelec_trainy = nelec_train[['nelec']]

nelec_testx = nelec_test.drop(['nelec'], axis=1)
nelec_testy = nelec_test[['nelec']]

dhw_trainx = dhw_train.drop(['dhw'], axis=1)
dhw_trainy = dhw_train[['dhw']]

dhw_testx = dhw_test.drop(['dhw'], axis=1)
dhw_testy = dhw_test[['dhw']]

# %%
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-1]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

nelec_trainx, nelec_trainy = buildDataSet(nelec_trainx, nelec_trainy, 7)
nelec_testx, nelec_testy = buildDataSet(nelec_testx, nelec_testy, 7)

dhw_trainx, dhw_trainy = buildDataSet(dhw_trainx, dhw_trainy, 7)
dhw_testx, dhw_testy = buildDataSet(dhw_testx, dhw_testy, 7)

# %%
print(nelec_trainx.shape)
print(nelec_trainy.shape)
print(nelec_testx.shape)
print(nelec_testy.shape)
print(dhw_trainx.shape)
print(dhw_trainy.shape)
print(dhw_testx.shape)
print(dhw_testy.shape)
# Out:
# (20409, 7, 12)
# (20409, 1)
# (8744, 7, 12)
# (8744, 1)
# (20409, 7, 12)
# (20409, 1)
# (8744, 7, 12)
# (8744, 1)

# %%
# 텐서로 변환
nelec_trainx_tensor = torch.FloatTensor(nelec_trainx)
nelec_trainy_tensor = torch.FloatTensor(nelec_trainy)

nelec_testx_tensor = torch.FloatTensor(nelec_testx)
nelec_testy_tensor = torch.FloatTensor(nelec_testy)

dhw_trainx_tensor = torch.FloatTensor(dhw_trainx)
dhw_trainy_tensor = torch.FloatTensor(dhw_trainy)

dhw_testx_tensor = torch.FloatTensor(dhw_testx)
dhw_testy_tensor = torch.FloatTensor(dhw_testy)

# %%
# 텐서 형태로 데이터 정의
nelec_train = TensorDataset(nelec_trainx_tensor, nelec_trainy_tensor)
nelec_test = TensorDataset(nelec_testx_tensor, nelec_testy_tensor)

dhw_train = TensorDataset(dhw_trainx_tensor, dhw_trainy_tensor)
dhw_test = TensorDataset(dhw_testx_tensor, dhw_testy_tensor)

# %%
batch_for_nelec_train = 512
batch_for_nelec_test = 512
batch_for_dhw_train = 512
batch_for_dhw_test = 512

NELEC_train = DataLoader(nelec_train,
                        batch_size=batch_for_nelec_train,
                        shuffle=False,  
                        drop_last=True)

NELEC_test = DataLoader(nelec_test,
                        batch_size=batch_for_nelec_test,
                        shuffle=False,  
                        drop_last=True)

DHW_train = DataLoader(dhw_train,
                        batch_size=batch_for_dhw_train,
                        shuffle=False,  
                        drop_last=True)

DHW_test = DataLoader(dhw_test,
                        batch_size=batch_for_dhw_test,
                        shuffle=False,  
                        drop_last=True)

# %%
# 데이터셋의 개수를 가정하여 변수에 저장
nelec_train_size = len(nelec_train)
nelec_test_size = len(nelec_test)
dhw_train_size = len(dhw_train)
dhw_test_size = len(dhw_test)

# 각 DataLoader에서 생성되는 배치의 개수 계산
nelec_train_batches = nelec_train_size // batch_for_nelec_train
nelec_test_batches = nelec_test_size // batch_for_nelec_test
dhw_train_batches = dhw_train_size // batch_for_dhw_train
dhw_test_batches = dhw_test_size // batch_for_dhw_test

# 결과 출력
print("nelec_train batches:", nelec_train_batches)
print("nelec_test batches:", nelec_test_batches)
print("dhw_train batches:", dhw_train_batches)
print("dhw_test batches:", dhw_test_batches)
# Out:
# nelec_train batches: 39
# nelec_test batches: 17
# dhw_train batches: 39
# dhw_test batches: 17

# %% [markdown]
# # 모델 구조 선언

# %%
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ### GradientReversalLayer

# %%
class GradientReversalFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, x):
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return (grad_output * -1), None

class GradientReversalLayer(torch.nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x):
        return GradientReversalFunction.apply(x)

# %% [markdown]
# ### LSTM for Feature Extraction

# %%
class Swish(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return x * self.sigmoid(x)

# %%
class lstm(nn.Module):
    def __init__(self):
        super(lstm, self).__init__()
        self.lstm1 = nn.LSTM(12, 64, batch_first=True)
        self.bn1 = nn.BatchNorm1d(7)
        self.lstm2 = nn.LSTM(64, 64, batch_first=True)
        self.bn2 = nn.BatchNorm1d(7)
        self.lstm3 = nn.LSTM(64, 64, batch_first=True)
        
        self.fc = nn.Linear(64, 64)
        self.fc2 = nn.Linear(64, 64)
        self.bn3 = nn.BatchNorm1d(7)
        self.bn4 = nn.BatchNorm1d(7)
        self.bn5 = nn.BatchNorm1d(64)
        self.dropout = nn.Dropout(0.5)
        self.swish = Swish()
        self.relu = nn.ReLU()

        
    def forward(self, x):
        x, (h0, c0) = self.lstm1(x)
        x = self.bn1(x)
        x = self.swish(x)
        #x = self.dropout(x)
        
        x, (h1, c1) = self.lstm2(x, (h0, c0))
        x = self.bn2(x)
        x = self.swish(x)
        #x = self.dropout(x)
        
        x, _ = self.lstm3(x, (h1, c1))
        x = self.bn3(x)
        x = self.swish(x)
        
        x = self.fc(x)
        x = self.bn4(x)
        
        x = self.fc2(x[:,-1])
        #x = self.bn5(x)
        x = self.swish(x)
        x = self.dropout(x)

        return x#[:,-1]

# %%
hoxy = lstm()
inputx = torch.randn(512,7,12)
hoxy2 = hoxy(inputx)
print(hoxy2.shape)
# Out:
# torch.Size([512, 64])

# %%
class domain_regression(nn.Module):
    def __init__(self):
        super(domain_regression, self).__init__()
        self.regression_layer1 = nn.Linear(64, 100)
        self.regression_layer2 = nn.Linear(100, 100)
        self.regression_layer3 = nn.Linear(100, 100)
        self.regression_layer4 = nn.Linear(100, 1)
        self.swish = Swish()
        self.bn1 = nn.BatchNorm1d(100)
        self.dropout = nn.Dropout(0.5)
        self.relu = nn.ReLU()
    def forward(self, x):
        x = self.bn1(self.regression_layer1(x))
        x = self.relu(x)#x = self.dropout(self.swish(x))
        x = self.bn1(self.regression_layer2(x))
        x = self.relu(x)#x = self.dropout(self.swish(x))
        x = self.bn1(self.regression_layer3(x))
        x = self.relu(x)#x = self.dropout(self.swish(x))
        x = self.relu(self.regression_layer4(x))
        #x = self.dropout(x)
        return x

# %% [markdown]
# ### Domain Classification

# %%
class domain_classfication(nn.Module):
    def __init__(self):
        super(domain_classfication, self).__init__()
        self.classification_layer0 = GradientReversalLayer()
        self.classification_layer1 = nn.Linear(64,100)
        self.classification_layer2 = nn.Linear(100,100)
        self.classification_layer3 = nn.Linear(100,100)
        self.classification_layer4 = nn.Linear(100, 1)
        self.swish = Swish()
        self.relu = nn.ReLU()
        self.bn1 = nn.BatchNorm1d(100)
        self.dropout = nn.Dropout(0.5)
        
    def forward(self, x):
        x = self.classification_layer0(x)
        x = self.bn1(self.classification_layer1(x))
        x = self.relu(x)#x = self.dropout(self.swish(x))
        x = self.bn1(self.classification_layer2(x))
        x = self.relu(x)#x = self.dropout(self.swish(x))
        x = self.bn1(self.classification_layer3(x))
        x = self.relu(x)#x = self.dropout(self.swish(x))
        x = self.classification_layer4(x)#torch.sigmoid(self.classification_layer4(x))
        #x = self.dropout(x)
        return x

# %% [markdown]
# ### Set the DANN

# %%
class dann(nn.Module):
    def __init__(self, lstm):
        super(dann, self).__init__()
        self.lstm = lstm
        self.regression = domain_regression()
        self.classification = domain_classfication()
        
    def forward(self, x):
        feature = self.lstm(x)
        reg_output = self.regression(feature)
        cla_output = self.classification(feature)
        
        return reg_output, cla_output

# %% [markdown]
# ### Loss 선언

# %%
class dann_loss(nn.Module):
    def __init__(self):
        super(dann_loss, self).__init__()
        self.reg = nn.L1Loss()
        self.cla = nn.BCEWithLogitsLoss()#nn.BCELoss()
        
    def forward(self, result, reg_real, domain_num, alpha=1):
        reg_output, cla_output = result
        batch_size = reg_output.shape[0]
        cla_target = torch.FloatTensor([domain_num] * batch_size).unsqueeze(1).to(device)
        
        reg_loss = self.reg(reg_output, reg_real)
        cla_loss = self.cla(cla_output, cla_target)
        cla_loss2 = cla_loss * alpha
        
        loss = reg_loss + cla_loss2
        
        return loss, reg_loss, cla_loss2

# %%
my_lstm = lstm().to(device)
model = dann(my_lstm).to(device)
loss_fn = dann_loss().to(device)

# %% [markdown]
# # 훈련

# %%
from torch.optim.lr_scheduler import LinearLR

alpha = 1.0
epochs = 200

model.train() # 훈련 모드 설정

optimizer= torch.optim.Adamax(model.parameters(), lr=0.001, weight_decay=0.01)
scheduler = LinearLR(optimizer, start_factor=1.0, end_factor=0.0, total_iters = epochs * len(NELEC_train))

patience = 100  # Early stopping을 위한 기다리는 최대 epoch 수
best_loss = float('inf')
best_source_loss = float('inf')
best_model_state_dict = None
counter = 10  # Early stopping 카운터

for i in range(1, epochs + 1):
    total_loss = 0
    source_total_loss = 0
    target_total_loss = 0
    src_reg_total = 0
    src_cla_total = 0
    tar_reg_total = 0
    tar_cal_total = 0
    reg_loss_total = 0
    cla_loss_total = 0
    for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
        source_x = source_data[0].to(device)
        source_y = source_data[1].to(device)
        target_x = target_data[0].to(device)
        target_y = target_data[1].to(device)
        #print(source_x.shape)
        #print(source_y.shape)
        #print(target_x.shape)
        #print(target_y.shape)
        # 순전파
        source_result = model(source_x)
        target_result = model(target_x)
        #print(source_result[0].shape)
        #print(target_result[0].shape)
        #print(source_result[1].shape)
        #print(target_result[1].shape)
        # 순전파 loss
        source_loss, source_reg_loss, source_cla_loss = loss_fn(source_result, source_y, 0, alpha=alpha) # 소스 도메인 레이블 0
        target_loss, target_reg_loss, target_cla_loss = loss_fn(target_result, target_y, 1, alpha=alpha) # 타겟 도메인 레이블 1
        
        loss = source_loss + target_loss
        reg_loss = source_reg_loss + target_reg_loss
        cla_loss = source_cla_loss + target_cla_loss
        
        #src_reg_total += source_reg_loss.item()
        #src_cla_total += source_cla_loss.item()
        #tar_reg_total += target_reg_loss.item()
        #tar_cal_total += target_cla_loss.item()
        
        #source_total_loss += source_loss.item()
        #target_total_loss += target_loss.item()
        
        reg_loss_total += reg_loss.item()
        cla_loss_total += cla_loss.item()
        
        total_loss += loss.item()
        
        # 그래디언트 계산 및 업데이트
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()
        
        # Early stopping 확인
    if reg_loss_total / len(NELEC_train) < best_loss:
        best_loss = reg_loss_total / len(NELEC_train)
        best_model_state_dict = model.state_dict()
        counter = 0  # Counter 초기화
    else:
        counter += 1
        if counter >= patience:
            print(f'Early stopping at epoch {i}')
            break

    print('Epoch : %d, Total Avg Loss : %.4f' % (i, total_loss / len(NELEC_train)))     
    #print('Source Avg Loss : %.4f' % (source_total_loss / len(NELEC_train)))
    #print('Target Avg Loss : %.4f' % (target_total_loss / len(NELEC_train)))
    #print('Source Avg reg Loss : %.4f' % (src_reg_total / len(NELEC_train)))
    #print('Target Avg reg Loss : %.4f' % (tar_reg_total / len(NELEC_train)))
    #print('Source Avg cla Loss : %.4f' % (src_cla_total / len(NELEC_train)))
    #print('Target Avg cla Loss : %.4f' % (tar_cal_total / len(NELEC_train)))
    print('Avg Regression Loss : %.4f' % (reg_loss_total / len(NELEC_train)))
    print('Avg Classification Loss : %.4f' % (cla_loss_total / len(NELEC_train)))
    print('')
    
    # source_loss가 가장 낮은 경우 모델 가중치 저장
    if reg_loss / len(NELEC_train) < best_source_loss:
        best_source_loss = reg_loss / len(NELEC_train)
        best_model_state_dict = model.state_dict()

# 최상의 모델을 파일로 저장
if best_model_state_dict is not None:
    torch.save(best_model_state_dict, '0823_03shift.pth')
    #torch.save(model, "model.pth")
# Out:
# Epoch : 1, Total Avg Loss : 2.0277
# Avg Regression Loss : 0.6344
# Avg Classification Loss : 1.3933
#
# Epoch : 2, Total Avg Loss : 1.9282
# Avg Regression Loss : 0.5406
# Avg Classification Loss : 1.3876
#
# Epoch : 3, Total Avg Loss : 1.7919
# Avg Regression Loss : 0.4237
# Avg Classification Loss : 1.3682
#
# Epoch : 4, Total Avg Loss : 1.6873
# Avg Regression Loss : 0.3398
# Avg Classification Loss : 1.3475
#
# Epoch : 5, Total Avg Loss : 1.6175
# Avg Regression Loss : 0.3003
# Avg Classification Loss : 1.3172
#
# Epoch : 6, Total Avg Loss : 1.6755
# Avg Regression Loss : 0.3376
# Avg Classification Loss : 1.3379
#
# Epoch : 7, Total Avg Loss : 1.6226
# Avg Regression Loss : 0.3235
# Avg Classification Loss : 1.2991
#
# Epoch : 8, Total Avg Loss : 1.6232
# Avg Regression Loss : 0.3197
# Avg Classification Loss : 1.3035
#
# Epoch : 9, Total Avg Loss : 1.6474
# Avg Regression Loss : 0.3244
# Avg Classification Loss : 1.3230
#
# Epoch : 10, Total Avg Loss : 1.6495
# Avg Regression Loss : 0.3186
# Avg Classification Loss : 1.3310
#
# Epoch : 11, Total Avg Loss : 1.6364
# Avg Regression Loss : 0.3089
# Avg Classification Loss : 1.3275
#
# Epoch : 12, Total Avg Loss : 1.6504
# Avg Regression Loss : 0.3148
# Avg Classification Loss : 1.3356
#
# Epoch : 13, Total Avg Loss : 1.6283
# Avg Regression Loss : 0.3200
# Avg Classification Loss : 1.3084
#
# Epoch : 14, Total Avg Loss : 1.6520
# Avg Regression Loss : 0.3241
# Avg Classification Loss : 1.3279
#
# Epoch : 15, Total Avg Loss : 1.6517
# Avg Regression Loss : 0.3263
# Avg Classification Loss : 1.3254
#
# Epoch : 16, Total Avg Loss : 1.6933
# Avg Regression Loss : 0.3385
# Avg Classification Loss : 1.3548
#
# Epoch : 17, Total Avg Loss : 1.6353
# Avg Regression Loss : 0.3134
# Avg Classification Loss : 1.3219
#
# Epoch : 18, Total Avg Loss : 1.6426
# Avg Regression Loss : 0.3129
# Avg Classification Loss : 1.3297
#
# Epoch : 19, Total Avg Loss : 1.6634
# Avg Regression Loss : 0.3192
# Avg Classification Loss : 1.3442
#
# Epoch : 20, Total Avg Loss : 1.6938
# Avg Regression Loss : 0.3517
# Avg Classification Loss : 1.3420
#
# Epoch : 21, Total Avg Loss : 1.6692
# Avg Regression Loss : 0.3388
# Avg Classification Loss : 1.3304
#
# Epoch : 22, Total Avg Loss : 1.6486
# Avg Regression Loss : 0.3206
# Avg Classification Loss : 1.3280
#
# Epoch : 23, Total Avg Loss : 1.6622
# Avg Regression Loss : 0.3237
# Avg Classification Loss : 1.3386
#
# Epoch : 24, Total Avg Loss : 1.7229
# Avg Regression Loss : 0.3637
# Avg Classification Loss : 1.3592
#
# Epoch : 25, Total Avg Loss : 1.6660
# Avg Regression Loss : 0.3266
# Avg Classification Loss : 1.3394
#
# Epoch : 26, Total Avg Loss : 1.7053
# Avg Regression Loss : 0.3483
# Avg Classification Loss : 1.3570
#
# Epoch : 27, Total Avg Loss : 1.7061
# Avg Regression Loss : 0.3465
# Avg Classification Loss : 1.3596
#
# Epoch : 28, Total Avg Loss : 1.6788
# Avg Regression Loss : 0.3348
# Avg Classification Loss : 1.3441
#
# Epoch : 29, Total Avg Loss : 1.6738
# Avg Regression Loss : 0.3408
# Avg Classification Loss : 1.3330
#
# Epoch : 30, Total Avg Loss : 1.6957
# Avg Regression Loss : 0.3517
# Avg Classification Loss : 1.3440
#
# Epoch : 31, Total Avg Loss : 1.6680
# Avg Regression Loss : 0.3281
# Avg Classification Loss : 1.3398
#
# Epoch : 32, Total Avg Loss : 1.6885
# Avg Regression Loss : 0.3360
# Avg Classification Loss : 1.3525
#
# Epoch : 33, Total Avg Loss : 1.7040
# Avg Regression Loss : 0.3473
# Avg Classification Loss : 1.3567
#
# Epoch : 34, Total Avg Loss : 1.7028
# Avg Regression Loss : 0.3606
# Avg Classification Loss : 1.3423
#
# Epoch : 35, Total Avg Loss : 1.6734
# Avg Regression Loss : 0.3295
# Avg Classification Loss : 1.3438
#
# Epoch : 36, Total Avg Loss : 1.6561
# Avg Regression Loss : 0.3231
# Avg Classification Loss : 1.3330
#
# Epoch : 37, Total Avg Loss : 1.6840
# Avg Regression Loss : 0.3307
# Avg Classification Loss : 1.3533
#
# Epoch : 38, Total Avg Loss : 1.6810
# Avg Regression Loss : 0.3298
# Avg Classification Loss : 1.3512
#
# Epoch : 39, Total Avg Loss : 1.6661
# Avg Regression Loss : 0.3378
# Avg Classification Loss : 1.3282
#
# Epoch : 40, Total Avg Loss : 1.6678
# Avg Regression Loss : 0.3379
# Avg Classification Loss : 1.3299
#
# Epoch : 41, Total Avg Loss : 1.6833
# Avg Regression Loss : 0.3344
# Avg Classification Loss : 1.3489
#
# Epoch : 42, Total Avg Loss : 1.6823
# Avg Regression Loss : 0.3354
# Avg Classification Loss : 1.3470
#
# Epoch : 43, Total Avg Loss : 1.7166
# Avg Regression Loss : 0.3570
# Avg Classification Loss : 1.3596
#
# Epoch : 44, Total Avg Loss : 1.7092
# Avg Regression Loss : 0.3521
# Avg Classification Loss : 1.3570
#
# Epoch : 45, Total Avg Loss : 1.7048
# Avg Regression Loss : 0.3409
# Avg Classification Loss : 1.3639
#
# Epoch : 46, Total Avg Loss : 1.6732
# Avg Regression Loss : 0.3294
# Avg Classification Loss : 1.3438
#
# Epoch : 47, Total Avg Loss : 1.7145
# Avg Regression Loss : 0.3584
# Avg Classification Loss : 1.3561
#
# Epoch : 48, Total Avg Loss : 1.7324
# Avg Regression Loss : 0.3623
# Avg Classification Loss : 1.3701
#
# Epoch : 49, Total Avg Loss : 1.6893
# Avg Regression Loss : 0.3333
# Avg Classification Loss : 1.3561
#
# Epoch : 50, Total Avg Loss : 1.6714
# Avg Regression Loss : 0.3215
# Avg Classification Loss : 1.3500
#
# Epoch : 51, Total Avg Loss : 1.6948
# Avg Regression Loss : 0.3328
# Avg Classification Loss : 1.3620
#
# Epoch : 52, Total Avg Loss : 1.7167
# Avg Regression Loss : 0.3557
# Avg Classification Loss : 1.3610
#
# Epoch : 53, Total Avg Loss : 1.7400
# Avg Regression Loss : 0.3676
# Avg Classification Loss : 1.3724
#
# Epoch : 54, Total Avg Loss : 1.7092
# Avg Regression Loss : 0.3421
# Avg Classification Loss : 1.3671
#
# Epoch : 55, Total Avg Loss : 1.6265
# Avg Regression Loss : 0.3050
# Avg Classification Loss : 1.3215
#
# Epoch : 56, Total Avg Loss : 1.6709
# Avg Regression Loss : 0.3273
# Avg Classification Loss : 1.3436
#
# Epoch : 57, Total Avg Loss : 1.7085
# Avg Regression Loss : 0.3403
# Avg Classification Loss : 1.3682
#
# Epoch : 58, Total Avg Loss : 1.7049
# Avg Regression Loss : 0.3404
# Avg Classification Loss : 1.3646
#
# Epoch : 59, Total Avg Loss : 1.7012
# Avg Regression Loss : 0.3393
# Avg Classification Loss : 1.3618
#
# Epoch : 60, Total Avg Loss : 1.6923
# Avg Regression Loss : 0.3290
# Avg Classification Loss : 1.3633
#
# Epoch : 61, Total Avg Loss : 1.6500
# Avg Regression Loss : 0.3006
# Avg Classification Loss : 1.3495
#
# Epoch : 62, Total Avg Loss : 1.6166
# Avg Regression Loss : 0.2910
# Avg Classification Loss : 1.3256
#
# Epoch : 63, Total Avg Loss : 1.5892
# Avg Regression Loss : 0.2719
# Avg Classification Loss : 1.3173
#
# Epoch : 64, Total Avg Loss : 1.6096
# Avg Regression Loss : 0.2778
# Avg Classification Loss : 1.3318
#
# Epoch : 65, Total Avg Loss : 1.5784
# Avg Regression Loss : 0.2674
# Avg Classification Loss : 1.3110
#
# Epoch : 66, Total Avg Loss : 1.6024
# Avg Regression Loss : 0.2685
# Avg Classification Loss : 1.3339
#
# Epoch : 67, Total Avg Loss : 1.5703
# Avg Regression Loss : 0.2582
# Avg Classification Loss : 1.3121
#
# Epoch : 68, Total Avg Loss : 1.5768
# Avg Regression Loss : 0.2490
# Avg Classification Loss : 1.3278
#
# Epoch : 69, Total Avg Loss : 1.5751
# Avg Regression Loss : 0.2398
# Avg Classification Loss : 1.3353
#
# Epoch : 70, Total Avg Loss : 1.5729
# Avg Regression Loss : 0.2440
# Avg Classification Loss : 1.3289
#
# Epoch : 71, Total Avg Loss : 1.5484
# Avg Regression Loss : 0.2295
# Avg Classification Loss : 1.3189
#
# Epoch : 72, Total Avg Loss : 1.5583
# Avg Regression Loss : 0.2464
# Avg Classification Loss : 1.3119
#
# Epoch : 73, Total Avg Loss : 1.5616
# Avg Regression Loss : 0.2419
# Avg Classification Loss : 1.3197
#
# Epoch : 74, Total Avg Loss : 1.5417
# Avg Regression Loss : 0.2238
# Avg Classification Loss : 1.3179
#
# Epoch : 75, Total Avg Loss : 1.5373
# Avg Regression Loss : 0.2225
# Avg Classification Loss : 1.3148
#
# Epoch : 76, Total Avg Loss : 1.5243
# Avg Regression Loss : 0.2173
# Avg Classification Loss : 1.3070
#
# Epoch : 77, Total Avg Loss : 1.5235
# Avg Regression Loss : 0.2100
# Avg Classification Loss : 1.3135
#
# Epoch : 78, Total Avg Loss : 1.5355
# Avg Regression Loss : 0.2058
# Avg Classification Loss : 1.3298
#
# Epoch : 79, Total Avg Loss : 1.5929
# Avg Regression Loss : 0.2514
# Avg Classification Loss : 1.3415
#
# Epoch : 80, Total Avg Loss : 1.5772
# Avg Regression Loss : 0.2369
# Avg Classification Loss : 1.3403
#
# Epoch : 81, Total Avg Loss : 1.5158
# Avg Regression Loss : 0.2088
# Avg Classification Loss : 1.3071
#
# Epoch : 82, Total Avg Loss : 1.5715
# Avg Regression Loss : 0.2406
# Avg Classification Loss : 1.3309
#
# Epoch : 83, Total Avg Loss : 1.5660
# Avg Regression Loss : 0.2437
# Avg Classification Loss : 1.3222
#
# Epoch : 84, Total Avg Loss : 1.5172
# Avg Regression Loss : 0.2062
# Avg Classification Loss : 1.3110
#
# Epoch : 85, Total Avg Loss : 1.5326
# Avg Regression Loss : 0.2116
# Avg Classification Loss : 1.3210
#
# Epoch : 86, Total Avg Loss : 1.5552
# Avg Regression Loss : 0.2194
# Avg Classification Loss : 1.3358
#
# Epoch : 87, Total Avg Loss : 1.5654
# Avg Regression Loss : 0.2383
# Avg Classification Loss : 1.3271
#
# Epoch : 88, Total Avg Loss : 1.5794
# Avg Regression Loss : 0.2361
# Avg Classification Loss : 1.3433
#
# Epoch : 89, Total Avg Loss : 1.5183
# Avg Regression Loss : 0.2026
# Avg Classification Loss : 1.3157
#
# Epoch : 90, Total Avg Loss : 1.5286
# Avg Regression Loss : 0.2186
# Avg Classification Loss : 1.3100
#
# Epoch : 91, Total Avg Loss : 1.5558
# Avg Regression Loss : 0.2266
# Avg Classification Loss : 1.3292
#
# Epoch : 92, Total Avg Loss : 1.6044
# Avg Regression Loss : 0.2508
# Avg Classification Loss : 1.3536
#
# Epoch : 93, Total Avg Loss : 1.5275
# Avg Regression Loss : 0.2089
# Avg Classification Loss : 1.3186
#
# Epoch : 94, Total Avg Loss : 1.5424
# Avg Regression Loss : 0.2197
# Avg Classification Loss : 1.3226
#
# Epoch : 95, Total Avg Loss : 1.5570
# Avg Regression Loss : 0.2225
# Avg Classification Loss : 1.3345
#
# Epoch : 96, Total Avg Loss : 1.5219
# Avg Regression Loss : 0.2077
# Avg Classification Loss : 1.3143
#
# Epoch : 97, Total Avg Loss : 1.5599
# Avg Regression Loss : 0.2212
# Avg Classification Loss : 1.3387
#
# Epoch : 98, Total Avg Loss : 1.5661
# Avg Regression Loss : 0.2312
# Avg Classification Loss : 1.3348
#
# Epoch : 99, Total Avg Loss : 1.5773
# Avg Regression Loss : 0.2357
# Avg Classification Loss : 1.3416
#
# Epoch : 100, Total Avg Loss : 1.5700
# Avg Regression Loss : 0.2262
# Avg Classification Loss : 1.3438
#
# Epoch : 101, Total Avg Loss : 1.4890
# Avg Regression Loss : 0.1869
# Avg Classification Loss : 1.3021
#
# Epoch : 102, Total Avg Loss : 1.4940
# Avg Regression Loss : 0.1970
# Avg Classification Loss : 1.2970
#
# Epoch : 103, Total Avg Loss : 1.5529
# Avg Regression Loss : 0.2340
# Avg Classification Loss : 1.3190
#
# Epoch : 104, Total Avg Loss : 1.5253
# Avg Regression Loss : 0.2045
# Avg Classification Loss : 1.3207
#
# Epoch : 105, Total Avg Loss : 1.5678
# Avg Regression Loss : 0.2356
# Avg Classification Loss : 1.3322
#
# Epoch : 106, Total Avg Loss : 1.5480
# Avg Regression Loss : 0.2031
# Avg Classification Loss : 1.3449
#
# Epoch : 107, Total Avg Loss : 1.4999
# Avg Regression Loss : 0.1833
# Avg Classification Loss : 1.3165
#
# Epoch : 108, Total Avg Loss : 1.5354
# Avg Regression Loss : 0.1979
# Avg Classification Loss : 1.3375
#
# Epoch : 109, Total Avg Loss : 1.5475
# Avg Regression Loss : 0.1997
# Avg Classification Loss : 1.3478
#
# Epoch : 110, Total Avg Loss : 1.5607
# Avg Regression Loss : 0.2030
# Avg Classification Loss : 1.3577
#
# Epoch : 111, Total Avg Loss : 1.5135
# Avg Regression Loss : 0.1782
# Avg Classification Loss : 1.3353
#
# Epoch : 112, Total Avg Loss : 1.5200
# Avg Regression Loss : 0.1831
# Avg Classification Loss : 1.3369
#
# Epoch : 113, Total Avg Loss : 1.5243
# Avg Regression Loss : 0.2040
# Avg Classification Loss : 1.3203
#
# Epoch : 114, Total Avg Loss : 1.5047
# Avg Regression Loss : 0.1822
# Avg Classification Loss : 1.3225
#
# Epoch : 115, Total Avg Loss : 1.5017
# Avg Regression Loss : 0.1739
# Avg Classification Loss : 1.3278
#
# Epoch : 116, Total Avg Loss : 1.5378
# Avg Regression Loss : 0.1987
# Avg Classification Loss : 1.3390
#
# Epoch : 117, Total Avg Loss : 1.5202
# Avg Regression Loss : 0.1803
# Avg Classification Loss : 1.3399
#
# Epoch : 118, Total Avg Loss : 1.5228
# Avg Regression Loss : 0.1822
# Avg Classification Loss : 1.3405
#
# Epoch : 119, Total Avg Loss : 1.5322
# Avg Regression Loss : 0.1897
# Avg Classification Loss : 1.3425
#
# Epoch : 120, Total Avg Loss : 1.5524
# Avg Regression Loss : 0.1990
# Avg Classification Loss : 1.3535
#
# Epoch : 121, Total Avg Loss : 1.5240
# Avg Regression Loss : 0.1800
# Avg Classification Loss : 1.3439
#
# Epoch : 122, Total Avg Loss : 1.5245
# Avg Regression Loss : 0.1794
# Avg Classification Loss : 1.3451
#
# Epoch : 123, Total Avg Loss : 1.5379
# Avg Regression Loss : 0.1894
# Avg Classification Loss : 1.3485
#
# Epoch : 124, Total Avg Loss : 1.5167
# Avg Regression Loss : 0.1719
# Avg Classification Loss : 1.3448
#
# Epoch : 125, Total Avg Loss : 1.5225
# Avg Regression Loss : 0.1772
# Avg Classification Loss : 1.3453
#
# Epoch : 126, Total Avg Loss : 1.5305
# Avg Regression Loss : 0.1790
# Avg Classification Loss : 1.3515
#
# Epoch : 127, Total Avg Loss : 1.5191
# Avg Regression Loss : 0.1827
# Avg Classification Loss : 1.3364
#
# Epoch : 128, Total Avg Loss : 1.5027
# Avg Regression Loss : 0.1660
# Avg Classification Loss : 1.3367
#
# Epoch : 129, Total Avg Loss : 1.5196
# Avg Regression Loss : 0.1743
# Avg Classification Loss : 1.3454
#
# Epoch : 130, Total Avg Loss : 1.5125
# Avg Regression Loss : 0.1693
# Avg Classification Loss : 1.3432
#
# Epoch : 131, Total Avg Loss : 1.5149
# Avg Regression Loss : 0.1743
# Avg Classification Loss : 1.3406
#
# Epoch : 132, Total Avg Loss : 1.4980
# Avg Regression Loss : 0.1634
# Avg Classification Loss : 1.3346
#
# Epoch : 133, Total Avg Loss : 1.5055
# Avg Regression Loss : 0.1613
# Avg Classification Loss : 1.3442
#
# Epoch : 134, Total Avg Loss : 1.5095
# Avg Regression Loss : 0.1687
# Avg Classification Loss : 1.3408
#
# Epoch : 135, Total Avg Loss : 1.5015
# Avg Regression Loss : 0.1712
# Avg Classification Loss : 1.3303
#
# Epoch : 136, Total Avg Loss : 1.4897
# Avg Regression Loss : 0.1612
# Avg Classification Loss : 1.3285
#
# Epoch : 137, Total Avg Loss : 1.5043
# Avg Regression Loss : 0.1646
# Avg Classification Loss : 1.3397
#
# Epoch : 138, Total Avg Loss : 1.4952
# Avg Regression Loss : 0.1642
# Avg Classification Loss : 1.3310
#
# Epoch : 139, Total Avg Loss : 1.4956
# Avg Regression Loss : 0.1552
# Avg Classification Loss : 1.3404
#
# Epoch : 140, Total Avg Loss : 1.4972
# Avg Regression Loss : 0.1661
# Avg Classification Loss : 1.3311
#
# Epoch : 141, Total Avg Loss : 1.4914
# Avg Regression Loss : 0.1587
# Avg Classification Loss : 1.3327
#
# Epoch : 142, Total Avg Loss : 1.5029
# Avg Regression Loss : 0.1700
# Avg Classification Loss : 1.3330
#
# Epoch : 143, Total Avg Loss : 1.5046
# Avg Regression Loss : 0.1791
# Avg Classification Loss : 1.3255
#
# Epoch : 144, Total Avg Loss : 1.4854
# Avg Regression Loss : 0.1591
# Avg Classification Loss : 1.3263
#
# Epoch : 145, Total Avg Loss : 1.4999
# Avg Regression Loss : 0.1664
# Avg Classification Loss : 1.3335
#
# Epoch : 146, Total Avg Loss : 1.4868
# Avg Regression Loss : 0.1605
# Avg Classification Loss : 1.3263
#
# Epoch : 147, Total Avg Loss : 1.4977
# Avg Regression Loss : 0.1581
# Avg Classification Loss : 1.3397
#
# Epoch : 148, Total Avg Loss : 1.4964
# Avg Regression Loss : 0.1677
# Avg Classification Loss : 1.3287
#
# Epoch : 149, Total Avg Loss : 1.4822
# Avg Regression Loss : 0.1593
# Avg Classification Loss : 1.3229
#
# Epoch : 150, Total Avg Loss : 1.4904
# Avg Regression Loss : 0.1655
# Avg Classification Loss : 1.3249
#
# Epoch : 151, Total Avg Loss : 1.4872
# Avg Regression Loss : 0.1610
# Avg Classification Loss : 1.3262
#
# Epoch : 152, Total Avg Loss : 1.4967
# Avg Regression Loss : 0.1705
# Avg Classification Loss : 1.3262
#
# Epoch : 153, Total Avg Loss : 1.4854
# Avg Regression Loss : 0.1648
# Avg Classification Loss : 1.3206
#
# Epoch : 154, Total Avg Loss : 1.4852
# Avg Regression Loss : 0.1552
# Avg Classification Loss : 1.3300
#
# Epoch : 155, Total Avg Loss : 1.5029
# Avg Regression Loss : 0.1699
# Avg Classification Loss : 1.3330
#
# Epoch : 156, Total Avg Loss : 1.4946
# Avg Regression Loss : 0.1714
# Avg Classification Loss : 1.3231
#
# Epoch : 157, Total Avg Loss : 1.4915
# Avg Regression Loss : 0.1626
# Avg Classification Loss : 1.3289
#
# Epoch : 158, Total Avg Loss : 1.4909
# Avg Regression Loss : 0.1592
# Avg Classification Loss : 1.3317
#
# Epoch : 159, Total Avg Loss : 1.4812
# Avg Regression Loss : 0.1577
# Avg Classification Loss : 1.3235
#
# Epoch : 160, Total Avg Loss : 1.4769
# Avg Regression Loss : 0.1550
# Avg Classification Loss : 1.3219
#
# Epoch : 161, Total Avg Loss : 1.5034
# Avg Regression Loss : 0.1690
# Avg Classification Loss : 1.3344
#
# Epoch : 162, Total Avg Loss : 1.4862
# Avg Regression Loss : 0.1606
# Avg Classification Loss : 1.3256
#
# Epoch : 163, Total Avg Loss : 1.4924
# Avg Regression Loss : 0.1581
# Avg Classification Loss : 1.3343
#
# Epoch : 164, Total Avg Loss : 1.4970
# Avg Regression Loss : 0.1694
# Avg Classification Loss : 1.3276
#
# Epoch : 165, Total Avg Loss : 1.4905
# Avg Regression Loss : 0.1646
# Avg Classification Loss : 1.3259
#
# Epoch : 166, Total Avg Loss : 1.5079
# Avg Regression Loss : 0.1761
# Avg Classification Loss : 1.3318
#
# Epoch : 167, Total Avg Loss : 1.4755
# Avg Regression Loss : 0.1546
# Avg Classification Loss : 1.3208
#
# Epoch : 168, Total Avg Loss : 1.4755
# Avg Regression Loss : 0.1511
# Avg Classification Loss : 1.3244
#
# Epoch : 169, Total Avg Loss : 1.4813
# Avg Regression Loss : 0.1533
# Avg Classification Loss : 1.3280
#
# Epoch : 170, Total Avg Loss : 1.4880
# Avg Regression Loss : 0.1603
# Avg Classification Loss : 1.3277
#
# Epoch : 171, Total Avg Loss : 1.4732
# Avg Regression Loss : 0.1571
# Avg Classification Loss : 1.3161
#
# Epoch : 172, Total Avg Loss : 1.4651
# Avg Regression Loss : 0.1473
# Avg Classification Loss : 1.3178
#
# Epoch : 173, Total Avg Loss : 1.5194
# Avg Regression Loss : 0.1847
# Avg Classification Loss : 1.3348
#
# Epoch : 174, Total Avg Loss : 1.4969
# Avg Regression Loss : 0.1744
# Avg Classification Loss : 1.3225
#
# Epoch : 175, Total Avg Loss : 1.4495
# Avg Regression Loss : 0.1438
# Avg Classification Loss : 1.3057
#
# Epoch : 176, Total Avg Loss : 1.4784
# Avg Regression Loss : 0.1570
# Avg Classification Loss : 1.3215
#
# Epoch : 177, Total Avg Loss : 1.4672
# Avg Regression Loss : 0.1545
# Avg Classification Loss : 1.3127
#
# Epoch : 178, Total Avg Loss : 1.4860
# Avg Regression Loss : 0.1606
# Avg Classification Loss : 1.3254
#
# Epoch : 179, Total Avg Loss : 1.4703
# Avg Regression Loss : 0.1493
# Avg Classification Loss : 1.3209
#
# Epoch : 180, Total Avg Loss : 1.4717
# Avg Regression Loss : 0.1536
# Avg Classification Loss : 1.3181
#
# Epoch : 181, Total Avg Loss : 1.4658
# Avg Regression Loss : 0.1501
# Avg Classification Loss : 1.3158
#
# Epoch : 182, Total Avg Loss : 1.4707
# Avg Regression Loss : 0.1567
# Avg Classification Loss : 1.3140
#
# Epoch : 183, Total Avg Loss : 1.4628
# Avg Regression Loss : 0.1488
# Avg Classification Loss : 1.3140
#
# Epoch : 184, Total Avg Loss : 1.4743
# Avg Regression Loss : 0.1545
# Avg Classification Loss : 1.3199
#
# Epoch : 185, Total Avg Loss : 1.4571
# Avg Regression Loss : 0.1480
# Avg Classification Loss : 1.3091
#
# Epoch : 186, Total Avg Loss : 1.4610
# Avg Regression Loss : 0.1499
# Avg Classification Loss : 1.3111
#
# Epoch : 187, Total Avg Loss : 1.4761
# Avg Regression Loss : 0.1548
# Avg Classification Loss : 1.3213
#
# Epoch : 188, Total Avg Loss : 1.4757
# Avg Regression Loss : 0.1535
# Avg Classification Loss : 1.3222
#
# Epoch : 189, Total Avg Loss : 1.4748
# Avg Regression Loss : 0.1535
# Avg Classification Loss : 1.3213
#
# Epoch : 190, Total Avg Loss : 1.4727
# Avg Regression Loss : 0.1509
# Avg Classification Loss : 1.3218
#
# Epoch : 191, Total Avg Loss : 1.4754
# Avg Regression Loss : 0.1543
# Avg Classification Loss : 1.3211
#
# Epoch : 192, Total Avg Loss : 1.4817
# Avg Regression Loss : 0.1641
# Avg Classification Loss : 1.3176
#
# Epoch : 193, Total Avg Loss : 1.4629
# Avg Regression Loss : 0.1484
# Avg Classification Loss : 1.3146
#
# Epoch : 194, Total Avg Loss : 1.4753
# Avg Regression Loss : 0.1540
# Avg Classification Loss : 1.3213
#
# Epoch : 195, Total Avg Loss : 1.4877
# Avg Regression Loss : 0.1642
# Avg Classification Loss : 1.3235
#
# Epoch : 196, Total Avg Loss : 1.4633
# Avg Regression Loss : 0.1496
# Avg Classification Loss : 1.3137
#
# Epoch : 197, Total Avg Loss : 1.4700
# Avg Regression Loss : 0.1518
# Avg Classification Loss : 1.3182
#
# Epoch : 198, Total Avg Loss : 1.4734
# Avg Regression Loss : 0.1561
# Avg Classification Loss : 1.3173
#
# Epoch : 199, Total Avg Loss : 1.4784
# Avg Regression Loss : 0.1563
# Avg Classification Loss : 1.3220
#
# Epoch : 200, Total Avg Loss : 1.4700
# Avg Regression Loss : 0.1530
# Avg Classification Loss : 1.3170

# %%
# from torchinfo import summary

# summary(model, (512,3,12))

# %% [markdown]
# # train 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('0823_03shift.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []
s_d_pred = []
t_d_pred = []

for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    source_domain_label_pred, source_pred = best_source_model2(sourcex)
    target_domain_label_pred, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())
    s_d_pred.extend(source_domain_label_pred.detach().cpu().numpy())
    t_d_pred.extend(target_domain_label_pred.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: 0.6737865466345949
# TARGET R2 Score: 0.8540979282428502

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# # test 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('0823_03shift.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []


for step, (source_data, target_data) in enumerate(zip(NELEC_test, DHW_test)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    _, source_pred = best_source_model2(sourcex)
    _, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: 0.7073077468900291
# TARGET R2 Score: 0.8430064360115249

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# ### Domain Embedding Space 시각화

# %%
# 가장 앞 batch의 250개씩의 데이터만 샘플링
source_tsne = DataLoader(nelec_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

target_tsne = DataLoader(dhw_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

source_tsne2 = next(iter(source_tsne))
target_tsne2 = next(iter(target_tsne))

source_x_TNSE = source_tsne2[0].to(device)
source_y_TNSE = source_tsne2[1].to(device)

target_x_TNSE = target_tsne2[0].to(device)
target_y_TNSE = target_tsne2[1].to(device)

# 학습된 모델의 LSTM 부분만 활용 (100차원 임베딩 벡터를 받아오는 과정)
source_vector = model.lstm(source_x_TNSE)
target_vector = model.lstm(target_x_TNSE)

# %%
from sklearn.manifold import TSNE

df = pd.DataFrame(np.concatenate([source_vector.cpu().detach().numpy(), target_vector.cpu().detach().numpy()]))

tsne_np = TSNE(n_components=2).fit_transform(df)
tsne_df = pd.DataFrame(tsne_np, columns=['component 0', 'component 1'])

# %%
tsne_df_0 = tsne_df.loc[:1000]
tsne_df_1 = tsne_df.loc[1000:]

plt.scatter(tsne_df_0['component 0'], tsne_df_0['component 1'], color='green', label='NELEC', alpha=0.5)
plt.scatter(tsne_df_1['component 0'], tsne_df_1['component 1'], color='black', label='DHW', alpha=0.5)

plt.title('alpha = '+ str(alpha))
plt.xlabel('component 0')
plt.ylabel('component 1')
plt.legend()
plt.show()
