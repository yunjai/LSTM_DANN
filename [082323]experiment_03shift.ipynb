# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.utils.data as data_util
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from torchsummary import summary
from sklearn.metrics import r2_score

# %%
CUDA = torch.cuda.is_available()
print(CUDA)

device = torch.device('cuda:0' if CUDA else 'cpu')
# Out:
# True

# %%
nelec = pd.read_csv('nelec_082323.csv')
dhw = pd.read_csv('dhw_merge.csv')

# %%
nelec = nelec.drop(['YEAR'], axis=1)
dhw = dhw.drop(['YEAR'], axis=1)

# %%
input_nelec = nelec.iloc[:-1,].reset_index(drop=True)
output_nelec = nelec[['n_elec']].iloc[1:].reset_index(drop=True)
output_nelec.columns = ['nelec']

input_dhw = dhw.iloc[:-1,].reset_index(drop=True)
output_dhw = dhw[['DHW']].iloc[1:].reset_index(drop=True)
output_dhw.columns = ['dhw']

nelec = pd.concat([input_nelec, output_nelec], axis=1)
dhw = pd.concat([input_dhw, output_dhw], axis=1)

# %%
scaler_nelec = MinMaxScaler()
scaler_dhw = MinMaxScaler()

scaler_nelec.fit(nelec)
scaler_dhw.fit(dhw)

scaled_nelec = scaler_nelec.transform(nelec)
scaled_dhw = scaler_dhw.transform(dhw)

nelec = pd.DataFrame(scaled_nelec, index=nelec.index, columns=nelec.columns)
dhw = pd.DataFrame(scaled_dhw, index=dhw.index, columns=dhw.columns)

# %%
standard_nelec = int(len(nelec) * 0.7)
standard_dhw = int(len(dhw) * 0.7)

nelec_train = nelec.iloc[:standard_nelec]
nelec_test = nelec.iloc[standard_nelec:].reset_index(drop=True)

dhw_train = dhw.iloc[:standard_dhw]
dhw_test = dhw.iloc[standard_dhw:].reset_index(drop=True)

# %%
nelec_trainx = nelec_train.drop(['nelec'], axis=1)
nelec_trainy = nelec_train[['nelec']]

nelec_testx = nelec_test.drop(['nelec'], axis=1)
nelec_testy = nelec_test[['nelec']]

dhw_trainx = dhw_train.drop(['dhw'], axis=1)
dhw_trainy = dhw_train[['dhw']]

dhw_testx = dhw_test.drop(['dhw'], axis=1)
dhw_testy = dhw_test[['dhw']]

# %%
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-1]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

nelec_trainx, nelec_trainy = buildDataSet(nelec_trainx, nelec_trainy, 7)
nelec_testx, nelec_testy = buildDataSet(nelec_testx, nelec_testy, 7)

dhw_trainx, dhw_trainy = buildDataSet(dhw_trainx, dhw_trainy, 7)
dhw_testx, dhw_testy = buildDataSet(dhw_testx, dhw_testy, 7)

# %%
print(nelec_trainx.shape)
print(nelec_trainy.shape)
print(nelec_testx.shape)
print(nelec_testy.shape)
print(dhw_trainx.shape)
print(dhw_trainy.shape)
print(dhw_testx.shape)
print(dhw_testy.shape)
# Out:
# (20409, 7, 12)
# (20409, 1)
# (8744, 7, 12)
# (8744, 1)
# (20409, 7, 12)
# (20409, 1)
# (8744, 7, 12)
# (8744, 1)

# %%
# 텐서로 변환
nelec_trainx_tensor = torch.FloatTensor(nelec_trainx)
nelec_trainy_tensor = torch.FloatTensor(nelec_trainy)

nelec_testx_tensor = torch.FloatTensor(nelec_testx)
nelec_testy_tensor = torch.FloatTensor(nelec_testy)

dhw_trainx_tensor = torch.FloatTensor(dhw_trainx)
dhw_trainy_tensor = torch.FloatTensor(dhw_trainy)

dhw_testx_tensor = torch.FloatTensor(dhw_testx)
dhw_testy_tensor = torch.FloatTensor(dhw_testy)

# %%
# 텐서 형태로 데이터 정의
nelec_train = TensorDataset(nelec_trainx_tensor, nelec_trainy_tensor)
nelec_test = TensorDataset(nelec_testx_tensor, nelec_testy_tensor)

dhw_train = TensorDataset(dhw_trainx_tensor, dhw_trainy_tensor)
dhw_test = TensorDataset(dhw_testx_tensor, dhw_testy_tensor)

# %%
batch_for_nelec_train = 512
batch_for_nelec_test = 512
batch_for_dhw_train = 512
batch_for_dhw_test = 512

NELEC_train = DataLoader(nelec_train,
                        batch_size=batch_for_nelec_train,
                        shuffle=False,  
                        drop_last=True)

NELEC_test = DataLoader(nelec_test,
                        batch_size=batch_for_nelec_test,
                        shuffle=False,  
                        drop_last=True)

DHW_train = DataLoader(dhw_train,
                        batch_size=batch_for_dhw_train,
                        shuffle=False,  
                        drop_last=True)

DHW_test = DataLoader(dhw_test,
                        batch_size=batch_for_dhw_test,
                        shuffle=False,  
                        drop_last=True)

# %%
# 데이터셋의 개수를 가정하여 변수에 저장
nelec_train_size = len(nelec_train)
nelec_test_size = len(nelec_test)
dhw_train_size = len(dhw_train)
dhw_test_size = len(dhw_test)

# 각 DataLoader에서 생성되는 배치의 개수 계산
nelec_train_batches = nelec_train_size // batch_for_nelec_train
nelec_test_batches = nelec_test_size // batch_for_nelec_test
dhw_train_batches = dhw_train_size // batch_for_dhw_train
dhw_test_batches = dhw_test_size // batch_for_dhw_test

# 결과 출력
print("nelec_train batches:", nelec_train_batches)
print("nelec_test batches:", nelec_test_batches)
print("dhw_train batches:", dhw_train_batches)
print("dhw_test batches:", dhw_test_batches)
# Out:
# nelec_train batches: 39
# nelec_test batches: 17
# dhw_train batches: 39
# dhw_test batches: 17

# %% [markdown]
# # 모델 구조 선언

# %%
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ### GradientReversalLayer

# %%
class GradientReversalFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, x):
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return (grad_output * -1), None

class GradientReversalLayer(torch.nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x):
        return GradientReversalFunction.apply(x)

# %% [markdown]
# ### LSTM for Feature Extraction

# %%
class Swish(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return x * self.sigmoid(x)

# %%
class lstm(nn.Module):
    def __init__(self):
        super(lstm, self).__init__()
        self.lstm1 = nn.LSTM(12, 64, batch_first=True)
        self.bn1 = nn.BatchNorm1d(7)
        self.lstm2 = nn.LSTM(64, 64, batch_first=True)
        self.bn2 = nn.BatchNorm1d(7)
        self.lstm3 = nn.LSTM(64, 64, batch_first=True)
        
        self.fc = nn.Linear(64, 64)
        self.fc2 = nn.Linear(64, 100)
        self.bn3 = nn.BatchNorm1d(7)
        self.bn4 = nn.BatchNorm1d(7)
        self.bn5 = nn.BatchNorm1d(100)
        self.dropout = nn.Dropout(0.5)
        self.swish = Swish()

        
    def forward(self, x):
        x, (h0, c0) = self.lstm1(x)
        x = self.bn1(x)
        #x = self.swish(x)
        #x = self.dropout(x)
        
        x, (h1, c1) = self.lstm2(x, (h0, c0))
        x = self.bn2(x)
        #x = self.swish(x)
        #x = self.dropout(x)
        
        x, _ = self.lstm3(x, (h1, c1))
        x = self.bn3(x)
        #x = self.swish(x)
        x = self.dropout(x)

        return x[:,-1]

# %%
hoxy = lstm()
inputx = torch.randn(512,7,12)
hoxy2 = hoxy(inputx)
print(hoxy2.shape)
# Out:
# torch.Size([512, 64])

# %%
class domain_regression(nn.Module):
    def __init__(self):
        super(domain_regression, self).__init__()
        self.regression_layer1 = nn.Linear(64, 100)
        self.regression_layer2 = nn.Linear(100, 100)
        self.regression_layer3 = nn.Linear(100, 100)
        self.regression_layer4 = nn.Linear(100, 1)
        self.swish = Swish()
        self.bn1 = nn.BatchNorm1d(100)
        self.dropout = nn.Dropout(0.5)
    def forward(self, x):
        x = self.bn1(self.regression_layer1(x))
        x = self.swish(x)#x = self.dropout(self.swish(x))
        x = self.bn1(self.regression_layer2(x))
        x = self.swish(x)#x = self.dropout(self.swish(x))
        x = self.bn1(self.regression_layer3(x))
        x = self.swish(x)#x = self.dropout(self.swish(x))
        x = self.swish(self.regression_layer4(x))
        return x

# %% [markdown]
# ### Domain Classification

# %%
class domain_classfication(nn.Module):
    def __init__(self):
        super(domain_classfication, self).__init__()
        self.classification_layer0 = GradientReversalLayer()
        self.classification_layer1 = nn.Linear(64,100)
        self.classification_layer2 = nn.Linear(100,100)
        self.classification_layer3 = nn.Linear(100,100)
        self.classification_layer4 = nn.Linear(100, 1)
        self.swish = Swish()
        self.bn1 = nn.BatchNorm1d(100)
        self.dropout = nn.Dropout(0.5)
        
    def forward(self, x):
        x = self.classification_layer0(x)
        x = self.bn1(self.classification_layer1(x))
        x = self.swish(x)#x = self.dropout(self.swish(x))
        x = self.bn1(self.classification_layer2(x))
        x = self.swish(x)#x = self.dropout(self.swish(x))
        x = self.bn1(self.classification_layer3(x))
        x = self.swish(x)#x = self.dropout(self.swish(x))
        x = self.classification_layer4(x)#torch.sigmoid(self.classification_layer4(x))
        return x

# %% [markdown]
# ### Set the DANN

# %%
class dann(nn.Module):
    def __init__(self, lstm):
        super(dann, self).__init__()
        self.lstm = lstm
        self.regression = domain_regression()
        self.classification = domain_classfication()
        
    def forward(self, x):
        feature = self.lstm(x)
        reg_output = self.regression(feature)
        cla_output = self.classification(feature)
        
        return reg_output, cla_output

# %% [markdown]
# ### Loss 선언

# %%
class dann_loss(nn.Module):
    def __init__(self):
        super(dann_loss, self).__init__()
        self.reg = nn.L1Loss()
        self.cla = nn.BCEWithLogitsLoss()#nn.BCELoss()
        
    def forward(self, result, reg_real, domain_num, alpha=1):
        reg_output, cla_output = result
        batch_size = reg_output.shape[0]
        cla_target = torch.FloatTensor([domain_num] * batch_size).unsqueeze(1).to(device)
        
        reg_loss = self.reg(reg_output, reg_real)
        cla_loss = self.cla(cla_output, cla_target)
        cla_loss2 = cla_loss * alpha
        
        loss = reg_loss + cla_loss2
        
        return loss, reg_loss, cla_loss2

# %%
my_lstm = lstm().to(device)
model = dann(my_lstm).to(device)
loss_fn = dann_loss().to(device)

# %% [markdown]
# # 훈련

# %%
from torch.optim.lr_scheduler import LinearLR

alpha = 1.0
epochs = 200

model.train() # 훈련 모드 설정

optimizer= torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.01)
scheduler = LinearLR(optimizer, start_factor=1.0, end_factor=0.0, total_iters = epochs * len(NELEC_train))

patience = 100  # Early stopping을 위한 기다리는 최대 epoch 수
best_loss = float('inf')
best_source_loss = float('inf')
best_model_state_dict = None
counter = 10  # Early stopping 카운터

for i in range(1, epochs + 1):
    total_loss = 0
    source_total_loss = 0
    target_total_loss = 0
    src_reg_total = 0
    src_cla_total = 0
    tar_reg_total = 0
    tar_cal_total = 0
    reg_loss_total = 0
    cla_loss_total = 0
    for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
        source_x = source_data[0].to(device)
        source_y = source_data[1].to(device)
        target_x = target_data[0].to(device)
        target_y = target_data[1].to(device)
        #print(source_x.shape)
        #print(source_y.shape)
        #print(target_x.shape)
        #print(target_y.shape)
        # 순전파
        source_result = model(source_x)
        target_result = model(target_x)
        #print(source_result[0].shape)
        #print(target_result[0].shape)
        #print(source_result[1].shape)
        #print(target_result[1].shape)
        # 순전파 loss
        source_loss, source_reg_loss, source_cla_loss = loss_fn(source_result, source_y, 0, alpha=alpha) # 소스 도메인 레이블 0
        target_loss, target_reg_loss, target_cla_loss = loss_fn(target_result, target_y, 1, alpha=alpha) # 타겟 도메인 레이블 1
        
        loss = source_loss + target_loss
        reg_loss = source_reg_loss + target_reg_loss
        cla_loss = source_cla_loss + target_cla_loss
        
        #src_reg_total += source_reg_loss.item()
        #src_cla_total += source_cla_loss.item()
        #tar_reg_total += target_reg_loss.item()
        #tar_cal_total += target_cla_loss.item()
        
        #source_total_loss += source_loss.item()
        #target_total_loss += target_loss.item()
        
        reg_loss_total += reg_loss.item()
        cla_loss_total += cla_loss.item()
        
        total_loss += loss.item()
        
        # 그래디언트 계산 및 업데이트
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()
        
        # Early stopping 확인
    if reg_loss_total / len(NELEC_train) < best_loss:
        best_loss = reg_loss_total / len(NELEC_train)
        best_model_state_dict = model.state_dict()
        counter = 0  # Counter 초기화
    else:
        counter += 1
        if counter >= patience:
            print(f'Early stopping at epoch {i}')
            break

    print('Epoch : %d, Total Avg Loss : %.4f' % (i, total_loss / len(NELEC_train)))     
    #print('Source Avg Loss : %.4f' % (source_total_loss / len(NELEC_train)))
    #print('Target Avg Loss : %.4f' % (target_total_loss / len(NELEC_train)))
    #print('Source Avg reg Loss : %.4f' % (src_reg_total / len(NELEC_train)))
    #print('Target Avg reg Loss : %.4f' % (tar_reg_total / len(NELEC_train)))
    #print('Source Avg cla Loss : %.4f' % (src_cla_total / len(NELEC_train)))
    #print('Target Avg cla Loss : %.4f' % (tar_cal_total / len(NELEC_train)))
    print('Avg Regression Loss : %.4f' % (reg_loss_total / len(NELEC_train)))
    print('Avg Classification Loss : %.4f' % (cla_loss_total / len(NELEC_train)))
    print('')
    
    # source_loss가 가장 낮은 경우 모델 가중치 저장
    if reg_loss / len(NELEC_train) < best_source_loss:
        best_source_loss = reg_loss / len(NELEC_train)
        best_model_state_dict = model.state_dict()

# 최상의 모델을 파일로 저장
if best_model_state_dict is not None:
    torch.save(best_model_state_dict, '0823_03shift.pth')
    #torch.save(model, "model.pth")
# Out:
# Epoch : 1, Total Avg Loss : 1.9270
# Avg Regression Loss : 0.5364
# Avg Classification Loss : 1.3906
#
# Epoch : 2, Total Avg Loss : 1.7763
# Avg Regression Loss : 0.3912
# Avg Classification Loss : 1.3851
#
# Epoch : 3, Total Avg Loss : 1.7443
# Avg Regression Loss : 0.3660
# Avg Classification Loss : 1.3783
#
# Epoch : 4, Total Avg Loss : 1.7449
# Avg Regression Loss : 0.3669
# Avg Classification Loss : 1.3780
#
# Epoch : 5, Total Avg Loss : 1.7317
# Avg Regression Loss : 0.3551
# Avg Classification Loss : 1.3766
#
# Epoch : 6, Total Avg Loss : 1.7394
# Avg Regression Loss : 0.3621
# Avg Classification Loss : 1.3773
#
# Epoch : 7, Total Avg Loss : 1.7482
# Avg Regression Loss : 0.3639
# Avg Classification Loss : 1.3844
#
# Epoch : 8, Total Avg Loss : 1.7410
# Avg Regression Loss : 0.3589
# Avg Classification Loss : 1.3821
#
# Epoch : 9, Total Avg Loss : 1.7390
# Avg Regression Loss : 0.3577
# Avg Classification Loss : 1.3813
#
# Epoch : 10, Total Avg Loss : 1.7115
# Avg Regression Loss : 0.3360
# Avg Classification Loss : 1.3755
#
# Epoch : 11, Total Avg Loss : 1.6943
# Avg Regression Loss : 0.3201
# Avg Classification Loss : 1.3742
#
# Epoch : 12, Total Avg Loss : 1.6927
# Avg Regression Loss : 0.3241
# Avg Classification Loss : 1.3686
#
# Epoch : 13, Total Avg Loss : 1.6695
# Avg Regression Loss : 0.3032
# Avg Classification Loss : 1.3662
#
# Epoch : 14, Total Avg Loss : 1.6642
# Avg Regression Loss : 0.2935
# Avg Classification Loss : 1.3707
#
# Epoch : 15, Total Avg Loss : 1.6537
# Avg Regression Loss : 0.2898
# Avg Classification Loss : 1.3639
#
# Epoch : 16, Total Avg Loss : 1.6773
# Avg Regression Loss : 0.3015
# Avg Classification Loss : 1.3758
#
# Epoch : 17, Total Avg Loss : 1.6568
# Avg Regression Loss : 0.2854
# Avg Classification Loss : 1.3714
#
# Epoch : 18, Total Avg Loss : 1.6294
# Avg Regression Loss : 0.2675
# Avg Classification Loss : 1.3619
#
# Epoch : 19, Total Avg Loss : 1.6351
# Avg Regression Loss : 0.2630
# Avg Classification Loss : 1.3722
#
# Epoch : 20, Total Avg Loss : 1.6244
# Avg Regression Loss : 0.2593
# Avg Classification Loss : 1.3651
#
# Epoch : 21, Total Avg Loss : 1.6303
# Avg Regression Loss : 0.2550
# Avg Classification Loss : 1.3753
#
# Epoch : 22, Total Avg Loss : 1.6282
# Avg Regression Loss : 0.2533
# Avg Classification Loss : 1.3749
#
# Epoch : 23, Total Avg Loss : 1.6066
# Avg Regression Loss : 0.2377
# Avg Classification Loss : 1.3689
#
# Epoch : 24, Total Avg Loss : 1.5949
# Avg Regression Loss : 0.2332
# Avg Classification Loss : 1.3617
#
# Epoch : 25, Total Avg Loss : 1.6107
# Avg Regression Loss : 0.2387
# Avg Classification Loss : 1.3720
#
# Epoch : 26, Total Avg Loss : 1.6050
# Avg Regression Loss : 0.2381
# Avg Classification Loss : 1.3669
#
# Epoch : 27, Total Avg Loss : 1.6010
# Avg Regression Loss : 0.2346
# Avg Classification Loss : 1.3664
#
# Epoch : 28, Total Avg Loss : 1.6038
# Avg Regression Loss : 0.2405
# Avg Classification Loss : 1.3632
#
# Epoch : 29, Total Avg Loss : 1.6160
# Avg Regression Loss : 0.2367
# Avg Classification Loss : 1.3793
#
# Epoch : 30, Total Avg Loss : 1.5995
# Avg Regression Loss : 0.2309
# Avg Classification Loss : 1.3686
#
# Epoch : 31, Total Avg Loss : 1.5987
# Avg Regression Loss : 0.2280
# Avg Classification Loss : 1.3707
#
# Epoch : 32, Total Avg Loss : 1.5764
# Avg Regression Loss : 0.2146
# Avg Classification Loss : 1.3618
#
# Epoch : 33, Total Avg Loss : 1.5712
# Avg Regression Loss : 0.2080
# Avg Classification Loss : 1.3633
#
# Epoch : 34, Total Avg Loss : 1.5603
# Avg Regression Loss : 0.2009
# Avg Classification Loss : 1.3595
#
# Epoch : 35, Total Avg Loss : 1.5611
# Avg Regression Loss : 0.2088
# Avg Classification Loss : 1.3523
#
# Epoch : 36, Total Avg Loss : 1.5613
# Avg Regression Loss : 0.2043
# Avg Classification Loss : 1.3570
#
# Epoch : 37, Total Avg Loss : 1.5455
# Avg Regression Loss : 0.1991
# Avg Classification Loss : 1.3464
#
# Epoch : 38, Total Avg Loss : 1.5495
# Avg Regression Loss : 0.2039
# Avg Classification Loss : 1.3456
#
# Epoch : 39, Total Avg Loss : 1.5687
# Avg Regression Loss : 0.2252
# Avg Classification Loss : 1.3435
#
# Epoch : 40, Total Avg Loss : 1.5290
# Avg Regression Loss : 0.2007
# Avg Classification Loss : 1.3283
#
# Epoch : 41, Total Avg Loss : 1.5392
# Avg Regression Loss : 0.2081
# Avg Classification Loss : 1.3311
#
# Epoch : 42, Total Avg Loss : 1.5149
# Avg Regression Loss : 0.1921
# Avg Classification Loss : 1.3228
#
# Epoch : 43, Total Avg Loss : 1.5291
# Avg Regression Loss : 0.2057
# Avg Classification Loss : 1.3234
#
# Epoch : 44, Total Avg Loss : 1.6140
# Avg Regression Loss : 0.2477
# Avg Classification Loss : 1.3663
#
# Epoch : 45, Total Avg Loss : 1.5747
# Avg Regression Loss : 0.2197
# Avg Classification Loss : 1.3549
#
# Epoch : 46, Total Avg Loss : 1.5376
# Avg Regression Loss : 0.2070
# Avg Classification Loss : 1.3305
#
# Epoch : 47, Total Avg Loss : 1.5336
# Avg Regression Loss : 0.2190
# Avg Classification Loss : 1.3146
#
# Epoch : 48, Total Avg Loss : 1.5508
# Avg Regression Loss : 0.2285
# Avg Classification Loss : 1.3223
#
# Epoch : 49, Total Avg Loss : 1.6309
# Avg Regression Loss : 0.2535
# Avg Classification Loss : 1.3775
#
# Epoch : 50, Total Avg Loss : 1.6218
# Avg Regression Loss : 0.2524
# Avg Classification Loss : 1.3695
#
# Epoch : 51, Total Avg Loss : 1.5365
# Avg Regression Loss : 0.2111
# Avg Classification Loss : 1.3254
#
# Epoch : 52, Total Avg Loss : 1.5727
# Avg Regression Loss : 0.2296
# Avg Classification Loss : 1.3430
#
# Epoch : 53, Total Avg Loss : 1.6803
# Avg Regression Loss : 0.2964
# Avg Classification Loss : 1.3839
#
# Epoch : 54, Total Avg Loss : 1.5880
# Avg Regression Loss : 0.2538
# Avg Classification Loss : 1.3343
#
# Epoch : 55, Total Avg Loss : 1.5289
# Avg Regression Loss : 0.2172
# Avg Classification Loss : 1.3117
#
# Epoch : 56, Total Avg Loss : 1.4964
# Avg Regression Loss : 0.2017
# Avg Classification Loss : 1.2947
#
# Epoch : 57, Total Avg Loss : 1.5094
# Avg Regression Loss : 0.2189
# Avg Classification Loss : 1.2905
#
# Epoch : 58, Total Avg Loss : 1.4782
# Avg Regression Loss : 0.1965
# Avg Classification Loss : 1.2817
#
# Epoch : 59, Total Avg Loss : 1.4683
# Avg Regression Loss : 0.1947
# Avg Classification Loss : 1.2736
#
# Epoch : 60, Total Avg Loss : 1.4538
# Avg Regression Loss : 0.1894
# Avg Classification Loss : 1.2644
#
# Epoch : 61, Total Avg Loss : 1.4586
# Avg Regression Loss : 0.1886
# Avg Classification Loss : 1.2699
#
# Epoch : 62, Total Avg Loss : 1.6957
# Avg Regression Loss : 0.3193
# Avg Classification Loss : 1.3765
#
# Epoch : 63, Total Avg Loss : 1.7099
# Avg Regression Loss : 0.3083
# Avg Classification Loss : 1.4016
#
# Epoch : 64, Total Avg Loss : 1.6283
# Avg Regression Loss : 0.2536
# Avg Classification Loss : 1.3747
#
# Epoch : 65, Total Avg Loss : 1.5509
# Avg Regression Loss : 0.2270
# Avg Classification Loss : 1.3239
#
# Epoch : 66, Total Avg Loss : 1.6205
# Avg Regression Loss : 0.2442
# Avg Classification Loss : 1.3763
#
# Epoch : 67, Total Avg Loss : 1.6045
# Avg Regression Loss : 0.2323
# Avg Classification Loss : 1.3723
#
# Epoch : 68, Total Avg Loss : 1.6141
# Avg Regression Loss : 0.2349
# Avg Classification Loss : 1.3791
#
# Epoch : 69, Total Avg Loss : 1.5690
# Avg Regression Loss : 0.2126
# Avg Classification Loss : 1.3564
#
# Epoch : 70, Total Avg Loss : 1.5703
# Avg Regression Loss : 0.2148
# Avg Classification Loss : 1.3556
#
# Epoch : 71, Total Avg Loss : 1.5892
# Avg Regression Loss : 0.2239
# Avg Classification Loss : 1.3653
#
# Epoch : 72, Total Avg Loss : 1.5709
# Avg Regression Loss : 0.2248
# Avg Classification Loss : 1.3461
#
# Epoch : 73, Total Avg Loss : 1.5775
# Avg Regression Loss : 0.2265
# Avg Classification Loss : 1.3510
#
# Epoch : 74, Total Avg Loss : 1.5550
# Avg Regression Loss : 0.2140
# Avg Classification Loss : 1.3410
#
# Epoch : 75, Total Avg Loss : 1.5933
# Avg Regression Loss : 0.2368
# Avg Classification Loss : 1.3564
#
# Epoch : 76, Total Avg Loss : 1.6107
# Avg Regression Loss : 0.2464
# Avg Classification Loss : 1.3643
#
# Epoch : 77, Total Avg Loss : 1.5836
# Avg Regression Loss : 0.2268
# Avg Classification Loss : 1.3568
#
# Epoch : 78, Total Avg Loss : 1.5868
# Avg Regression Loss : 0.2198
# Avg Classification Loss : 1.3670
#
# Epoch : 79, Total Avg Loss : 1.5804
# Avg Regression Loss : 0.2198
# Avg Classification Loss : 1.3606
#
# Epoch : 80, Total Avg Loss : 1.5952
# Avg Regression Loss : 0.2322
# Avg Classification Loss : 1.3630
#
# Epoch : 81, Total Avg Loss : 1.5663
# Avg Regression Loss : 0.2177
# Avg Classification Loss : 1.3486
#
# Epoch : 82, Total Avg Loss : 1.5632
# Avg Regression Loss : 0.2190
# Avg Classification Loss : 1.3442
#
# Epoch : 83, Total Avg Loss : 1.5939
# Avg Regression Loss : 0.2362
# Avg Classification Loss : 1.3577
#
# Epoch : 84, Total Avg Loss : 1.5478
# Avg Regression Loss : 0.1997
# Avg Classification Loss : 1.3481
#
# Epoch : 85, Total Avg Loss : 1.5665
# Avg Regression Loss : 0.2142
# Avg Classification Loss : 1.3523
#
# Epoch : 86, Total Avg Loss : 1.5472
# Avg Regression Loss : 0.2036
# Avg Classification Loss : 1.3436
#
# Epoch : 87, Total Avg Loss : 1.5811
# Avg Regression Loss : 0.2265
# Avg Classification Loss : 1.3546
#
# Epoch : 88, Total Avg Loss : 1.5590
# Avg Regression Loss : 0.2100
# Avg Classification Loss : 1.3490
#
# Epoch : 89, Total Avg Loss : 1.5901
# Avg Regression Loss : 0.2306
# Avg Classification Loss : 1.3595
#
# Epoch : 90, Total Avg Loss : 1.5524
# Avg Regression Loss : 0.2092
# Avg Classification Loss : 1.3433
#
# Epoch : 91, Total Avg Loss : 1.5591
# Avg Regression Loss : 0.2118
# Avg Classification Loss : 1.3473
#
# Epoch : 92, Total Avg Loss : 1.5841
# Avg Regression Loss : 0.2211
# Avg Classification Loss : 1.3630
#
# Epoch : 93, Total Avg Loss : 1.6277
# Avg Regression Loss : 0.2559
# Avg Classification Loss : 1.3718
#
# Epoch : 94, Total Avg Loss : 1.6626
# Avg Regression Loss : 0.2844
# Avg Classification Loss : 1.3782
#
# Epoch : 95, Total Avg Loss : 1.5955
# Avg Regression Loss : 0.2434
# Avg Classification Loss : 1.3520
#
# Epoch : 96, Total Avg Loss : 1.6083
# Avg Regression Loss : 0.2358
# Avg Classification Loss : 1.3725
#
# Epoch : 97, Total Avg Loss : 1.6053
# Avg Regression Loss : 0.2342
# Avg Classification Loss : 1.3711
#
# Epoch : 98, Total Avg Loss : 1.5835
# Avg Regression Loss : 0.2207
# Avg Classification Loss : 1.3628
#
# Epoch : 99, Total Avg Loss : 1.5995
# Avg Regression Loss : 0.2305
# Avg Classification Loss : 1.3691
#
# Epoch : 100, Total Avg Loss : 1.5772
# Avg Regression Loss : 0.2204
# Avg Classification Loss : 1.3568
#
# Epoch : 101, Total Avg Loss : 1.5568
# Avg Regression Loss : 0.2077
# Avg Classification Loss : 1.3491
#
# Epoch : 102, Total Avg Loss : 1.5284
# Avg Regression Loss : 0.1869
# Avg Classification Loss : 1.3414
#
# Epoch : 103, Total Avg Loss : 1.5462
# Avg Regression Loss : 0.1996
# Avg Classification Loss : 1.3466
#
# Epoch : 104, Total Avg Loss : 1.5731
# Avg Regression Loss : 0.2140
# Avg Classification Loss : 1.3591
#
# Epoch : 105, Total Avg Loss : 1.5357
# Avg Regression Loss : 0.1959
# Avg Classification Loss : 1.3398
#
# Epoch : 106, Total Avg Loss : 1.5729
# Avg Regression Loss : 0.2235
# Avg Classification Loss : 1.3494
#
# Epoch : 107, Total Avg Loss : 1.5414
# Avg Regression Loss : 0.2032
# Avg Classification Loss : 1.3382
#
# Epoch : 108, Total Avg Loss : 1.5291
# Avg Regression Loss : 0.1921
# Avg Classification Loss : 1.3371
#
# Epoch : 109, Total Avg Loss : 1.5463
# Avg Regression Loss : 0.2048
# Avg Classification Loss : 1.3415
#
# Epoch : 110, Total Avg Loss : 1.5584
# Avg Regression Loss : 0.2154
# Avg Classification Loss : 1.3430
#
# Epoch : 111, Total Avg Loss : 1.5181
# Avg Regression Loss : 0.1876
# Avg Classification Loss : 1.3305
#
# Epoch : 112, Total Avg Loss : 1.5253
# Avg Regression Loss : 0.1928
# Avg Classification Loss : 1.3324
#
# Epoch : 113, Total Avg Loss : 1.5337
# Avg Regression Loss : 0.1962
# Avg Classification Loss : 1.3375
#
# Epoch : 114, Total Avg Loss : 1.5207
# Avg Regression Loss : 0.1869
# Avg Classification Loss : 1.3338
#
# Epoch : 115, Total Avg Loss : 1.5623
# Avg Regression Loss : 0.2121
# Avg Classification Loss : 1.3503
#
# Epoch : 116, Total Avg Loss : 1.5454
# Avg Regression Loss : 0.2052
# Avg Classification Loss : 1.3402
#
# Epoch : 117, Total Avg Loss : 1.5473
# Avg Regression Loss : 0.2018
# Avg Classification Loss : 1.3455
#
# Epoch : 118, Total Avg Loss : 1.5344
# Avg Regression Loss : 0.1969
# Avg Classification Loss : 1.3375
#
# Epoch : 119, Total Avg Loss : 1.5357
# Avg Regression Loss : 0.1962
# Avg Classification Loss : 1.3395
#
# Epoch : 120, Total Avg Loss : 1.5392
# Avg Regression Loss : 0.1992
# Avg Classification Loss : 1.3400
#
# Epoch : 121, Total Avg Loss : 1.5436
# Avg Regression Loss : 0.1922
# Avg Classification Loss : 1.3514
#
# Epoch : 122, Total Avg Loss : 1.5953
# Avg Regression Loss : 0.2261
# Avg Classification Loss : 1.3693
#
# Epoch : 123, Total Avg Loss : 1.5679
# Avg Regression Loss : 0.2102
# Avg Classification Loss : 1.3577
#
# Epoch : 124, Total Avg Loss : 1.5688
# Avg Regression Loss : 0.2058
# Avg Classification Loss : 1.3630
#
# Epoch : 125, Total Avg Loss : 1.5378
# Avg Regression Loss : 0.1909
# Avg Classification Loss : 1.3468
#
# Epoch : 126, Total Avg Loss : 1.5516
# Avg Regression Loss : 0.1999
# Avg Classification Loss : 1.3517
#
# Epoch : 127, Total Avg Loss : 1.5375
# Avg Regression Loss : 0.1903
# Avg Classification Loss : 1.3472
#
# Epoch : 128, Total Avg Loss : 1.5756
# Avg Regression Loss : 0.2077
# Avg Classification Loss : 1.3679
#
# Epoch : 129, Total Avg Loss : 1.5426
# Avg Regression Loss : 0.1950
# Avg Classification Loss : 1.3476
#
# Epoch : 130, Total Avg Loss : 1.5496
# Avg Regression Loss : 0.2045
# Avg Classification Loss : 1.3451
#
# Epoch : 131, Total Avg Loss : 1.5495
# Avg Regression Loss : 0.1980
# Avg Classification Loss : 1.3515
#
# Epoch : 132, Total Avg Loss : 1.5161
# Avg Regression Loss : 0.1768
# Avg Classification Loss : 1.3393
#
# Epoch : 133, Total Avg Loss : 1.5340
# Avg Regression Loss : 0.1901
# Avg Classification Loss : 1.3439
#
# Epoch : 134, Total Avg Loss : 1.5476
# Avg Regression Loss : 0.1987
# Avg Classification Loss : 1.3489
#
# Epoch : 135, Total Avg Loss : 1.5192
# Avg Regression Loss : 0.1816
# Avg Classification Loss : 1.3376
#
# Epoch : 136, Total Avg Loss : 1.5391
# Avg Regression Loss : 0.1999
# Avg Classification Loss : 1.3392
#
# Epoch : 137, Total Avg Loss : 1.5591
# Avg Regression Loss : 0.2109
# Avg Classification Loss : 1.3482
#
# Epoch : 138, Total Avg Loss : 1.5215
# Avg Regression Loss : 0.1849
# Avg Classification Loss : 1.3367
#
# Epoch : 139, Total Avg Loss : 1.5391
# Avg Regression Loss : 0.1935
# Avg Classification Loss : 1.3456
#
# Epoch : 140, Total Avg Loss : 1.5278
# Avg Regression Loss : 0.1813
# Avg Classification Loss : 1.3465
#
# Epoch : 141, Total Avg Loss : 1.5469
# Avg Regression Loss : 0.1964
# Avg Classification Loss : 1.3504
#
# Epoch : 142, Total Avg Loss : 1.5418
# Avg Regression Loss : 0.1956
# Avg Classification Loss : 1.3462
#
# Epoch : 143, Total Avg Loss : 1.5402
# Avg Regression Loss : 0.1936
# Avg Classification Loss : 1.3466
#
# Epoch : 144, Total Avg Loss : 1.5371
# Avg Regression Loss : 0.1907
# Avg Classification Loss : 1.3465
#
# Epoch : 145, Total Avg Loss : 1.5243
# Avg Regression Loss : 0.1821
# Avg Classification Loss : 1.3422
#
# Epoch : 146, Total Avg Loss : 1.5160
# Avg Regression Loss : 0.1805
# Avg Classification Loss : 1.3355
#
# Epoch : 147, Total Avg Loss : 1.5183
# Avg Regression Loss : 0.1774
# Avg Classification Loss : 1.3409
#
# Epoch : 148, Total Avg Loss : 1.5136
# Avg Regression Loss : 0.1761
# Avg Classification Loss : 1.3374
#
# Epoch : 149, Total Avg Loss : 1.5278
# Avg Regression Loss : 0.1851
# Avg Classification Loss : 1.3427
#
# Epoch : 150, Total Avg Loss : 1.5079
# Avg Regression Loss : 0.1755
# Avg Classification Loss : 1.3324
#
# Epoch : 151, Total Avg Loss : 1.5140
# Avg Regression Loss : 0.1769
# Avg Classification Loss : 1.3371
#
# Epoch : 152, Total Avg Loss : 1.5087
# Avg Regression Loss : 0.1766
# Avg Classification Loss : 1.3321
#
# Epoch : 153, Total Avg Loss : 1.5133
# Avg Regression Loss : 0.1768
# Avg Classification Loss : 1.3365
#
# Epoch : 154, Total Avg Loss : 1.5043
# Avg Regression Loss : 0.1705
# Avg Classification Loss : 1.3338
#
# Epoch : 155, Total Avg Loss : 1.5081
# Avg Regression Loss : 0.1724
# Avg Classification Loss : 1.3357
#
# Epoch : 156, Total Avg Loss : 1.5183
# Avg Regression Loss : 0.1794
# Avg Classification Loss : 1.3389
#
# Epoch : 157, Total Avg Loss : 1.5380
# Avg Regression Loss : 0.1833
# Avg Classification Loss : 1.3547
#
# Epoch : 158, Total Avg Loss : 1.5657
# Avg Regression Loss : 0.1951
# Avg Classification Loss : 1.3706
#
# Epoch : 159, Total Avg Loss : 1.5065
# Avg Regression Loss : 0.1651
# Avg Classification Loss : 1.3414
#
# Epoch : 160, Total Avg Loss : 1.5065
# Avg Regression Loss : 0.1667
# Avg Classification Loss : 1.3397
#
# Epoch : 161, Total Avg Loss : 1.5085
# Avg Regression Loss : 0.1725
# Avg Classification Loss : 1.3360
#
# Epoch : 162, Total Avg Loss : 1.4992
# Avg Regression Loss : 0.1621
# Avg Classification Loss : 1.3371
#
# Epoch : 163, Total Avg Loss : 1.5073
# Avg Regression Loss : 0.1664
# Avg Classification Loss : 1.3409
#
# Epoch : 164, Total Avg Loss : 1.4930
# Avg Regression Loss : 0.1563
# Avg Classification Loss : 1.3367
#
# Epoch : 165, Total Avg Loss : 1.5206
# Avg Regression Loss : 0.1740
# Avg Classification Loss : 1.3467
#
# Epoch : 166, Total Avg Loss : 1.5035
# Avg Regression Loss : 0.1674
# Avg Classification Loss : 1.3360
#
# Epoch : 167, Total Avg Loss : 1.4920
# Avg Regression Loss : 0.1597
# Avg Classification Loss : 1.3324
#
# Epoch : 168, Total Avg Loss : 1.4933
# Avg Regression Loss : 0.1603
# Avg Classification Loss : 1.3330
#
# Epoch : 169, Total Avg Loss : 1.4861
# Avg Regression Loss : 0.1588
# Avg Classification Loss : 1.3272
#
# Epoch : 170, Total Avg Loss : 1.5016
# Avg Regression Loss : 0.1670
# Avg Classification Loss : 1.3346
#
# Epoch : 171, Total Avg Loss : 1.5142
# Avg Regression Loss : 0.1748
# Avg Classification Loss : 1.3394
#
# Epoch : 172, Total Avg Loss : 1.4757
# Avg Regression Loss : 0.1524
# Avg Classification Loss : 1.3233
#
# Epoch : 173, Total Avg Loss : 1.4675
# Avg Regression Loss : 0.1441
# Avg Classification Loss : 1.3234
#
# Epoch : 174, Total Avg Loss : 1.4917
# Avg Regression Loss : 0.1601
# Avg Classification Loss : 1.3316
#
# Epoch : 175, Total Avg Loss : 1.5201
# Avg Regression Loss : 0.1713
# Avg Classification Loss : 1.3488
#
# Epoch : 176, Total Avg Loss : 1.5581
# Avg Regression Loss : 0.1833
# Avg Classification Loss : 1.3748
#
# Epoch : 177, Total Avg Loss : 1.5761
# Avg Regression Loss : 0.1958
# Avg Classification Loss : 1.3803
#
# Epoch : 178, Total Avg Loss : 1.5407
# Avg Regression Loss : 0.1778
# Avg Classification Loss : 1.3629
#
# Epoch : 179, Total Avg Loss : 1.5452
# Avg Regression Loss : 0.1759
# Avg Classification Loss : 1.3693
#
# Epoch : 180, Total Avg Loss : 1.5241
# Avg Regression Loss : 0.1637
# Avg Classification Loss : 1.3605
#
# Epoch : 181, Total Avg Loss : 1.5113
# Avg Regression Loss : 0.1567
# Avg Classification Loss : 1.3546
#
# Epoch : 182, Total Avg Loss : 1.5206
# Avg Regression Loss : 0.1645
# Avg Classification Loss : 1.3561
#
# Epoch : 183, Total Avg Loss : 1.5040
# Avg Regression Loss : 0.1561
# Avg Classification Loss : 1.3478
#
# Epoch : 184, Total Avg Loss : 1.5057
# Avg Regression Loss : 0.1588
# Avg Classification Loss : 1.3469
#
# Epoch : 185, Total Avg Loss : 1.4915
# Avg Regression Loss : 0.1464
# Avg Classification Loss : 1.3451
#
# Epoch : 186, Total Avg Loss : 1.5095
# Avg Regression Loss : 0.1568
# Avg Classification Loss : 1.3528
#
# Epoch : 187, Total Avg Loss : 1.4928
# Avg Regression Loss : 0.1527
# Avg Classification Loss : 1.3401
#
# Epoch : 188, Total Avg Loss : 1.4950
# Avg Regression Loss : 0.1495
# Avg Classification Loss : 1.3455
#
# Epoch : 189, Total Avg Loss : 1.4913
# Avg Regression Loss : 0.1471
# Avg Classification Loss : 1.3442
#
# Epoch : 190, Total Avg Loss : 1.4841
# Avg Regression Loss : 0.1417
# Avg Classification Loss : 1.3423
#
# Epoch : 191, Total Avg Loss : 1.4826
# Avg Regression Loss : 0.1453
# Avg Classification Loss : 1.3374
#
# Epoch : 192, Total Avg Loss : 1.4843
# Avg Regression Loss : 0.1416
# Avg Classification Loss : 1.3426
#
# Epoch : 193, Total Avg Loss : 1.4890
# Avg Regression Loss : 0.1474
# Avg Classification Loss : 1.3416
#
# Epoch : 194, Total Avg Loss : 1.4751
# Avg Regression Loss : 0.1410
# Avg Classification Loss : 1.3342
#
# Epoch : 195, Total Avg Loss : 1.4778
# Avg Regression Loss : 0.1434
# Avg Classification Loss : 1.3343
#
# Epoch : 196, Total Avg Loss : 1.4795
# Avg Regression Loss : 0.1423
# Avg Classification Loss : 1.3372
#
# Epoch : 197, Total Avg Loss : 1.4761
# Avg Regression Loss : 0.1388
# Avg Classification Loss : 1.3373
#
# Epoch : 198, Total Avg Loss : 1.4774
# Avg Regression Loss : 0.1394
# Avg Classification Loss : 1.3380
#
# Epoch : 199, Total Avg Loss : 1.4746
# Avg Regression Loss : 0.1384
# Avg Classification Loss : 1.3362
#
# Epoch : 200, Total Avg Loss : 1.4736
# Avg Regression Loss : 0.1361
# Avg Classification Loss : 1.3375

# %%
# from torchinfo import summary

# summary(model, (512,3,12))

# %% [markdown]
# # train 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('0823_03shift.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []
s_d_pred = []
t_d_pred = []

for step, (source_data, target_data) in enumerate(zip(NELEC_train, DHW_train)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    source_domain_label_pred, source_pred = best_source_model2(sourcex)
    target_domain_label_pred, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())
    s_d_pred.extend(source_domain_label_pred.detach().cpu().numpy())
    t_d_pred.extend(target_domain_label_pred.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: -0.6745716310964338
# TARGET R2 Score: -0.8383228075563445

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
np.max(s_pred)
# Out:
# 0.93454367

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# # test 데이터로 테스트

# %%
# 저장된 최상의 소스 모델 불러오기
best_source_model2 = dann(my_lstm).to(device)
best_source_model2.load_state_dict(torch.load('0823_03shift.pth'))
best_source_model2.eval()  # 평가 모드로 설정

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []


for step, (source_data, target_data) in enumerate(zip(NELEC_test, DHW_test)):
    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)

    # 저장된 최상의 모델로 예측
    _, source_pred = best_source_model2(sourcex)
    _, target_pred = best_source_model2(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: -0.43028694482508856
# TARGET R2 Score: -1.6389126318054732

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# ### Domain Embedding Space 시각화

# %%
# 가장 앞 batch의 250개씩의 데이터만 샘플링
source_tsne = DataLoader(nelec_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

target_tsne = DataLoader(dhw_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

source_tsne2 = next(iter(source_tsne))
target_tsne2 = next(iter(target_tsne))

source_x_TNSE = source_tsne2[0].to(device)
source_y_TNSE = source_tsne2[1].to(device)

target_x_TNSE = target_tsne2[0].to(device)
target_y_TNSE = target_tsne2[1].to(device)

# 학습된 모델의 LSTM 부분만 활용 (100차원 임베딩 벡터를 받아오는 과정)
source_vector = model.lstm(source_x_TNSE)
target_vector = model.lstm(target_x_TNSE)

# %%
from sklearn.manifold import TSNE

df = pd.DataFrame(np.concatenate([source_vector.cpu().detach().numpy(), target_vector.cpu().detach().numpy()]))

tsne_np = TSNE(n_components=2).fit_transform(df)
tsne_df = pd.DataFrame(tsne_np, columns=['component 0', 'component 1'])

# %%
tsne_df_0 = tsne_df.loc[:1000]
tsne_df_1 = tsne_df.loc[1000:]

plt.scatter(tsne_df_0['component 0'], tsne_df_0['component 1'], color='green', label='NELEC', alpha=0.5)
plt.scatter(tsne_df_1['component 0'], tsne_df_1['component 1'], color='black', label='DHW', alpha=0.5)

plt.title('alpha = '+ str(alpha))
plt.xlabel('component 0')
plt.ylabel('component 1')
plt.legend()
plt.show()
