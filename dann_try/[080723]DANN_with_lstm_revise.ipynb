# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision.transforms as transforms
import torch.utils.data as data_util
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import MinMaxScaler
#from torchinfo import summary
from torchsummary import summary

# %%
CUDA = torch.cuda.is_available()
print(CUDA)

device = torch.device('cuda:0' if CUDA else 'cpu')
# Out:
# True

# %%
elec = pd.read_csv('elec_merge.csv')
nelec = pd.read_csv('n_elec_merge.csv')
dhw = pd.read_csv('dhw_merge.csv')

# %%
scaler_nelec = MinMaxScaler()
scaler_elec = MinMaxScaler()
scaler_dhw = MinMaxScaler()

scaler_nelec.fit(nelec)
scaler_elec.fit(elec)
scaler_dhw.fit(dhw)

scaled_nelec = scaler_nelec.transform(nelec)
scaled_elec = scaler_elec.transform(elec)
scaled_dhw = scaler_dhw.transform(dhw)

new_nelec = pd.DataFrame(scaled_nelec, index=nelec.index, columns=nelec.columns)
new_elec = pd.DataFrame(scaled_elec, index=elec.index, columns=elec.columns)
new_dhw = pd.DataFrame(scaled_dhw, index=dhw.index, columns=dhw.columns)

# %%
input_nelec = new_nelec.iloc[:-1,].reset_index(drop=True)
output_nelec = new_nelec[['n_elec']].iloc[1:].reset_index(drop=True)
output_nelec.columns = ['nelec']

input_elec = new_elec.iloc[:-1,].reset_index(drop=True)
output_elec = new_elec[['ELEC']].iloc[1:].reset_index(drop=True)
output_elec.columns = ['elec']

input_dhw = new_dhw.iloc[:-1,].reset_index(drop=True)
output_dhw = new_dhw[['DHW']].iloc[1:].reset_index(drop=True)
output_dhw.columns = ['dhw']

nelec = pd.concat([input_nelec, output_nelec], axis=1)
elec = pd.concat([input_elec, output_elec], axis=1)
dhw = pd.concat([input_dhw, output_dhw], axis=1)

# %%
standard_nelec = int(len(nelec) * 0.7)
standard_elec = int(len(elec) * 0.7)
standard_dhw = int(len(dhw) * 0.7)

nelec_train = nelec.iloc[:standard_nelec]
nelec_test = nelec.iloc[standard_nelec:].reset_index(drop=True)

elec_train = elec.iloc[:standard_elec]
elec_test = elec.iloc[standard_elec:].reset_index(drop=True)

dhw_train = dhw.iloc[:standard_dhw]
dhw_test = dhw.iloc[standard_dhw:].reset_index(drop=True)

# %%
nelec_trainx = nelec_train.drop(['nelec'], axis=1)
nelec_trainy = nelec_train[['nelec']]

nelec_testx = nelec_test.drop(['nelec'], axis=1)
nelec_testy = nelec_test[['nelec']]

elec_trainx = elec_train.drop(['elec'], axis=1)
elec_trainy = elec_train[['elec']]

elec_testx = elec_test.drop(['elec'], axis=1)
elec_testy = elec_test[['elec']]

dhw_trainx = dhw_train.drop(['dhw'], axis=1)
dhw_trainy = dhw_train[['dhw']]

dhw_testx = dhw_test.drop(['dhw'], axis=1)
dhw_testy = dhw_test[['dhw']]

# %%
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-1]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

nelec_trainx, nelec_trainy = buildDataSet(nelec_trainx, nelec_trainy, 3)
nelec_testx, nelec_testy = buildDataSet(nelec_testx, nelec_testy, 3)

elec_trainx, elec_trainy = buildDataSet(elec_trainx, elec_trainy, 3)
elec_testx, elec_testy = buildDataSet(elec_testx, elec_testy, 3)

dhw_trainx, dhw_trainy = buildDataSet(dhw_trainx, dhw_trainy, 3)
dhw_testx, dhw_testy = buildDataSet(dhw_testx, dhw_testy, 3)

# %%
print(nelec_trainx.shape)
print(nelec_trainy.shape)
print(nelec_testx.shape)
print(nelec_testy.shape)
print(elec_trainx.shape)
print(elec_trainy.shape)
print(elec_testx.shape)
print(elec_testy.shape)
#print(dhw_trainx.shape)
#print(dhw_trainy.shape)
#print(dhw_testx.shape)
#print(dhw_testy.shape)
# Out:
# (20413, 3, 13)
# (20413, 1)
# (8748, 3, 13)
# (8748, 1)
# (2988, 3, 13)
# (2988, 1)
# (1279, 3, 13)
# (1279, 1)

# %%
# 텐서로 변환
nelec_trainx_tensor = torch.FloatTensor(nelec_trainx)
nelec_trainy_tensor = torch.FloatTensor(nelec_trainy)

nelec_testx_tensor = torch.FloatTensor(nelec_testx)
nelec_testy_tensor = torch.FloatTensor(nelec_testy)

elec_trainx_tensor = torch.FloatTensor(elec_trainx)
elec_trainy_tensor = torch.FloatTensor(elec_trainy)

elec_testx_tensor = torch.FloatTensor(elec_testx)
elec_testy_tensor = torch.FloatTensor(elec_testy)

dhw_trainx_tensor = torch.FloatTensor(dhw_trainx)
dhw_trainy_tensor = torch.FloatTensor(dhw_trainy)

dhw_testx_tensor = torch.FloatTensor(dhw_testx)
dhw_testy_tensor = torch.FloatTensor(dhw_testy)

# %%
# 텐서 형태로 데이터 정의
nelec_train = TensorDataset(nelec_trainx_tensor, nelec_trainy_tensor)
nelec_test = TensorDataset(nelec_testx_tensor, nelec_testy_tensor)
elec_train = TensorDataset(elec_trainx_tensor, elec_trainy_tensor)
elec_test = TensorDataset(elec_testx_tensor, elec_testy_tensor)
dhw_train = TensorDataset(dhw_trainx_tensor, dhw_trainy_tensor)
dhw_test = TensorDataset(dhw_testx_tensor, dhw_testy_tensor)

# %%
batch_for_source = 512
batch_for_target = 75
source_train = DataLoader(nelec_train,
                        batch_size=batch_for_source,
                        shuffle=False,  
                        drop_last=True)

source_test = DataLoader(nelec_test,
                        batch_size=batch_for_source,
                        shuffle=False,  
                        drop_last=True)

target_train = DataLoader(elec_train,
                        batch_size=batch_for_target,
                        shuffle=False,  
                        drop_last=True)

target_test = DataLoader(elec_test,
                        batch_size=batch_for_target,
                        shuffle=False,  
                        drop_last=True)

# %%
# 데이터셋의 개수를 가정하여 변수에 저장
nelec_train_size = len(nelec_train)
nelec_test_size = len(nelec_test)
elec_train_size = len(elec_train)
elec_test_size = len(elec_test)

# 각 DataLoader에서 생성되는 배치의 개수 계산
source_train_batches = nelec_train_size // batch_for_source
source_test_batches = nelec_test_size // batch_for_source
target_train_batches = elec_train_size // batch_for_target
target_test_batches = elec_test_size // batch_for_target

# 결과 출력
print("source_train batches:", source_train_batches)
print("source_test batches:", source_test_batches)
print("target_train batches:", target_train_batches)
print("target_test batches:", target_test_batches)
# Out:
# source_train batches: 39
# source_test batches: 17
# target_train batches: 39
# target_test batches: 17

# %% [markdown]
# # 모델 구조 선언

# %%
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ### GradientReversalLayer

# %%
# class GradientReversalLayer(torch.autograd.Function):
#     def forward(self, x):
#         return x.view_as(x)

#     def backward(self, grad_output):
#         return (grad_output * -1)

class GradientReversalFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, x):
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        return (grad_output * -1), None

class GradientReversalLayer(torch.nn.Module):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    def forward(self, x):
        return GradientReversalFunction.apply(x)

# %% [markdown]
# ### LSTM for Feature Extraction

# %%
# class lstm(nn.Module):
#     def __init__(self, input_dim, hidden_dim, seq_len, output_dim, layers):
#         super(lstm, self).__init__()
#         self.hidden_dim = hidden_dim
#         self.seq_len = seq_len
#         self.output_dim = output_dim
#         self.layers = layers
#         self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=layers, batch_first=True)
#         self.fc = nn.Linear(hidden_dim, output_dim, bias=False)
#         self.dropout = nn.Dropout(0.5)
#         self.gelu = nn.GELU()
        
#     def reset_hidden_state(self):
#         self.hidden(
#             torch.zeros(self.layers, self.seq_len, self.hidden_dim), # hidden state
#             torch.zeros(self.layers, self.seq_len, self.hidden_dim) # cell state
#         )
        
#     def forward(self, x):
#         x, _ = self.lstm(x)
#         x = self.gelu(x)
#         x = self.fc(x[:, -1, :]) #LSTM 레이어의 마지막 타임 스텝에 해당하는 은닉 상태
#         x = self.dropout(x)
#         x = x.view(-1, 64)
#         return x

# %%
class lstm(nn.Module):
    def __init__(self):
        super(lstm, self).__init__()
        self.lstm1 = nn.LSTM(13, 64, batch_first=True)
        self.bn1 = nn.BatchNorm1d(3)
        self.lstm2 = nn.LSTM(64, 64, batch_first=True)
        self.bn2 = nn.BatchNorm1d(3)
        self.fc = nn.Linear(64, 100, bias=False)
        self.dropout = nn.Dropout(0.5)
        self.gelu = nn.GELU()
        
    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.bn1(x)
        x = self.gelu(x)

        x, _ = self.lstm2(x)
        x = self.bn2(x)
        x = self.gelu(x)
        
        x = self.fc(x[:,-1,:]) #self.fc(x)
        x = self.dropout(x)
        x = x.view(-1, 100)
        return x

# %%
hoxy = lstm()
cnnx = torch.randn(64,3,13)
hoxy2 = hoxy(cnnx)
print(hoxy2.shape)
# Out:
# torch.Size([64, 100])

# %%
class domain_regression(nn.Module):
    def __init__(self):
        super(domain_regression, self).__init__()
        self.regression_layer1 = nn.Linear(100, 128)
        self.regression_layer2 = nn.Linear(128, 128)
        self.regression_layer3 = nn.Linear(128, 1)
        
    def forward(self, x):
        x = F.relu(self.regression_layer1(x))
        x = F.relu(self.regression_layer2(x))
        x = self.regression_layer3(x)
        return x

# %%
hoxy3 = domain_regression()
cnnx = torch.randn(64,100)
hoxy4 = hoxy3(cnnx)
print(hoxy4.shape)
# Out:
# torch.Size([64, 1])

# %% [markdown]
# ### Domain Classification

# %%
class domain_classfication(nn.Module):
    def __init__(self):
        super(domain_classfication, self).__init__()
        self.classification_layer0 = GradientReversalLayer()
        self.classification_layer1 = nn.Linear(100, 100)
        self.classification_layer2 = nn.Linear(100, 1)
        
    def forward(self, x):
        x = self.classification_layer0(x)
        x = F.relu(self.classification_layer1(x))
        x = torch.sigmoid(self.classification_layer2(x))
        return x

# %%
hoxy5 = domain_regression()
cnnx = torch.randn(64,100)
hoxy6 = hoxy5(cnnx)
print(hoxy6.shape)
# Out:
# torch.Size([64, 1])

# %% [markdown]
# ### Set the DANN

# %%
class dann(nn.Module):
    def __init__(self, lstm):
        super(dann, self).__init__()
        self.lstm = lstm
        self.regression = domain_regression()
        self.classification = domain_classfication()
        
    def forward(self, x):
        feature = self.lstm(x)
        reg_output = self.regression(feature)
        cla_output = self.classification(feature)
        
        return reg_output, cla_output

# %% [markdown]
# ### Loss 선언

# %%
class dann_loss(nn.Module):
    def __init__(self):
        super(dann_loss, self).__init__()
        self.reg = nn.L1Loss() # 회귀 L1 손실 == MAE
        self.cla = nn.BCEWithLogitsLoss() # 도메인 분류
        
    def forward(self, result, reg_real, domain_num, alpha=1):
        reg_output, cla_output = result
        batch_size = reg_output.shape[0]
        cla_target = torch.FloatTensor([domain_num] * batch_size).unsqueeze(1).to(device)
        
        reg_loss = self.reg(reg_output, reg_real)
        cla_loss = self.cla(cla_output, cla_target)
        loss = reg_loss + cla_loss * alpha
        return loss

# %% [markdown]
# # 훈련

# %%
from torch.optim.lr_scheduler import LinearLR

alpha = 1.0

my_lstm = lstm().to(device)
model = dann(my_lstm).to(device)
loss_fn = dann_loss().to(device)

epochs = 500

model.train() # 훈련 모드 설정

optimizer= torch.optim.Adamax(model.parameters(), lr = 0.01)
scheduler = LinearLR(optimizer, start_factor=1.0, end_factor=0.0, total_iters = epochs * len(source_train))

for i in range(1, epochs + 1):
    total_loss = 0
    source_total_loss = 0
    target_total_loss = 0
    #for step in tqdm(range(len(source_train))):
    for step, (source_data, target_data) in enumerate(zip(source_train, target_train)):
        #source_data = next(iter(source_train))
        #target_data = next(iter(target_train))
        
        source_x = source_data[0].to(device)
        source_y = source_data[1].to(device)
        target_x = target_data[0].to(device)
        target_y = target_data[1].to(device)
        
        # 순전파
        source_result = model(source_x)
        target_result = model(target_x)
        
        # 순전파 loss
        source_loss = loss_fn(source_result, source_y, 0, alpha=alpha) # 소스 도메인 레이블 0
        target_loss = loss_fn(target_result, target_y, 1, alpha=alpha) # 타겟 도메인 레이블 1
        loss = source_loss + target_loss
        
        source_total_loss += source_loss.item()
        target_total_loss += target_loss.item()
        total_loss += loss.item()
        
        # 그래디언트 계산 및 업데이트
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()
        
    print('Epoch : %d, Total Avg Loss : %.4f' % (i, total_loss / len(source_train)))     
    print('Source Avg Loss : %.4f' % (source_total_loss / len(source_train)))
    print('Target Avg Loss : %.4f' % (target_total_loss / len(source_train)))
    print('')
# Out:
# Epoch : 1, Total Avg Loss : 1.7618
# Source Avg Loss : 0.9450
# Target Avg Loss : 0.8168
#
# Epoch : 2, Total Avg Loss : 1.6516
# Source Avg Loss : 0.8491
# Target Avg Loss : 0.8024
#
# Epoch : 3, Total Avg Loss : 1.6736
# Source Avg Loss : 0.9557
# Target Avg Loss : 0.7179
#
# Epoch : 4, Total Avg Loss : 1.6114
# Source Avg Loss : 0.8133
# Target Avg Loss : 0.7980
#
# Epoch : 5, Total Avg Loss : 1.6214
# Source Avg Loss : 0.9444
# Target Avg Loss : 0.6770
#
# Epoch : 6, Total Avg Loss : 1.7274
# Source Avg Loss : 1.0272
# Target Avg Loss : 0.7001
#
# Epoch : 7, Total Avg Loss : 1.6136
# Source Avg Loss : 0.8390
# Target Avg Loss : 0.7746
#
# Epoch : 8, Total Avg Loss : 1.5888
# Source Avg Loss : 0.8077
# Target Avg Loss : 0.7811
#
# Epoch : 9, Total Avg Loss : 1.6256
# Source Avg Loss : 0.9460
# Target Avg Loss : 0.6796
#
# Epoch : 10, Total Avg Loss : 1.6205
# Source Avg Loss : 0.8404
# Target Avg Loss : 0.7801
#
# Epoch : 11, Total Avg Loss : 1.5791
# Source Avg Loss : 0.7983
# Target Avg Loss : 0.7808
#
# Epoch : 12, Total Avg Loss : 1.5609
# Source Avg Loss : 0.7766
# Target Avg Loss : 0.7843
#
# Epoch : 13, Total Avg Loss : 1.5391
# Source Avg Loss : 0.7609
# Target Avg Loss : 0.7783
#
# Epoch : 14, Total Avg Loss : 1.5318
# Source Avg Loss : 0.7571
# Target Avg Loss : 0.7747
#
# Epoch : 15, Total Avg Loss : 1.5313
# Source Avg Loss : 0.7580
# Target Avg Loss : 0.7733
#
# Epoch : 16, Total Avg Loss : 1.5263
# Source Avg Loss : 0.7540
# Target Avg Loss : 0.7723
#
# Epoch : 17, Total Avg Loss : 1.5168
# Source Avg Loss : 0.7470
# Target Avg Loss : 0.7698
#
# Epoch : 18, Total Avg Loss : 1.5160
# Source Avg Loss : 0.7482
# Target Avg Loss : 0.7678
#
# Epoch : 19, Total Avg Loss : 1.5077
# Source Avg Loss : 0.7435
# Target Avg Loss : 0.7642
#
# Epoch : 20, Total Avg Loss : 1.5145
# Source Avg Loss : 0.7478
# Target Avg Loss : 0.7668
#
# Epoch : 21, Total Avg Loss : 1.5285
# Source Avg Loss : 0.7591
# Target Avg Loss : 0.7693
#
# Epoch : 22, Total Avg Loss : 1.5296
# Source Avg Loss : 0.7615
# Target Avg Loss : 0.7681
#
# Epoch : 23, Total Avg Loss : 1.5174
# Source Avg Loss : 0.7514
# Target Avg Loss : 0.7660
#
# Epoch : 24, Total Avg Loss : 1.5048
# Source Avg Loss : 0.7405
# Target Avg Loss : 0.7642
#
# Epoch : 25, Total Avg Loss : 1.5135
# Source Avg Loss : 0.7461
# Target Avg Loss : 0.7675
#
# Epoch : 26, Total Avg Loss : 1.5213
# Source Avg Loss : 0.7559
# Target Avg Loss : 0.7655
#
# Epoch : 27, Total Avg Loss : 1.5108
# Source Avg Loss : 0.7465
# Target Avg Loss : 0.7643
#
# Epoch : 28, Total Avg Loss : 1.4979
# Source Avg Loss : 0.7369
# Target Avg Loss : 0.7609
#
# Epoch : 29, Total Avg Loss : 1.5049
# Source Avg Loss : 0.7411
# Target Avg Loss : 0.7639
#
# Epoch : 30, Total Avg Loss : 1.5339
# Source Avg Loss : 0.7665
# Target Avg Loss : 0.7673
#
# Epoch : 31, Total Avg Loss : 1.5051
# Source Avg Loss : 0.7412
# Target Avg Loss : 0.7639
#
# Epoch : 32, Total Avg Loss : 1.4950
# Source Avg Loss : 0.7344
# Target Avg Loss : 0.7606
#
# Epoch : 33, Total Avg Loss : 1.5160
# Source Avg Loss : 0.8753
# Target Avg Loss : 0.6407
#
# Epoch : 34, Total Avg Loss : 1.5566
# Source Avg Loss : 0.7821
# Target Avg Loss : 0.7745
#
# Epoch : 35, Total Avg Loss : 1.5085
# Source Avg Loss : 0.7442
# Target Avg Loss : 0.7643
#
# Epoch : 36, Total Avg Loss : 1.5015
# Source Avg Loss : 0.7401
# Target Avg Loss : 0.7614
#
# Epoch : 37, Total Avg Loss : 1.5036
# Source Avg Loss : 0.7408
# Target Avg Loss : 0.7628
#
# Epoch : 38, Total Avg Loss : 1.5202
# Source Avg Loss : 0.7544
# Target Avg Loss : 0.7658
#
# Epoch : 39, Total Avg Loss : 1.4969
# Source Avg Loss : 0.7361
# Target Avg Loss : 0.7608
#
# Epoch : 40, Total Avg Loss : 1.4917
# Source Avg Loss : 0.7330
# Target Avg Loss : 0.7587
#
# Epoch : 41, Total Avg Loss : 1.5190
# Source Avg Loss : 0.7666
# Target Avg Loss : 0.7524
#
# Epoch : 42, Total Avg Loss : 1.9609
# Source Avg Loss : 1.3117
# Target Avg Loss : 0.6492
#
# Epoch : 43, Total Avg Loss : 2.0681
# Source Avg Loss : 1.4005
# Target Avg Loss : 0.6676
#
# Epoch : 44, Total Avg Loss : 2.0368
# Source Avg Loss : 1.4001
# Target Avg Loss : 0.6367
#
# Epoch : 45, Total Avg Loss : 2.0750
# Source Avg Loss : 1.3667
# Target Avg Loss : 0.7083
#
# Epoch : 46, Total Avg Loss : 2.0663
# Source Avg Loss : 1.3551
# Target Avg Loss : 0.7113
#
# Epoch : 47, Total Avg Loss : 2.0567
# Source Avg Loss : 1.3604
# Target Avg Loss : 0.6963
#
# Epoch : 48, Total Avg Loss : 1.8616
# Source Avg Loss : 1.0548
# Target Avg Loss : 0.8068
#
# Epoch : 49, Total Avg Loss : 1.5887
# Source Avg Loss : 0.7910
# Target Avg Loss : 0.7977
#
# Epoch : 50, Total Avg Loss : 1.5632
# Source Avg Loss : 0.7812
# Target Avg Loss : 0.7820
#
# Epoch : 51, Total Avg Loss : 1.5274
# Source Avg Loss : 0.7535
# Target Avg Loss : 0.7739
#
# Epoch : 52, Total Avg Loss : 1.5194
# Source Avg Loss : 0.7518
# Target Avg Loss : 0.7677
#
# Epoch : 53, Total Avg Loss : 1.5059
# Source Avg Loss : 0.7423
# Target Avg Loss : 0.7636
#
# Epoch : 54, Total Avg Loss : 1.5083
# Source Avg Loss : 0.7452
# Target Avg Loss : 0.7631
#
# Epoch : 55, Total Avg Loss : 1.5081
# Source Avg Loss : 0.7448
# Target Avg Loss : 0.7634
#
# Epoch : 56, Total Avg Loss : 1.5245
# Source Avg Loss : 0.7584
# Target Avg Loss : 0.7661
#
# Epoch : 57, Total Avg Loss : 1.4973
# Source Avg Loss : 0.7355
# Target Avg Loss : 0.7619
#
# Epoch : 58, Total Avg Loss : 1.5010
# Source Avg Loss : 0.7390
# Target Avg Loss : 0.7620
#
# Epoch : 59, Total Avg Loss : 1.5052
# Source Avg Loss : 0.7383
# Target Avg Loss : 0.7669
#
# Epoch : 60, Total Avg Loss : 1.4943
# Source Avg Loss : 0.7342
# Target Avg Loss : 0.7602
#
# Epoch : 61, Total Avg Loss : 1.4914
# Source Avg Loss : 0.7319
# Target Avg Loss : 0.7595
#
# Epoch : 62, Total Avg Loss : 1.4955
# Source Avg Loss : 0.7353
# Target Avg Loss : 0.7601
#
# Epoch : 63, Total Avg Loss : 1.4979
# Source Avg Loss : 0.7408
# Target Avg Loss : 0.7571
#
# Epoch : 64, Total Avg Loss : 1.4921
# Source Avg Loss : 0.7340
# Target Avg Loss : 0.7581
#
# Epoch : 65, Total Avg Loss : 1.5066
# Source Avg Loss : 0.7423
# Target Avg Loss : 0.7643
#
# Epoch : 66, Total Avg Loss : 1.5172
# Source Avg Loss : 0.7488
# Target Avg Loss : 0.7684
#
# Epoch : 67, Total Avg Loss : 1.5234
# Source Avg Loss : 0.7606
# Target Avg Loss : 0.7628
#
# Epoch : 68, Total Avg Loss : 1.5198
# Source Avg Loss : 0.7510
# Target Avg Loss : 0.7688
#
# Epoch : 69, Total Avg Loss : 1.5021
# Source Avg Loss : 0.7389
# Target Avg Loss : 0.7633
#
# Epoch : 70, Total Avg Loss : 1.5043
# Source Avg Loss : 0.7388
# Target Avg Loss : 0.7655
#
# Epoch : 71, Total Avg Loss : 1.4973
# Source Avg Loss : 0.7365
# Target Avg Loss : 0.7608
#
# Epoch : 72, Total Avg Loss : 1.5151
# Source Avg Loss : 0.7503
# Target Avg Loss : 0.7648
#
# Epoch : 73, Total Avg Loss : 1.4956
# Source Avg Loss : 0.7343
# Target Avg Loss : 0.7614
#
# Epoch : 74, Total Avg Loss : 1.4972
# Source Avg Loss : 0.7360
# Target Avg Loss : 0.7612
#
# Epoch : 75, Total Avg Loss : 1.4916
# Source Avg Loss : 0.7300
# Target Avg Loss : 0.7616
#
# Epoch : 76, Total Avg Loss : 1.5050
# Source Avg Loss : 0.7446
# Target Avg Loss : 0.7604
#
# Epoch : 77, Total Avg Loss : 1.5584
# Source Avg Loss : 0.8599
# Target Avg Loss : 0.6985
#
# Epoch : 78, Total Avg Loss : 2.0315
# Source Avg Loss : 1.3170
# Target Avg Loss : 0.7144
#
# Epoch : 79, Total Avg Loss : 1.8016
# Source Avg Loss : 0.9861
# Target Avg Loss : 0.8155
#
# Epoch : 80, Total Avg Loss : 1.5724
# Source Avg Loss : 0.7852
# Target Avg Loss : 0.7872
#
# Epoch : 81, Total Avg Loss : 1.5309
# Source Avg Loss : 0.7566
# Target Avg Loss : 0.7744
#
# Epoch : 82, Total Avg Loss : 1.5473
# Source Avg Loss : 0.7744
# Target Avg Loss : 0.7729
#
# Epoch : 83, Total Avg Loss : 1.5148
# Source Avg Loss : 0.7458
# Target Avg Loss : 0.7690
#
# Epoch : 84, Total Avg Loss : 1.5125
# Source Avg Loss : 0.7454
# Target Avg Loss : 0.7671
#
# Epoch : 85, Total Avg Loss : 1.5128
# Source Avg Loss : 0.7477
# Target Avg Loss : 0.7651
#
# Epoch : 86, Total Avg Loss : 1.5087
# Source Avg Loss : 0.7443
# Target Avg Loss : 0.7644
#
# Epoch : 87, Total Avg Loss : 1.4963
# Source Avg Loss : 0.7325
# Target Avg Loss : 0.7638
#
# Epoch : 88, Total Avg Loss : 1.5054
# Source Avg Loss : 0.7392
# Target Avg Loss : 0.7662
#
# Epoch : 89, Total Avg Loss : 1.5017
# Source Avg Loss : 0.7388
# Target Avg Loss : 0.7628
#
# Epoch : 90, Total Avg Loss : 1.4930
# Source Avg Loss : 0.7330
# Target Avg Loss : 0.7600
#
# Epoch : 91, Total Avg Loss : 1.4942
# Source Avg Loss : 0.7354
# Target Avg Loss : 0.7588
#
# Epoch : 92, Total Avg Loss : 1.4987
# Source Avg Loss : 0.7363
# Target Avg Loss : 0.7624
#
# Epoch : 93, Total Avg Loss : 1.4935
# Source Avg Loss : 0.7313
# Target Avg Loss : 0.7622
#
# Epoch : 94, Total Avg Loss : 1.4974
# Source Avg Loss : 0.7335
# Target Avg Loss : 0.7639
#
# Epoch : 95, Total Avg Loss : 1.5146
# Source Avg Loss : 0.7500
# Target Avg Loss : 0.7647
#
# Epoch : 96, Total Avg Loss : 1.5144
# Source Avg Loss : 0.7414
# Target Avg Loss : 0.7730
#
# Epoch : 97, Total Avg Loss : 1.5101
# Source Avg Loss : 0.7454
# Target Avg Loss : 0.7648
#
# Epoch : 98, Total Avg Loss : 1.5227
# Source Avg Loss : 0.7570
# Target Avg Loss : 0.7657
#
# Epoch : 99, Total Avg Loss : 1.5141
# Source Avg Loss : 0.7458
# Target Avg Loss : 0.7684
#
# Epoch : 100, Total Avg Loss : 1.5309
# Source Avg Loss : 0.7630
# Target Avg Loss : 0.7679
#
# Epoch : 101, Total Avg Loss : 1.5169
# Source Avg Loss : 0.7478
# Target Avg Loss : 0.7690
#
# Epoch : 102, Total Avg Loss : 1.5273
# Source Avg Loss : 0.7624
# Target Avg Loss : 0.7650
#
# Epoch : 103, Total Avg Loss : 1.5309
# Source Avg Loss : 0.7679
# Target Avg Loss : 0.7630
#
# Epoch : 104, Total Avg Loss : 1.5186
# Source Avg Loss : 0.7546
# Target Avg Loss : 0.7640
#
# Epoch : 105, Total Avg Loss : 1.5003
# Source Avg Loss : 0.7384
# Target Avg Loss : 0.7619
#
# Epoch : 106, Total Avg Loss : 1.5115
# Source Avg Loss : 0.7500
# Target Avg Loss : 0.7615
#
# Epoch : 107, Total Avg Loss : 1.4983
# Source Avg Loss : 0.7369
# Target Avg Loss : 0.7614
#
# Epoch : 108, Total Avg Loss : 1.5034
# Source Avg Loss : 0.7401
# Target Avg Loss : 0.7632
#
# Epoch : 109, Total Avg Loss : 1.4988
# Source Avg Loss : 0.7382
# Target Avg Loss : 0.7606
#
# Epoch : 110, Total Avg Loss : 1.4843
# Source Avg Loss : 0.7262
# Target Avg Loss : 0.7581
#
# Epoch : 111, Total Avg Loss : 1.4957
# Source Avg Loss : 0.7353
# Target Avg Loss : 0.7603
#
# Epoch : 112, Total Avg Loss : 1.4962
# Source Avg Loss : 0.7370
# Target Avg Loss : 0.7592
#
# Epoch : 113, Total Avg Loss : 1.4920
# Source Avg Loss : 0.7349
# Target Avg Loss : 0.7571
#
# Epoch : 114, Total Avg Loss : 1.4913
# Source Avg Loss : 0.7326
# Target Avg Loss : 0.7587
#
# Epoch : 115, Total Avg Loss : 1.4887
# Source Avg Loss : 0.7308
# Target Avg Loss : 0.7580
#
# Epoch : 116, Total Avg Loss : 1.4819
# Source Avg Loss : 0.7247
# Target Avg Loss : 0.7572
#
# Epoch : 117, Total Avg Loss : 1.4831
# Source Avg Loss : 0.7247
# Target Avg Loss : 0.7584
#
# Epoch : 118, Total Avg Loss : 1.4843
# Source Avg Loss : 0.7263
# Target Avg Loss : 0.7580
#
# Epoch : 119, Total Avg Loss : 1.4923
# Source Avg Loss : 0.7339
# Target Avg Loss : 0.7584
#
# Epoch : 120, Total Avg Loss : 1.4806
# Source Avg Loss : 0.7233
# Target Avg Loss : 0.7573
#
# Epoch : 121, Total Avg Loss : 1.4810
# Source Avg Loss : 0.7238
# Target Avg Loss : 0.7572
#
# Epoch : 122, Total Avg Loss : 1.4926
# Source Avg Loss : 0.7321
# Target Avg Loss : 0.7604
#
# Epoch : 123, Total Avg Loss : 1.4938
# Source Avg Loss : 0.7343
# Target Avg Loss : 0.7595
#
# Epoch : 124, Total Avg Loss : 1.4870
# Source Avg Loss : 0.7268
# Target Avg Loss : 0.7603
#
# Epoch : 125, Total Avg Loss : 1.4879
# Source Avg Loss : 0.7271
# Target Avg Loss : 0.7608
#
# Epoch : 126, Total Avg Loss : 1.5025
# Source Avg Loss : 0.7398
# Target Avg Loss : 0.7627
#
# Epoch : 127, Total Avg Loss : 1.5029
# Source Avg Loss : 0.7406
# Target Avg Loss : 0.7622
#
# Epoch : 128, Total Avg Loss : 1.4891
# Source Avg Loss : 0.7314
# Target Avg Loss : 0.7577
#
# Epoch : 129, Total Avg Loss : 1.4944
# Source Avg Loss : 0.7359
# Target Avg Loss : 0.7585
#
# Epoch : 130, Total Avg Loss : 1.4817
# Source Avg Loss : 0.7231
# Target Avg Loss : 0.7586
#
# Epoch : 131, Total Avg Loss : 1.4990
# Source Avg Loss : 0.7390
# Target Avg Loss : 0.7600
#
# Epoch : 132, Total Avg Loss : 1.4926
# Source Avg Loss : 0.7324
# Target Avg Loss : 0.7603
#
# Epoch : 133, Total Avg Loss : 1.4844
# Source Avg Loss : 0.7276
# Target Avg Loss : 0.7568
#
# Epoch : 134, Total Avg Loss : 1.4875
# Source Avg Loss : 0.7314
# Target Avg Loss : 0.7561
#
# Epoch : 135, Total Avg Loss : 1.4833
# Source Avg Loss : 0.7265
# Target Avg Loss : 0.7568
#
# Epoch : 136, Total Avg Loss : 1.4962
# Source Avg Loss : 0.7355
# Target Avg Loss : 0.7607
#
# Epoch : 137, Total Avg Loss : 1.4941
# Source Avg Loss : 0.7328
# Target Avg Loss : 0.7613
#
# Epoch : 138, Total Avg Loss : 1.4892
# Source Avg Loss : 0.7300
# Target Avg Loss : 0.7592
#
# Epoch : 139, Total Avg Loss : 1.5080
# Source Avg Loss : 0.7466
# Target Avg Loss : 0.7614
#
# Epoch : 140, Total Avg Loss : 1.5090
# Source Avg Loss : 0.7409
# Target Avg Loss : 0.7681
#
# Epoch : 141, Total Avg Loss : 1.4952
# Source Avg Loss : 0.7378
# Target Avg Loss : 0.7573
#
# Epoch : 142, Total Avg Loss : 1.5001
# Source Avg Loss : 0.7375
# Target Avg Loss : 0.7626
#
# Epoch : 143, Total Avg Loss : 1.4847
# Source Avg Loss : 0.7283
# Target Avg Loss : 0.7564
#
# Epoch : 144, Total Avg Loss : 1.4822
# Source Avg Loss : 0.7259
# Target Avg Loss : 0.7563
#
# Epoch : 145, Total Avg Loss : 1.4798
# Source Avg Loss : 0.7238
# Target Avg Loss : 0.7560
#
# Epoch : 146, Total Avg Loss : 1.4810
# Source Avg Loss : 0.7249
# Target Avg Loss : 0.7561
#
# Epoch : 147, Total Avg Loss : 1.4806
# Source Avg Loss : 0.7256
# Target Avg Loss : 0.7550
#
# Epoch : 148, Total Avg Loss : 1.4775
# Source Avg Loss : 0.7235
# Target Avg Loss : 0.7540
#
# Epoch : 149, Total Avg Loss : 1.4776
# Source Avg Loss : 0.7222
# Target Avg Loss : 0.7553
#
# Epoch : 150, Total Avg Loss : 1.4788
# Source Avg Loss : 0.7220
# Target Avg Loss : 0.7567
#
# Epoch : 151, Total Avg Loss : 1.4724
# Source Avg Loss : 0.7181
# Target Avg Loss : 0.7543
#
# Epoch : 152, Total Avg Loss : 1.4800
# Source Avg Loss : 0.7254
# Target Avg Loss : 0.7546
#
# Epoch : 153, Total Avg Loss : 1.4805
# Source Avg Loss : 0.7259
# Target Avg Loss : 0.7547
#
# Epoch : 154, Total Avg Loss : 1.4862
# Source Avg Loss : 0.7301
# Target Avg Loss : 0.7561
#
# Epoch : 155, Total Avg Loss : 1.4827
# Source Avg Loss : 0.7237
# Target Avg Loss : 0.7591
#
# Epoch : 156, Total Avg Loss : 1.4873
# Source Avg Loss : 0.7318
# Target Avg Loss : 0.7556
#
# Epoch : 157, Total Avg Loss : 1.4836
# Source Avg Loss : 0.7278
# Target Avg Loss : 0.7558
#
# Epoch : 158, Total Avg Loss : 1.4849
# Source Avg Loss : 0.7262
# Target Avg Loss : 0.7587
#
# Epoch : 159, Total Avg Loss : 1.4743
# Source Avg Loss : 0.7202
# Target Avg Loss : 0.7541
#
# Epoch : 160, Total Avg Loss : 1.4744
# Source Avg Loss : 0.7215
# Target Avg Loss : 0.7529
#
# Epoch : 161, Total Avg Loss : 1.4740
# Source Avg Loss : 0.7212
# Target Avg Loss : 0.7528
#
# Epoch : 162, Total Avg Loss : 1.4826
# Source Avg Loss : 0.7259
# Target Avg Loss : 0.7567
#
# Epoch : 163, Total Avg Loss : 1.4793
# Source Avg Loss : 0.7227
# Target Avg Loss : 0.7566
#
# Epoch : 164, Total Avg Loss : 1.4911
# Source Avg Loss : 0.7344
# Target Avg Loss : 0.7567
#
# Epoch : 165, Total Avg Loss : 1.4828
# Source Avg Loss : 0.7277
# Target Avg Loss : 0.7551
#
# Epoch : 166, Total Avg Loss : 1.4886
# Source Avg Loss : 0.7297
# Target Avg Loss : 0.7589
#
# Epoch : 167, Total Avg Loss : 1.4841
# Source Avg Loss : 0.7280
# Target Avg Loss : 0.7561
#
# Epoch : 168, Total Avg Loss : 1.4810
# Source Avg Loss : 0.7272
# Target Avg Loss : 0.7538
#
# Epoch : 169, Total Avg Loss : 1.4840
# Source Avg Loss : 0.7277
# Target Avg Loss : 0.7563
#
# Epoch : 170, Total Avg Loss : 1.4789
# Source Avg Loss : 0.7235
# Target Avg Loss : 0.7554
#
# Epoch : 171, Total Avg Loss : 1.4765
# Source Avg Loss : 0.7236
# Target Avg Loss : 0.7529
#
# Epoch : 172, Total Avg Loss : 1.4769
# Source Avg Loss : 0.7231
# Target Avg Loss : 0.7539
#
# Epoch : 173, Total Avg Loss : 1.4716
# Source Avg Loss : 0.7191
# Target Avg Loss : 0.7524
#
# Epoch : 174, Total Avg Loss : 1.4800
# Source Avg Loss : 0.7250
# Target Avg Loss : 0.7549
#
# Epoch : 175, Total Avg Loss : 1.4757
# Source Avg Loss : 0.7231
# Target Avg Loss : 0.7527
#
# Epoch : 176, Total Avg Loss : 1.4716
# Source Avg Loss : 0.7184
# Target Avg Loss : 0.7532
#
# Epoch : 177, Total Avg Loss : 1.4743
# Source Avg Loss : 0.7227
# Target Avg Loss : 0.7516
#
# Epoch : 178, Total Avg Loss : 1.4710
# Source Avg Loss : 0.7184
# Target Avg Loss : 0.7526
#
# Epoch : 179, Total Avg Loss : 1.4732
# Source Avg Loss : 0.7215
# Target Avg Loss : 0.7517
#
# Epoch : 180, Total Avg Loss : 1.4721
# Source Avg Loss : 0.7203
# Target Avg Loss : 0.7518
#
# Epoch : 181, Total Avg Loss : 1.4774
# Source Avg Loss : 0.7239
# Target Avg Loss : 0.7535
#
# Epoch : 182, Total Avg Loss : 1.4701
# Source Avg Loss : 0.7187
# Target Avg Loss : 0.7514
#
# Epoch : 183, Total Avg Loss : 1.4768
# Source Avg Loss : 0.7244
# Target Avg Loss : 0.7524
#
# Epoch : 184, Total Avg Loss : 1.4771
# Source Avg Loss : 0.7232
# Target Avg Loss : 0.7540
#
# Epoch : 185, Total Avg Loss : 1.4759
# Source Avg Loss : 0.7224
# Target Avg Loss : 0.7535
#
# Epoch : 186, Total Avg Loss : 1.4763
# Source Avg Loss : 0.7228
# Target Avg Loss : 0.7535
#
# Epoch : 187, Total Avg Loss : 1.4759
# Source Avg Loss : 0.7230
# Target Avg Loss : 0.7530
#
# Epoch : 188, Total Avg Loss : 1.4793
# Source Avg Loss : 0.7261
# Target Avg Loss : 0.7531
#
# Epoch : 189, Total Avg Loss : 1.4898
# Source Avg Loss : 0.7365
# Target Avg Loss : 0.7533
#
# Epoch : 190, Total Avg Loss : 1.5094
# Source Avg Loss : 0.7533
# Target Avg Loss : 0.7561
#
# Epoch : 191, Total Avg Loss : 1.4924
# Source Avg Loss : 0.7352
# Target Avg Loss : 0.7572
#
# Epoch : 192, Total Avg Loss : 1.4809
# Source Avg Loss : 0.7262
# Target Avg Loss : 0.7546
#
# Epoch : 193, Total Avg Loss : 1.4804
# Source Avg Loss : 0.7258
# Target Avg Loss : 0.7547
#
# Epoch : 194, Total Avg Loss : 1.4686
# Source Avg Loss : 0.7178
# Target Avg Loss : 0.7508
#
# Epoch : 195, Total Avg Loss : 1.4723
# Source Avg Loss : 0.7214
# Target Avg Loss : 0.7509
#
# Epoch : 196, Total Avg Loss : 1.4652
# Source Avg Loss : 0.7152
# Target Avg Loss : 0.7500
#
# Epoch : 197, Total Avg Loss : 1.4755
# Source Avg Loss : 0.7238
# Target Avg Loss : 0.7516
#
# Epoch : 198, Total Avg Loss : 1.4694
# Source Avg Loss : 0.7184
# Target Avg Loss : 0.7510
#
# Epoch : 199, Total Avg Loss : 1.4816
# Source Avg Loss : 0.7275
# Target Avg Loss : 0.7542
#
# Epoch : 200, Total Avg Loss : 1.4721
# Source Avg Loss : 0.7217
# Target Avg Loss : 0.7504
#
# Epoch : 201, Total Avg Loss : 1.4705
# Source Avg Loss : 0.7205
# Target Avg Loss : 0.7500
#
# Epoch : 202, Total Avg Loss : 1.4794
# Source Avg Loss : 0.7254
# Target Avg Loss : 0.7540
#
# Epoch : 203, Total Avg Loss : 1.4689
# Source Avg Loss : 0.7179
# Target Avg Loss : 0.7510
#
# Epoch : 204, Total Avg Loss : 1.4774
# Source Avg Loss : 0.7267
# Target Avg Loss : 0.7506
#
# Epoch : 205, Total Avg Loss : 1.4772
# Source Avg Loss : 0.7257
# Target Avg Loss : 0.7515
#
# Epoch : 206, Total Avg Loss : 1.4668
# Source Avg Loss : 0.7170
# Target Avg Loss : 0.7498
#
# Epoch : 207, Total Avg Loss : 1.4746
# Source Avg Loss : 0.7247
# Target Avg Loss : 0.7499
#
# Epoch : 208, Total Avg Loss : 1.4706
# Source Avg Loss : 0.7211
# Target Avg Loss : 0.7495
#
# Epoch : 209, Total Avg Loss : 1.4735
# Source Avg Loss : 0.7213
# Target Avg Loss : 0.7521
#
# Epoch : 210, Total Avg Loss : 1.4789
# Source Avg Loss : 0.7275
# Target Avg Loss : 0.7514
#
# Epoch : 211, Total Avg Loss : 1.4758
# Source Avg Loss : 0.7247
# Target Avg Loss : 0.7512
#
# Epoch : 212, Total Avg Loss : 1.4653
# Source Avg Loss : 0.7169
# Target Avg Loss : 0.7484
#
# Epoch : 213, Total Avg Loss : 1.4677
# Source Avg Loss : 0.7200
# Target Avg Loss : 0.7476
#
# Epoch : 214, Total Avg Loss : 1.4685
# Source Avg Loss : 0.7207
# Target Avg Loss : 0.7478
#
# Epoch : 215, Total Avg Loss : 1.4677
# Source Avg Loss : 0.7182
# Target Avg Loss : 0.7495
#
# Epoch : 216, Total Avg Loss : 1.4695
# Source Avg Loss : 0.7202
# Target Avg Loss : 0.7493
#
# Epoch : 217, Total Avg Loss : 1.4649
# Source Avg Loss : 0.7175
# Target Avg Loss : 0.7474
#
# Epoch : 218, Total Avg Loss : 1.4708
# Source Avg Loss : 0.7204
# Target Avg Loss : 0.7504
#
# Epoch : 219, Total Avg Loss : 1.4620
# Source Avg Loss : 0.7155
# Target Avg Loss : 0.7465
#
# Epoch : 220, Total Avg Loss : 1.4669
# Source Avg Loss : 0.7201
# Target Avg Loss : 0.7468
#
# Epoch : 221, Total Avg Loss : 1.4663
# Source Avg Loss : 0.7197
# Target Avg Loss : 0.7466
#
# Epoch : 222, Total Avg Loss : 1.4682
# Source Avg Loss : 0.7187
# Target Avg Loss : 0.7495
#
# Epoch : 223, Total Avg Loss : 1.4721
# Source Avg Loss : 0.7223
# Target Avg Loss : 0.7498
#
# Epoch : 224, Total Avg Loss : 1.4737
# Source Avg Loss : 0.7241
# Target Avg Loss : 0.7496
#
# Epoch : 225, Total Avg Loss : 1.4703
# Source Avg Loss : 0.7203
# Target Avg Loss : 0.7499
#
# Epoch : 226, Total Avg Loss : 1.4704
# Source Avg Loss : 0.7209
# Target Avg Loss : 0.7496
#
# Epoch : 227, Total Avg Loss : 1.4694
# Source Avg Loss : 0.7224
# Target Avg Loss : 0.7470
#
# Epoch : 228, Total Avg Loss : 1.4630
# Source Avg Loss : 0.7166
# Target Avg Loss : 0.7464
#
# Epoch : 229, Total Avg Loss : 1.4638
# Source Avg Loss : 0.7171
# Target Avg Loss : 0.7467
#
# Epoch : 230, Total Avg Loss : 1.4662
# Source Avg Loss : 0.7202
# Target Avg Loss : 0.7460
#
# Epoch : 231, Total Avg Loss : 1.4679
# Source Avg Loss : 0.7215
# Target Avg Loss : 0.7464
#
# Epoch : 232, Total Avg Loss : 1.4612
# Source Avg Loss : 0.7164
# Target Avg Loss : 0.7448
#
# Epoch : 233, Total Avg Loss : 1.4595
# Source Avg Loss : 0.7155
# Target Avg Loss : 0.7440
#
# Epoch : 234, Total Avg Loss : 1.4601
# Source Avg Loss : 0.7160
# Target Avg Loss : 0.7441
#
# Epoch : 235, Total Avg Loss : 1.4642
# Source Avg Loss : 0.7199
# Target Avg Loss : 0.7443
#
# Epoch : 236, Total Avg Loss : 1.4530
# Source Avg Loss : 0.7250
# Target Avg Loss : 0.7279
#
# Epoch : 237, Total Avg Loss : 1.4688
# Source Avg Loss : 0.7254
# Target Avg Loss : 0.7434
#
# Epoch : 238, Total Avg Loss : 1.4795
# Source Avg Loss : 0.7210
# Target Avg Loss : 0.7585
#
# Epoch : 239, Total Avg Loss : 1.4747
# Source Avg Loss : 0.7243
# Target Avg Loss : 0.7504
#
# Epoch : 240, Total Avg Loss : 1.4760
# Source Avg Loss : 0.7325
# Target Avg Loss : 0.7436
#
# Epoch : 241, Total Avg Loss : 1.5384
# Source Avg Loss : 0.8013
# Target Avg Loss : 0.7371
#
# Epoch : 242, Total Avg Loss : 1.8833
# Source Avg Loss : 1.1467
# Target Avg Loss : 0.7366
#
# Epoch : 243, Total Avg Loss : 1.9252
# Source Avg Loss : 1.1560
# Target Avg Loss : 0.7693
#
# Epoch : 244, Total Avg Loss : 1.5888
# Source Avg Loss : 0.8449
# Target Avg Loss : 0.7439
#
# Epoch : 245, Total Avg Loss : 1.6620
# Source Avg Loss : 0.8388
# Target Avg Loss : 0.8232
#
# Epoch : 246, Total Avg Loss : 1.5319
# Source Avg Loss : 0.7547
# Target Avg Loss : 0.7772
#
# Epoch : 247, Total Avg Loss : 1.5128
# Source Avg Loss : 0.7447
# Target Avg Loss : 0.7681
#
# Epoch : 248, Total Avg Loss : 1.5001
# Source Avg Loss : 0.7353
# Target Avg Loss : 0.7648
#
# Epoch : 249, Total Avg Loss : 1.4996
# Source Avg Loss : 0.7345
# Target Avg Loss : 0.7650
#
# Epoch : 250, Total Avg Loss : 1.4948
# Source Avg Loss : 0.7317
# Target Avg Loss : 0.7631
#
# Epoch : 251, Total Avg Loss : 1.4884
# Source Avg Loss : 0.7273
# Target Avg Loss : 0.7611
#
# Epoch : 252, Total Avg Loss : 1.4927
# Source Avg Loss : 0.7315
# Target Avg Loss : 0.7612
#
# Epoch : 253, Total Avg Loss : 1.4966
# Source Avg Loss : 0.7339
# Target Avg Loss : 0.7627
#
# Epoch : 254, Total Avg Loss : 1.5008
# Source Avg Loss : 0.7356
# Target Avg Loss : 0.7652
#
# Epoch : 255, Total Avg Loss : 1.4883
# Source Avg Loss : 0.7284
# Target Avg Loss : 0.7599
#
# Epoch : 256, Total Avg Loss : 1.4827
# Source Avg Loss : 0.7245
# Target Avg Loss : 0.7582
#
# Epoch : 257, Total Avg Loss : 1.4850
# Source Avg Loss : 0.7264
# Target Avg Loss : 0.7586
#
# Epoch : 258, Total Avg Loss : 1.4821
# Source Avg Loss : 0.7243
# Target Avg Loss : 0.7579
#
# Epoch : 259, Total Avg Loss : 1.4834
# Source Avg Loss : 0.7255
# Target Avg Loss : 0.7580
#
# Epoch : 260, Total Avg Loss : 1.4816
# Source Avg Loss : 0.7235
# Target Avg Loss : 0.7582
#
# Epoch : 261, Total Avg Loss : 1.4807
# Source Avg Loss : 0.7237
# Target Avg Loss : 0.7570
#
# Epoch : 262, Total Avg Loss : 1.4838
# Source Avg Loss : 0.7260
# Target Avg Loss : 0.7577
#
# Epoch : 263, Total Avg Loss : 1.4769
# Source Avg Loss : 0.7210
# Target Avg Loss : 0.7559
#
# Epoch : 264, Total Avg Loss : 1.4834
# Source Avg Loss : 0.7270
# Target Avg Loss : 0.7564
#
# Epoch : 265, Total Avg Loss : 1.4855
# Source Avg Loss : 0.7262
# Target Avg Loss : 0.7593
#
# Epoch : 266, Total Avg Loss : 1.4828
# Source Avg Loss : 0.7240
# Target Avg Loss : 0.7588
#
# Epoch : 267, Total Avg Loss : 1.4830
# Source Avg Loss : 0.7242
# Target Avg Loss : 0.7588
#
# Epoch : 268, Total Avg Loss : 1.4814
# Source Avg Loss : 0.7248
# Target Avg Loss : 0.7566
#
# Epoch : 269, Total Avg Loss : 1.4813
# Source Avg Loss : 0.7241
# Target Avg Loss : 0.7573
#
# Epoch : 270, Total Avg Loss : 1.4796
# Source Avg Loss : 0.7230
# Target Avg Loss : 0.7566
#
# Epoch : 271, Total Avg Loss : 1.4791
# Source Avg Loss : 0.7223
# Target Avg Loss : 0.7568
#
# Epoch : 272, Total Avg Loss : 1.4752
# Source Avg Loss : 0.7206
# Target Avg Loss : 0.7546
#
# Epoch : 273, Total Avg Loss : 1.4720
# Source Avg Loss : 0.7186
# Target Avg Loss : 0.7534
#
# Epoch : 274, Total Avg Loss : 1.4733
# Source Avg Loss : 0.7195
# Target Avg Loss : 0.7539
#
# Epoch : 275, Total Avg Loss : 1.4728
# Source Avg Loss : 0.7193
# Target Avg Loss : 0.7535
#
# Epoch : 276, Total Avg Loss : 1.4737
# Source Avg Loss : 0.7201
# Target Avg Loss : 0.7536
#
# Epoch : 277, Total Avg Loss : 1.4739
# Source Avg Loss : 0.7199
# Target Avg Loss : 0.7540
#
# Epoch : 278, Total Avg Loss : 1.4754
# Source Avg Loss : 0.7214
# Target Avg Loss : 0.7540
#
# Epoch : 279, Total Avg Loss : 1.4728
# Source Avg Loss : 0.7199
# Target Avg Loss : 0.7529
#
# Epoch : 280, Total Avg Loss : 1.4730
# Source Avg Loss : 0.7201
# Target Avg Loss : 0.7529
#
# Epoch : 281, Total Avg Loss : 1.4736
# Source Avg Loss : 0.7197
# Target Avg Loss : 0.7539
#
# Epoch : 282, Total Avg Loss : 1.4732
# Source Avg Loss : 0.7183
# Target Avg Loss : 0.7549
#
# Epoch : 283, Total Avg Loss : 1.4768
# Source Avg Loss : 0.7190
# Target Avg Loss : 0.7578
#
# Epoch : 284, Total Avg Loss : 1.4770
# Source Avg Loss : 0.7202
# Target Avg Loss : 0.7568
#
# Epoch : 285, Total Avg Loss : 1.4747
# Source Avg Loss : 0.7205
# Target Avg Loss : 0.7542
#
# Epoch : 286, Total Avg Loss : 1.4800
# Source Avg Loss : 0.7255
# Target Avg Loss : 0.7545
#
# Epoch : 287, Total Avg Loss : 1.4739
# Source Avg Loss : 0.7213
# Target Avg Loss : 0.7525
#
# Epoch : 288, Total Avg Loss : 1.4734
# Source Avg Loss : 0.7208
# Target Avg Loss : 0.7527
#
# Epoch : 289, Total Avg Loss : 1.4731
# Source Avg Loss : 0.7190
# Target Avg Loss : 0.7541
#
# Epoch : 290, Total Avg Loss : 1.4736
# Source Avg Loss : 0.7192
# Target Avg Loss : 0.7544
#
# Epoch : 291, Total Avg Loss : 1.4774
# Source Avg Loss : 0.7218
# Target Avg Loss : 0.7557
#
# Epoch : 292, Total Avg Loss : 1.5015
# Source Avg Loss : 0.7402
# Target Avg Loss : 0.7613
#
# Epoch : 293, Total Avg Loss : 1.4973
# Source Avg Loss : 0.7360
# Target Avg Loss : 0.7613
#
# Epoch : 294, Total Avg Loss : 1.4880
# Source Avg Loss : 0.7337
# Target Avg Loss : 0.7544
#
# Epoch : 295, Total Avg Loss : 1.4714
# Source Avg Loss : 0.7189
# Target Avg Loss : 0.7525
#
# Epoch : 296, Total Avg Loss : 1.4697
# Source Avg Loss : 0.7188
# Target Avg Loss : 0.7509
#
# Epoch : 297, Total Avg Loss : 1.4767
# Source Avg Loss : 0.7249
# Target Avg Loss : 0.7518
#
# Epoch : 298, Total Avg Loss : 1.4757
# Source Avg Loss : 0.7222
# Target Avg Loss : 0.7535
#
# Epoch : 299, Total Avg Loss : 1.4738
# Source Avg Loss : 0.7221
# Target Avg Loss : 0.7517
#
# Epoch : 300, Total Avg Loss : 1.4704
# Source Avg Loss : 0.7195
# Target Avg Loss : 0.7509
#
# Epoch : 301, Total Avg Loss : 1.4665
# Source Avg Loss : 0.7171
# Target Avg Loss : 0.7495
#
# Epoch : 302, Total Avg Loss : 1.4659
# Source Avg Loss : 0.7169
# Target Avg Loss : 0.7490
#
# Epoch : 303, Total Avg Loss : 1.4665
# Source Avg Loss : 0.7179
# Target Avg Loss : 0.7486
#
# Epoch : 304, Total Avg Loss : 1.4640
# Source Avg Loss : 0.7155
# Target Avg Loss : 0.7485
#
# Epoch : 305, Total Avg Loss : 1.4640
# Source Avg Loss : 0.7153
# Target Avg Loss : 0.7487
#
# Epoch : 306, Total Avg Loss : 1.4687
# Source Avg Loss : 0.7177
# Target Avg Loss : 0.7510
#
# Epoch : 307, Total Avg Loss : 1.4747
# Source Avg Loss : 0.7234
# Target Avg Loss : 0.7513
#
# Epoch : 308, Total Avg Loss : 1.4712
# Source Avg Loss : 0.7204
# Target Avg Loss : 0.7508
#
# Epoch : 309, Total Avg Loss : 1.4744
# Source Avg Loss : 0.7204
# Target Avg Loss : 0.7540
#
# Epoch : 310, Total Avg Loss : 1.4702
# Source Avg Loss : 0.7210
# Target Avg Loss : 0.7493
#
# Epoch : 311, Total Avg Loss : 1.4729
# Source Avg Loss : 0.7215
# Target Avg Loss : 0.7513
#
# Epoch : 312, Total Avg Loss : 1.4685
# Source Avg Loss : 0.7198
# Target Avg Loss : 0.7488
#
# Epoch : 313, Total Avg Loss : 1.4700
# Source Avg Loss : 0.7210
# Target Avg Loss : 0.7490
#
# Epoch : 314, Total Avg Loss : 1.4679
# Source Avg Loss : 0.7188
# Target Avg Loss : 0.7491
#
# Epoch : 315, Total Avg Loss : 1.4677
# Source Avg Loss : 0.7197
# Target Avg Loss : 0.7480
#
# Epoch : 316, Total Avg Loss : 1.4697
# Source Avg Loss : 0.7193
# Target Avg Loss : 0.7503
#
# Epoch : 317, Total Avg Loss : 1.4874
# Source Avg Loss : 0.7334
# Target Avg Loss : 0.7541
#
# Epoch : 318, Total Avg Loss : 1.4924
# Source Avg Loss : 0.7346
# Target Avg Loss : 0.7578
#
# Epoch : 319, Total Avg Loss : 1.4703
# Source Avg Loss : 0.7199
# Target Avg Loss : 0.7504
#
# Epoch : 320, Total Avg Loss : 1.4644
# Source Avg Loss : 0.7179
# Target Avg Loss : 0.7465
#
# Epoch : 321, Total Avg Loss : 1.4645
# Source Avg Loss : 0.7246
# Target Avg Loss : 0.7399
#
# Epoch : 322, Total Avg Loss : 1.4692
# Source Avg Loss : 0.7311
# Target Avg Loss : 0.7381
#
# Epoch : 323, Total Avg Loss : 1.5579
# Source Avg Loss : 0.8008
# Target Avg Loss : 0.7571
#
# Epoch : 324, Total Avg Loss : 1.6706
# Source Avg Loss : 0.8942
# Target Avg Loss : 0.7764
#
# Epoch : 325, Total Avg Loss : 1.5005
# Source Avg Loss : 0.7387
# Target Avg Loss : 0.7618
#
# Epoch : 326, Total Avg Loss : 1.4818
# Source Avg Loss : 0.7248
# Target Avg Loss : 0.7570
#
# Epoch : 327, Total Avg Loss : 1.4749
# Source Avg Loss : 0.7210
# Target Avg Loss : 0.7539
#
# Epoch : 328, Total Avg Loss : 1.4741
# Source Avg Loss : 0.7218
# Target Avg Loss : 0.7522
#
# Epoch : 329, Total Avg Loss : 1.4687
# Source Avg Loss : 0.7175
# Target Avg Loss : 0.7512
#
# Epoch : 330, Total Avg Loss : 1.4673
# Source Avg Loss : 0.7174
# Target Avg Loss : 0.7499
#
# Epoch : 331, Total Avg Loss : 1.4659
# Source Avg Loss : 0.7162
# Target Avg Loss : 0.7496
#
# Epoch : 332, Total Avg Loss : 1.4642
# Source Avg Loss : 0.7158
# Target Avg Loss : 0.7483
#
# Epoch : 333, Total Avg Loss : 1.4636
# Source Avg Loss : 0.7161
# Target Avg Loss : 0.7475
#
# Epoch : 334, Total Avg Loss : 1.4624
# Source Avg Loss : 0.7149
# Target Avg Loss : 0.7475
#
# Epoch : 335, Total Avg Loss : 1.4620
# Source Avg Loss : 0.7148
# Target Avg Loss : 0.7471
#
# Epoch : 336, Total Avg Loss : 1.4621
# Source Avg Loss : 0.7148
# Target Avg Loss : 0.7473
#
# Epoch : 337, Total Avg Loss : 1.4673
# Source Avg Loss : 0.7186
# Target Avg Loss : 0.7487
#
# Epoch : 338, Total Avg Loss : 1.4793
# Source Avg Loss : 0.7304
# Target Avg Loss : 0.7489
#
# Epoch : 339, Total Avg Loss : 1.4735
# Source Avg Loss : 0.7250
# Target Avg Loss : 0.7485
#
# Epoch : 340, Total Avg Loss : 1.4635
# Source Avg Loss : 0.7174
# Target Avg Loss : 0.7462
#
# Epoch : 341, Total Avg Loss : 1.4605
# Source Avg Loss : 0.7149
# Target Avg Loss : 0.7456
#
# Epoch : 342, Total Avg Loss : 1.4588
# Source Avg Loss : 0.7143
# Target Avg Loss : 0.7445
#
# Epoch : 343, Total Avg Loss : 1.4582
# Source Avg Loss : 0.7137
# Target Avg Loss : 0.7445
#
# Epoch : 344, Total Avg Loss : 1.4583
# Source Avg Loss : 0.7134
# Target Avg Loss : 0.7448
#
# Epoch : 345, Total Avg Loss : 1.4584
# Source Avg Loss : 0.7139
# Target Avg Loss : 0.7445
#
# Epoch : 346, Total Avg Loss : 1.4573
# Source Avg Loss : 0.7130
# Target Avg Loss : 0.7443
#
# Epoch : 347, Total Avg Loss : 1.4583
# Source Avg Loss : 0.7134
# Target Avg Loss : 0.7449
#
# Epoch : 348, Total Avg Loss : 1.4595
# Source Avg Loss : 0.7153
# Target Avg Loss : 0.7442
#
# Epoch : 349, Total Avg Loss : 1.4590
# Source Avg Loss : 0.7144
# Target Avg Loss : 0.7446
#
# Epoch : 350, Total Avg Loss : 1.4586
# Source Avg Loss : 0.7144
# Target Avg Loss : 0.7442
#
# Epoch : 351, Total Avg Loss : 1.4585
# Source Avg Loss : 0.7147
# Target Avg Loss : 0.7438
#
# Epoch : 352, Total Avg Loss : 1.4602
# Source Avg Loss : 0.7161
# Target Avg Loss : 0.7441
#
# Epoch : 353, Total Avg Loss : 1.4611
# Source Avg Loss : 0.7171
# Target Avg Loss : 0.7441
#
# Epoch : 354, Total Avg Loss : 1.4618
# Source Avg Loss : 0.7173
# Target Avg Loss : 0.7444
#
# Epoch : 355, Total Avg Loss : 1.4623
# Source Avg Loss : 0.7178
# Target Avg Loss : 0.7445
#
# Epoch : 356, Total Avg Loss : 1.4756
# Source Avg Loss : 0.7280
# Target Avg Loss : 0.7476
#
# Epoch : 357, Total Avg Loss : 1.4730
# Source Avg Loss : 0.7266
# Target Avg Loss : 0.7463
#
# Epoch : 358, Total Avg Loss : 1.4598
# Source Avg Loss : 0.7177
# Target Avg Loss : 0.7421
#
# Epoch : 359, Total Avg Loss : 1.4580
# Source Avg Loss : 0.7173
# Target Avg Loss : 0.7407
#
# Epoch : 360, Total Avg Loss : 1.4590
# Source Avg Loss : 0.7179
# Target Avg Loss : 0.7411
#
# Epoch : 361, Total Avg Loss : 1.4731
# Source Avg Loss : 0.7321
# Target Avg Loss : 0.7410
#
# Epoch : 362, Total Avg Loss : 1.5233
# Source Avg Loss : 0.7753
# Target Avg Loss : 0.7479
#
# Epoch : 363, Total Avg Loss : 1.4732
# Source Avg Loss : 0.7230
# Target Avg Loss : 0.7502
#
# Epoch : 364, Total Avg Loss : 1.4657
# Source Avg Loss : 0.7197
# Target Avg Loss : 0.7460
#
# Epoch : 365, Total Avg Loss : 1.4601
# Source Avg Loss : 0.7156
# Target Avg Loss : 0.7445
#
# Epoch : 366, Total Avg Loss : 1.4584
# Source Avg Loss : 0.7144
# Target Avg Loss : 0.7440
#
# Epoch : 367, Total Avg Loss : 1.4582
# Source Avg Loss : 0.7154
# Target Avg Loss : 0.7428
#
# Epoch : 368, Total Avg Loss : 1.4592
# Source Avg Loss : 0.7163
# Target Avg Loss : 0.7429
#
# Epoch : 369, Total Avg Loss : 1.4574
# Source Avg Loss : 0.7141
# Target Avg Loss : 0.7433
#
# Epoch : 370, Total Avg Loss : 1.4600
# Source Avg Loss : 0.7168
# Target Avg Loss : 0.7432
#
# Epoch : 371, Total Avg Loss : 1.4567
# Source Avg Loss : 0.7145
# Target Avg Loss : 0.7421
#
# Epoch : 372, Total Avg Loss : 1.4548
# Source Avg Loss : 0.7133
# Target Avg Loss : 0.7415
#
# Epoch : 373, Total Avg Loss : 1.4579
# Source Avg Loss : 0.7159
# Target Avg Loss : 0.7420
#
# Epoch : 374, Total Avg Loss : 1.4585
# Source Avg Loss : 0.7167
# Target Avg Loss : 0.7418
#
# Epoch : 375, Total Avg Loss : 1.4606
# Source Avg Loss : 0.7165
# Target Avg Loss : 0.7441
#
# Epoch : 376, Total Avg Loss : 1.4589
# Source Avg Loss : 0.7162
# Target Avg Loss : 0.7427
#
# Epoch : 377, Total Avg Loss : 1.4546
# Source Avg Loss : 0.7131
# Target Avg Loss : 0.7415
#
# Epoch : 378, Total Avg Loss : 1.4542
# Source Avg Loss : 0.7134
# Target Avg Loss : 0.7409
#
# Epoch : 379, Total Avg Loss : 1.4589
# Source Avg Loss : 0.7177
# Target Avg Loss : 0.7412
#
# Epoch : 380, Total Avg Loss : 1.4570
# Source Avg Loss : 0.7165
# Target Avg Loss : 0.7406
#
# Epoch : 381, Total Avg Loss : 1.4578
# Source Avg Loss : 0.7172
# Target Avg Loss : 0.7406
#
# Epoch : 382, Total Avg Loss : 1.4541
# Source Avg Loss : 0.7141
# Target Avg Loss : 0.7400
#
# Epoch : 383, Total Avg Loss : 1.4535
# Source Avg Loss : 0.7132
# Target Avg Loss : 0.7403
#
# Epoch : 384, Total Avg Loss : 1.4547
# Source Avg Loss : 0.7148
# Target Avg Loss : 0.7399
#
# Epoch : 385, Total Avg Loss : 1.4529
# Source Avg Loss : 0.7126
# Target Avg Loss : 0.7402
#
# Epoch : 386, Total Avg Loss : 1.4526
# Source Avg Loss : 0.7135
# Target Avg Loss : 0.7391
#
# Epoch : 387, Total Avg Loss : 1.4514
# Source Avg Loss : 0.7122
# Target Avg Loss : 0.7392
#
# Epoch : 388, Total Avg Loss : 1.4507
# Source Avg Loss : 0.7119
# Target Avg Loss : 0.7389
#
# Epoch : 389, Total Avg Loss : 1.4519
# Source Avg Loss : 0.7126
# Target Avg Loss : 0.7393
#
# Epoch : 390, Total Avg Loss : 1.4519
# Source Avg Loss : 0.7127
# Target Avg Loss : 0.7392
#
# Epoch : 391, Total Avg Loss : 1.4556
# Source Avg Loss : 0.7160
# Target Avg Loss : 0.7396
#
# Epoch : 392, Total Avg Loss : 1.4571
# Source Avg Loss : 0.7174
# Target Avg Loss : 0.7398
#
# Epoch : 393, Total Avg Loss : 1.4594
# Source Avg Loss : 0.7190
# Target Avg Loss : 0.7403
#
# Epoch : 394, Total Avg Loss : 1.4543
# Source Avg Loss : 0.7149
# Target Avg Loss : 0.7394
#
# Epoch : 395, Total Avg Loss : 1.4526
# Source Avg Loss : 0.7147
# Target Avg Loss : 0.7379
#
# Epoch : 396, Total Avg Loss : 1.4503
# Source Avg Loss : 0.7128
# Target Avg Loss : 0.7375
#
# Epoch : 397, Total Avg Loss : 1.4500
# Source Avg Loss : 0.7125
# Target Avg Loss : 0.7375
#
# Epoch : 398, Total Avg Loss : 1.4498
# Source Avg Loss : 0.7120
# Target Avg Loss : 0.7379
#
# Epoch : 399, Total Avg Loss : 1.4507
# Source Avg Loss : 0.7130
# Target Avg Loss : 0.7377
#
# Epoch : 400, Total Avg Loss : 1.4508
# Source Avg Loss : 0.7139
# Target Avg Loss : 0.7369
#
# Epoch : 401, Total Avg Loss : 1.4506
# Source Avg Loss : 0.7133
# Target Avg Loss : 0.7373
#
# Epoch : 402, Total Avg Loss : 1.4513
# Source Avg Loss : 0.7145
# Target Avg Loss : 0.7368
#
# Epoch : 403, Total Avg Loss : 1.4530
# Source Avg Loss : 0.7157
# Target Avg Loss : 0.7373
#
# Epoch : 404, Total Avg Loss : 1.4514
# Source Avg Loss : 0.7146
# Target Avg Loss : 0.7369
#
# Epoch : 405, Total Avg Loss : 1.4532
# Source Avg Loss : 0.7161
# Target Avg Loss : 0.7371
#
# Epoch : 406, Total Avg Loss : 1.4523
# Source Avg Loss : 0.7152
# Target Avg Loss : 0.7371
#
# Epoch : 407, Total Avg Loss : 1.4537
# Source Avg Loss : 0.7162
# Target Avg Loss : 0.7375
#
# Epoch : 408, Total Avg Loss : 1.4561
# Source Avg Loss : 0.7190
# Target Avg Loss : 0.7371
#
# Epoch : 409, Total Avg Loss : 1.4550
# Source Avg Loss : 0.7181
# Target Avg Loss : 0.7369
#
# Epoch : 410, Total Avg Loss : 1.4642
# Source Avg Loss : 0.7250
# Target Avg Loss : 0.7392
#
# Epoch : 411, Total Avg Loss : 1.4677
# Source Avg Loss : 0.7267
# Target Avg Loss : 0.7411
#
# Epoch : 412, Total Avg Loss : 1.4760
# Source Avg Loss : 0.7325
# Target Avg Loss : 0.7435
#
# Epoch : 413, Total Avg Loss : 1.4839
# Source Avg Loss : 0.7395
# Target Avg Loss : 0.7444
#
# Epoch : 414, Total Avg Loss : 1.4816
# Source Avg Loss : 0.7333
# Target Avg Loss : 0.7482
#
# Epoch : 415, Total Avg Loss : 1.4697
# Source Avg Loss : 0.7250
# Target Avg Loss : 0.7446
#
# Epoch : 416, Total Avg Loss : 1.4647
# Source Avg Loss : 0.7223
# Target Avg Loss : 0.7423
#
# Epoch : 417, Total Avg Loss : 1.4595
# Source Avg Loss : 0.7205
# Target Avg Loss : 0.7391
#
# Epoch : 418, Total Avg Loss : 1.4587
# Source Avg Loss : 0.7197
# Target Avg Loss : 0.7390
#
# Epoch : 419, Total Avg Loss : 1.4560
# Source Avg Loss : 0.7185
# Target Avg Loss : 0.7375
#
# Epoch : 420, Total Avg Loss : 1.4558
# Source Avg Loss : 0.7180
# Target Avg Loss : 0.7378
#
# Epoch : 421, Total Avg Loss : 1.4537
# Source Avg Loss : 0.7167
# Target Avg Loss : 0.7370
#
# Epoch : 422, Total Avg Loss : 1.4521
# Source Avg Loss : 0.7155
# Target Avg Loss : 0.7366
#
# Epoch : 423, Total Avg Loss : 1.4508
# Source Avg Loss : 0.7149
# Target Avg Loss : 0.7359
#
# Epoch : 424, Total Avg Loss : 1.4505
# Source Avg Loss : 0.7147
# Target Avg Loss : 0.7358
#
# Epoch : 425, Total Avg Loss : 1.4500
# Source Avg Loss : 0.7141
# Target Avg Loss : 0.7359
#
# Epoch : 426, Total Avg Loss : 1.4498
# Source Avg Loss : 0.7139
# Target Avg Loss : 0.7359
#
# Epoch : 427, Total Avg Loss : 1.4501
# Source Avg Loss : 0.7145
# Target Avg Loss : 0.7356
#
# Epoch : 428, Total Avg Loss : 1.4490
# Source Avg Loss : 0.7133
# Target Avg Loss : 0.7357
#
# Epoch : 429, Total Avg Loss : 1.4479
# Source Avg Loss : 0.7129
# Target Avg Loss : 0.7350
#
# Epoch : 430, Total Avg Loss : 1.4473
# Source Avg Loss : 0.7129
# Target Avg Loss : 0.7345
#
# Epoch : 431, Total Avg Loss : 1.4475
# Source Avg Loss : 0.7133
# Target Avg Loss : 0.7342
#
# Epoch : 432, Total Avg Loss : 1.4471
# Source Avg Loss : 0.7127
# Target Avg Loss : 0.7344
#
# Epoch : 433, Total Avg Loss : 1.4485
# Source Avg Loss : 0.7135
# Target Avg Loss : 0.7350
#
# Epoch : 434, Total Avg Loss : 1.4483
# Source Avg Loss : 0.7134
# Target Avg Loss : 0.7349
#
# Epoch : 435, Total Avg Loss : 1.4498
# Source Avg Loss : 0.7147
# Target Avg Loss : 0.7351
#
# Epoch : 436, Total Avg Loss : 1.4498
# Source Avg Loss : 0.7155
# Target Avg Loss : 0.7343
#
# Epoch : 437, Total Avg Loss : 1.4492
# Source Avg Loss : 0.7149
# Target Avg Loss : 0.7343
#
# Epoch : 438, Total Avg Loss : 1.4495
# Source Avg Loss : 0.7154
# Target Avg Loss : 0.7341
#
# Epoch : 439, Total Avg Loss : 1.4503
# Source Avg Loss : 0.7162
# Target Avg Loss : 0.7341
#
# Epoch : 440, Total Avg Loss : 1.4512
# Source Avg Loss : 0.7167
# Target Avg Loss : 0.7345
#
# Epoch : 441, Total Avg Loss : 1.4513
# Source Avg Loss : 0.7167
# Target Avg Loss : 0.7346
#
# Epoch : 442, Total Avg Loss : 1.4495
# Source Avg Loss : 0.7154
# Target Avg Loss : 0.7341
#
# Epoch : 443, Total Avg Loss : 1.4494
# Source Avg Loss : 0.7150
# Target Avg Loss : 0.7344
#
# Epoch : 444, Total Avg Loss : 1.4486
# Source Avg Loss : 0.7140
# Target Avg Loss : 0.7346
#
# Epoch : 445, Total Avg Loss : 1.4494
# Source Avg Loss : 0.7148
# Target Avg Loss : 0.7345
#
# Epoch : 446, Total Avg Loss : 1.4500
# Source Avg Loss : 0.7156
# Target Avg Loss : 0.7344
#
# Epoch : 447, Total Avg Loss : 1.4504
# Source Avg Loss : 0.7157
# Target Avg Loss : 0.7347
#
# Epoch : 448, Total Avg Loss : 1.4519
# Source Avg Loss : 0.7167
# Target Avg Loss : 0.7352
#
# Epoch : 449, Total Avg Loss : 1.4535
# Source Avg Loss : 0.7172
# Target Avg Loss : 0.7364
#
# Epoch : 450, Total Avg Loss : 1.4554
# Source Avg Loss : 0.7183
# Target Avg Loss : 0.7371
#
# Epoch : 451, Total Avg Loss : 1.4585
# Source Avg Loss : 0.7196
# Target Avg Loss : 0.7389
#
# Epoch : 452, Total Avg Loss : 1.4626
# Source Avg Loss : 0.7213
# Target Avg Loss : 0.7413
#
# Epoch : 453, Total Avg Loss : 1.4624
# Source Avg Loss : 0.7224
# Target Avg Loss : 0.7400
#
# Epoch : 454, Total Avg Loss : 1.4621
# Source Avg Loss : 0.7226
# Target Avg Loss : 0.7394
#
# Epoch : 455, Total Avg Loss : 1.4595
# Source Avg Loss : 0.7210
# Target Avg Loss : 0.7385
#
# Epoch : 456, Total Avg Loss : 1.4564
# Source Avg Loss : 0.7192
# Target Avg Loss : 0.7372
#
# Epoch : 457, Total Avg Loss : 1.4541
# Source Avg Loss : 0.7174
# Target Avg Loss : 0.7367
#
# Epoch : 458, Total Avg Loss : 1.4520
# Source Avg Loss : 0.7160
# Target Avg Loss : 0.7360
#
# Epoch : 459, Total Avg Loss : 1.4509
# Source Avg Loss : 0.7153
# Target Avg Loss : 0.7356
#
# Epoch : 460, Total Avg Loss : 1.4506
# Source Avg Loss : 0.7152
# Target Avg Loss : 0.7354
#
# Epoch : 461, Total Avg Loss : 1.4504
# Source Avg Loss : 0.7152
# Target Avg Loss : 0.7352
#
# Epoch : 462, Total Avg Loss : 1.4504
# Source Avg Loss : 0.7152
# Target Avg Loss : 0.7352
#
# Epoch : 463, Total Avg Loss : 1.4512
# Source Avg Loss : 0.7156
# Target Avg Loss : 0.7356
#
# Epoch : 464, Total Avg Loss : 1.4502
# Source Avg Loss : 0.7153
# Target Avg Loss : 0.7349
#
# Epoch : 465, Total Avg Loss : 1.4499
# Source Avg Loss : 0.7151
# Target Avg Loss : 0.7348
#
# Epoch : 466, Total Avg Loss : 1.4501
# Source Avg Loss : 0.7151
# Target Avg Loss : 0.7350
#
# Epoch : 467, Total Avg Loss : 1.4496
# Source Avg Loss : 0.7148
# Target Avg Loss : 0.7348
#
# Epoch : 468, Total Avg Loss : 1.4484
# Source Avg Loss : 0.7144
# Target Avg Loss : 0.7340
#
# Epoch : 469, Total Avg Loss : 1.4480
# Source Avg Loss : 0.7141
# Target Avg Loss : 0.7339
#
# Epoch : 470, Total Avg Loss : 1.4470
# Source Avg Loss : 0.7137
# Target Avg Loss : 0.7333
#
# Epoch : 471, Total Avg Loss : 1.4471
# Source Avg Loss : 0.7132
# Target Avg Loss : 0.7339
#
# Epoch : 472, Total Avg Loss : 1.4459
# Source Avg Loss : 0.7127
# Target Avg Loss : 0.7332
#
# Epoch : 473, Total Avg Loss : 1.4459
# Source Avg Loss : 0.7125
# Target Avg Loss : 0.7334
#
# Epoch : 474, Total Avg Loss : 1.4454
# Source Avg Loss : 0.7122
# Target Avg Loss : 0.7333
#
# Epoch : 475, Total Avg Loss : 1.4451
# Source Avg Loss : 0.7119
# Target Avg Loss : 0.7332
#
# Epoch : 476, Total Avg Loss : 1.4447
# Source Avg Loss : 0.7117
# Target Avg Loss : 0.7330
#
# Epoch : 477, Total Avg Loss : 1.4446
# Source Avg Loss : 0.7115
# Target Avg Loss : 0.7332
#
# Epoch : 478, Total Avg Loss : 1.4443
# Source Avg Loss : 0.7113
# Target Avg Loss : 0.7330
#
# Epoch : 479, Total Avg Loss : 1.4439
# Source Avg Loss : 0.7113
# Target Avg Loss : 0.7326
#
# Epoch : 480, Total Avg Loss : 1.4435
# Source Avg Loss : 0.7111
# Target Avg Loss : 0.7324
#
# Epoch : 481, Total Avg Loss : 1.4434
# Source Avg Loss : 0.7111
# Target Avg Loss : 0.7323
#
# Epoch : 482, Total Avg Loss : 1.4434
# Source Avg Loss : 0.7110
# Target Avg Loss : 0.7323
#
# Epoch : 483, Total Avg Loss : 1.4429
# Source Avg Loss : 0.7110
# Target Avg Loss : 0.7319
#
# Epoch : 484, Total Avg Loss : 1.4428
# Source Avg Loss : 0.7107
# Target Avg Loss : 0.7320
#
# Epoch : 485, Total Avg Loss : 1.4425
# Source Avg Loss : 0.7105
# Target Avg Loss : 0.7320
#
# Epoch : 486, Total Avg Loss : 1.4419
# Source Avg Loss : 0.7104
# Target Avg Loss : 0.7315
#
# Epoch : 487, Total Avg Loss : 1.4420
# Source Avg Loss : 0.7103
# Target Avg Loss : 0.7316
#
# Epoch : 488, Total Avg Loss : 1.4425
# Source Avg Loss : 0.7102
# Target Avg Loss : 0.7323
#
# Epoch : 489, Total Avg Loss : 1.4420
# Source Avg Loss : 0.7102
# Target Avg Loss : 0.7317
#
# Epoch : 490, Total Avg Loss : 1.4418
# Source Avg Loss : 0.7100
# Target Avg Loss : 0.7318
#
# Epoch : 491, Total Avg Loss : 1.4417
# Source Avg Loss : 0.7098
# Target Avg Loss : 0.7318
#
# Epoch : 492, Total Avg Loss : 1.4413
# Source Avg Loss : 0.7097
# Target Avg Loss : 0.7315
#
# Epoch : 493, Total Avg Loss : 1.4410
# Source Avg Loss : 0.7097
# Target Avg Loss : 0.7312
#
# Epoch : 494, Total Avg Loss : 1.4412
# Source Avg Loss : 0.7097
# Target Avg Loss : 0.7314
#
# Epoch : 495, Total Avg Loss : 1.4411
# Source Avg Loss : 0.7097
# Target Avg Loss : 0.7314
#
# Epoch : 496, Total Avg Loss : 1.4413
# Source Avg Loss : 0.7096
# Target Avg Loss : 0.7317
#
# Epoch : 497, Total Avg Loss : 1.4410
# Source Avg Loss : 0.7095
# Target Avg Loss : 0.7315
#
# Epoch : 498, Total Avg Loss : 1.4408
# Source Avg Loss : 0.7096
# Target Avg Loss : 0.7313
#
# Epoch : 499, Total Avg Loss : 1.4408
# Source Avg Loss : 0.7095
# Target Avg Loss : 0.7313
#
# Epoch : 500, Total Avg Loss : 1.4411
# Source Avg Loss : 0.7095
# Target Avg Loss : 0.7316

# %%
# from torchinfo import summary

# summary(model, (64,3,13))

# %% [markdown]
# # 테스트

# %%
from sklearn.metrics import r2_score

model.eval()  # 테스트 모드로 전환

s_pred = []  # MNIST 데이터셋의 예측값을 저장할 리스트
t_pred = []  # SVHN 데이터셋의 예측값을 저장할 리스트
s_real = []
t_real = []

#for step in tqdm(range(len(source_train))):
for step, (source_data, target_data) in enumerate(zip(source_train, target_train)):
    # source_data = next(iter(source_train))
    # target_data = next(iter(target_train))

    sourcex = source_data[0].to(device)
    sourcey = source_data[1].to(device)
    targetx = target_data[0].to(device)
    targety = target_data[1].to(device)
    # domain 분류와 관련된 logits은 사용하지 않기에 _로 받아서 처리
    _, source_pred = model(sourcex)
    _, target_pred = model(targetx)

    ## 예측값을 리스트에 저장
    s_pred.extend(source_pred.detach().cpu().numpy())
    t_pred.extend(target_pred.detach().cpu().numpy())
    s_real.extend(sourcey.detach().cpu().numpy())
    t_real.extend(targety.detach().cpu().numpy())

# R2 스코어 계산
s_r2 = r2_score(s_real, s_pred)
t_r2 = r2_score(t_real, t_pred)

print('SOURCE R2 Score:', s_r2)
print('TARGET R2 Score:', t_r2)
# Out:
# SOURCE R2 Score: -7.843291956303579
# TARGET R2 Score: -2.7212984809599607

# %%
plt.figure(figsize=(40,10))
plt.plot(s_real, color='red', label='source real')
plt.plot(s_pred, color='blue', label='source pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(t_real, color='red', label='target real')
plt.plot(t_pred, color='blue', label='target pred')
plt.legend()
plt.show()

# %% [markdown]
# ### Domain Embedding Space 시각화

# %%
# 가장 앞 batch의 250개씩의 데이터만 샘플링
source_tsne = DataLoader(nelec_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

target_tsne = DataLoader(elec_train,
                        batch_size=1000,
                        shuffle=False,  
                        drop_last=True)

source_tsne2 = next(iter(source_tsne))
target_tsne2 = next(iter(target_tsne))

source_x_TNSE = source_tsne2[0].to(device)
source_y_TNSE = source_tsne2[1].to(device)

target_x_TNSE = target_tsne2[0].to(device)
target_y_TNSE = target_tsne2[1].to(device)

# 학습된 모델의 LSTM 부분만 활용 (100차원 임베딩 벡터를 받아오는 과정)
source_vector = model.lstm(source_x_TNSE)
target_vector = model.lstm(target_x_TNSE)

# %%
from sklearn.manifold import TSNE

df = pd.DataFrame(np.concatenate([source_vector.cpu().detach().numpy(), target_vector.cpu().detach().numpy()]))

tsne_np = TSNE(n_components=2).fit_transform(df)
tsne_df = pd.DataFrame(tsne_np, columns=['component 0', 'component 1'])

# %%
tsne_df_0 = tsne_df.loc[:1000]
tsne_df_1 = tsne_df.loc[1000:]

plt.scatter(tsne_df_0['component 0'], tsne_df_0['component 1'], color='blue', label='NELEC', alpha=0.5)
plt.scatter(tsne_df_1['component 0'], tsne_df_1['component 1'], color='green', label='ELEC', alpha=0.5)

plt.title('alpha = '+ str(alpha))
plt.xlabel('component 0')
plt.ylabel('component 1')
plt.legend()
plt.show()
